# %% [markdown]
# Rounds Analysis
# ---
#
# Analysis of judge record data.

# %% [markdown]
# ### Setup
#
# #### Imports

# %%
import csv

# %% [markdown]
# #### Settings

# %%
DATAPATH = "tab_data/"

# %%
with open(DATAPATH + "records_1.csv", 'r') as inFile:
    reader = csv.DictReader(inFile)
    records = [dict(row) for row in reader]

# %% [markdown]
# ### Squirrel Analysis

# %%
def isSquirrel(record):
    if record['Panel']:
        return record['Panel'].split()[0] != record['Decision']
    return False

# %%
squirrels = []
for record in records:
    if isSquirrel(record):
        squirrels.append(record)

# %%
judgeOutrounds = {}
judgeSquirrels = {}
judgeSqrRate = {}

# %%
for record in records:
    if record['Panel']:
        judge = record['Judge']
        if judge in judgeOutrounds:
            judgeOutrounds[judge] += 1
        else:
            judgeOutrounds[judge] = 1

# %%
for record in squirrels:
    judge = record['Judge']
    if judge in judgeSquirrels:
        judgeSquirrels[judge] += 1
    else:
        judgeSquirrels[judge] = 1

# %%
for judge in judgeSquirrels:
    judgeSqrRate[judge] = judgeSquirrels[judge]/judgeOutrounds[judge]

# %%
judges = [judge for judge in judgeSquirrels.keys() if judgeOutrounds[judge] > 20]

# %%
[(judge, judgeSqrRate[judge]) for judge in sorted(judges, key=lambda j: judgeSqrRate[j])]
# Out:
# [('Andrew Welton', 0.020833333333333332),
#  ('Christopher Stone', 0.021739130434782608),
#  ('Arun Ramakrishna', 0.02702702702702703),
#  ('Bill Wilson', 0.029411764705882353),
#  ('Callan Hazeldine', 0.03225806451612903),
#  ('Carly Rieger', 0.03278688524590164),
#  ('Drew Thorburn', 0.03333333333333333),
#  ('David Worth', 0.03333333333333333),
#  ('Elias Payne', 0.034482758620689655),
#  ('Diganta Rashed', 0.03571428571428571),
#  ('Emma Smith', 0.03571428571428571),
#  ('Ideen Saiedian', 0.03571428571428571),
#  ('Anthony Survance', 0.037037037037037035),
#  ('Brandon Mader', 0.037037037037037035),
#  ('Clark Johnson', 0.037037037037037035),
#  ('David Moon', 0.037037037037037035),
#  ('Elyse Pham', 0.037037037037037035),
#  ('Asim Gaffar', 0.038461538461538464),
#  ('Adam Scher', 0.04),
#  ('Emily Luther', 0.04),
#  ('Farhad Ahmed', 0.04),
#  ('Andrew Yim', 0.041666666666666664),
#  ('Alex Frogner', 0.041666666666666664),
#  ('Connor Duncan', 0.041666666666666664),
#  ('Fariha Rahman', 0.041666666666666664),
#  ('Arjun Rao', 0.043478260869565216),
#  ('Adam Testerman', 0.043478260869565216),
#  ('Blaine Wilson', 0.043478260869565216),
#  ('Christopher Rothgeb', 0.043478260869565216),
#  ('Aidan Kane', 0.045454545454545456),
#  ('Alexandra Myers', 0.045454545454545456),
#  ('Brandon Garcia', 0.045454545454545456),
#  ('Imen Boussayoud', 0.045454545454545456),
#  ('Anna Williams', 0.047619047619047616),
#  ('Beau Larsen', 0.047619047619047616),
#  ('Corinne Sugino', 0.047619047619047616),
#  ('Cameron Dehmlow Dunne', 0.047619047619047616),
#  ('Christian Rodriguez', 0.047619047619047616),
#  ('Daniel Haskell', 0.047619047619047616),
#  ('Daniel Rowe', 0.047619047619047616),
#  ('eve robinson', 0.047619047619047616),
#  ('Henry SooHoo', 0.047619047619047616),
#  ('Isaac Gutierrez', 0.047619047619047616),
#  ('Annabelle Long', 0.05),
#  ('Beth Mendenhall', 0.05),
#  ('David Merkle', 0.05128205128205128),
#  ('Daniel Armbrust', 0.05172413793103448),
#  ('Colin Quinn', 0.05319148936170213),
#  ('Bill Batterman', 0.05434782608695652),
#  ('AJ Byrne', 0.05555555555555555),
#  ('Dustin Greenwalt', 0.05555555555555555),
#  ('Anna Myers', 0.058823529411764705),
#  ('Allegro Wang', 0.058823529411764705),
#  ('David Huston', 0.06060606060606061),
#  ('Adam smiley', 0.0625),
#  ('Avi Munoz', 0.0625),
#  ('Adam Martin', 0.0625),
#  ('Andrew Qin', 0.0625),
#  ('Antony Nation', 0.0625),
#  ('Chris Miles', 0.0625),
#  ('Cody Gustafson', 0.0625),
#  ('Charles Karcher', 0.0625),
#  ('Grady Wiedeman', 0.0625),
#  ('Harrison Hall', 0.0625),
#  ('Darin Maier', 0.06349206349206349),
#  ('Corey Fisher', 0.06451612903225806),
#  ('Evan McCarty', 0.06451612903225806),
#  ('Anish Warty', 0.06666666666666667),
#  ('Brian Shouse', 0.06666666666666667),
#  ('Carmen Kohn', 0.06666666666666667),
#  ('Christopher Paulison', 0.06666666666666667),
#  ('David Asafu-Adjaye', 0.06666666666666667),
#  ('Erik Pielstick', 0.06666666666666667),
#  ('Gershom Chan', 0.06666666666666667),
#  ('Corey Stone', 0.06818181818181818),
#  ('Christopher Fry', 0.06818181818181818),
#  ('Alexander Belanger', 0.06896551724137931),
#  ('Benjamin Hughes', 0.06896551724137931),
#  ('Craig Wall', 0.06896551724137931),
#  ('Dan Bannister', 0.06896551724137931),
#  ('greg zoda', 0.06896551724137931),
#  ('Austen Yorko', 0.06944444444444445),
#  ('Daryl Burch', 0.06976744186046512),
#  ('Ian Beier', 0.07006369426751592),
#  ('Danny DeBois', 0.0707070707070707),
#  ('Anton Shircel', 0.07142857142857142),
#  ('Aubrey Semple', 0.07142857142857142),
#  ('Claire Haflich', 0.07142857142857142),
#  ('Eric Melin', 0.07142857142857142),
#  ('Hannah Stafford', 0.07142857142857142),
#  ('Harrison Schlossberg', 0.07142857142857142),
#  ('Danny Li', 0.07291666666666667),
#  ('Ashan Peiris', 0.07317073170731707),
#  ('Angelica Mercado-Ford', 0.07407407407407407),
#  ('Benjamin Fagan', 0.07407407407407407),
#  ('Blake Andrews', 0.07407407407407407),
#  ('Brian Yang', 0.07407407407407407),
#  ('Belen Mella', 0.07407407407407407),
#  ('Christopher Bentley', 0.07407407407407407),
#  ('Emily Carter', 0.07407407407407407),
#  ('Greg Malis', 0.07407407407407407),
#  ('Dan Perdomo', 0.07547169811320754),
#  ('Ananth Panchanadam', 0.07692307692307693),
#  ('Alec Antonakakis', 0.07692307692307693),
#  ('Chris Perez', 0.07692307692307693),
#  ('David Levin', 0.07692307692307693),
#  ('Eric Beane', 0.07692307692307693),
#  ('Gabriel Koo', 0.07692307692307693),
#  ('Adam R. Lee', 0.0784313725490196),
#  ('Adam Brown', 0.07894736842105263),
#  ('Aaron Clarke', 0.07894736842105263),
#  ('Amy Elzarka', 0.07894736842105263),
#  ('Carlos Henry Sr.', 0.07894736842105263),
#  ('David Zin', 0.07894736842105263),
#  ('Ashley Murphy', 0.08),
#  ('Alexander James', 0.08),
#  ('Aryn Walker', 0.08),
#  ('Basil Abushama', 0.08),
#  ('Eric Oddo', 0.08),
#  ('Elliot Kovnick', 0.08),
#  ('Grace Gill', 0.08),
#  ('Colten White', 0.08064516129032258),
#  ('David Coates', 0.08080808080808081),
#  ('Elizabeth Meerson', 0.08108108108108109),
#  ('Emily Marvin', 0.08108108108108109),
#  ('Indu Pandey', 0.08108108108108109),
#  ('Brock Hanson', 0.08235294117647059),
#  ('Andy Casey', 0.08333333333333333),
#  ('Akhil Gandra', 0.08333333333333333),
#  ('Cynthia McGrath', 0.08333333333333333),
#  ('Dominik Lett', 0.08333333333333333),
#  ('Gabriel Jankovsky', 0.08333333333333333),
#  ('Dontae Hill', 0.08396946564885496),
#  ('Aaron Vinson', 0.0851063829787234),
#  ('Ethan Massa', 0.0851063829787234),
#  ('Aimun Khan', 0.08571428571428572),
#  ('Alex Avery', 0.08571428571428572),
#  ('Banafshae Khan', 0.08571428571428572),
#  ('Courtney Schauer', 0.0859375),
#  ('Ann Peter', 0.08695652173913043),
#  ('Ariel Shin', 0.08695652173913043),
#  ('Charles Li', 0.08695652173913043),
#  ('Chris Stinson', 0.08695652173913043),
#  ('Casey Anderson', 0.08695652173913043),
#  ('Chris Paredes', 0.08695652173913043),
#  ('Danny Siegel', 0.08695652173913043),
#  ('Dakota Folkerts', 0.08695652173913043),
#  ('Gary Peters', 0.08695652173913043),
#  ('Adam Torson', 0.08743169398907104),
#  ('Carly Wunderlich', 0.0875),
#  ('Christopher Thomas', 0.08823529411764706),
#  ('Cameron Henderson', 0.08823529411764706),
#  ('Fletcher Wingfield', 0.08823529411764706),
#  ('David Hingstman', 0.08928571428571429),
#  ('Ariel Olson', 0.09090909090909091),
#  ('Alyson Escalante', 0.09090909090909091),
#  ('Becca Traber', 0.09090909090909091),
#  ('Britani Fraser', 0.09090909090909091),
#  ('Brock Spencer', 0.09090909090909091),
#  ('Brent Lamb', 0.09090909090909091),
#  ('Brad Noethe', 0.09090909090909091),
#  ('Chris Roberds', 0.09090909090909091),
#  ('Carolyn Hassett', 0.09090909090909091),
#  ('Chloe Wang', 0.09090909090909091),
#  ('Doris Sexton', 0.09090909090909091),
#  ('Daniel Lu', 0.09090909090909091),
#  ('Gordon Kochman', 0.09090909090909091),
#  ('Gerrit Hansen', 0.09090909090909091),
#  ('Greta Thomas', 0.09090909090909091),
#  ('Hunter Martin', 0.09090909090909091),
#  ('Christina Phillips', 0.09230769230769231),
#  ('Codey Hawkins', 0.09230769230769231),
#  ('Camila Vasquez', 0.09302325581395349),
#  ('Alyssa Hoover', 0.09375),
#  ('Alan George', 0.09375),
#  ('Chris Riffer', 0.09375),
#  ('Darell Womack', 0.09375),
#  ('Demarcus Powell', 0.09433962264150944),
#  ('ALexander Yoakum', 0.0945945945945946),
#  ('Casey Harrigan', 0.0948905109489051),
#  ('Andy Stubbs', 0.09523809523809523),
#  ('Andrew Nguyen', 0.09523809523809523),
#  ('Amanda Cheung', 0.09523809523809523),
#  ('Booker Mendes', 0.09523809523809523),
#  ('Bonnie Bonnette', 0.09523809523809523),
#  ('Brandon Stras', 0.09523809523809523),
#  ('Benjamin Sauer', 0.09523809523809523),
#  ('Connor Munsinger', 0.09523809523809523),
#  ('Connor Lauer', 0.09523809523809523),
#  ('Daniel Carlson', 0.09523809523809523),
#  ('Elizabeth Young', 0.09523809523809523),
#  ('erin niemela', 0.09523809523809523),
#  ('Gillian Zipursky', 0.09523809523809523),
#  ('Adam Bistagne', 0.096),
#  ('Amanda Ozaki-Laughon', 0.0967741935483871),
#  ('Douglas Husic', 0.0967741935483871),
#  ('Henry Curtis', 0.0970873786407767),
#  ('Aleisha Readye', 0.0975609756097561),
#  ('Aisha Bawany', 0.0975609756097561),
#  ('Holden Bukowsky', 0.0975609756097561),
#  ('Geoff Lundeen', 0.09774436090225563),
#  ('Alex Rivera', 0.09803921568627451),
#  ('Conor Cameron', 0.09803921568627451),
#  ('Cara Day', 0.09836065573770492),
#  ('David Cram Helwich', 0.09836065573770492),
#  ('Dhruv Sudesh', 0.09859154929577464),
#  ('Eric Short', 0.09868421052631579),
#  ('Anav Sharma', 0.1),
#  ('Briggs Warren', 0.1),
#  ('Chetan Reddy', 0.1),
#  ('Chan Hong Park', 0.1),
#  ('Ian Miller', 0.1),
#  ('Carlos Astacio', 0.10067114093959731),
#  ('Colton Gilbert', 0.1016949152542373),
#  ('David Weston', 0.10227272727272728),
#  ('Andrew Geathers', 0.10256410256410256),
#  ('Aly Mithani', 0.10256410256410256),
#  ('Eric Skoglund', 0.10256410256410256),
#  ('Alec Lenamond', 0.10344827586206896),
#  ('Alina Shivji', 0.10344827586206896),
#  ('Byron Arthur', 0.10344827586206896),
#  ('Dylan Gentilcore', 0.10344827586206896),
#  ('Hayden Uihlein', 0.10344827586206896),
#  ('Alixandria Arungah', 0.10416666666666667),
#  ('Anson Fung', 0.1044776119402985),
#  ('Alex Gazmararian', 0.10526315789473684),
#  ('Bill Russell', 0.10526315789473684),
#  ('Brian Rubaie', 0.10526315789473684),
#  ('Danny Frank-Siegel', 0.10526315789473684),
#  ('Graham Phlieger', 0.10526315789473684),
#  ('Craig Hennigan', 0.10606060606060606),
#  ('Brian McBride', 0.10655737704918032),
#  ('Aron Berger', 0.10666666666666667),
#  ('Amit Kukreja', 0.10666666666666667),
#  ('Amar Adam', 0.10714285714285714),
#  ('Alexandra Mork', 0.10714285714285714),
#  ('Colin Coppock', 0.10714285714285714),
#  ('Cale McCrary', 0.10714285714285714),
#  ('Daniel Shatzkin', 0.10752688172043011),
#  ('Hays Watson', 0.10778443113772455),
#  ('Andrew Halverson', 0.10810810810810811),
#  ('Clark Foster', 0.10810810810810811),
#  ('Andrew Overing', 0.10869565217391304),
#  ('Brandon Inzinna', 0.10869565217391304),
#  ('Emmiee Malyugina', 0.10891089108910891),
#  ('Gabriel Esquivel Yglesias', 0.10909090909090909),
#  ('Bennett Eckert', 0.1092436974789916),
#  ('Erik Mathis', 0.10967741935483871),
#  ('Andrew Hart', 0.11),
#  ('Heather Hall', 0.11009174311926606),
#  ('Chris Castillo', 0.11011904761904762),
#  ('Christopher Randall', 0.1103448275862069),
#  ('Aaron Langerman', 0.1111111111111111),
#  ('Ansuman Bardalai', 0.1111111111111111),
#  ('Benjamin Barov', 0.1111111111111111),
#  ('Conal Thomas-McGinnis', 0.1111111111111111),
#  ('Clement Agho-Otoghile', 0.1111111111111111),
#  ('Callie Ham', 0.1111111111111111),
#  ('Cory Newman', 0.1111111111111111),
#  ('Courtney Burke', 0.1111111111111111),
#  ('Darren Elliott', 0.1111111111111111),
#  ('Dan Bagwell', 0.1111111111111111),
#  ('Deanne Christensen', 0.1111111111111111),
#  ('David Schneck', 0.1111111111111111),
#  ('Elizabeth Bender', 0.1111111111111111),
#  ('Grace McFadden - Kuang', 0.1111111111111111),
#  ('Heidi Rinkacs', 0.1111111111111111),
#  ('Ivelisse Tirado', 0.1111111111111111),
#  ('Ian Lowery', 0.1111111111111111),
#  ('Brian Wiora', 0.1125),
#  ('Fredrick Ditzian', 0.11267605633802817),
#  ('Eliza Haas', 0.11290322580645161),
#  ('Ben Zeppos', 0.11363636363636363),
#  ('Drew Marshall', 0.11363636363636363),
#  ('Daniel Stout', 0.11403508771929824),
#  ('Ansh Khullar', 0.11428571428571428),
#  ('Andrew Lake', 0.11428571428571428),
#  ('Ian Mikkelsen', 0.11428571428571428),
#  ('Chris Flowers', 0.11475409836065574),
#  ('Brian Box', 0.11494252873563218),
#  ('Al Hiland', 0.11538461538461539),
#  ('Alexa Glendinning', 0.11538461538461539),
#  ('Alyssa Stokes', 0.11538461538461539),
#  ('Brandon Komatsu', 0.11538461538461539),
#  ('Christian Sheerer', 0.11538461538461539),
#  ('Daniel Taylor', 0.11538461538461539),
#  ('Dominique Baker', 0.11538461538461539),
#  ('Devesh Kodnani', 0.11538461538461539),
#  ('chris loghry', 0.11627906976744186),
#  ('Gabe Rusk', 0.1165644171779141),
#  ('Alexis Litzky', 0.11764705882352941),
#  ('Christopher Callahan', 0.11764705882352941),
#  ('Chloe Ricks', 0.11764705882352941),
#  ('David Henning', 0.11764705882352941),
#  ('Dakota Yates', 0.11764705882352941),
#  ('Glen Frappier', 0.11764705882352941),
#  ('Gabriel Morbeck', 0.11764705882352941),
#  ('Cody Crunkilton', 0.11842105263157894),
#  ('Eric Forslund', 0.11842105263157894),
#  ('Alex Martel', 0.11904761904761904),
#  ('Dhruv Sehgal', 0.11904761904761904),
#  ('David Heidt', 0.11934156378600823),
#  ('Allen Abbott', 0.11940298507462686),
#  ('Ashton Smith', 0.12),
#  ('Benjamin Koh', 0.12),
#  ('Brandon Evans', 0.12121212121212122),
#  ('Christopher Conrad', 0.12121212121212122),
#  ('Christopher Kozak', 0.12173913043478261),
#  ('Chetan Hertzig', 0.12177121771217712),
#  ('Christian Bato', 0.12195121951219512),
#  ('Dennis Savill', 0.12195121951219512),
#  ('Bryan Gaston', 0.12280701754385964),
#  ('Eli Brennan', 0.12280701754385964),
#  ('Eddie Fitzgerald', 0.1232876712328767),
#  ('Dan Lingel', 0.12345679012345678),
#  ('Alan Tannenwald', 0.125),
#  ('Aaron Swanlek', 0.125),
#  ('Ava Vargason', 0.125),
#  ('Alex Brown', 0.125),
#  ('Abhilash Datti', 0.125),
#  ('Amber Kemmerly', 0.125),
#  ('Blayne Scofield', 0.125),
#  ('Brian Roche', 0.125),
#  ('Ben Weinhardt', 0.125),
#  ('Clay Stewart', 0.125),
#  ('Cody Dorumsgaard', 0.125),
#  ('Derek Brown', 0.125),
#  ('David Griffith', 0.125),
#  ('Ethan Wheeler', 0.125),
#  ('Ellie Singer', 0.125),
#  ('Elizabeth Sperti', 0.125),
#  ('Gia Karpouzis', 0.125),
#  ('Hunter Harwood', 0.125),
#  ('Hailey Robertson', 0.125),
#  ('David Kilpatrick', 0.12631578947368421),
#  ('Aaron Kall', 0.12643678160919541),
#  ('Abby Schirmer', 0.12643678160919541),
#  ('Isaac Chao', 0.12698412698412698),
#  ('Allison Harper', 0.12716763005780346),
#  ('Anthony Trufanov', 0.1276595744680851),
#  ('Brooke Erickson', 0.1276595744680851),
#  ('Dylan Quigley', 0.1276595744680851),
#  ('Donato Luongo', 0.1276595744680851),
#  ('Imran Makani', 0.1276595744680851),
#  ('Abhi Elisetty', 0.1282051282051282),
#  ('Aditya Dhar', 0.1282051282051282),
#  ('Ben Schultz', 0.1282051282051282),
#  ('Cecilia Cerja', 0.1282051282051282),
#  ('Firoz Gill', 0.1282051282051282),
#  ('Gabriel Sanchez', 0.1282051282051282),
#  ('Adam Krell', 0.12903225806451613),
#  ('Ben Menzies', 0.12903225806451613),
#  ('Beth Zhao', 0.12903225806451613),
#  ('Bilal Butt', 0.1292517006802721),
#  ('Alex Sherman', 0.13043478260869565),
#  ('Anand Raman', 0.13043478260869565),
#  ('Aaron Marineau', 0.13043478260869565),
#  ('Brandon Reynolds', 0.13043478260869565),
#  ('Dustin Rymph', 0.13043478260869565),
#  ('Esme Longley', 0.13043478260869565),
#  ('George Lee', 0.13043478260869565),
#  ('Donald Grasse', 0.13095238095238096),
#  ('andy montee', 0.13157894736842105),
#  ('Andrea Brown', 0.13157894736842105),
#  ('Corey Turoff', 0.13157894736842105),
#  ('Heaven Montague', 0.1323529411764706),
#  ('Grant Brown', 0.1326530612244898),
#  ('Aarron Schurevich', 0.13333333333333333),
#  ('Alex Zhao', 0.13333333333333333),
#  ('Blake Deng', 0.13333333333333333),
#  ('Ben Hanson', 0.13333333333333333),
#  ('Chris Biswell', 0.13333333333333333),
#  ('Curtis Wang', 0.13333333333333333),
#  ('Davis LaBarre', 0.13333333333333333),
#  ('Elyse Conklin', 0.13333333333333333),
#  ('Evan Engel', 0.13333333333333333),
#  ('Chris Thiele', 0.13392857142857142),
#  ('Christy Webster Dunn', 0.1346153846153846),
#  ('Hunter McFarland', 0.1349206349206349),
#  ('Dawn Paciotti', 0.13533834586466165),
#  ('Brian Manuel', 0.136),
#  ('Brad Meloche', 0.13617021276595745),
#  ('Anna Lasseter', 0.13636363636363635),
#  ('Abel Addleman', 0.13636363636363635),
#  ('Billy Graves', 0.13636363636363635),
#  ('Brett Rydalch', 0.13636363636363635),
#  ('Braden James', 0.13636363636363635),
#  ('Claire Rung', 0.13636363636363635),
#  ('Christoph Diasio', 0.13636363636363635),
#  ('David Larson', 0.13636363636363635),
#  ('Ezra Louvis', 0.13636363636363635),
#  ('Em Parker', 0.13636363636363635),
#  ('Ed Kwan', 0.13636363636363635),
#  ('Henry Weikel', 0.13636363636363635),
#  ('Hunter McCullough', 0.13675213675213677),
#  ('Cameron McConway', 0.13725490196078433),
#  ('Carol Dennis', 0.13793103448275862),
#  ("D'Angelo Oberto-Besso", 0.13793103448275862),
#  ('Brent Huang', 0.13846153846153847),
#  ('Austin Oliver', 0.1388888888888889),
#  ('Dylan Frederick', 0.1388888888888889),
#  ('Don Steiner', 0.1388888888888889),
#  ('Devin Hernandez', 0.1388888888888889),
#  ('Ignacio Evans', 0.1388888888888889),
#  ('Brenden Dimmig', 0.13924050632911392),
#  ('Cody Peterson', 0.13953488372093023),
#  ('Charlie Jackson', 0.14),
#  ('Abraham Corrigan', 0.14035087719298245),
#  ('Colin Dike', 0.14035087719298245),
#  ('Erik Perez', 0.140625),
#  ('Aurelia Williams', 0.14084507042253522),
#  ('Brendon Bankey', 0.1411042944785276),
#  ('Aaron Timmons', 0.14285714285714285),
#  ('Adrienne Brovero', 0.14285714285714285),
#  ('Andre Washington', 0.14285714285714285),
#  ('Alexander Parini', 0.14285714285714285),
#  ('Andy Zhu', 0.14285714285714285),
#  ('Alex Gray', 0.14285714285714285),
#  ('Andrew young', 0.14285714285714285),
#  ('Amisha Mehta', 0.14285714285714285),
#  ('Anthony Berryhill', 0.14285714285714285),
#  ('Aniruth Narayanan', 0.14285714285714285),
#  ('Barbara Pascale-Blossom', 0.14285714285714285),
#  ('Bekah Boyer', 0.14285714285714285),
#  ('Chase McCool', 0.14285714285714285),
#  ('Chad Infante', 0.14285714285714285),
#  ('Christian Tarsney', 0.14285714285714285),
#  ('Crystal Legionaires', 0.14285714285714285),
#  ('Cori Roberts', 0.14285714285714285),
#  ('Caitlin Riffer', 0.14285714285714285),
#  ('Debnil Sur', 0.14285714285714285),
#  ('Douglas Mungin', 0.14285714285714285),
#  ('Everett Hackett', 0.14285714285714285),
#  ('Ellis London', 0.14285714285714285),
#  ('Gabe Murillo', 0.14285714285714285),
#  ('Grace Findley', 0.14285714285714285),
#  ('Gabe Cook', 0.14285714285714285),
#  ('Harry Bagenstos', 0.14285714285714285),
#  ('Christian Vasquez', 0.14418604651162792),
#  ('Cade Cottrell', 0.14444444444444443),
#  ('Greg Stevens', 0.14516129032258066),
#  ('Calum Matheson', 0.14545454545454545),
#  ('Chris Harrow', 0.14545454545454545),
#  ('chris bryant', 0.14634146341463414),
#  ('Danielle Dosch', 0.14634146341463414),
#  ('Gavin Serr', 0.14634146341463414),
#  ('Ben Rosenthal', 0.14666666666666667),
#  ('Albi Manfredi', 0.14705882352941177),
#  ('Ahmed Farrukh', 0.14705882352941177),
#  ('Alec Opperman', 0.14814814814814814),
#  ('Crawford Leavoy', 0.14814814814814814),
#  ('Donny Peters', 0.14814814814814814),
#  ('Brian Klarman', 0.1487603305785124),
#  ('Eric Lanning', 0.14893617021276595),
#  ('Fred Robertson', 0.14893617021276595),
#  ('Caspar Arbeeny', 0.15),
#  ('Cameron Zurmuhl', 0.15),
#  ("Danielle O'Gorman", 0.15053763440860216),
#  ('Alex McVey', 0.1506849315068493),
#  ('Devon Weis', 0.1509433962264151),
#  ('Elise Matton', 0.1509433962264151),
#  ('Andy McCord', 0.15151515151515152),
#  ('Daniel Saunders', 0.15151515151515152),
#  ('Damon Routzhan', 0.15151515151515152),
#  ('Daniel Ciocca', 0.15151515151515152),
#  ('Eric Deng', 0.15151515151515152),
#  ('Brent Brossmann', 0.15217391304347827),
#  ('Cody Morrow', 0.15306122448979592),
#  ('Heather Walters', 0.15306122448979592),
#  ('Devane Murphy', 0.15333333333333332),
#  ('Alex Miles', 0.15384615384615385),
#  ('Alaina Walberg', 0.15384615384615385),
#  ('Amanda Ciocca', 0.15384615384615385),
#  ('Anirudh Prabhu', 0.15384615384615385),
#  ('Charlotte Blatt', 0.15384615384615385),
#  ('Dayvon Love', 0.15384615384615385),
#  ('Geordano Liriano', 0.15384615384615385),
#  ('Armands Revelins', 0.15436241610738255),
#  ('Edward Lee', 0.15476190476190477),
#  ('Allan Xu', 0.15555555555555556),
#  ('Cayman Giordano', 0.15555555555555556),
#  ('Gabriela Gonzalez', 0.15555555555555556),
#  ('Collin Roark', 0.15606936416184972),
#  ('Fred Sternhagen', 0.1568627450980392),
#  ('Austin Woodruff', 0.15714285714285714),
#  ('David Gomez Siu', 0.15789473684210525),
#  ('Erin Szczechowski', 0.15789473684210525),
#  ('Gabriel Delsol', 0.15789473684210525),
#  ('Adam Tomasi', 0.1590909090909091),
#  ("Dennis O'Donnell", 0.1590909090909091),
#  ('Adam Symonds', 0.15942028985507245),
#  ('Aditya Dhere', 0.16),
#  ('Ben Jablonski', 0.16),
#  ('Eunice Jung', 0.16),
#  ('Andrew Myers', 0.16129032258064516),
#  ('Benjamin Wolf', 0.16129032258064516),
#  ('Brent Nicholson', 0.16129032258064516),
#  ('Brian Murray', 0.16129032258064516),
#  ('Chinnel Williams', 0.16129032258064516),
#  ('dana randall', 0.16129032258064516),
#  ('Donald Fagan', 0.16129032258064516),
#  ('David Abraham', 0.16129032258064516),
#  ('Erik Legried', 0.16167664670658682),
#  ('Arun Sharma', 0.16176470588235295),
#  ('Christian Quiroz', 0.1619047619047619),
#  ('Danny Cigale', 0.16216216216216217),
#  ('David Arnett', 0.16304347826086957),
#  ('Bruce Najor', 0.16326530612244897),
#  ('Brendon Morris', 0.16363636363636364),
#  ('Bryce Piotrowski', 0.1651376146788991),
#  ('Bob Overing', 0.16546762589928057),
#  ('Aaron Hardy', 0.16666666666666666),
#  ('Adam Lipton', 0.16666666666666666),
#  ('Anne-Marie Hwang', 0.16666666666666666),
#  ('Alan Fishman', 0.16666666666666666),
#  ('Animesh Joshi', 0.16666666666666666),
#  ('Brett Bricker', 0.16666666666666666),
#  ('Brian Ontiveros-Kersch', 0.16666666666666666),
#  ('Brinda Balagopal', 0.16666666666666666),
#  ('Chris Crowe', 0.16666666666666666),
#  ('Chris Leonardi', 0.16666666666666666),
#  ('Cameron Nilles', 0.16666666666666666),
#  ('Cort Sylvester', 0.16666666666666666),
#  ('Daniel Stanfield', 0.16666666666666666),
#  ('Daniel Tartakovsky', 0.16666666666666666),
#  ('David Wells', 0.16666666666666666),
#  ('Darya Kaviani', 0.16666666666666666),
#  ('Bob Shurtz', 0.16766467065868262),
#  ('Benjamin Hagwood', 0.16806722689075632),
#  ('Abbey Chapman', 0.16831683168316833),
#  ('Chad Meadows', 0.16842105263157894),
#  ('Dustin Meyers-Levy', 0.16901408450704225),
#  ('Carter Henman', 0.1694915254237288),
#  ('Benjamin Morbeck', 0.16981132075471697),
#  ('CV Vitolo-Haddad', 0.1702127659574468),
#  ('Flynn Makuch', 0.17045454545454544),
#  ('David Kingston', 0.17073170731707318),
#  ('David Dosch', 0.17105263157894737),
#  ('Dino De La O', 0.17105263157894737),
#  ('Araceli Neuner', 0.17142857142857143),
#  ('Amy McCormick', 0.17142857142857143),
#  ('Andrew Torrez', 0.17142857142857143),
#  ('Benjamin Morris', 0.17142857142857143),
#  ('Deserea Niemann', 0.17142857142857143),
#  ('Hannah Johnson', 0.17142857142857143),
#  ('Amanda Bone', 0.1724137931034483),
#  ('Brandon Garrett', 0.17333333333333334),
#  ('Anthony Ogbuli', 0.17391304347826086),
#  ('Alexander Lennon', 0.17391304347826086),
#  ('Adrian Mitchell', 0.17391304347826086),
#  ('Cecilia Hagen', 0.17391304347826086),
#  ('Catie Ford', 0.17391304347826086),
#  ('Deb Banerjee', 0.17391304347826086),
#  ('Harrison Hurt', 0.17391304347826086),
#  ('DavidMichael Woodward', 0.1743119266055046),
#  ('Allie Chase', 0.17435897435897435),
#  ('David McGinnis', 0.17592592592592593),
#  ('Claudia Ribera', 0.176),
#  ('Arjun Tambe', 0.17647058823529413),
#  ('Andrew Chadwell', 0.17647058823529413),
#  ('Gerard Grigsby', 0.17777777777777778),
#  ('Brian DeLong', 0.1780821917808219),
#  ('Arjun Vellayappan', 0.17857142857142858),
#  ('Andrew Lopez', 0.17857142857142858),
#  ('Annie Wang', 0.17857142857142858),
#  ('Eden Medina', 0.17857142857142858),
#  ('Eric Le', 0.17857142857142858),
#  ('George Clemens', 0.17857142857142858),
#  ('Dave Chamberlain', 0.1791044776119403),
#  ('Doug Miller', 0.1791044776119403),
#  ('Catherine Shackelford', 0.1794871794871795),
#  ('Elijah Smith', 0.1797752808988764),
#  ('Dominic Henderson', 0.18),
#  ('Christopher Vincent', 0.18045112781954886),
#  ('Cory Ackerman', 0.18085106382978725),
#  ('Avery Henry', 0.18181818181818182),
#  ('Addisson Stugart', 0.18181818181818182),
#  ('Chase Williams', 0.18181818181818182),
#  ('Callie Avondet', 0.18181818181818182),
#  ('Connor Jolley', 0.18181818181818182),
#  ('David Herman', 0.18181818181818182),
#  ('Doron Darnov', 0.18181818181818182),
#  ('Daniel Kruger', 0.18181818181818182),
#  ('Eric Morris', 0.18253968253968253),
#  ('Amber Kelsie', 0.18333333333333332),
#  ('Ashveer Singh', 0.18421052631578946),
#  ('Aabid Shivji', 0.18518518518518517),
#  ('Akhil Jalan', 0.18518518518518517),
#  ('Brian Bloss', 0.18518518518518517),
#  ('Hemanth Sanjeev', 0.18518518518518517),
#  ('Addie Wilson', 0.18604651162790697),
#  ('B. Williams', 0.18604651162790697),
#  ('Chuck Walts', 0.18604651162790697),
#  ('Derek Hilligoss', 0.1864406779661017),
#  ('Caitlin Walrath', 0.18681318681318682),
#  ('Alex Carter', 0.1875),
#  ('Bilal Askari', 0.1875),
#  ('Chris Colvin', 0.1875),
#  ('Chelsea King', 0.1875),
#  ('Eva Motolinia', 0.1875),
#  ('adegoke fakorede', 0.18840579710144928),
#  ('H Dylan Willett', 0.18867924528301888),
#  ('Caitlyn Jones', 0.1891891891891892),
#  ('Eric Uecker', 0.1891891891891892),
#  ('Gabby Knight', 0.1891891891891892),
#  ('Andres Gannon', 0.1896551724137931),
#  ('Alice Lin', 0.19047619047619047),
#  ('Arman Jaffer', 0.19047619047619047),
#  ('Alexander Sherer', 0.19047619047619047),
#  ('Brandon Kelley', 0.19047619047619047),
#  ('Cynthia Lin', 0.19047619047619047),
#  ('Eric English', 0.19047619047619047),
#  ('Eamonn cummings', 0.19047619047619047),
#  ('Fatima Al Amir', 0.19047619047619047),
#  ('Gabriel Hopkins', 0.19047619047619047),
#  ('Audrey Cree', 0.19230769230769232),
#  ('Brandon Largin', 0.19230769230769232),
#  ('Deven Cooper', 0.19230769230769232),
#  ('David Umstot', 0.19230769230769232),
#  ('Emily Bosch', 0.19230769230769232),
#  ('Daiya Massac', 0.1935483870967742),
#  ('Didi Barry', 0.1935483870967742),
#  ('Emily Jackson', 0.1935483870967742),
#  ('Eleanor Mendelson', 0.1935483870967742),
#  ('Hayden Harper', 0.1935483870967742),
#  ('Emily White', 0.19444444444444445),
#  ('Genevieve Hackman', 0.19444444444444445),
#  ('Claire Kueffner', 0.1951219512195122),
#  ('Evan Gilbert', 0.1951219512195122),
#  ('Brandon Lu', 0.19607843137254902),
#  ('Darby Ginsberg', 0.19696969696969696),
#  ('Dallas Perkins', 0.19718309859154928),
#  ('Eric Robinson', 0.19718309859154928),
#  ('Alex Holguin', 0.1978021978021978),
#  ('Charles Schletzbaum', 0.19806763285024154),
#  ('Aracelis Biel', 0.2),
#  ('Alyssa Hooks', 0.2),
#  ('Aaron Schoeneman', 0.2),
#  ('Ashley Howden', 0.2),
#  ('Ben Allen', 0.2),
#  ('Christopher Theis', 0.2),
#  ('Caroline Wohl', 0.2),
#  ('Cecilia Birge', 0.2),
#  ('David Stoecker-Strauss', 0.2),
#  ('Emily Massey', 0.2),
#  ('Elisa McCartin', 0.2),
#  ('Hanh Do', 0.2),
#  ('Ben Crossan', 0.2018348623853211),
#  ('Daniel Fitzmier', 0.2028985507246377),
#  ('Courtney Coffman', 0.20430107526881722),
#  ('Austin Thoma', 0.20512820512820512),
#  ('Darcell Brown', 0.20512820512820512),
#  ('Brian Saipramouk', 0.20588235294117646),
#  ('Colin McElhinny', 0.20588235294117646),
#  ('Alex Pappas', 0.20689655172413793),
#  ('Andrew Glickman', 0.20689655172413793),
#  ('Dan Jacobs', 0.20689655172413793),
#  ('Andrew Allsup', 0.20833333333333334),
#  ('abdus najmi', 0.20833333333333334),
#  ('Bro. John McGrory', 0.20833333333333334),
#  ('Bee Smale', 0.20833333333333334),
#  ('Evan Chyriwski', 0.20833333333333334),
#  ('Harry Strong', 0.20833333333333334),
#  ('Isaac Cui', 0.20833333333333334),
#  ('Bob Portnoy', 0.21052631578947367),
#  ('alyssa turk', 0.21153846153846154),
#  ('Andrea Reed', 0.21212121212121213),
#  ('Caitlyn Wicks', 0.21212121212121213),
#  ('Isaac Brown', 0.2127659574468085),
#  ('Hannah Call', 0.21311475409836064),
#  ('Anthony Joseph', 0.21428571428571427),
#  ('Devon Schley', 0.21428571428571427),
#  ('Erick Berdugo', 0.21428571428571427),
#  ('Ed Williams', 0.21568627450980393),
#  ('Andrew Monagle', 0.21739130434782608),
#  ('Alyssa Corrigan', 0.21739130434782608),
#  ('Bailey Brunyer', 0.21739130434782608),
#  ('Chris Lowery', 0.21739130434782608),
#  ('Candis Tate', 0.21739130434782608),
#  ('Clayton Engelby', 0.21739130434782608),
#  ('DJ Spiker', 0.21739130434782608),
#  ('Edmund Zagorin', 0.21739130434782608),
#  ('Greg Achten', 0.21739130434782608),
#  ('Chris Theis', 0.21794871794871795),
#  ('Brianna Aaron', 0.21818181818181817),
#  ('Erika Thomas', 0.21875),
#  ('Glen Gustafson', 0.21875),
#  ('Colleen Mooney', 0.2222222222222222),
#  ('Dan Miyamoto', 0.2222222222222222),
#  ('Danielle Mahoney', 0.2222222222222222),
#  ('Ezra Lerner', 0.2222222222222222),
#  ('Gabriel Josko', 0.2222222222222222),
#  ('Ameena Ruffin', 0.2247191011235955),
#  ('Adam Freilich', 0.22727272727272727),
#  ('Christine Tsai', 0.22727272727272727),
#  ('Caylie Ratzlaff', 0.22727272727272727),
#  ('Dean Gerstein', 0.22727272727272727),
#  ('Eric Tang', 0.22727272727272727),
#  ('Advait Ramanan', 0.23076923076923078),
#  ('Arnav Bawa', 0.23076923076923078),
#  ('Christopher McDonald', 0.23076923076923078),
#  ('Derek Ziegler', 0.23076923076923078),
#  ('Daniel Alessandro', 0.23076923076923078),
#  ('David Ramachandran', 0.23076923076923078),
#  ('Ashley Denney', 0.23170731707317074),
#  ('Izak Dunn', 0.23255813953488372),
#  ('Colter Heirigs', 0.23809523809523808),
#  ('Chris Powell', 0.23809523809523808),
#  ('Dan Brown', 0.23809523809523808),
#  ('Drew Schettler', 0.23809523809523808),
#  ('Fabian Redler', 0.23809523809523808),
#  ('Charles Fisher', 0.24),
#  ('Darlene Lambert', 0.24),
#  ('Hal Sanford', 0.24),
#  ('Amy Santos', 0.2413793103448276),
#  ('Adam Nir', 0.24324324324324326),
#  ('Aly Fiebrantz', 0.24528301886792453),
#  ('Brad Bolman', 0.24770642201834864),
#  ('Amrut Chowdhury', 0.25),
#  ('Asher Spector', 0.25),
#  ('Brianna Thomas', 0.25),
#  ('chaz wyche', 0.25),
#  ('Donald Broussard', 0.25),
#  ('Elizabeth Prete', 0.25),
#  ('Erica Cooper', 0.25),
#  ('David Finnigan', 0.25396825396825395),
#  ('Devon Reese', 0.2553191489361702),
#  ('Aarti Kapoor', 0.25806451612903225),
#  ('Chris Hess', 0.25806451612903225),
#  ('Alex Velto', 0.25925925925925924),
#  ('Brandon Chen', 0.25925925925925924),
#  ('Chris Coovert', 0.25925925925925924),
#  ('Gabi Yamout', 0.25925925925925924),
#  ('Brixz Gonzaba', 0.2608695652173913),
#  ('Brian Seymour', 0.2608695652173913),
#  ('Chris Fielder', 0.2608695652173913),
#  ('Christopher Teters', 0.2608695652173913),
#  ('Ella Kuzmenko', 0.2608695652173913),
#  ('David Almonte', 0.2631578947368421),
#  ('Denise Grisham', 0.2647058823529412),
#  ('Abraham Fraifeld', 0.2682926829268293),
#  ('Cyrus Jackson', 0.2692307692307692),
#  ('Alex Stransky', 0.2727272727272727),
#  ('Evan Streams', 0.2727272727272727),
#  ('Fredrick Ni', 0.2727272727272727),
#  ('Calen Smith', 0.27450980392156865),
#  ('Azja Butler', 0.27906976744186046),
#  ('Anthony Brown', 0.28),
#  ('Holden Martinson', 0.28),
#  ('Evan Dugery', 0.2857142857142857),
#  ('Charles Huang', 0.2903225806451613),
#  ('Dongji Xie', 0.2916666666666667),
#  ('Ashley Morgan', 0.2962962962962963),
#  ('David Rooney', 0.2962962962962963),
#  ('Deena McNamara', 0.2962962962962963),
#  ('Darius White', 0.3055555555555556),
#  ('Adesuwa Omoruyi', 0.3076923076923077),
#  ('DaCobi Anderson', 0.30952380952380953),
#  ('Christopher Jackson', 0.3103448275862069),
#  ('Casey Meyer', 0.32),
#  ('alison becker', 0.3333333333333333),
#  ('Bob Beideck', 0.3333333333333333),
#  ('Cameron Smith', 0.3333333333333333),
#  ('Chaoyang Wang', 0.3333333333333333),
#  ('Greg Pratt', 0.3333333333333333),
#  ('chih-ling chou', 0.35),
#  ('Evan McCordick', 0.36),
#  ('Erich DeSchepper', 0.38095238095238093),
#  ('Hillary Burchuk', 0.3888888888888889),
#  ('Hannah Babcock', 0.42857142857142855)]

# %%
[record for record in records if record['Judge'] == 'David Moon' and record['Panel']]
# Out:
# [{'Judge': 'David Moon',
#   'Tournament': '46th Annual Harvard National Forensics Tournament',
#   'Date': '2/13/2020',
#   'Event': 'VLD',
#   'Round Number': '9',
#   'Round Name': ' Octafi ',
#   'Aff': 'Newsome DB',
#   'Neg': 'William G. Enloe TG',
#   'Decision': 'Neg',
#   'Panel': 'Neg on a 3-0'},
#  {'Judge': 'David Moon',
#   'Tournament': '46th Annual Harvard National Forensics Tournament',
#   'Date': '2/13/2020',
#   'Event': 'VLD',
#   'Round Number': '7',
#   'Round Name': ' Triple ',
#   'Aff': 'Bronx Science AW',
#   'Neg': 'Acton-Boxborough ML',
#   'Decision': 'Neg',
#   'Panel': 'Neg on a 3-0'},
#  {'Judge': 'David Moon',
#   'Tournament': '46th Annual Harvard National Forensics Tournament',
#   'Date': '2/13/2020',
#   'Event': 'VLD',
#   'Round Number': '7',
#   'Round Name': ' Triple ',
#   'Aff': 'Thomas Jefferson HSST AD',
#   'Neg': 'Millburn KW',
#   'Decision': 'Neg',
#   'Panel': 'Neg on a 3-0'},
#  {'Judge': 'David Moon',
#   'Tournament': '45th Harvard National Forensics Tournament',
#   'Date': '2/16/2019',
#   'Event': 'VLD',
#   'Round Number': '8',
#   'Round Name': ' Double ',
#   'Aff': 'American Heritage Plantation PB',
#   'Neg': "St. Andrew's Episcopal IB",
#   'Decision': 'Neg',
#   'Panel': 'Neg on a 3-0'},
#  {'Judge': 'David Moon',
#   'Tournament': '45th Harvard National Forensics Tournament',
#   'Date': '2/16/2019',
#   'Event': 'VLD',
#   'Round Number': '8',
#   'Round Name': ' Double ',
#   'Aff': 'Lexington JM',
#   'Neg': 'Acton-Boxborough ML',
#   'Decision': 'Neg',
#   'Panel': 'Neg on a 2-1'},
#  {'Judge': 'David Moon',
#   'Tournament': '45th Harvard National Forensics Tournament',
#   'Date': '2/16/2019',
#   'Event': 'VLD',
#   'Round Number': '7',
#   'Round Name': ' Triple ',
#   'Aff': 'Cambridge Rindge and Latin AG',
#   'Neg': 'Thomas Jefferson HSST RK',
#   'Decision': 'Aff',
#   'Panel': 'Aff on a 3-0'},
#  {'Judge': 'David Moon',
#   'Tournament': '45th Harvard National Forensics Tournament',
#   'Date': '2/16/2019',
#   'Event': 'VLD',
#   'Round Number': '7',
#   'Round Name': ' Triple ',
#   'Aff': 'Roslyn BL',
#   'Neg': 'Millburn AH',
#   'Decision': 'Aff',
#   'Panel': 'Aff on a 2-1'},
#  {'Judge': 'David Moon',
#   'Tournament': 'Harvard Round Robin',
#   'Date': '2/14/2019',
#   'Event': 'LD RR',
#   'Round Number': '2',
#   'Round Name': ' R2 ',
#   'Aff': 'Cambridge Rindge and Latin AG',
#   'Neg': 'Harrison AZ',
#   'Decision': 'Aff',
#   'Panel': 'Aff on a 2-0'},
#  {'Judge': 'David Moon',
#   'Tournament': 'Harvard Round Robin',
#   'Date': '2/14/2019',
#   'Event': 'LD RR',
#   'Round Number': '1',
#   'Round Name': ' R1 ',
#   'Aff': 'Cambridge Rindge and Latin AG',
#   'Neg': 'Needham ZL',
#   'Decision': 'Aff',
#   'Panel': 'Aff on a 2-0'},
#  {'Judge': 'David Moon',
#   'Tournament': '44th Annual Harvard National Forensics Tournament',
#   'Date': '2/17/2018',
#   'Event': 'JVLD',
#   'Round Number': '9',
#   'Round Name': ' Octafi ',
#   'Aff': 'Charlotte Catholic LS',
#   'Neg': 'Thomas Jefferson HSST TC',
#   'Decision': 'Aff',
#   'Panel': 'Aff on a 2-1'},
#  {'Judge': 'David Moon',
#   'Tournament': '44th Annual Harvard National Forensics Tournament',
#   'Date': '2/17/2018',
#   'Event': 'VLD',
#   'Round Number': '8',
#   'Round Name': ' Double ',
#   'Aff': 'Law Magnet MG',
#   'Neg': 'Lake Highland Prep JW',
#   'Decision': 'Aff',
#   'Panel': 'Aff on a 2-1'},
#  {'Judge': 'David Moon',
#   'Tournament': '44th Annual Harvard National Forensics Tournament',
#   'Date': '2/17/2018',
#   'Event': 'VLD',
#   'Round Number': '7',
#   'Round Name': ' Triple ',
#   'Aff': 'Needham ZL',
#   'Neg': 'Lexington RW',
#   'Decision': 'Neg',
#   'Panel': 'Neg on a 2-1'},
#  {'Judge': 'David Moon',
#   'Tournament': '44th Annual Harvard National Forensics Tournament',
#   'Date': '2/17/2018',
#   'Event': 'VLD',
#   'Round Number': '7',
#   'Round Name': ' Triple ',
#   'Aff': 'Stuyvesant KL',
#   'Neg': 'Hattiesburg OS',
#   'Decision': 'Aff',
#   'Panel': 'Aff on a 3-0'},
#  {'Judge': 'David Moon',
#   'Tournament': 'Harvard Round Robin',
#   'Date': '2/15/2018',
#   'Event': 'LD RR',
#   'Round Number': '6',
#   'Round Name': ' R6 ',
#   'Aff': 'Lake Highland Prep AA',
#   'Neg': 'JBS Law Magnet MG',
#   'Decision': 'Aff',
#   'Panel': 'Aff on a 2-0'},
#  {'Judge': 'David Moon',
#   'Tournament': 'Harvard Round Robin',
#   'Date': '2/15/2018',
#   'Event': 'LD RR',
#   'Round Number': '5',
#   'Round Name': ' R5 ',
#   'Aff': 'Stuyvesant PY',
#   'Neg': 'West Des Moines Valley CT',
#   'Decision': 'Neg',
#   'Panel': 'Neg on a 2-0'},
#  {'Judge': 'David Moon',
#   'Tournament': 'Harvard Round Robin',
#   'Date': '2/15/2018',
#   'Event': 'LD RR',
#   'Round Number': '1',
#   'Round Name': ' R1 ',
#   'Aff': 'West Des Moines Valley CT',
#   'Neg': "St. Andrew's Episcopal IB",
#   'Decision': 'Neg',
#   'Panel': 'Neg on a 2-0'},
#  {'Judge': 'David Moon',
#   'Tournament': 'Lexington Winter Invitational',
#   'Date': '1/13/2018',
#   'Event': 'VLD',
#   'Round Number': '7',
#   'Round Name': ' Double ',
#   'Aff': 'Scarsdale NI',
#   'Neg': 'Cambridge Rindge and Latin AG',
#   'Decision': 'Neg',
#   'Panel': 'Neg on a 3-0'},
#  {'Judge': 'David Moon',
#   'Tournament': 'New York City Invitational Debate and Speech Tournament',
#   'Date': '10/13/2017',
#   'Event': 'LD',
#   'Round Number': '9',
#   'Round Name': ' Sextod ',
#   'Aff': 'Scarsdale NI',
#   'Neg': 'Millburn AJ',
#   'Decision': 'Neg',
#   'Panel': 'Neg on a 2-1'},
#  {'Judge': 'David Moon',
#   'Tournament': 'New York City Invitational Debate and Speech Tournament',
#   'Date': '10/13/2017',
#   'Event': 'LD',
#   'Round Number': '8',
#   'Round Name': ' Runoff ',
#   'Aff': 'Pennsbury CZ',
#   'Neg': 'Princeton DS',
#   'Decision': 'Aff',
#   'Panel': 'Aff on a 3-0'},
#  {'Judge': 'David Moon',
#   'Tournament': 'Yale Invitational',
#   'Date': '9/15/2017',
#   'Event': 'VLD',
#   'Round Number': '11',
#   'Round Name': ' Semis ',
#   'Aff': 'American Heritage School - Plantation DM',
#   'Neg': 'Phillips Academy Andover TC',
#   'Decision': 'Aff',
#   'Panel': 'Aff on a 2-1'},
#  {'Judge': 'David Moon',
#   'Tournament': 'Yale Invitational',
#   'Date': '9/15/2017',
#   'Event': 'VLD',
#   'Round Number': '10',
#   'Round Name': ' Quarte ',
#   'Aff': 'Gilmour SW',
#   'Neg': 'American Heritage School - Plantation DM',
#   'Decision': 'Neg',
#   'Panel': 'Neg on a 3-0'},
#  {'Judge': 'David Moon',
#   'Tournament': 'Yale Invitational',
#   'Date': '9/15/2017',
#   'Event': 'VLD',
#   'Round Number': '9',
#   'Round Name': ' Octas ',
#   'Aff': 'Stuyvesant PY',
#   'Neg': 'Westview RS',
#   'Decision': 'Aff',
#   'Panel': 'Neg on a 2-1'},
#  {'Judge': 'David Moon',
#   'Tournament': 'Yale Invitational',
#   'Date': '9/15/2017',
#   'Event': 'VLD',
#   'Round Number': '8',
#   'Round Name': ' Double ',
#   'Aff': 'Hunter ML',
#   'Neg': 'West Des Moines Valley AJ',
#   'Decision': 'Neg',
#   'Panel': 'Neg on a 3-0'},
#  {'Judge': 'David Moon',
#   'Tournament': 'Yale Invitational',
#   'Date': '9/15/2017',
#   'Event': 'VLD',
#   'Round Number': '7',
#   'Round Name': ' Triple ',
#   'Aff': 'La Salle AT',
#   'Neg': 'Hunter MS',
#   'Decision': 'Neg',
#   'Panel': 'Neg on a 3-0'},
#  {'Judge': 'David Moon',
#   'Tournament': 'Yale Invitational',
#   'Date': '9/15/2017',
#   'Event': 'VLD',
#   'Round Number': '7',
#   'Round Name': ' Triple ',
#   'Aff': 'Stuyvesant CL',
#   'Neg': 'Thomas Jefferson HSST RK',
#   'Decision': 'Aff',
#   'Panel': 'Aff on a 3-0'},
#  {'Judge': 'David Moon',
#   'Tournament': 'NSD Philadelphia Camp Tournament',
#   'Date': '7/27/2017',
#   'Event': 'LD',
#   'Round Number': '8',
#   'Round Name': ' Quarte ',
#   'Aff': 'Captains Christopher Wong',
#   'Neg': 'Medics Wolf Cukier',
#   'Decision': 'Neg',
#   'Panel': 'Neg on a 3-0'},
#  {'Judge': 'David Moon',
#   'Tournament': 'NSD Philadelphia Camp Tournament',
#   'Date': '7/27/2017',
#   'Event': 'LD',
#   'Round Number': '8',
#   'Round Name': ' Quarte ',
#   'Aff': 'Aliens John Choi',
#   'Neg': 'Aliens Zane Encinas',
#   'Decision': 'Neg',
#   'Panel': 'Neg on a 3-0'}]

# %% [markdown]
# ### Repeats Analysis

# %%
def findRepeats(record):
    repeats = {}
    seen = {}
    for matchup in record:
        pair = matchup["Judge"] + "-" + matchup["Aff"] + "-" + matchup["Neg"]
        if pair in seen:
            seen[pair].append(matchup)
        else:
            seen[pair] = [matchup]
            
    for pair in seen:
        matchups = seen[pair]
        
        if len(matchups) > 1:
            repeats[pair] = matchups
            
    return repeats

# %%
repeats = findRepeats(records)

# %%
same = 0
flips = 0
for pair in repeats:
    
    rounds = repeats[pair]
    winners = [r[r["Decision"]] for r in rounds  if r["Decision"] in ["Aff", "Neg"]]
    if winners:
        last = winners[0]
    for winner in winners[1:]:
        if winner == last:
            same += 1
        else:
            flips += 1
            last = winner

# %%
print(same, flips)
# Out:
# 287 108

# %%
repeats
# Out:
# {'Amber Kelsie-Kansas HR-Oklahoma CY': [{'Judge': 'Amber Kelsie',
#    'Tournament': 'CEDA Nationals  Wichita State',
#    'Date': '3/20/2015',
#    'Event': 'Open',
#    'Round Number': '13',
#    'Round Name': ' Semi ',
#    'Aff': 'Kansas HR',
#    'Neg': 'Oklahoma CY',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 4-1'},
#   {'Judge': 'Amber Kelsie',
#    'Tournament': 'CEDA Nationals  Wichita State',
#    'Date': '3/20/2015',
#    'Event': 'Open',
#    'Round Number': '13',
#    'Round Name': ' Semi ',
#    'Aff': 'Kansas HR',
#    'Neg': 'Oklahoma CY',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 4-1'}],
#  'Amber Kelsie-Vermont BB-Rutgers-Newark SR': [{'Judge': 'Amber Kelsie',
#    'Tournament': 'CEDA Nats  Indiana',
#    'Date': '3/21/2014',
#    'Event': '',
#    'Round Number': '12',
#    'Round Name': ' Qtrs ',
#    'Aff': 'Vermont BB',
#    'Neg': 'Rutgers-Newark SR',
#    'Decision': 'Aff',
#    'Panel': 'Neg on a 4-1'},
#   {'Judge': 'Amber Kelsie',
#    'Tournament': '2013 Franklin R Shirley Classic at Wake Forest',
#    'Date': '11/15/2013',
#    'Event': 'OPN',
#    'Round Number': '11',
#    'Round Name': ' QTRS ',
#    'Aff': 'Vermont BB',
#    'Neg': 'Rutgers-Newark SR',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 5-0'}],
#  'Aaron Timmons-Appleton East MM-Harvard-Westlake MP': [{'Judge': 'Aaron Timmons',
#    'Tournament': 'Tournament of Champions',
#    'Date': '4/27/2019',
#    'Event': 'LD',
#    'Round Number': '2',
#    'Round Name': ' R2 ',
#    'Aff': 'Appleton East MM',
#    'Neg': 'Harvard-Westlake MP',
#    'Decision': 'Aff',
#    'Panel': ''},
#   {'Judge': 'Aaron Timmons',
#    'Tournament': 'National Debate Coaches Association National Championship',
#    'Date': '4/13/2019',
#    'Event': 'LD',
#    'Round Number': '6',
#    'Round Name': ' R6 ',
#    'Aff': 'Appleton East MM',
#    'Neg': 'Harvard-Westlake MP',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Adrienne Brovero-Georgia RS-Kentucky BT': [{'Judge': 'Adrienne Brovero',
#    'Tournament': '73rd National Debate Tournament',
#    'Date': '3/21/2019',
#    'Event': 'Open',
#    'Round Number': '13',
#    'Round Name': ' Finals ',
#    'Aff': 'Georgia RS',
#    'Neg': 'Kentucky BT',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 6-1'},
#   {'Judge': 'Adrienne Brovero',
#    'Tournament': '72nd National Debate Tournament at Wichita State',
#    'Date': '3/22/2018',
#    'Event': 'Open',
#    'Round Number': '5',
#    'Round Name': ' Round  ',
#    'Aff': 'Georgia RS',
#    'Neg': 'Kentucky BT',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 3-0'}],
#  'Adrienne Brovero-GTown AM-Northwestern LV': [{'Judge': 'Adrienne Brovero',
#    'Tournament': 'Northwestern Owen L Coon',
#    'Date': '2/9/2013',
#    'Event': 'OC',
#    'Round Number': '14',
#    'Round Name': ' Qtrs ',
#    'Aff': 'GTown AM',
#    'Neg': 'Northwestern LV',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 2-1'},
#   {'Judge': 'Adrienne Brovero',
#    'Tournament': 'Franklin R. Shirley Classic at Wake Forest University',
#    'Date': '11/8/2012',
#    'Event': '-',
#    'Round Number': '15',
#    'Round Name': ' Semis ',
#    'Aff': 'GTown AM',
#    'Neg': 'Northwestern LV',
#    'Decision': 'Aff',
#    'Panel': 'Neg on a 2-1'}],
#  'Andrew Allsup-Wake Forest HV-West Georgia CC': [{'Judge': 'Andrew Allsup',
#    'Tournament': '73rd National Debate Tournament',
#    'Date': '3/21/2019',
#    'Event': 'Open',
#    'Round Number': '5',
#    'Round Name': ' Round  ',
#    'Aff': 'Wake Forest HV',
#    'Neg': 'West Georgia CC',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 3-0'},
#   {'Judge': 'Andrew Allsup',
#    'Tournament': '55th Owen L Coon Memorial at Northwestern',
#    'Date': '2/2/2019',
#    'Event': 'Open',
#    'Round Number': '8',
#    'Round Name': ' RD 8 ',
#    'Aff': 'Wake Forest HV',
#    'Neg': 'West Georgia CC',
#    'Decision': 'Neg',
#    'Panel': ''},
#   {'Judge': 'Andrew Allsup',
#    'Tournament': 'The Jesuit Gonzaga University',
#    'Date': '10/27/2018',
#    'Event': 'Open',
#    'Round Number': '8',
#    'Round Name': ' RD 8 ',
#    'Aff': 'Wake Forest HV',
#    'Neg': 'West Georgia CC',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Amrut Chowdhury-Emory FL-Oklahoma WJ': [{'Judge': 'Amrut Chowdhury',
#    'Tournament': '71st National Debate Tournament at Kansas',
#    'Date': '3/23/2017',
#    'Event': 'Open',
#    'Round Number': '8',
#    'Round Name': ' Round  ',
#    'Aff': 'Emory FL',
#    'Neg': 'Oklahoma WJ',
#    'Decision': 'Neg',
#    'Panel': 'Aff on a 2-1'},
#   {'Judge': 'Amrut Chowdhury',
#    'Tournament': 'USC Alan Nichols Tournament',
#    'Date': '1/3/2017',
#    'Event': 'Var',
#    'Round Number': '6',
#    'Round Name': ' R6 ',
#    'Aff': 'Emory FL',
#    'Neg': 'Oklahoma WJ',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Aaron Kall-Kentucky HR-Michigan State JS': [{'Judge': 'Aaron Kall',
#    'Tournament': '73rd National Debate Tournament',
#    'Date': '3/21/2019',
#    'Event': 'Open',
#    'Round Number': '8',
#    'Round Name': ' Round  ',
#    'Aff': 'Kentucky HR',
#    'Neg': 'Michigan State JS',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 2-1'},
#   {'Judge': 'Aaron Kall',
#    'Tournament': 'JW Patterson Debates at Kentucky',
#    'Date': '9/29/2018',
#    'Event': 'Open',
#    'Round Number': '2',
#    'Round Name': ' R2 ',
#    'Aff': 'Kentucky HR',
#    'Neg': 'Michigan State JS',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Armands Revelins-Trinity DK-West Georgia CJ': [{'Judge': 'Armands Revelins',
#    'Tournament': '72nd National Debate Tournament at Wichita State',
#    'Date': '3/22/2018',
#    'Event': 'Open',
#    'Round Number': '4',
#    'Round Name': ' Round  ',
#    'Aff': 'Trinity DK',
#    'Neg': 'West Georgia CJ',
#    'Decision': 'Aff',
#    'Panel': 'Neg on a 2-1'},
#   {'Judge': 'Armands Revelins',
#    'Tournament': 'Franklin R Shirley Classic at Wake Forest University',
#    'Date': '11/11/2017',
#    'Event': 'SHIR',
#    'Round Number': '5',
#    'Round Name': ' RD 5 ',
#    'Aff': 'Trinity DK',
#    'Neg': 'West Georgia CJ',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Al Hiland-Kansas KR-Harvard MS': [{'Judge': 'Al Hiland',
#    'Tournament': '72nd National Debate Tournament at Wichita State',
#    'Date': '3/22/2018',
#    'Event': 'Open',
#    'Round Number': '12',
#    'Round Name': ' Semis ',
#    'Aff': 'Kansas KR',
#    'Neg': 'Harvard MS',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 3-2'},
#   {'Judge': 'Al Hiland',
#    'Tournament': 'Texas Open',
#    'Date': '2/3/2018',
#    'Event': 'TXO',
#    'Round Number': '13',
#    'Round Name': ' Finals ',
#    'Aff': 'Kansas KR',
#    'Neg': 'Harvard MS',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 2-1'}],
#  'Abby Schirmer-BEPST Tambe & Wang-BEPST Mahajan & Nys': [{'Judge': 'Abby Schirmer',
#    'Tournament': 'SDI 4 Week Tournament',
#    'Date': '7/28/2015',
#    'Event': 'CX',
#    'Round Number': '8',
#    'Round Name': ' Octafi ',
#    'Aff': 'BEPST Tambe & Wang',
#    'Neg': 'BEPST Mahajan & Nys',
#    'Decision': 'Aff',
#    'Panel': ''},
#   {'Judge': 'Abby Schirmer',
#    'Tournament': 'SDI 4 Week Tournament',
#    'Date': '7/28/2015',
#    'Event': 'CX',
#    'Round Number': '7',
#    'Round Name': ' R7 ',
#    'Aff': 'BEPST Tambe & Wang',
#    'Neg': 'BEPST Mahajan & Nys',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Alex McVey-Kansas McGregory & Hill-UCO Kyle Wendland': [{'Judge': 'Alex McVey',
#    'Tournament': 'Texas Swing 2 Rowdy Debates in Dallas',
#    'Date': '1/9/2020',
#    'Event': 'JV',
#    'Round Number': '7',
#    'Round Name': ' Sems ',
#    'Aff': 'Kansas McGregory & Hill',
#    'Neg': 'UCO Kyle Wendland',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 3-0'},
#   {'Judge': 'Alex McVey',
#    'Tournament': 'Texas Swing 1 Fear and Loathing in Dallas',
#    'Date': '1/6/2020',
#    'Event': 'JV',
#    'Round Number': '2',
#    'Round Name': ' R2 ',
#    'Aff': 'Kansas McGregory & Hill',
#    'Neg': 'UCO Kyle Wendland',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Allie Chase-KCKCC ST-Augie SV': [{'Judge': 'Allie Chase',
#    'Tournament': 'NJDDT at Johnson County Community College',
#    'Date': '3/15/2014',
#    'Event': 'Novic',
#    'Round Number': '4',
#    'Round Name': ' Novice ',
#    'Aff': 'KCKCC ST',
#    'Neg': 'Augie SV',
#    'Decision': 'Aff',
#    'Panel': ''},
#   {'Judge': 'Allie Chase',
#    'Tournament': 'William DeMougeot Debates',
#    'Date': '1/9/2014',
#    'Event': 'Novice',
#    'Round Number': '16',
#    'Round Name': ' Novice ',
#    'Aff': 'KCKCC ST',
#    'Neg': 'Augie SV',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 3-0'}],
#  'andy montee-Central Oklahoma CM-Kansas FR': [{'Judge': 'andy montee',
#    'Tournament': 'Wichita State Season Opener',
#    'Date': '9/14/2018',
#    'Event': 'Open',
#    'Round Number': '8',
#    'Round Name': ' R8 ',
#    'Aff': 'Central Oklahoma CM',
#    'Neg': 'Kansas FR',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 3-0'},
#   {'Judge': 'andy montee',
#    'Tournament': 'Wichita State Season Opener',
#    'Date': '9/14/2018',
#    'Event': 'Open',
#    'Round Number': '6',
#    'Round Name': ' R6 ',
#    'Aff': 'Central Oklahoma CM',
#    'Neg': 'Kansas FR',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'andy montee-Texas BP-Weber State GT': [{'Judge': 'andy montee',
#    'Tournament': '70th National Debate Tournament at Binghamton',
#    'Date': '3/31/2016',
#    'Event': 'Open',
#    'Round Number': '3',
#    'Round Name': ' Round  ',
#    'Aff': 'Texas BP',
#    'Neg': 'Weber State GT',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 2-1'},
#   {'Judge': 'andy montee',
#    'Tournament': 'Las Vegas Classic',
#    'Date': '10/17/2015',
#    'Event': 'Open',
#    'Round Number': '6',
#    'Round Name': ' R6 ',
#    'Aff': 'Texas BP',
#    'Neg': 'Weber State GT',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'andy montee-Kansas HR-Oklahoma CY': [{'Judge': 'andy montee',
#    'Tournament': 'CEDA Nationals  Wichita State',
#    'Date': '3/20/2015',
#    'Event': 'Open',
#    'Round Number': '13',
#    'Round Name': ' Semi ',
#    'Aff': 'Kansas HR',
#    'Neg': 'Oklahoma CY',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 4-1'},
#   {'Judge': 'andy montee',
#    'Tournament': 'CEDA Nationals  Wichita State',
#    'Date': '3/20/2015',
#    'Event': 'Open',
#    'Round Number': '13',
#    'Round Name': ' Semi ',
#    'Aff': 'Kansas HR',
#    'Neg': 'Oklahoma CY',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 4-1'}],
#  'Alec Opperman-RutgerVH-BHamtnCP': [{'Judge': 'Alec Opperman',
#    'Tournament': 'NE Regional Opener',
#    'Date': '9/21/2012',
#    'Event': '',
#    'Round Number': '14',
#    'Round Name': ' Quarte ',
#    'Aff': 'RutgerVH',
#    'Neg': 'BHamtnCP',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 3-0'},
#   {'Judge': 'Alec Opperman',
#    'Tournament': 'NE Regional Opener',
#    'Date': '9/21/2012',
#    'Event': '',
#    'Round Number': '4',
#    'Round Name': ' 4 ',
#    'Aff': 'RutgerVH',
#    'Neg': 'BHamtnCP',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Andy Casey-Towson JR-Oklahoma LM': [{'Judge': 'Andy Casey',
#    'Tournament': 'Kentucky College Tournament',
#    'Date': '10/5/2013',
#    'Event': 'Opn',
#    'Round Number': '9',
#    'Round Name': ' DBLS ',
#    'Aff': 'Towson JR',
#    'Neg': 'Oklahoma LM',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 4-1'},
#   {'Judge': 'Andy Casey',
#    'Tournament': '67th National Debate Tournament',
#    'Date': '3/29/2013',
#    'Event': 'Open',
#    'Round Number': '13',
#    'Round Name': ' Octofi ',
#    'Aff': 'Towson JR',
#    'Neg': 'Oklahoma LM',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 4-1'}],
#  'Austin Woodruff-Wake Forest DV-George Mason GM': [{'Judge': 'Austin Woodruff',
#    'Tournament': 'Liberty University Debate Tournament',
#    'Date': '11/6/2015',
#    'Event': 'Open',
#    'Round Number': '2',
#    'Round Name': ' R2 ',
#    'Aff': 'Wake Forest DV',
#    'Neg': 'George Mason GM',
#    'Decision': 'Aff',
#    'Panel': ''},
#   {'Judge': 'Austin Woodruff',
#    'Tournament': 'UMW Debate Tournament',
#    'Date': '10/10/2015',
#    'Event': 'Open',
#    'Round Number': '5',
#    'Round Name': ' R5 ',
#    'Aff': 'Wake Forest DV',
#    'Neg': 'George Mason GM',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Austin Woodruff-Navy MR-Pittsburgh CK': [{'Judge': 'Austin Woodruff',
#    'Tournament': 'NDT District VII Qualifier',
#    'Date': '2/22/2014',
#    'Event': 'D7',
#    'Round Number': '5',
#    'Round Name': ' D7 5 ',
#    'Aff': 'Navy MR',
#    'Neg': 'Pittsburgh CK',
#    'Decision': 'Aff',
#    'Panel': ''},
#   {'Judge': 'Austin Woodruff',
#    'Tournament': 'Crowe Warken Debates at NAVY',
#    'Date': '1/18/2014',
#    'Event': 'Open',
#    'Round Number': '2',
#    'Round Name': '  2 ',
#    'Aff': 'Navy MR',
#    'Neg': 'Pittsburgh CK',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Andrew Ridgeway-Hicks Lab PP-Hicks Lab LW': [{'Judge': 'Andrew Ridgeway',
#    'Tournament': 'Capitol Debate PF Loyola 2014',
#    'Date': '7/23/2014',
#    'Event': 'MSPF',
#    'Round Number': '6',
#    'Round Name': ' QUAD ',
#    'Aff': 'Hicks Lab PP',
#    'Neg': 'Hicks Lab LW',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 3-0'},
#   {'Judge': 'Andrew Ridgeway',
#    'Tournament': 'Capitol Debate PF Loyola 2014',
#    'Date': '7/23/2014',
#    'Event': 'MSPF',
#    'Round Number': '1',
#    'Round Name': ' R1 ',
#    'Aff': 'Hicks Lab PP',
#    'Neg': 'Hicks Lab LW',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Allison Harper-WaySta JM-CenFlo OS': [{'Judge': 'Allison Harper',
#    'Tournament': 'Vanderbilt',
#    'Date': '10/13/2017',
#    'Event': 'JV',
#    'Round Number': '7',
#    'Round Name': ' Semis ',
#    'Aff': 'WaySta JM',
#    'Neg': 'CenFlo OS',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 2-1'},
#   {'Judge': 'Allison Harper',
#    'Tournament': 'Vanderbilt',
#    'Date': '10/13/2017',
#    'Event': 'JV',
#    'Round Number': '6',
#    'Round Name': ' R6 ',
#    'Aff': 'WaySta JM',
#    'Neg': 'CenFlo OS',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Adam Torson-Harvard-Westlake WB-Immaculate Heart MC': [{'Judge': 'Adam Torson',
#    'Tournament': 'National Debate Coaches Association National Championship',
#    'Date': '4/13/2019',
#    'Event': 'LD',
#    'Round Number': '8',
#    'Round Name': ' Octo ',
#    'Aff': 'Harvard-Westlake WB',
#    'Neg': 'Immaculate Heart MC',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 2-1'},
#   {'Judge': 'Adam Torson',
#    'Tournament': 'Golden Desert Debate Tournament at UNLV',
#    'Date': '2/2/2019',
#    'Event': 'VLD',
#    'Round Number': '7',
#    'Round Name': ' Double ',
#    'Aff': 'Harvard-Westlake WB',
#    'Neg': 'Immaculate Heart MC',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 2-1'}],
#  'Adam Torson-Harvard-Westlake AM-Harker EM': [{'Judge': 'Adam Torson',
#    'Tournament': 'National Debate Coaches Association National Championships',
#    'Date': '4/8/2017',
#    'Event': 'LD',
#    'Round Number': '3',
#    'Round Name': ' R3 ',
#    'Aff': 'Harvard-Westlake AM',
#    'Neg': 'Harker EM',
#    'Decision': 'Neg',
#    'Panel': ''},
#   {'Judge': 'Adam Torson',
#    'Tournament': 'Golden Desert Debate Tournament at UNLV',
#    'Date': '2/4/2017',
#    'Event': 'VLD',
#    'Round Number': '9',
#    'Round Name': ' Quarte ',
#    'Aff': 'Harvard-Westlake AM',
#    'Neg': 'Harker EM',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 2-1'}],
#  'Adam Torson-Brentwood KM-Harvard-Westlake LM': [{'Judge': 'Adam Torson',
#    'Tournament': 'Cal Invitational UC Berkeley',
#    'Date': '2/18/2017',
#    'Event': 'VLD',
#    'Round Number': '6',
#    'Round Name': ' R6 ',
#    'Aff': 'Brentwood KM',
#    'Neg': 'Harvard-Westlake LM',
#    'Decision': 'Neg',
#    'Panel': ''},
#   {'Judge': 'Adam Torson',
#    'Tournament': 'USC Damus Spring Trojan Championships',
#    'Date': '3/4/2016',
#    'Event': 'VLD',
#    'Round Number': '2',
#    'Round Name': ' R2 ',
#    'Aff': 'Brentwood KM',
#    'Neg': 'Harvard-Westlake LM',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Adam Torson-La Canada AZ-Harvard-Westlake NS': [{'Judge': 'Adam Torson',
#    'Tournament': 'Voices Foundation Invitational',
#    'Date': '10/10/2014',
#    'Event': 'VLD',
#    'Round Number': '8',
#    'Round Name': ' Octas ',
#    'Aff': 'La Canada AZ',
#    'Neg': 'Harvard-Westlake NS',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 3-0'},
#   {'Judge': 'Adam Torson',
#    'Tournament': 'Loyola Invitational',
#    'Date': '9/12/2014',
#    'Event': 'LD',
#    'Round Number': '5',
#    'Round Name': ' R5 ',
#    'Aff': 'La Canada AZ',
#    'Neg': 'Harvard-Westlake NS',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Anthony Ogbuli-UNLV HS-Liberty HT': [{'Judge': 'Anthony Ogbuli',
#    'Tournament': '73rd National Debate Tournament',
#    'Date': '3/21/2019',
#    'Event': 'Open',
#    'Round Number': '9',
#    'Round Name': ' Double ',
#    'Aff': 'UNLV HS',
#    'Neg': 'Liberty HT',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 4-1'},
#   {'Judge': 'Anthony Ogbuli',
#    'Tournament': '55th Owen L Coon Memorial at Northwestern',
#    'Date': '2/2/2019',
#    'Event': 'Open',
#    'Round Number': '9',
#    'Round Name': ' DBLS ',
#    'Aff': 'UNLV HS',
#    'Neg': 'Liberty HT',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 4-1'}],
#  'Anthony Ogbuli-Harvard MS-Baylor BZ': [{'Judge': 'Anthony Ogbuli',
#    'Tournament': '72nd National Debate Tournament at Wichita State',
#    'Date': '3/22/2018',
#    'Event': 'Open',
#    'Round Number': '10',
#    'Round Name': ' Octos ',
#    'Aff': 'Harvard MS',
#    'Neg': 'Baylor BZ',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 5-0'},
#   {'Judge': 'Anthony Ogbuli',
#    'Tournament': 'Franklin R Shirley Classic at Wake Forest University',
#    'Date': '11/11/2017',
#    'Event': 'SHIR',
#    'Round Number': '8',
#    'Round Name': ' RD 8 ',
#    'Aff': 'Harvard MS',
#    'Neg': 'Baylor BZ',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Anthony Ogbuli-Central Oklahoma MB-Kansas FR': [{'Judge': 'Anthony Ogbuli',
#    'Tournament': 'Fear and Loathing Texas Two Step 2',
#    'Date': '1/6/2018',
#    'Event': 'Open',
#    'Round Number': '4',
#    'Round Name': ' R4 ',
#    'Aff': 'Central Oklahoma MB',
#    'Neg': 'Kansas FR',
#    'Decision': 'Neg',
#    'Panel': ''},
#   {'Judge': 'Anthony Ogbuli',
#    'Tournament': 'Fear and Loathing Texas Two Step 1',
#    'Date': '1/3/2018',
#    'Event': 'OPEN',
#    'Round Number': '1',
#    'Round Name': ' R1 ',
#    'Aff': 'Central Oklahoma MB',
#    'Neg': 'Kansas FR',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Anthony Ogbuli-Baylor SW-Wyoming CH': [{'Judge': 'Anthony Ogbuli',
#    'Tournament': 'Owen L Coon Memorial Debates at Northwestern',
#    'Date': '2/4/2017',
#    'Event': 'Open',
#    'Round Number': '7',
#    'Round Name': ' RD 7 ',
#    'Aff': 'Baylor SW',
#    'Neg': 'Wyoming CH',
#    'Decision': 'Neg',
#    'Panel': ''},
#   {'Judge': 'Anthony Ogbuli',
#    'Tournament': 'William DeMougeot Debates',
#    'Date': '1/6/2017',
#    'Event': 'Open',
#    'Round Number': '9',
#    'Round Name': ' Quarte ',
#    'Aff': 'Baylor SW',
#    'Neg': 'Wyoming CH',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 3-0'}],
#  'Aubtin Heydari--La Reina DS': [{'Judge': 'Aubtin Heydari',
#    'Tournament': 'The Damien Debates',
#    'Date': '11/14/2015',
#    'Event': 'OPol',
#    'Round Number': '8',
#    'Round Name': ' Novice ',
#    'Aff': '',
#    'Neg': 'La Reina DS',
#    'Decision': '',
#    'Panel': ''},
#   {'Judge': 'Aubtin Heydari',
#    'Tournament': 'The Damien Debates',
#    'Date': '11/14/2015',
#    'Event': 'NPol',
#    'Round Number': '2',
#    'Round Name': ' Finals ',
#    'Aff': '',
#    'Neg': 'La Reina DS',
#    'Decision': '',
#    'Panel': ''}],
#  'Aabid Shivji-Plano West Senior GV-Plano Senior MM': [{'Judge': 'Aabid Shivji',
#    'Tournament': 'Jesuit College Prep Invitational',
#    'Date': '2/10/2017',
#    'Event': 'PF',
#    'Round Number': '5',
#    'Round Name': ' Quar ',
#    'Aff': 'Plano West Senior GV',
#    'Neg': 'Plano Senior MM',
#    'Decision': 'Aff',
#    'Panel': 'Neg on a 2-1'},
#   {'Judge': 'Aabid Shivji',
#    'Tournament': 'Jesuit College Prep Invitational',
#    'Date': '2/10/2017',
#    'Event': 'PF',
#    'Round Number': '1',
#    'Round Name': ' R1 ',
#    'Aff': 'Plano West Senior GV',
#    'Neg': 'Plano Senior MM',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Aabid Shivji-Albuquerque KC-Anderson CW': [{'Judge': 'Aabid Shivji',
#    'Tournament': 'Heart of Texas Invitational',
#    'Date': '10/14/2016',
#    'Event': 'PF',
#    'Round Number': '7',
#    'Round Name': ' Quarte ',
#    'Aff': 'Albuquerque KC',
#    'Neg': 'Anderson CW',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 3-0'},
#   {'Judge': 'Aabid Shivji',
#    'Tournament': 'Heart of Texas Invitational',
#    'Date': '10/14/2016',
#    'Event': 'PF',
#    'Round Number': '2',
#    'Round Name': ' R2 ',
#    'Aff': 'Albuquerque KC',
#    'Neg': 'Anderson CW',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Anthony Joseph-Oklahoma JS-Rutgers-Newark AH': [{'Judge': 'Anthony Joseph',
#    'Tournament': 'CEDA Nationals Long Beach',
#    'Date': '4/4/2019',
#    'Event': 'Open',
#    'Round Number': '4',
#    'Round Name': ' R4 ',
#    'Aff': 'Oklahoma JS',
#    'Neg': 'Rutgers-Newark AH',
#    'Decision': 'Aff',
#    'Panel': ''},
#   {'Judge': 'Anthony Joseph',
#    'Tournament': '73rd National Debate Tournament',
#    'Date': '3/21/2019',
#    'Event': 'Open',
#    'Round Number': '5',
#    'Round Name': ' Round  ',
#    'Aff': 'Oklahoma JS',
#    'Neg': 'Rutgers-Newark AH',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 3-0'}],
#  'Ashley Denney-Lindenwood NW-UNI AE': [{'Judge': 'Ashley Denney',
#    'Tournament': 'Bear Shock  Wichita State',
#    'Date': '1/25/2014',
#    'Event': 'JV',
#    'Round Number': '14',
#    'Round Name': ' JV Qua ',
#    'Aff': 'Lindenwood NW',
#    'Neg': 'UNI AE',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 2-1'},
#   {'Judge': 'Ashley Denney',
#    'Tournament': 'Bear Shock  Wichita State',
#    'Date': '1/25/2014',
#    'Event': 'JV',
#    'Round Number': '3',
#    'Round Name': ' JV 3 ',
#    'Aff': 'Lindenwood NW',
#    'Neg': 'UNI AE',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Adam Bistagne-Harvard-Westlake CE-Marlborough ZW': [{'Judge': 'Adam Bistagne',
#    'Tournament': 'USC Damus Spring Trojan Championships',
#    'Date': '3/3/2017',
#    'Event': 'VLD',
#    'Round Number': '3',
#    'Round Name': ' R3 ',
#    'Aff': 'Harvard-Westlake CE',
#    'Neg': 'Marlborough ZW',
#    'Decision': 'Aff',
#    'Panel': ''},
#   {'Judge': 'Adam Bistagne',
#    'Tournament': 'USC Damus Spring Trojan Championships',
#    'Date': '3/4/2016',
#    'Event': 'VLD',
#    'Round Number': '3',
#    'Round Name': ' R3 ',
#    'Aff': 'Harvard-Westlake CE',
#    'Neg': 'Marlborough ZW',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Alixandria Arungah-Green PZ-Alston CL': [{'Judge': 'Alixandria Arungah',
#    'Tournament': 'Capitol Debate Summer Camps   Princeton NJ',
#    'Date': '8/4/2015',
#    'Event': 'BPF',
#    'Round Number': '6',
#    'Round Name': ' QUAD ',
#    'Aff': 'Green PZ',
#    'Neg': 'Alston CL',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 3-0'},
#   {'Judge': 'Alixandria Arungah',
#    'Tournament': 'Capitol Debate Summer Camps   Princeton NJ',
#    'Date': '8/4/2015',
#    'Event': 'BPF',
#    'Round Number': '5',
#    'Round Name': ' R5 ',
#    'Aff': 'Green PZ',
#    'Neg': 'Alston CL',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Ameena Ruffin-Wake Forest AS-Kansas DR': [{'Judge': 'Ameena Ruffin',
#    'Tournament': 'Owen L Coon Memorial Debates at Northwestern',
#    'Date': '2/4/2017',
#    'Event': 'Open',
#    'Round Number': '11',
#    'Round Name': ' QTRS ',
#    'Aff': 'Wake Forest AS',
#    'Neg': 'Kansas DR',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 5-0'},
#   {'Judge': 'Ameena Ruffin',
#    'Tournament': 'USC Alan Nichols Tournament',
#    'Date': '1/3/2017',
#    'Event': 'Var',
#    'Round Number': '5',
#    'Round Name': ' R5 ',
#    'Aff': 'Wake Forest AS',
#    'Neg': 'Kansas DR',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Anthony Trufanov-Dallas Highland Park ML-Greenhill LH': [{'Judge': 'Anthony Trufanov',
#    'Tournament': 'Barkley Forum for High Schools',
#    'Date': '1/24/2020',
#    'Event': 'PEL',
#    'Round Number': '8',
#    'Round Name': ' PFB ',
#    'Aff': 'Dallas Highland Park ML',
#    'Neg': 'Greenhill LH',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 2-1'},
#   {'Judge': 'Anthony Trufanov',
#    'Tournament': 'Billy Tate Southern Bell Forum MBA',
#    'Date': '1/4/2020',
#    'Event': 'SBF',
#    'Round Number': '7',
#    'Round Name': ' Octos ',
#    'Aff': 'Dallas Highland Park ML',
#    'Neg': 'Greenhill LH',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 3-0'}],
#  'Anthony Trufanov-New Trier EK-Montgomery Bell BH': [{'Judge': 'Anthony Trufanov',
#    'Tournament': 'Tournament of Champions',
#    'Date': '4/27/2019',
#    'Event': 'CX',
#    'Round Number': '10',
#    'Round Name': ' Quarte ',
#    'Aff': 'New Trier EK',
#    'Neg': 'Montgomery Bell BH',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 2-1'},
#   {'Judge': 'Anthony Trufanov',
#    'Tournament': 'Barkley Forum for High Schools',
#    'Date': '1/25/2019',
#    'Event': 'PEL',
#    'Round Number': '3',
#    'Round Name': ' R3 ',
#    'Aff': 'New Trier EK',
#    'Neg': 'Montgomery Bell BH',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Alice Lin-Concordia University Irvine Corso-Gonzales & Lange-McKendree Deleel & Powell': [{'Judge': 'Alice Lin',
#    'Tournament': 'National Parliamentary Tournament of Excellence',
#    'Date': '3/21/2019',
#    'Event': 'NPDA',
#    'Round Number': '9',
#    'Round Name': ' E3D ',
#    'Aff': 'Concordia University Irvine Corso-Gonzales & Lange',
#    'Neg': 'McKendree Deleel & Powell',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 2-1'},
#   {'Judge': 'Alice Lin',
#    'Tournament': 'National Parliamentary Tournament of Excellence',
#    'Date': '3/21/2019',
#    'Event': 'NPDA',
#    'Round Number': '2',
#    'Round Name': ' R2 ',
#    'Aff': 'Concordia University Irvine Corso-Gonzales & Lange',
#    'Neg': 'McKendree Deleel & Powell',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 2-0'}],
#  'Alex Gazmararian-Northwestern JW-UC Berkeley FG': [{'Judge': 'Alex Gazmararian',
#    'Tournament': 'Herbert L James Debates Dartmouth Round Robin',
#    'Date': '1/18/2020',
#    'Event': 'DRR',
#    'Round Number': '2',
#    'Round Name': ' 2 ',
#    'Aff': 'Northwestern JW',
#    'Neg': 'UC Berkeley FG',
#    'Decision': 'Aff',
#    'Panel': ''},
#   {'Judge': 'Alex Gazmararian',
#    'Tournament': 'Georgetown College Tournament',
#    'Date': '1/3/2020',
#    'Event': 'Open',
#    'Round Number': '13',
#    'Round Name': ' Finals ',
#    'Aff': 'Northwestern JW',
#    'Neg': 'UC Berkeley FG',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 3-0'}],
#  'Abraham Fraifeld-Plano West Senior LY-Bronx HS Of Science LO': [{'Judge': 'Abraham Fraifeld',
#    'Tournament': 'Tournament of Champions',
#    'Date': '4/28/2018',
#    'Event': 'GPF',
#    'Round Number': '3',
#    'Round Name': ' R3 ',
#    'Aff': 'Plano West Senior LY',
#    'Neg': 'Bronx HS Of Science LO',
#    'Decision': 'Neg',
#    'Panel': ''},
#   {'Judge': 'Abraham Fraifeld',
#    'Tournament': 'Tournament of Champions',
#    'Date': '4/29/2017',
#    'Event': 'PF',
#    'Round Number': '2',
#    'Round Name': ' R2 ',
#    'Aff': 'Plano West Senior LY',
#    'Neg': 'Bronx HS Of Science LO',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Ashan Peiris-Brentwood JR-Peninsula KK': [{'Judge': 'Ashan Peiris',
#    'Tournament': 'Harvard Westlake Debate',
#    'Date': '1/14/2016',
#    'Event': 'VLD',
#    'Round Number': '8',
#    'Round Name': ' Elim 2 ',
#    'Aff': 'Brentwood JR',
#    'Neg': 'Peninsula KK',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 2-1'},
#   {'Judge': 'Ashan Peiris',
#    'Tournament': 'Damus Hollywood Invitational and USC RR',
#    'Date': '11/5/2015',
#    'Event': 'VarLD',
#    'Round Number': '5',
#    'Round Name': ' R5 ',
#    'Aff': 'Brentwood JR',
#    'Neg': 'Peninsula KK',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Ashan Peiris-La Reina DS-Marlborough CC': [{'Judge': 'Ashan Peiris',
#    'Tournament': 'Damus Hollywood Invitational and USC RR',
#    'Date': '11/5/2015',
#    'Event': 'VarLD',
#    'Round Number': '6',
#    'Round Name': ' R6 ',
#    'Aff': 'La Reina DS',
#    'Neg': 'Marlborough CC',
#    'Decision': 'Neg',
#    'Panel': ''},
#   {'Judge': 'Ashan Peiris',
#    'Tournament': 'USC David Damus Trojan Championships',
#    'Date': '3/6/2015',
#    'Event': 'NLD',
#    'Round Number': '6',
#    'Round Name': ' R6 ',
#    'Aff': 'La Reina DS',
#    'Neg': 'Marlborough CC',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Amanda Dabney-George Mason GK-Mary Washington AH': [{'Judge': 'Amanda Dabney',
#    'Tournament': 'NDT District VII Qualifier',
#    'Date': '2/17/2018',
#    'Event': 'JV',
#    'Round Number': '5',
#    'Round Name': ' R5 ',
#    'Aff': 'George Mason GK',
#    'Neg': 'Mary Washington AH',
#    'Decision': 'Aff',
#    'Panel': ''},
#   {'Judge': 'Amanda Dabney',
#    'Tournament': 'JMU College Invitational',
#    'Date': '1/26/2018',
#    'Event': 'JV',
#    'Round Number': '4',
#    'Round Name': ' R4 ',
#    'Aff': 'George Mason GK',
#    'Neg': 'Mary Washington AH',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Andrew Myers-OES OW-Ferris OS': [{'Judge': 'Andrew Myers',
#    'Tournament': 'The Conway at Gonzaga University',
#    'Date': '1/4/2019',
#    'Event': 'OpeCX',
#    'Round Number': '9',
#    'Round Name': ' Quarte ',
#    'Aff': 'OES OW',
#    'Neg': 'Ferris OS',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 2-1'},
#   {'Judge': 'Andrew Myers',
#    'Tournament': 'Saint Georges Invitational',
#    'Date': '12/7/2018',
#    'Event': 'OPol',
#    'Round Number': '8',
#    'Round Name': ' Semis ',
#    'Aff': 'OES OW',
#    'Neg': 'Ferris OS',
#    'Decision': 'Neg',
#    'Panel': 'Aff on a 2-1'}],
#  'Anna Wu-Sharon BA-Lexington DY': [{'Judge': 'Anna Wu',
#    'Tournament': 'MSDL State Debate Final',
#    'Date': '3/24/2018',
#    'Event': 'LD-N',
#    'Round Number': '2',
#    'Round Name': ' R2 ',
#    'Aff': 'Sharon BA',
#    'Neg': 'Lexington DY',
#    'Decision': 'Aff',
#    'Panel': ''},
#   {'Judge': 'Anna Wu',
#    'Tournament': '2018 March Merryness',
#    'Date': '3/17/2018',
#    'Event': 'NLD',
#    'Round Number': '1',
#    'Round Name': ' R1 ',
#    'Aff': 'Sharon BA',
#    'Neg': 'Lexington DY',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Andrew young-Blake GM-Park City MS': [{'Judge': 'Andrew young',
#    'Tournament': 'National Debate Coaches Association National Championship',
#    'Date': '4/14/2018',
#    'Event': 'PF',
#    'Round Number': '7',
#    'Round Name': ' Quarte ',
#    'Aff': 'Blake GM',
#    'Neg': 'Park City MS',
#    'Decision': 'Aff',
#    'Panel': 'Neg on a 2-1'},
#   {'Judge': 'Andrew young',
#    'Tournament': 'National Debate Coaches Association National Championship',
#    'Date': '4/14/2018',
#    'Event': 'PF',
#    'Round Number': '4',
#    'Round Name': ' R4 ',
#    'Aff': 'Blake GM',
#    'Neg': 'Park City MS',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Alyssa Hooks-Plano Senior MM-Lamar NV': [{'Judge': 'Alyssa Hooks',
#    'Tournament': 'The NDF Round Robin at Strake Jesuit',
#    'Date': '12/17/2016',
#    'Event': '',
#    'Round Number': '6',
#    'Round Name': ' R6 ',
#    'Aff': 'Plano Senior MM',
#    'Neg': 'Lamar NV',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 5-0'},
#   {'Judge': 'Alyssa Hooks',
#    'Tournament': 'The NDF Round Robin at Strake Jesuit',
#    'Date': '12/17/2016',
#    'Event': '',
#    'Round Number': '3',
#    'Round Name': ' R3 ',
#    'Aff': 'Plano Senior MM',
#    'Neg': 'Lamar NV',
#    'Decision': 'Neg',
#    'Panel': 'Aff on a 2-1'}],
#  'Anjum Shaik-SFW Catherine Liu-BRK Prasoon Kharel': [{'Judge': 'Anjum Shaik',
#    'Tournament': 'Washington Warrior Invite NIETOC Bid',
#    'Date': '11/19/2020',
#    'Event': 'VLD',
#    'Round Number': '6',
#    'Round Name': ' Finals ',
#    'Aff': 'SFW Catherine Liu',
#    'Neg': 'BRK Prasoon Kharel',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 3-0'},
#   {'Judge': 'Anjum Shaik',
#    'Tournament': 'SF Roosevelt Sweetstakes',
#    'Date': '11/12/2020',
#    'Event': 'VLD',
#    'Round Number': '8',
#    'Round Name': ' Final ',
#    'Aff': 'SFW Catherine Liu',
#    'Neg': 'BRK Prasoon Kharel',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 3-0'}],
#  'Avery Gonzales-Ro-DP': [{'Judge': 'Avery Gonzales',
#    'Tournament': 'Leopard Novice Cup',
#    'Date': '4/17/2017',
#    'Event': 'PF',
#    'Round Number': '14',
#    'Round Name': ' R14 ',
#    'Aff': 'Ro',
#    'Neg': 'DP',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 5-1'},
#   {'Judge': 'Avery Gonzales',
#    'Tournament': 'Leopard Novice Cup',
#    'Date': '4/17/2017',
#    'Event': 'PF',
#    'Round Number': '5',
#    'Round Name': ' R5 ',
#    'Aff': 'Ro',
#    'Neg': 'DP',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 7-1'}],
#  'Avery Gonzales-DP-AW': [{'Judge': 'Avery Gonzales',
#    'Tournament': 'Leopard Novice Cup',
#    'Date': '4/17/2017',
#    'Event': 'PF',
#    'Round Number': '11',
#    'Round Name': ' R11 ',
#    'Aff': 'DP',
#    'Neg': 'AW',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 6-1'},
#   {'Judge': 'Avery Gonzales',
#    'Tournament': 'Leopard Novice Cup',
#    'Date': '4/17/2017',
#    'Event': 'PF',
#    'Round Number': '10',
#    'Round Name': ' R10 ',
#    'Aff': 'DP',
#    'Neg': 'AW',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 7-2'}],
#  'Aubrey Semple-Atholton RS-Eastside BR': [{'Judge': 'Aubrey Semple',
#    'Tournament': 'Electric City Invitational',
#    'Date': '12/5/2013',
#    'Event': 'VCX',
#    'Round Number': '8',
#    'Round Name': ' Octafi ',
#    'Aff': 'Atholton RS',
#    'Neg': 'Eastside BR',
#    'Decision': 'Aff',
#    'Panel': 'Neg on a 2-1'},
#   {'Judge': 'Aubrey Semple',
#    'Tournament': 'New York City Invitational',
#    'Date': '10/18/2013',
#    'Event': 'TD',
#    'Round Number': '7',
#    'Round Name': ' Double ',
#    'Aff': 'Atholton RS',
#    'Neg': 'Eastside BR',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 3-0'}],
#  'Akshay Patil-Houston County Joseph & Campbell-Columbus Anderson & Marto': [{'Judge': 'Akshay Patil',
#    'Tournament': 'GFCA 1st 2nd Year State Championships',
#    'Date': '2/7/2020',
#    'Event': 'PF2',
#    'Round Number': '6',
#    'Round Name': ' Quar ',
#    'Aff': 'Houston County Joseph & Campbell',
#    'Neg': 'Columbus Anderson & Marto',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 2-1'},
#   {'Judge': 'Akshay Patil',
#    'Tournament': 'GFCA 1st 2nd Year State Championships',
#    'Date': '2/7/2020',
#    'Event': 'PF2',
#    'Round Number': '3',
#    'Round Name': ' R3 ',
#    'Aff': 'Houston County Joseph & Campbell',
#    'Neg': 'Columbus Anderson & Marto',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Alyson Escalante-Parliamentary Debate at Berkeley Tolchard & Kadie-Rice Torres & Barton': [{'Judge': 'Alyson Escalante',
#    'Tournament': 'National Parliamentary Tournament of Excellence',
#    'Date': '3/21/2019',
#    'Event': 'NPDA',
#    'Round Number': '16',
#    'Round Name': ' F ',
#    'Aff': 'Parliamentary Debate at Berkeley Tolchard & Kadie',
#    'Neg': 'Rice Torres & Barton',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 7-0'},
#   {'Judge': 'Alyson Escalante',
#    'Tournament': 'National Parliamentary Tournament of Excellence',
#    'Date': '3/21/2019',
#    'Event': 'NPDA',
#    'Round Number': '12',
#    'Round Name': ' E4 ',
#    'Aff': 'Parliamentary Debate at Berkeley Tolchard & Kadie',
#    'Neg': 'Rice Torres & Barton',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 3-0'}],
#  'Aditya Dhere--X Evelyn Moore': [{'Judge': 'Aditya Dhere',
#    'Tournament': 'Pittsburgh District Tournament',
#    'Date': '3/9/2019',
#    'Event': 'BQ',
#    'Round Number': '6',
#    'Round Name': ' R6 ',
#    'Aff': '',
#    'Neg': 'X Evelyn Moore',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 3-0'},
#   {'Judge': 'Aditya Dhere',
#    'Tournament': 'Pittsburgh District Tournament',
#    'Date': '3/9/2019',
#    'Event': 'BQ',
#    'Round Number': '5',
#    'Round Name': ' R5 ',
#    'Aff': '',
#    'Neg': 'X Evelyn Moore',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 3-0'}],
#  'Aditya Dhere--F Victor Yu': [{'Judge': 'Aditya Dhere',
#    'Tournament': 'Pittsburgh District Tournament',
#    'Date': '3/9/2019',
#    'Event': 'BQ',
#    'Round Number': '4',
#    'Round Name': ' R4 ',
#    'Aff': '',
#    'Neg': 'F Victor Yu',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 3-0'},
#   {'Judge': 'Aditya Dhere',
#    'Tournament': 'Pittsburgh District Tournament',
#    'Date': '3/9/2019',
#    'Event': 'BQ',
#    'Round Number': '3',
#    'Round Name': ' R3 ',
#    'Aff': '',
#    'Neg': 'F Victor Yu',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 3-0'}],
#  'Annie Wang-Northview SD-Lake Highland Prep KS': [{'Judge': 'Annie Wang',
#    'Tournament': 'New York City Invitational Debate and Speech Tournament',
#    'Date': '10/15/2020',
#    'Event': 'LD',
#    'Round Number': '8',
#    'Round Name': ' Run-of ',
#    'Aff': 'Northview SD',
#    'Neg': 'Lake Highland Prep KS',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 3-0'},
#   {'Judge': 'Annie Wang',
#    'Tournament': 'New York City Invitational Debate and Speech Tournament',
#    'Date': '10/15/2020',
#    'Event': 'LD',
#    'Round Number': '8',
#    'Round Name': ' Run-of ',
#    'Aff': 'Northview SD',
#    'Neg': 'Lake Highland Prep KS',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 3-0'}],
#  'Ali Bharwani-Grapevine RT-Cross Timbers APa': [{'Judge': 'Ali Bharwani',
#    'Tournament': 'Colleyville Heritage Winter Invitational',
#    'Date': '2/1/2019',
#    'Event': 'MSLD',
#    'Round Number': '4',
#    'Round Name': ' Final ',
#    'Aff': 'Grapevine RT',
#    'Neg': 'Cross Timbers APa',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 3-0'},
#   {'Judge': 'Ali Bharwani',
#    'Tournament': 'Colleyville Heritage Winter Invitational',
#    'Date': '2/1/2019',
#    'Event': 'MSLD',
#    'Round Number': '3',
#    'Round Name': ' R3 ',
#    'Aff': 'Grapevine RT',
#    'Neg': 'Cross Timbers APa',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Anthony Brown-Lovejoy PR-Coppell NG': [{'Judge': 'Anthony Brown',
#    'Tournament': 'Guyer Wildcat Invitational',
#    'Date': '1/11/2020',
#    'Event': 'VPF',
#    'Round Number': '4',
#    'Round Name': ' Qrtrs ',
#    'Aff': 'Lovejoy PR',
#    'Neg': 'Coppell NG',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 2-1'},
#   {'Judge': 'Anthony Brown',
#    'Tournament': 'Guyer Wildcat Invitational',
#    'Date': '1/11/2020',
#    'Event': 'VPF',
#    'Round Number': '3',
#    'Round Name': ' R3 ',
#    'Aff': 'Lovejoy PR',
#    'Neg': 'Coppell NG',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Alec Antonakakis-Coppell VS-Hebron NS': [{'Judge': 'Alec Antonakakis',
#    'Tournament': 'North Texas Longhorns District Tournament',
#    'Date': '2/27/2020',
#    'Event': 'LD',
#    'Round Number': '6',
#    'Round Name': ' Elim2 ',
#    'Aff': 'Coppell VS',
#    'Neg': 'Hebron NS',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 2-1'},
#   {'Judge': 'Alec Antonakakis',
#    'Tournament': 'Marcus Marauder Debate Tournament',
#    'Date': '11/22/2019',
#    'Event': 'VLD',
#    'Round Number': '6',
#    'Round Name': ' S ',
#    'Aff': 'Coppell VS',
#    'Neg': 'Hebron NS',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 2-1'}],
#  'albert cardenas-Harvard-Westlake JI-Brentwood DL': [{'Judge': 'albert cardenas',
#    'Tournament': 'Loyola Invitational',
#    'Date': '9/6/2019',
#    'Event': 'LD',
#    'Round Number': '2',
#    'Round Name': ' R2 ',
#    'Aff': 'Harvard-Westlake JI',
#    'Neg': 'Brentwood DL',
#    'Decision': 'Aff',
#    'Panel': ''},
#   {'Judge': 'albert cardenas',
#    'Tournament': 'Jack Howe Memorial Tournament',
#    'Date': '9/22/2018',
#    'Event': 'TOCLD',
#    'Round Number': '3',
#    'Round Name': ' R3 ',
#    'Aff': 'Harvard-Westlake JI',
#    'Neg': 'Brentwood DL',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Abby Pater-Ro-DP': [{'Judge': 'Abby Pater',
#    'Tournament': 'Leopard Novice Cup',
#    'Date': '4/17/2017',
#    'Event': 'PF',
#    'Round Number': '14',
#    'Round Name': ' R14 ',
#    'Aff': 'Ro',
#    'Neg': 'DP',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 5-1'},
#   {'Judge': 'Abby Pater',
#    'Tournament': 'Leopard Novice Cup',
#    'Date': '4/17/2017',
#    'Event': 'PF',
#    'Round Number': '5',
#    'Round Name': ' R5 ',
#    'Aff': 'Ro',
#    'Neg': 'DP',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 7-1'}],
#  'Abby Pater-DP-AW': [{'Judge': 'Abby Pater',
#    'Tournament': 'Leopard Novice Cup',
#    'Date': '4/17/2017',
#    'Event': 'PF',
#    'Round Number': '11',
#    'Round Name': ' R11 ',
#    'Aff': 'DP',
#    'Neg': 'AW',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 6-1'},
#   {'Judge': 'Abby Pater',
#    'Tournament': 'Leopard Novice Cup',
#    'Date': '4/17/2017',
#    'Event': 'PF',
#    'Round Number': '10',
#    'Round Name': ' R10 ',
#    'Aff': 'DP',
#    'Neg': 'AW',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 7-2'}],
#  'Ahmed Farrukh-Auburn NR-Montgomery TD': [{'Judge': 'Ahmed Farrukh',
#    'Tournament': 'Alabama State Tournament',
#    'Date': '4/11/2019',
#    'Event': 'NLD',
#    'Round Number': '6',
#    'Round Name': ' Semis ',
#    'Aff': 'Auburn NR',
#    'Neg': 'Montgomery TD',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 3-0'},
#   {'Judge': 'Ahmed Farrukh',
#    'Tournament': 'The Betty Gunn Invitational at Mountain Brook High School',
#    'Date': '2/1/2019',
#    'Event': 'NLD',
#    'Round Number': '8',
#    'Round Name': ' F ',
#    'Aff': 'Auburn NR',
#    'Neg': 'Montgomery TD',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 3-0'}],
#  'Ahmed Farrukh-Westminster Christian ES-Altamont WF': [{'Judge': 'Ahmed Farrukh',
#    'Tournament': 'Alabama State Tournament',
#    'Date': '2/15/2018',
#    'Event': 'VLD',
#    'Round Number': '3',
#    'Round Name': ' R3 ',
#    'Aff': 'Westminster Christian ES',
#    'Neg': 'Altamont WF',
#    'Decision': 'Aff',
#    'Panel': ''},
#   {'Judge': 'Ahmed Farrukh',
#    'Tournament': 'The Betty Gunn Invitational at Mountain Brook High School',
#    'Date': '2/2/2018',
#    'Event': 'VLD',
#    'Round Number': '4',
#    'Round Name': ' R4 ',
#    'Aff': 'Westminster Christian ES',
#    'Neg': 'Altamont WF',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Abi Glaum-Fort Atkinson TK-Brookfield Central HR': [{'Judge': 'Abi Glaum',
#    'Tournament': 'WDCA Pref Sandbox',
#    'Date': '1/18/2020',
#    'Event': 'NCX',
#    'Round Number': '6',
#    'Round Name': ' R6 ',
#    'Aff': 'Fort Atkinson TK',
#    'Neg': 'Brookfield Central HR',
#    'Decision': 'Aff',
#    'Panel': ''},
#   {'Judge': 'Abi Glaum',
#    'Tournament': 'The Wisconsin State Debate Tournament',
#    'Date': '1/18/2020',
#    'Event': 'NCX',
#    'Round Number': '6',
#    'Round Name': ' R6 ',
#    'Aff': 'Fort Atkinson TK',
#    'Neg': 'Brookfield Central HR',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Abi Glaum-La Crosse Central SE-Brookfield East SR': [{'Judge': 'Abi Glaum',
#    'Tournament': 'WDCA Pref Sandbox',
#    'Date': '1/18/2020',
#    'Event': 'NCX',
#    'Round Number': '4',
#    'Round Name': ' R4 ',
#    'Aff': 'La Crosse Central SE',
#    'Neg': 'Brookfield East SR',
#    'Decision': 'Neg',
#    'Panel': ''},
#   {'Judge': 'Abi Glaum',
#    'Tournament': 'The Wisconsin State Debate Tournament',
#    'Date': '1/18/2020',
#    'Event': 'NCX',
#    'Round Number': '4',
#    'Round Name': ' R4 ',
#    'Aff': 'La Crosse Central SE',
#    'Neg': 'Brookfield East SR',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Abi Glaum-Fort Atkinson BH-La Crosse Central CR': [{'Judge': 'Abi Glaum',
#    'Tournament': 'WDCA Pref Sandbox',
#    'Date': '1/18/2020',
#    'Event': 'NCX',
#    'Round Number': '3',
#    'Round Name': ' R3 ',
#    'Aff': 'Fort Atkinson BH',
#    'Neg': 'La Crosse Central CR',
#    'Decision': 'Aff',
#    'Panel': ''},
#   {'Judge': 'Abi Glaum',
#    'Tournament': 'The Wisconsin State Debate Tournament',
#    'Date': '1/18/2020',
#    'Event': 'NCX',
#    'Round Number': '3',
#    'Round Name': ' R3 ',
#    'Aff': 'Fort Atkinson BH',
#    'Neg': 'La Crosse Central CR',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Abhishek Pratap--': [{'Judge': 'Abhishek Pratap',
#    'Tournament': 'Sartartia Debate Club Workshops Tournament',
#    'Date': '4/25/2019',
#    'Event': 'LD',
#    'Round Number': '3',
#    'Round Name': ' R3 ',
#    'Aff': '',
#    'Neg': '',
#    'Decision': 'Neg',
#    'Panel': ''},
#   {'Judge': 'Abhishek Pratap',
#    'Tournament': 'Sartartia Debate Club Workshops Tournament',
#    'Date': '4/25/2019',
#    'Event': 'LD',
#    'Round Number': '1',
#    'Round Name': ' R1 ',
#    'Aff': '',
#    'Neg': '',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Abigail Hodges-La Crosse Central BT-Homestead KW': [{'Judge': 'Abigail Hodges',
#    'Tournament': 'The Wisconsin State Debate Tournament',
#    'Date': '1/18/2020',
#    'Event': 'VCX',
#    'Round Number': '9',
#    'Round Name': ' Semi ',
#    'Aff': 'La Crosse Central BT',
#    'Neg': 'Homestead KW',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 3-0'},
#   {'Judge': 'Abigail Hodges',
#    'Tournament': 'WDCA Pref Sandbox',
#    'Date': '1/18/2020',
#    'Event': 'VCX',
#    'Round Number': '9',
#    'Round Name': ' Semi ',
#    'Aff': 'La Crosse Central BT',
#    'Neg': 'Homestead KW',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 3-0'}],
#  'Abigail Hodges-Neenah PF-Ronald Reagan  ZR': [{'Judge': 'Abigail Hodges',
#    'Tournament': 'The Wisconsin State Debate Tournament',
#    'Date': '1/18/2020',
#    'Event': 'VCX',
#    'Round Number': '5',
#    'Round Name': ' R5 ',
#    'Aff': 'Neenah PF',
#    'Neg': 'Ronald Reagan  ZR',
#    'Decision': 'Aff',
#    'Panel': ''},
#   {'Judge': 'Abigail Hodges',
#    'Tournament': 'WDCA Pref Sandbox',
#    'Date': '1/18/2020',
#    'Event': 'VCX',
#    'Round Number': '5',
#    'Round Name': ' R5 ',
#    'Aff': 'Neenah PF',
#    'Neg': 'Ronald Reagan  ZR',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Alyson Brusie-Brooklyn Technical QC-Marist VL': [{'Judge': 'Alyson Brusie',
#    'Tournament': 'Nova Titan Invitational',
#    'Date': '10/10/2020',
#    'Event': 'VPF',
#    'Round Number': '9',
#    'Round Name': ' Quarte ',
#    'Aff': 'Brooklyn Technical QC',
#    'Neg': 'Marist VL',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 2-1'},
#   {'Judge': 'Alyson Brusie',
#    'Tournament': 'Nova Titan Invitational',
#    'Date': '10/10/2020',
#    'Event': 'VPF',
#    'Round Number': '4',
#    'Round Name': ' R4 ',
#    'Aff': 'Brooklyn Technical QC',
#    'Neg': 'Marist VL',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Annalise Dillon-BCAcad PJ-Sehome JM': [{'Judge': 'Annalise Dillon',
#    'Tournament': 'Sedro Woolley 11th Annual Invitational',
#    'Date': '11/1/2019',
#    'Event': 'PF-O',
#    'Round Number': '4',
#    'Round Name': ' R4 ',
#    'Aff': 'BCAcad PJ',
#    'Neg': 'Sehome JM',
#    'Decision': 'Neg',
#    'Panel': ''},
#   {'Judge': 'Annalise Dillon',
#    'Tournament': 'Sedro Woolley 11th Annual Invitational',
#    'Date': '11/1/2019',
#    'Event': 'PF-O',
#    'Round Number': '3',
#    'Round Name': ' R3 ',
#    'Aff': 'BCAcad PJ',
#    'Neg': 'Sehome JM',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Adrian Pilkington-LinEas BX-Marian HK': [{'Judge': 'Adrian Pilkington',
#    'Tournament': 'Norfolk Roger Maxwell Debate Invitational',
#    'Date': '11/14/2020',
#    'Event': 'NPF',
#    'Round Number': '7',
#    'Round Name': ' Sems ',
#    'Aff': 'LinEas BX',
#    'Neg': 'Marian HK',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 3-0'},
#   {'Judge': 'Adrian Pilkington',
#    'Tournament': 'Norfolk Roger Maxwell Debate Invitational',
#    'Date': '11/14/2020',
#    'Event': 'NPF',
#    'Round Number': '3',
#    'Round Name': ' R3 ',
#    'Aff': 'LinEas BX',
#    'Neg': 'Marian HK',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Andrew Page-Millard North NW-Millard West NB': [{'Judge': 'Andrew Page',
#    'Tournament': 'Lincoln Northeast Space Race',
#    'Date': '1/19/2019',
#    'Event': 'OPF',
#    'Round Number': '7',
#    'Round Name': ' Finals ',
#    'Aff': 'Millard North NW',
#    'Neg': 'Millard West NB',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 3-0'},
#   {'Judge': 'Andrew Page',
#    'Tournament': 'Lincoln Northeast Space Race',
#    'Date': '1/19/2019',
#    'Event': 'OPF',
#    'Round Number': '4',
#    'Round Name': ' R4 ',
#    'Aff': 'Millard North NW',
#    'Neg': 'Millard West NB',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Annabelle Arney-Neenah IH-Brookfield East XG': [{'Judge': 'Annabelle Arney',
#    'Tournament': 'The Wisconsin State Debate Tournament',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '8',
#    'Round Name': ' Octo ',
#    'Aff': 'Neenah IH',
#    'Neg': 'Brookfield East XG',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 2-1'},
#   {'Judge': 'Annabelle Arney',
#    'Tournament': 'WDCA Pref Sandbox',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '7',
#    'Round Name': ' Octo ',
#    'Aff': 'Neenah IH',
#    'Neg': 'Brookfield East XG',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 2-1'}],
#  'Annabelle Arney-Brookfield East DW-Sussex Hamilton HS': [{'Judge': 'Annabelle Arney',
#    'Tournament': 'WDCA Pref Sandbox',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '5',
#    'Round Name': ' R5 ',
#    'Aff': 'Brookfield East DW',
#    'Neg': 'Sussex Hamilton HS',
#    'Decision': 'Neg',
#    'Panel': ''},
#   {'Judge': 'Annabelle Arney',
#    'Tournament': 'The Wisconsin State Debate Tournament',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '5',
#    'Round Name': ' R5 ',
#    'Aff': 'Brookfield East DW',
#    'Neg': 'Sussex Hamilton HS',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Audrey Demas-100-101': [{'Judge': 'Audrey Demas',
#    'Tournament': '2020 LIFA November Debate',
#    'Date': '11/21/2020',
#    'Event': 'LDTST',
#    'Round Number': '1',
#    'Round Name': ' Test ',
#    'Aff': '100',
#    'Neg': '101',
#    'Decision': 'Neg',
#    'Panel': 'Aff on a 6-3'},
#   {'Judge': 'Audrey Demas',
#    'Tournament': 'LIFA October Debate',
#    'Date': '10/24/2020',
#    'Event': 'LDTST',
#    'Round Number': '1',
#    'Round Name': ' Test ',
#    'Aff': '100',
#    'Neg': '101',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 4-2'}],
#  'Ben Schultz-Alpharetta HS BM-Chattahoochee JN': [{'Judge': 'Ben Schultz',
#    'Tournament': 'University of Michigan HS Debate Tournament',
# ...
#    'Panel': ''},
#   {'Judge': 'Henry Wehrs',
#    'Tournament': 'WDCA Pref Sandbox',
#    'Date': '1/18/2020',
#    'Event': 'NCX',
#    'Round Number': '2',
#    'Round Name': ' R2 ',
#    'Aff': 'Fort Atkinson SM',
#    'Neg': 'SPASH BV',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Hunter Martin-GBATH Manfredi & Huang-GBATH Sinclair & Lam': [{'Judge': 'Hunter Martin',
#    'Tournament': 'ISD Florida PF Tournament',
#    'Date': '7/26/2017',
#    'Event': 'PF',
#    'Round Number': '9',
#    'Round Name': ' Semis ',
#    'Aff': 'GBATH Manfredi & Huang',
#    'Neg': 'GBATH Sinclair & Lam',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 5-0'},
#   {'Judge': 'Hunter Martin',
#    'Tournament': 'ISD Florida PF Tournament',
#    'Date': '7/26/2017',
#    'Event': 'PF',
#    'Round Number': '5',
#    'Round Name': ' R5 ',
#    'Aff': 'GBATH Manfredi & Huang',
#    'Neg': 'GBATH Sinclair & Lam',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Hersh Pareek-Appleton East SM-Marquette Univ SL': [{'Judge': 'Hersh Pareek',
#    'Tournament': 'The Wisconsin State Debate Tournament',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '11',
#    'Round Name': ' Final ',
#    'Aff': 'Appleton East SM',
#    'Neg': 'Marquette Univ SL',
#    'Decision': 'Neg',
#    'Panel': 'Aff on a 3-2'},
#   {'Judge': 'Hersh Pareek',
#    'Tournament': 'WDCA Pref Sandbox',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '10',
#    'Round Name': ' Final ',
#    'Aff': 'Appleton East SM',
#    'Neg': 'Marquette Univ SL',
#    'Decision': 'Neg',
#    'Panel': 'Aff on a 3-2'}],
#  'Hersh Pareek-Sussex Hamilton MK-Marquette Univ SL': [{'Judge': 'Hersh Pareek',
#    'Tournament': 'The Wisconsin State Debate Tournament',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '10',
#    'Round Name': ' Semi ',
#    'Aff': 'Sussex Hamilton MK',
#    'Neg': 'Marquette Univ SL',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 2-1'},
#   {'Judge': 'Hersh Pareek',
#    'Tournament': 'WDCA Pref Sandbox',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '9',
#    'Round Name': ' Semi ',
#    'Aff': 'Sussex Hamilton MK',
#    'Neg': 'Marquette Univ SL',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 2-1'}],
#  'Hersh Pareek-Sussex Hamilton MK-Marquette Univ SP': [{'Judge': 'Hersh Pareek',
#    'Tournament': 'The Wisconsin State Debate Tournament',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '9',
#    'Round Name': ' Qtr ',
#    'Aff': 'Sussex Hamilton MK',
#    'Neg': 'Marquette Univ SP',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 3-0'},
#   {'Judge': 'Hersh Pareek',
#    'Tournament': 'WDCA Pref Sandbox',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '8',
#    'Round Name': ' Qtr ',
#    'Aff': 'Sussex Hamilton MK',
#    'Neg': 'Marquette Univ SP',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 3-0'}],
#  'Hersh Pareek-Brookfield East AK-Appleton East DP': [{'Judge': 'Hersh Pareek',
#    'Tournament': 'The Wisconsin State Debate Tournament',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '8',
#    'Round Name': ' Octo ',
#    'Aff': 'Brookfield East AK',
#    'Neg': 'Appleton East DP',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 3-0'},
#   {'Judge': 'Hersh Pareek',
#    'Tournament': 'WDCA Pref Sandbox',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '7',
#    'Round Name': ' Octo ',
#    'Aff': 'Brookfield East AK',
#    'Neg': 'Appleton East DP',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 3-0'}],
#  'Hersh Pareek-Appleton East JS-Brookfield East XG': [{'Judge': 'Hersh Pareek',
#    'Tournament': 'WDCA Pref Sandbox',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '6',
#    'Round Name': ' R6 ',
#    'Aff': 'Appleton East JS',
#    'Neg': 'Brookfield East XG',
#    'Decision': 'Neg',
#    'Panel': ''},
#   {'Judge': 'Hersh Pareek',
#    'Tournament': 'The Wisconsin State Debate Tournament',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '6',
#    'Round Name': ' R6 ',
#    'Aff': 'Appleton East JS',
#    'Neg': 'Brookfield East XG',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Hersh Pareek-Sussex Hamilton MK-Appleton East DP': [{'Judge': 'Hersh Pareek',
#    'Tournament': 'The Wisconsin State Debate Tournament',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '5',
#    'Round Name': ' R5 ',
#    'Aff': 'Sussex Hamilton MK',
#    'Neg': 'Appleton East DP',
#    'Decision': 'Aff',
#    'Panel': ''},
#   {'Judge': 'Hersh Pareek',
#    'Tournament': 'WDCA Pref Sandbox',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '5',
#    'Round Name': ' R5 ',
#    'Aff': 'Sussex Hamilton MK',
#    'Neg': 'Appleton East DP',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Hersh Pareek-Neenah MO-Brookfield East DJ': [{'Judge': 'Hersh Pareek',
#    'Tournament': 'The Wisconsin State Debate Tournament',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '4',
#    'Round Name': ' R4 ',
#    'Aff': 'Neenah MO',
#    'Neg': 'Brookfield East DJ',
#    'Decision': 'Aff',
#    'Panel': ''},
#   {'Judge': 'Hersh Pareek',
#    'Tournament': 'WDCA Pref Sandbox',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '4',
#    'Round Name': ' R4 ',
#    'Aff': 'Neenah MO',
#    'Neg': 'Brookfield East DJ',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Hersh Pareek-Appleton East SM-Brookfield East NT': [{'Judge': 'Hersh Pareek',
#    'Tournament': 'The Wisconsin State Debate Tournament',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '4',
#    'Round Name': ' R4 ',
#    'Aff': 'Appleton East SM',
#    'Neg': 'Brookfield East NT',
#    'Decision': 'Aff',
#    'Panel': ''},
#   {'Judge': 'Hersh Pareek',
#    'Tournament': 'WDCA Pref Sandbox',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '4',
#    'Round Name': ' R4 ',
#    'Aff': 'Appleton East SM',
#    'Neg': 'Brookfield East NT',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Hersh Pareek-Brookfield East MK-Bradley Tech AC': [{'Judge': 'Hersh Pareek',
#    'Tournament': 'The Wisconsin State Debate Tournament',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '2',
#    'Round Name': ' R2 ',
#    'Aff': 'Brookfield East MK',
#    'Neg': 'Bradley Tech AC',
#    'Decision': 'Aff',
#    'Panel': ''},
#   {'Judge': 'Hersh Pareek',
#    'Tournament': 'WDCA Pref Sandbox',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '2',
#    'Round Name': ' R2 ',
#    'Aff': 'Brookfield East MK',
#    'Neg': 'Bradley Tech AC',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Hersh Pareek-Bradley Tech JH-Sussex Hamilton RP': [{'Judge': 'Hersh Pareek',
#    'Tournament': 'WDCA Pref Sandbox',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '2',
#    'Round Name': ' R2 ',
#    'Aff': 'Bradley Tech JH',
#    'Neg': 'Sussex Hamilton RP',
#    'Decision': 'Neg',
#    'Panel': ''},
#   {'Judge': 'Hersh Pareek',
#    'Tournament': 'The Wisconsin State Debate Tournament',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '2',
#    'Round Name': ' R2 ',
#    'Aff': 'Bradley Tech JH',
#    'Neg': 'Sussex Hamilton RP',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Hersh Pareek-Bradley Tech AP-Marquette Univ DM': [{'Judge': 'Hersh Pareek',
#    'Tournament': 'WDCA Pref Sandbox',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '1',
#    'Round Name': ' R1 ',
#    'Aff': 'Bradley Tech AP',
#    'Neg': 'Marquette Univ DM',
#    'Decision': 'Neg',
#    'Panel': ''},
#   {'Judge': 'Hersh Pareek',
#    'Tournament': 'The Wisconsin State Debate Tournament',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '1',
#    'Round Name': ' R1 ',
#    'Aff': 'Bradley Tech AP',
#    'Neg': 'Marquette Univ DM',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Haritha Sigili-Lambert MS-Johns Creek BG': [{'Judge': 'Haritha Sigili',
#    'Tournament': 'Peach State Classic',
#    'Date': '11/13/2020',
#    'Event': 'VPF',
#    'Round Number': '8',
#    'Round Name': ' Quarte ',
#    'Aff': 'Lambert MS',
#    'Neg': 'Johns Creek BG',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 2-1'},
#   {'Judge': 'Haritha Sigili',
#    'Tournament': 'Peach State Classic',
#    'Date': '11/13/2020',
#    'Event': 'VPF',
#    'Round Number': '5',
#    'Round Name': ' R5 ',
#    'Aff': 'Lambert MS',
#    'Neg': 'Johns Creek BG',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Hannah Jacobsen-Harm-Saline BY-Skyline HS KK': [{'Judge': 'Hannah Jacobsen-Harm',
#    'Tournament': 'University of Michigan HS Debate Tournament',
#    'Date': '10/30/2019',
#    'Event': 'NPF',
#    'Round Number': '6',
#    'Round Name': ' Quarte ',
#    'Aff': 'Saline BY',
#    'Neg': 'Skyline HS KK',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 2-1'},
#   {'Judge': 'Hannah Jacobsen-Harm',
#    'Tournament': 'University of Michigan HS Debate Tournament',
#    'Date': '10/30/2019',
#    'Event': 'NPF',
#    'Round Number': '4',
#    'Round Name': ' R4 ',
#    'Aff': 'Saline BY',
#    'Neg': 'Skyline HS KK',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Hanming Sun-CloCloud International Kim & Eappen-CloCloud International Gupta & Gautam': [{'Judge': 'Hanming Sun',
#    'Tournament': 'Ivy Bridge Academy Summer Slam',
#    'Date': '6/3/2020',
#    'Event': 'PF',
#    'Round Number': '6',
#    'Round Name': ' F ',
#    'Aff': 'CloCloud International Kim & Eappen',
#    'Neg': 'CloCloud International Gupta & Gautam',
#    'Decision': 'Aff',
#    'Panel': 'Neg on a 8-5'},
#   {'Judge': 'Hanming Sun',
#    'Tournament': 'Ivy Bridge Academy Summer Slam',
#    'Date': '6/3/2020',
#    'Event': 'PF',
#    'Round Number': '1',
#    'Round Name': ' R1 ',
#    'Aff': 'CloCloud International Kim & Eappen',
#    'Neg': 'CloCloud International Gupta & Gautam',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 3-0'}],
#  'Heath Reinl-Brookfield East AK-Marquette Univ SL': [{'Judge': 'Heath Reinl',
#    'Tournament': 'The Wisconsin State Debate Tournament',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '9',
#    'Round Name': ' Qtr ',
#    'Aff': 'Brookfield East AK',
#    'Neg': 'Marquette Univ SL',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 3-0'},
#   {'Judge': 'Heath Reinl',
#    'Tournament': 'WDCA Pref Sandbox',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '8',
#    'Round Name': ' Qtr ',
#    'Aff': 'Brookfield East AK',
#    'Neg': 'Marquette Univ SL',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 3-0'}],
#  'Heath Reinl-Appleton East JS-Marquette Univ DM': [{'Judge': 'Heath Reinl',
#    'Tournament': 'The Wisconsin State Debate Tournament',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '8',
#    'Round Name': ' Octo ',
#    'Aff': 'Appleton East JS',
#    'Neg': 'Marquette Univ DM',
#    'Decision': 'Aff',
#    'Panel': 'Neg on a 2-1'},
#   {'Judge': 'Heath Reinl',
#    'Tournament': 'WDCA Pref Sandbox',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '7',
#    'Round Name': ' Octo ',
#    'Aff': 'Appleton East JS',
#    'Neg': 'Marquette Univ DM',
#    'Decision': 'Aff',
#    'Panel': 'Neg on a 2-1'}],
#  'Heath Reinl-Appleton East OS-Whitefish Bay AH': [{'Judge': 'Heath Reinl',
#    'Tournament': 'The Wisconsin State Debate Tournament',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '6',
#    'Round Name': ' R6 ',
#    'Aff': 'Appleton East OS',
#    'Neg': 'Whitefish Bay AH',
#    'Decision': 'Neg',
#    'Panel': ''},
#   {'Judge': 'Heath Reinl',
#    'Tournament': 'WDCA Pref Sandbox',
#    'Date': '1/18/2020',
#    'Event': 'LD',
#    'Round Number': '6',
#    'Round Name': ' R6 ',
#    'Aff': 'Appleton East OS',
#    'Neg': 'Whitefish Bay AH',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Hayden Harper-Foothill AS-Mountain Brook HB': [{'Judge': 'Hayden Harper',
#    'Tournament': 'Peach State Classic',
#    'Date': '11/13/2020',
#    'Event': 'VPF',
#    'Round Number': '8',
#    'Round Name': ' Quarte ',
#    'Aff': 'Foothill AS',
#    'Neg': 'Mountain Brook HB',
#    'Decision': 'Neg',
#    'Panel': 'Aff on a 2-1'},
#   {'Judge': 'Hayden Harper',
#    'Tournament': 'Peach State Classic',
#    'Date': '11/13/2020',
#    'Event': 'VPF',
#    'Round Number': '5',
#    'Round Name': ' R5 ',
#    'Aff': 'Foothill AS',
#    'Neg': 'Mountain Brook HB',
#    'Decision': 'Aff',
#    'Panel': ''}],
#  'Hayden Harper-Myers Park RT-Independent RF': [{'Judge': 'Hayden Harper',
#    'Tournament': 'The Debate In Idaho Invitational',
#    'Date': '5/8/2020',
#    'Event': '',
#    'Round Number': '6',
#    'Round Name': ' Quarte ',
#    'Aff': 'Myers Park RT',
#    'Neg': 'Independent RF',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 3-0'},
#   {'Judge': 'Hayden Harper',
#    'Tournament': 'The Debate In Idaho Invitational',
#    'Date': '5/8/2020',
#    'Event': '',
#    'Round Number': '1',
#    'Round Name': ' R1 ',
#    'Aff': 'Myers Park RT',
#    'Neg': 'Independent RF',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Izak Dunn-UNLV Aguilar & Warren-Southern California Kuffour & Wang': [{'Judge': 'Izak Dunn',
#    'Tournament': 'D1 Pacific Championship',
#    'Date': '2/23/2019',
#    'Event': 'OPol',
#    'Round Number': '8',
#    'Round Name': ' Semis ',
#    'Aff': 'UNLV Aguilar & Warren',
#    'Neg': 'Southern California Kuffour & Wang',
#    'Decision': 'Aff',
#    'Panel': 'Aff on a 2-1'},
#   {'Judge': 'Izak Dunn',
#    'Tournament': 'Winter at the Beach',
#    'Date': '1/25/2019',
#    'Event': 'OCX',
#    'Round Number': '8',
#    'Round Name': ' Semi ',
#    'Aff': 'UNLV Aguilar & Warren',
#    'Neg': 'Southern California Kuffour & Wang',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 2-1'}],
#  'Izak Dunn-Southern California Kuffour & Wang-UNLV Aguilar & Warren': [{'Judge': 'Izak Dunn',
#    'Tournament': 'D1 Pacific Championship',
#    'Date': '2/23/2019',
#    'Event': 'OPol',
#    'Round Number': '3',
#    'Round Name': ' R3 ',
#    'Aff': 'Southern California Kuffour & Wang',
#    'Neg': 'UNLV Aguilar & Warren',
#    'Decision': 'Neg',
#    'Panel': ''},
#   {'Judge': 'Izak Dunn',
#    'Tournament': 'Winter at the Beach',
#    'Date': '1/25/2019',
#    'Event': 'OCX',
#    'Round Number': '5',
#    'Round Name': ' R5 ',
#    'Aff': 'Southern California Kuffour & Wang',
#    'Neg': 'UNLV Aguilar & Warren',
#    'Decision': 'Neg',
#    'Panel': ''}],
#  'Ian Beier-Peninsula TW-New Trier BW': [{'Judge': 'Ian Beier',
#    'Tournament': 'National Debate Coaches Association National Championships',
#    'Date': '4/8/2017',
#    'Event': 'POL',
#    'Round Number': '6',
#    'Round Name': ' R6 ',
#    'Aff': 'Peninsula TW',
#    'Neg': 'New Trier BW',
#    'Decision': 'Aff',
#    'Panel': ''},
#   {'Judge': 'Ian Beier',
#    'Tournament': '2016 Glenbrooks Speech and Debate Tournament',
#    'Date': '11/19/2016',
#    'Event': 'VCX',
#    'Round Number': '10',
#    'Round Name': ' Qtrs ',
#    'Aff': 'Peninsula TW',
#    'Neg': 'New Trier BW',
#    'Decision': 'Neg',
#    'Panel': 'Aff on a 2-1'}],
#  'Ignacio Evans-Louisville BY-Kansas BD': [{'Judge': 'Ignacio Evans',
#    'Tournament': 'Cal Swing 2',
#    'Date': '1/7/2020',
#    'Event': 'Open',
#    'Round Number': '7',
#    'Round Name': ' Quarte ',
#    'Aff': 'Louisville BY',
#    'Neg': 'Kansas BD',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 3-0'},
#   {'Judge': 'Ignacio Evans',
#    'Tournament': 'CEDA Nationals Long Beach',
#    'Date': '4/4/2019',
#    'Event': 'Open',
#    'Round Number': '14',
#    'Round Name': ' Quarte ',
#    'Aff': 'Louisville BY',
#    'Neg': 'Kansas BD',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 4-1'}],
#  'Ignacio Evans-Rutger AH-Louisv BY': [{'Judge': 'Ignacio Evans',
#    'Tournament': '7th Mukai College Classic',
#    'Date': '10/5/2019',
#    'Event': 'O',
#    'Round Number': '6',
#    'Round Name': ' R6 ',
#    'Aff': 'Rutger AH',
#    'Neg': 'Louisv BY',
#    'Decision': 'Neg',
#    'Panel': ''},
#   {'Judge': 'Ignacio Evans',
#    'Tournament': '6th Mukai College Classic',
#    'Date': '9/28/2018',
#    'Event': 'O',
#    'Round Number': '10',
#    'Round Name': ' Q ',
#    'Aff': 'Rutger AH',
#    'Neg': 'Louisv BY',
#    'Decision': 'Neg',
#    'Panel': 'Neg on a 3-0'}],
#  'Ignacio Evans-Kansas HR-Oklahoma CY': [{'Judge': 'Ignacio Evans',
#    'Tournament': 'CEDA Nationals  Wichita State',
#    'Date': '3/20/2015',
#    'Event': 'Open',
#    'Round Number': '13',
#    'Round Name': ' Semi ',
#    'Aff': 'Kansas HR',
#    'Neg': 'Oklahoma CY',
#    'Decision': 'Neg',
#    'Panel': 'Aff on a 4-1'},
#   {'Judge': 'Ignacio Evans',
#    'Tournament': 'CEDA Nationals  Wichita State',
#    'Date': '3/20/2015',
#    'Event': 'Open',
#    'Round Number': '13',
#    'Round Name': ' Semi ',
#    'Aff': 'Kansas HR',
#    'Neg': 'Oklahoma CY',
#    'Decision': 'Neg',
#    'Panel': 'Aff on a 4-1'}]}
