# %% [markdown]
# Wiki Scraper
# ---
#
# Author: Peter Zhang
#
# Scraping tool for the Wiki.

# %% [markdown]
# ### Setup
#
# #### Imports

# %%
# imports
import urllib.request, urllib.parse, urllib.error
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import csv
import os.path
from os import path
import re

# %% [markdown]
# #### Settings
#
# - OVERWRITE determines whether or not to update existing files.
# - PAGES_URL is a list of Wiki pages
# - OUTPATH is where files are stored

# %%
# settings
OVERWRITE = False

# %%
# get page URLs
WIKIS_URL = "tools/wiki_pages.csv"
WIKIS = [row for row in csv.reader(open(WIKIS_URL, 'r'))]

# %%
# outpath
OUTPATH = "wiki_data/"

# %% [markdown]
# ### Scrapers
#
# #### Wiki Page
#
# Take the URL to a wiki page and returns a list of all the school names and their respective URLs.

# %%
# for a given archive year, return all schools
def getSchools(url):
    
    # try opening URL
    try:
        html = urlopen(url).read()
    except Exeption:
        print("Wiki URL broke")
        return []
    
    
    # soupify
    soup = BeautifulSoup(html, "html.parser")
    
    # find all links
    links = soup.find_all('a')
    
    # find only school links
    links = [link for link in links if "(" in link.text and ")" in link.text]
    
    # get link text and URL
    schools = [[link.text, link.get('href')] for link in links]

    return schools

# %%
getSchools("https://hspolicy19.debatecoaches.org/")
# Out:
# [['Advanced Technologies Academy (NV)', '/Advanced%20Technologies%20Academy/'],
#  ['Airline (AL)', '/Airline/'],
#  ['Aledo (TX)', '/Aledo/'],
#  ['Alief Taylor (TX)', '/Alief%20Taylor/'],
#  ['Alpharetta (GA)', '/Alpharetta/'],
#  ['Altamont (AL)', '/Altamont/'],
#  ['American Heritage (FL)', '/American%20Heritage/'],
#  ['Anderson (TX)', '/Anderson/'],
#  ['Andover (KS)', '/Andover/'],
#  ['Andover Central (KS)', '/Andover%20Central/'],
#  ['Andrews (TX)', '/Andrews/'],
#  ['Archbishop Mitty (CA)', '/Archbishop%20Mitty/'],
#  ['Ashland (OR)', '/Ashland/'],
#  ['Asian Debate League (AK)', '/Asian%20Debate%20League/'],
#  ['Athens (TX)', '/Athens/'],
#  ['Aubrey (TX)', '/Aubrey/'],
#  ['BASIS Chandler (AZ)', '/BASIS%20Chandler/'],
#  ['BASIS Peoria (AZ)', '/BASIS%20Peoria/'],
#  ['BASIS Shavano (TX)', '/BASIS%20Shavano/'],
#  ['Bakersfield (CA)', '/Bakersfield/'],
#  ['Baltimore City College (MD)', '/Baltimore%20City%20College/'],
#  ['Barstow (MO)', '/Barstow/'],
#  ['Baton Rouge Magnet (LA)', '/Baton%20Rouge%20Magnet/'],
#  ['Bellarmine (CA)', '/Bellarmine/'],
#  ['Benjamin Tasker (MD)', '/Benjamin%20Tasker/'],
#  ['Bentonville (AR)', '/Bentonville/'],
#  ['Bentonville West (AR)', '/Bentonville%20West/'],
#  ['Berkeley Prep (FL)', '/Berkeley%20Prep/'],
#  ['Bingham (UT)', '/Bingham/'],
#  ['Blue Springs South (MO)', '/Blue%20Springs%20South/'],
#  ['Blue Valley (KS)', '/Blue%20Valley/'],
#  ['Blue Valley North (KS)', '/Blue%20Valley%20North/'],
#  ['Blue Valley Northwest (KS)', '/Blue%20Valley%20Northwest/'],
#  ['Blue Valley Southwest (KS)', '/Blue%20Valley%20Southwest/'],
#  ['Blue Valley West (KS)', '/Blue%20Valley%20West/'],
#  ['Bolivar (MO)', '/Bolivar/'],
#  ['Boston Latin Academy (MA)', '/Boston%20Latin%20Academy/'],
#  ['Bowie (MD)', '/Bowie/'],
#  ['Branham (CA)', '/Branham/'],
#  ['Bravo (CA)', '/Bravo/'],
#  ['Bronx Science (NY)', '/Bronx%20Science/'],
#  ['Brooke (MA)', '/Brooke/'],
#  ['Brooklyn Technical (NY)', '/Brooklyn%20Technical/'],
#  ['Buhler (KS)', '/Buhler/'],
#  ['CHAMPS (CA)', '/CHAMPS/'],
#  ['CK McClatchy (CA)', '/CK%20McClatchy/'],
#  ['Cabot (AR)', '/Cabot/'],
#  ['Caddo Magnet (LA)', '/Caddo%20Magnet/'],
#  ['Calhoun (GA)', '/Calhoun/'],
#  ['Calvert Hall (MD)', '/Calvert%20Hall/'],
#  ['Cambridge (GA)', '/Cambridge/'],
#  ['Canyon Crest (CA)', '/Canyon%20Crest/'],
#  ['Capital City (DC)', '/Capital%20City/'],
#  ['Carlsbad (CA)', '/Carlsbad/'],
#  ['Carmel Valley Independent (CA)', '/Carmel%20Valley%20Independent/'],
#  ['Carrollton Sacred Heart (FL)', '/Carrollton%20Sacred%20Heart/'],
#  ['Carthage (MO)', '/Carthage/'],
#  ['Casady (OK)', '/Casady/'],
#  ['Cathedral Prep (PA)', '/Cathedral%20Prep/'],
#  ['Cedar Rapids Washington (IA)', '/Cedar%20Rapids%20Washington/'],
#  ['Century (ID)', '/Century/'],
#  ['Chaminade (CA)', '/Chaminade/'],
#  ['Champion (TX)', '/Champion/'],
#  ['Charlestown (MA)', '/Charlestown/'],
#  ['Charlotte Catholic (NC)', '/Charlotte%20Catholic/'],
#  ['Charter School Of Wilmington (DE)', '/Charter%20School%20Of%20Wilmington/'],
#  ['Chattahoochee (GA)', '/Chattahoochee/'],
#  ['Chesterton (IN)', '/Chesterton/'],
#  ['Children Of Per Bear (FL)', '/Children%20Of%20Per%20Bear/'],
#  ['China Spring (TX)', '/China%20Spring/'],
#  ['Clackamas (OR)', '/Clackamas/'],
#  ['Classical Academy (CA)', '/Classical%20Academy/'],
#  ['Cleveland (OR)', '/Cleveland/'],
#  ['College Prep (CA)', '/College%20Prep/'],
#  ['Colleyville Heritage (TX)', '/Colleyville%20Heritage/'],
#  ['Connally (TX)', '/Connally/'],
#  ['Coppell (TX)', '/Coppell/'],
#  ['Coppell Ninth (TX)', '/Coppell%20Ninth/'],
#  ['Copper Hills (UT)', '/Copper%20Hills/'],
#  ['Coronado (NV)', '/Coronado/'],
#  ['Crenshaw (CA)', '/Crenshaw/'],
#  ['Crossings Christian School (AL)', '/Crossings%20Christian%20School/'],
#  ['Cueva (NM)', '/Cueva/'],
#  ['Cypress Bay (FL)', '/Cypress%20Bay/'],
#  ['Cypress Woods (TX)', '/Cypress%20Woods/'],
#  ['DC International (DC)', '/DC%20International/'],
#  ['DMV INDEPENDENT (DC)', '/DMV%20INDEPENDENT/'],
#  ['Dallas TAG Magnet (TX)', '/Dallas%20TAG%20Magnet/'],
#  ['Damien (CA)', '/Damien/'],
#  ['Davidson (NV)', '/Davidson/'],
#  ['Davis (UT)', '/Davis/'],
#  ['Davis Senior (CA)', '/Davis%20Senior/'],
#  ['Dawson (TX)', '/Dawson/'],
#  ['DeBakey (TX)', '/DeBakey/'],
#  ['Decatur (GA)', '/Decatur/'],
#  ['Delbarton School (NJ)', '/Delbarton%20School/'],
#  ['Denver Center For International Studies (CO)',
#   '/Denver%20Center%20For%20International%20Studies/'],
#  ['Denver East (CO)', '/Denver%20East/'],
#  ['Derby (KS)', '/Derby/'],
#  ['Desert Vista (AZ)', '/Desert%20Vista/'],
#  ['Detroit Country Day (MI)', '/Detroit%20Country%20Day/'],
#  ['Dougherty Valley (CA)', '/Dougherty%20Valley/'],
#  ['Douglas (SD)', '/Douglas/'],
#  ['Dowling (IA)', '/Dowling/'],
#  ['Downtown College Prep (CA)', '/Downtown%20College%20Prep/'],
#  ['Downtown Magnets (CA)', '/Downtown%20Magnets/'],
#  ['Drew Charter (GA)', '/Drew%20Charter/'],
#  ['Dripping Springs (TX)', '/Dripping%20Springs/'],
#  ['Druid Hills (GA)', '/Druid%20Hills/'],
#  ['DuVal (MD)', '/DuVal/'],
#  ['Dulles (TX)', '/Dulles/'],
#  ['Durham (NC)', '/Durham/'],
#  ['Duval (MD)', '/Duval/'],
#  ['Eagan (MN)', '/Eagan/'],
#  ['Eagle (ID)', '/Eagle/'],
#  ['Eaglecrest (CO)', '/Eaglecrest/'],
#  ['Eastlake (WA)', '/Eastlake/'],
#  ['Eastside (WA)', '/Eastside/'],
#  ['Edgemont (NY)', '/Edgemont/'],
#  ['Edina (MN)', '/Edina/'],
#  ['Eisenhower (KS)', '/Eisenhower/'],
#  ['Elizabeth LC (CA)', '/Elizabeth%20LC/'],
#  ['Emporia (KS)', '/Emporia/'],
#  ['Evanston (IL)', '/Evanston/'],
#  ['Fairview (CO)', '/Fairview/'],
#  ['Farmington (MN)', '/Farmington/'],
#  ['Ferris (WA)', '/Ferris/'],
#  ['Fort Collins (CO)', '/Fort%20Collins/'],
#  ['Fox Chapel (PA)', '/Fox%20Chapel/'],
#  ['Fremont (CA)', '/Fremont/'],
#  ['Galloway (GA)', '/Galloway/'],
#  ['Galloway School (GA)', '/Galloway%20School/'],
#  ['Garfield (WA)', '/Garfield/'],
#  ['George Washington (CO)', '/George%20Washington/'],
#  ['Georgetown Day (DC)', '/Georgetown%20Day/'],
#  ['Gilman (MD)', '/Gilman/'],
#  ['Glenbrook North (IL)', '/Glenbrook%20North/'],
#  ['Glenbrook South (IL)', '/Glenbrook%20South/'],
#  ['Glendale (MO)', '/Glendale/'],
#  ['Grace (TX)', '/Grace/'],
#  ['Grand Rapids City (MI)', '/Grand%20Rapids%20City/'],
#  ['Grapevine (TX)', '/Grapevine/'],
#  ['Green Valley (NV)', '/Green%20Valley/'],
#  ['Greenhill (TX)', '/Greenhill/'],
#  ['Greenwood Lab School (MO)', '/Greenwood%20Lab%20School/'],
#  ['Groves (MI)', '/Groves/'],
#  ['Gulliver (FL)', '/Gulliver/'],
#  ['Gunn (CA)', '/Gunn/'],
#  ['Guyer (TX)', '/Guyer/'],
#  ['H H Dow (MI)', '/H%20H%20Dow/'],
#  ['Hamilton (AZ)', '/Hamilton/'],
#  ['Harbor Teacher Prep (CA)', '/Harbor%20Teacher%20Prep/'],
#  ['Harding Charter Prep (OK)', '/Harding%20Charter%20Prep/'],
#  ['Harker (CA)', '/Harker/'],
#  ['Harvard Westlake (CA)', '/Harvard%20Westlake/'],
#  ['Hawken (OH)', '/Hawken/'],
#  ['Hawknatius (OH)', '/Hawknatius/'],
#  ['Head Royce (CA)', '/Head%20Royce/'],
#  ['Hebron (TX)', '/Hebron/'],
#  ['Heights (TX)', '/Heights/'],
#  ['Hendrickson (TX)', '/Hendrickson/'],
#  ['Henry M Gunn (CA)', '/Henry%20M%20Gunn/'],
#  ['Henry W Grady (GA)', '/Henry%20W%20Grady/'],
#  ['Heritage Hall (OK)', '/Heritage%20Hall/'],
#  ['Highland (ID)', '/Highland/'],
#  ['Highland Park (MN)', '/Highland%20Park/'],
#  ['Highland Park Dallas (TX)', '/Highland%20Park%20Dallas/'],
#  ['Homestead (WI)', '/Homestead/'],
#  ['Hoover (OH)', '/Hoover/'],
#  ['Houston (TX)', '/Houston/'],
#  ['Houston Memorial (TX)', '/Houston%20Memorial/'],
#  ['Humanities And Arts (CA)', '/Humanities%20And%20Arts/'],
#  ['Hume Fogg (TN)', '/Hume%20Fogg/'],
#  ['Hunter College (NY)', '/Hunter%20College/'],
#  ['Hyattsville Independent (MD)', '/Hyattsville%20Independent/'],
#  ['Immaculate Heart (CA)', '/Immaculate%20Heart/'],
#  ['Independence Independent (TX)', '/Independence%20Independent/'],
#  ['Ingraham (WA)', '/Ingraham/'],
#  ['Inspired Teaching (DC)', '/Inspired%20Teaching/'],
#  ['Interlake (WA)', '/Interlake/'],
#  ['Iowa City City (IA)', '/Iowa%20City%20City/'],
#  ['Iowa City West (AL)', '/Iowa%20City%20West/'],
#  ['Irma Rangel YWLS (TX)', '/Irma%20Rangel%20YWLS/'],
#  ['Isidore Newman (LA)', '/Isidore%20Newman/'],
#  ['Jack C Hays (TX)', '/Jack%20C%20Hays/'],
#  ['Jackson (OH)', '/Jackson/'],
#  ['James Logan (CA)', '/James%20Logan/'],
#  ['James Madison (NY)', '/James%20Madison/'],
#  ['Jefferson City (MO)', '/Jefferson%20City/'],
#  ['Jenks (OK)', '/Jenks/'],
#  ['Jesuit Dallas (TX)', '/Jesuit%20Dallas/'],
#  ['John C Fremont (CA)', '/John%20C%20Fremont/'],
#  ['Johns Creek (GA)', '/Johns%20Creek/'],
#  ['Jones College Prep (IL)', '/Jones%20College%20Prep/'],
#  ['Josiah Quincy (MA)', '/Josiah%20Quincy/'],
#  ['Juan Diego (UT)', '/Juan%20Diego/'],
#  ['Juicewrld Intermediate (ID)', '/Juicewrld%20Intermediate/'],
#  ['KIPP San Francisco College Preparatory (CA)',
#   '/KIPP%20San%20Francisco%20College%20Preparatory/'],
#  ['KIS (MD)', '/KIS/'],
#  ['Kamiak (WA)', '/Kamiak/'],
#  ['Kapaun Mount Carmel (KS)', '/Kapaun%20Mount%20Carmel/'],
#  ['Kennedy (IL)', '/Kennedy/'],
#  ['Kent Denver (CO)', '/Kent%20Denver/'],
#  ['Kenwood (IL)', '/Kenwood/'],
#  ['Kerr (TX)', '/Kerr/'],
#  ['Kickapoo (MO)', '/Kickapoo/'],
#  ['Kinkaid (TX)', '/Kinkaid/'],
#  ['La Crosse Central (WI)', '/La%20Crosse%20Central/'],
#  ['La Cueva (NM)', '/La%20Cueva/'],
#  ['La Reina (CA)', '/La%20Reina/'],
#  ['La Salle College (PA)', '/La%20Salle%20College/'],
#  ['Lake City (ID)', '/Lake%20City/'],
#  ['Lake Travis (TX)', '/Lake%20Travis/'],
#  ['Lane Tech (IL)', '/Lane%20Tech/'],
#  ['Langham Creek (TX)', '/Langham%20Creek/'],
#  ['Lansing (KS)', '/Lansing/'],
#  ['Law Magnet (TX)', '/Law%20Magnet/'],
#  ['Lawrence (KS)', '/Lawrence/'],
#  ['Lawrence Free State (KS)', '/Lawrence%20Free%20State/'],
#  ['Lees Summit West (MO)', '/Lees%20Summit%20West/'],
#  ['Leland (CA)', '/Leland/'],
#  ['Leon M Goldstein (NY)', '/Leon%20M%20Goldstein/'],
#  ['Lewis And Clark (WA)', '/Lewis%20And%20Clark/'],
#  ['Lexington (MA)', '/Lexington/'],
#  ['Liberal Arts And Science Academy (TX)',
#   '/Liberal%20Arts%20And%20Science%20Academy/'],
#  ['Liberty (MO)', '/Liberty/'],
#  ['Lilburn (GA)', '/Lilburn/'],
#  ['Lincoln (OR)', '/Lincoln/'],
#  ['Lincoln CA (CA)', '/Lincoln%20CA/'],
#  ['Lincoln East (NE)', '/Lincoln%20East/'],
#  ['Lincoln North Star (NE)', '/Lincoln%20North%20Star/'],
#  ['Lincoln Park (IL)', '/Lincoln%20Park/'],
#  ['Lincoln Southeast (NE)', '/Lincoln%20Southeast/'],
#  ['Lindale (TX)', '/Lindale/'],
#  ['Lindblom (IL)', '/Lindblom/'],
#  ['Little Rock Central (AR)', '/Little%20Rock%20Central/'],
#  ['Lone Peak (UT)', '/Lone%20Peak/'],
#  ['Long Branch (NJ)', '/Long%20Branch/'],
#  ['Lovejoy (TX)', '/Lovejoy/'],
#  ['Lowell (CA)', '/Lowell/'],
#  ['Madison Central (MS)', '/Madison%20Central/'],
#  ['Madison East (WI)', '/Madison%20East/'],
#  ['Maine East (IL)', '/Maine%20East/'],
#  ['Maize (KS)', '/Maize/'],
#  ['Mamaroneck (NY)', '/Mamaroneck/'],
#  ['Manhattan (KS)', '/Manhattan/'],
#  ['Maplewood (MO)', '/Maplewood/'],
#  ['Marian (MI)', '/Marian/'],
#  ['Marquette (WI)', '/Marquette/'],
#  ['Maywood (CA)', '/Maywood/'],
#  ['McCormack (MA)', '/McCormack/'],
#  ['McDonogh (MD)', '/McDonogh/'],
#  ['McDonough (MD)', '/McDonough/'],
#  ['McDowell (PA)', '/McDowell/'],
#  ['McLain (OK)', '/McLain/'],
#  ['McQueen (NV)', '/McQueen/'],
#  ['Mckinney Boyd (TX)', '/Mckinney%20Boyd/'],
#  ['Melissa (TX)', '/Melissa/'],
#  ['Midland (MI)', '/Midland/'],
#  ['Midway Academy Of Fine Arts (TX)', '/Midway%20Academy%20Of%20Fine%20Arts/'],
#  ['Mill Valley (KS)', '/Mill%20Valley/'],
#  ['Millard North (NE)', '/Millard%20North/'],
#  ['Millard South (NE)', '/Millard%20South/'],
#  ['Millard West (NE)', '/Millard%20West/'],
#  ['Minneapolis South (MN)', '/Minneapolis%20South/'],
#  ['Minneapolis Washburn (MN)', '/Minneapolis%20Washburn/'],
#  ['Miramonte (CA)', '/Miramonte/'],
#  ['ModernBrain (CA)', '/ModernBrain/'],
#  ['Montgomery Bell (TN)', '/Montgomery%20Bell/'],
#  ['Montgomery Blair (MD)', '/Montgomery%20Blair/'],
#  ['Moore (OK)', '/Moore/'],
#  ['Mount Pleasant (TX)', '/Mount%20Pleasant/'],
#  ['Mount Vernon (AL)', '/Mount%20Vernon/'],
#  ['Mountain Brook (AL)', '/Mountain%20Brook/'],
#  ['Mountain House (CA)', '/Mountain%20House/'],
#  ['Nashua South (NH)', '/Nashua%20South/'],
#  ['Neenah (WI)', '/Neenah/'],
#  ['Nevada Union (CA)', '/Nevada%20Union/'],
#  ['Neville (LA)', '/Neville/'],
#  ['New Designs UP (CA)', '/New%20Designs%20UP/'],
#  ['New Mission (MA)', '/New%20Mission/'],
#  ['New Technology (CA)', '/New%20Technology/'],
#  ['New Trier (IL)', '/New%20Trier/'],
#  ['Newark Science (NJ)', '/Newark%20Science/'],
#  ['NewarkTech (NJ)', '/NewarkTech/'],
#  ['Newton (KS)', '/Newton/'],
#  ['Niles North (IL)', '/Niles%20North/'],
#  ['Niles West (IL)', '/Niles%20West/'],
#  ['Norman North (OK)', '/Norman%20North/'],
#  ['North Allegheny (PA)', '/North%20Allegheny/'],
#  ['North Broward Prep (FL)', '/North%20Broward%20Prep/'],
#  ['North Central (WA)', '/North%20Central/'],
#  ['North Liberty (IA)', '/North%20Liberty/'],
#  ['NorthStar (NJ)', '/NorthStar/'],
#  ['Northridge (UT)', '/Northridge/'],
#  ['Northside (IL)', '/Northside/'],
#  ['Northview (AL)', '/Northview/'],
#  ['Northwest (NV)', '/Northwest/'],
#  ['Northwest TX (TX)', '/Northwest%20TX/'],
#  ['Northwestern (MD)', '/Northwestern/'],
#  ['Northwood (CA)', '/Northwood/'],
#  ['Notre Dame (CA)', '/Notre%20Dame/'],
#  ['OBryant (MA)', '/OBryant/'],
#  ['Oak Grove (CA)', '/Oak%20Grove/'],
#  ['Oak Hall (FL)', '/Oak%20Hall/'],
#  ['Oak Hill (OR)', '/Oak%20Hill/'],
#  ['Oak Park River Forest (IL)', '/Oak%20Park%20River%20Forest/'],
#  ['Oakland Tech (CA)', '/Oakland%20Tech/'],
#  ['Oakton (VA)', '/Oakton/'],
#  ['Oakton Independent (VA)', '/Oakton%20Independent/'],
#  ['Okemos (MI)', '/Okemos/'],
#  ['Olathe East (KS)', '/Olathe%20East/'],
#  ['Olympia (FL)', '/Olympia/'],
#  ['Omaha Marian (NE)', '/Omaha%20Marian/'],
#  ['Oregon Episcopal School (OR)', '/Oregon%20Episcopal%20School/'],
#  ['Padre Pio Academy (OH)', '/Padre%20Pio%20Academy/'],
#  ['Palo Verde (NV)', '/Palo%20Verde/'],
#  ['Park Hill (MO)', '/Park%20Hill/'],
#  ['Park Hill South (MO)', '/Park%20Hill%20South/'],
#  ['Parkview (MO)', '/Parkview/'],
#  ['Parkview Magnet (AR)', '/Parkview%20Magnet/'],
#  ['Parkway (LA)', '/Parkway/'],
#  ['Peninsula (CA)', '/Peninsula/'],
#  ['Penn (IN)', '/Penn/'],
#  ['Perry (OH)', '/Perry/'],
#  ['Phoenix Country Day School (AZ)', '/Phoenix%20Country%20Day%20School/'],
#  ['Phoenix Military Academy (IL)', '/Phoenix%20Military%20Academy/'],
#  ['Pine Crest (FL)', '/Pine%20Crest/'],
#  ['Pine Crest School (FL)', '/Pine%20Crest%20School/'],
#  ['Piper (KS)', '/Piper/'],
#  ['Pittsburg (KS)', '/Pittsburg/'],
#  ['Pittsburgh Central Catholic (PA)', '/Pittsburgh%20Central%20Catholic/'],
#  ['Plano East (TX)', '/Plano%20East/'],
#  ['Plano West (TX)', '/Plano%20West/'],
#  ['Pocatello (ID)', '/Pocatello/'],
#  ['Poly Prep (NY)', '/Poly%20Prep/'],
#  ['Polytechnic (CA)', '/Polytechnic/'],
#  ['Port Of Los Angeles (CA)', '/Port%20Of%20Los%20Angeles/'],
#  ['Presentation (CA)', '/Presentation/'],
#  ['Princeton (TX)', '/Princeton/'],
#  ['Princeton NJ (NJ)', '/Princeton%20NJ/'],
#  ['Prosper (TX)', '/Prosper/'],
#  ['Providence (NC)', '/Providence/'],
#  ['Rancho (CA)', '/Rancho/'],
#  ['Rancho San Joaquin (CA)', '/Rancho%20San%20Joaquin/'],
#  ['RaymorePeculiar (MO)', '/RaymorePeculiar/'],
#  ['Reagan (TX)', '/Reagan/'],
#  ['Riverfield (OK)', '/Riverfield/'],
#  ['Riverwood (GA)', '/Riverwood/'],
#  ['Rock Springs (WY)', '/Rock%20Springs/'],
#  ['Rockdale County (GA)', '/Rockdale%20County/'],
#  ['Rocky Mountain (CO)', '/Rocky%20Mountain/'],
#  ['Roosevelt (MN)', '/Roosevelt/'],
#  ['Rosemont (CA)', '/Rosemont/'],
#  ['Rosemount (MN)', '/Rosemount/'],
#  ['Roseville (MN)', '/Roseville/'],
#  ['Roswell (GA)', '/Roswell/'],
#  ['Round Rock (TX)', '/Round%20Rock/'],
#  ['Rowland Hall (UT)', '/Rowland%20Hall/'],
#  ['Rufus King (WI)', '/Rufus%20King/'],
#  ['Rural Independent (KS)', '/Rural%20Independent/'],
#  ['SA Harlem North Central (NJ)', '/SA%20Harlem%20North%20Central/'],
#  ['SA Queens (NY)', '/SA%20Queens/'],
#  ['SLC West (UT)', '/SLC%20West/'],
#  ['SPASH (WI)', '/SPASH/'],
#  ['STEAM Legacy (CA)', '/STEAM%20Legacy/'],
#  ['SWW (DC)', '/SWW/'],
#  ['Saint Georges (WA)', '/Saint%20Georges/'],
#  ['Salem Hills (UT)', '/Salem%20Hills/'],
#  ['Shawnee Mission East (KS)', '/Shawnee%20Mission%20East/'],
#  ['Shawnee Mission North (KS)', '/Shawnee%20Mission%20North/'],
#  ['Shawnee Mission Northwest (KS)', '/Shawnee%20Mission%20Northwest/'],
#  ['Shawnee Mission South (KS)', '/Shawnee%20Mission%20South/'],
#  ['Shawnee Mission West (KS)', '/Shawnee%20Mission%20West/'],
#  ['Sidwell Friends (DC)', '/Sidwell%20Friends/'],
#  ['Silver Creek (CA)', '/Silver%20Creek/'],
#  ['Sioux Falls (SD)', '/Sioux%20Falls/'],
#  ['Sioux Falls Roosevelt (SD)', '/Sioux%20Falls%20Roosevelt/'],
#  ['Sky View (UT)', '/Sky%20View/'],
#  ['Skyline UT (UT)', '/Skyline%20UT/'],
#  ['Slocum (TX)', '/Slocum/'],
#  ['Solon (OH)', '/Solon/'],
#  ['Solorio (IL)', '/Solorio/'],
#  ['Sonoma Academy (CA)', '/Sonoma%20Academy/'],
#  ['South Eugene (OR)', '/South%20Eugene/'],
#  ['South Gate (CA)', '/South%20Gate/'],
#  ['Springfield Catholic (MO)', '/Springfield%20Catholic/'],
#  ['St Andrews Episcopal School (MS)', '/St%20Andrews%20Episcopal%20School/'],
#  ['St Francis (CA)', '/St%20Francis/'],
#  ['St Ignatius (OH)', '/St%20Ignatius/'],
#  ['St Marks (TX)', '/St%20Marks/'],
#  ['St Paul Central (MN)', '/St%20Paul%20Central/'],
#  ['Stanford Online (CA)', '/Stanford%20Online/'],
#  ['Stern MASS (CA)', '/Stern%20MASS/'],
#  ['Stockdale (CA)', '/Stockdale/'],
#  ['Strath Haven (PA)', '/Strath%20Haven/'],
#  ['Stuyvesant (NY)', '/Stuyvesant/'],
#  ['Success Academy Bronx (NY)', '/Success%20Academy%20Bronx/'],
#  ['Success Academy DP (NY)', '/Success%20Academy%20DP/'],
#  ['Success Academy Midtown West (NY)', '/Success%20Academy%20Midtown%20West/'],
#  ['Summit Christian Academy (MO)', '/Summit%20Christian%20Academy/'],
#  ['The Meadows School (NV)', '/The%20Meadows%20School/'],
#  ['Thomas Jefferson (VA)', '/Thomas%20Jefferson/'],
#  ['Thomas Kelly (IL)', '/Thomas%20Kelly/'],
#  ['Topeka (KS)', '/Topeka/'],
#  ['Trinity (TX)', '/Trinity/'],
#  ['Trinity Academy (KS)', '/Trinity%20Academy/'],
#  ['Truman (MO)', '/Truman/'],
#  ['Tuloso Midway (TX)', '/Tuloso%20Midway/'],
#  ['Tulsa Union (OK)', '/Tulsa%20Union/'],
#  ['U Chicago Lab (IL)', '/U%20Chicago%20Lab/'],
#  ['USN (TN)', '/USN/'],
#  ['Unionville (PA)', '/Unionville/'],
#  ['University (CA)', '/University/'],
#  ['University Hi (WA)', '/University%20Hi/'],
#  ['VHTPA (CA)', '/VHTPA/'],
#  ['VIP (CA)', '/VIP/'],
#  ['Valdosta (GA)', '/Valdosta/'],
#  ['Valle De Mill (KS)', '/Valle%20De%20Mill/'],
#  ['Valor (CA)', '/Valor/'],
#  ['Vespa College Prep (CA)', '/Vespa%20College%20Prep/'],
#  ['Village (TX)', '/Village/'],
#  ['Vista Ridge (TX)', '/Vista%20Ridge/'],
#  ['WB Ray (TX)', '/WB%20Ray/'],
#  ['Waco Midway (TX)', '/Waco%20Midway/'],
#  ['Wakeland (TX)', '/Wakeland/'],
#  ['Wallenberg (CA)', '/Wallenberg/'],
#  ['Walter Payton (IL)', '/Walter%20Payton/'],
#  ['Washburn Rural (KS)', '/Washburn%20Rural/'],
#  ['Washington (SD)', '/Washington/'],
#  ['Washington Latin (DC)', '/Washington%20Latin/'],
#  ['Wayzata (MN)', '/Wayzata/'],
#  ['West Campus (CA)', '/West%20Campus/'],
#  ['West Des Moines Valley (IA)', '/West%20Des%20Moines%20Valley/'],
#  ['Westminster (GA)', '/Westminster/'],
#  ['Westside (TX)', '/Westside/'],
#  ['Westview (OR)', '/Westview/'],
#  ['Westwood (TX)', '/Westwood/'],
#  ['Wheeler (GA)', '/Wheeler/'],
#  ['Whitney Young (IL)', '/Whitney%20Young/'],
#  ['Wichita East (KS)', '/Wichita%20East/'],
#  ['Will Rogers (OK)', '/Will%20Rogers/'],
#  ['Willard (MO)', '/Willard/'],
#  ['William Chrisman (MO)', '/William%20Chrisman/'],
#  ['Winston Churchill (TX)', '/Winston%20Churchill/'],
#  ['Woodward (GA)', '/Woodward/'],
#  ['Wooster (OH)', '/Wooster/'],
#  ['Wylie (TX)', '/Wylie/'],
#  ['Yerba Buena (CA)', '/Yerba%20Buena/']]

# %% [markdown]
# #### School Page
#
# Take the URL to a school and return a list of debaters and the URLs that point to their Aff and Neg pages

# %%
# return aff and neg URLs for all the debaters of a given school

def getTeams(url):
    
    # try opening URL
    try:
        html = urlopen(url).read()
    except Exception:
        return (0, [], {}, "School URL broke")
        
    # soupify
    soup = BeautifulSoup(html, "html.parser")
    
    # look for a table
    if len(soup.find_all("table")):
        table = soup.find_all("table")[0]
    else:
        return (0, [], {}, "School page not set up")
        
    # exclude header
    numDebaters = len(table.find_all('tr'))-1
    
    if numDebaters == 0:
        return (0, [], {}, "No debaters listed")
    
    # track team names and map to URLs
    teamNames = []
    pageURLs = {}
    
    
    # for each table row
    for row in table.find_all('tr')[1:]:
        
        # the first column's string is the team name
        team = row.find('td').string
        teamNames.append(team)
        
        # collect the URLs to the aff and neg page
        links = row.find_all('a')
        URLs = [link.get("href") for link in links]
        pageURLs[team] = URLs
    
    return (numDebaters, teamNames, pageURLs, "")

# %%
getTeams("https://hspolicy19.debatecoaches.org/Advanced%20Technologies%20Academy")
# Out:
# (3,
#  ['Advanced Technologies Academy Jacqueline Balanovsky - Raymond Behnke',
#   'Advanced Technologies Academy Sam Self - Jonah Gentleman',
#   'Advanced Technologies Academy Ryan Fritchel - Hannah Lewis'],
#  {'Advanced Technologies Academy Jacqueline Balanovsky - Raymond Behnke': ['/Advanced%20Technologies%20Academy/Balanovsky-Behnke%20Aff',
#    '/Advanced%20Technologies%20Academy/Balanovsky-Behnke%20Neg'],
#   'Advanced Technologies Academy Sam Self - Jonah Gentleman': ['/Advanced%20Technologies%20Academy/Self-Gentleman%20Aff',
#    '/Advanced%20Technologies%20Academy/Self-Gentleman%20Neg'],
#   'Advanced Technologies Academy Ryan Fritchel - Hannah Lewis': ['/Advanced%20Technologies%20Academy/Fritchel-Lewis%20Aff',
#    '/Advanced%20Technologies%20Academy/Fritchel-Lewis%20Neg']},
#  '')

# %% [markdown]
# #### Team Page

# %%
def getDisclosure(url):

    # try opening URL
    try:
        html = urlopen(url).read().decode('utf-8-sig')
        
    except Exception:
        return {"Team URL":url,
                "Rounds": [],
                "Round Reports": [],
                "Cites": [],
                "Errors": "Did not open"}
    
    
    # soupify
    soup = BeautifulSoup(html, "html.parser")
    
    tables = soup.find_all("table")

    if len(tables) > 2:
        
        rnds = tables[0]
        rndrprts = tables[1]
        cts = tables[2]
    
    else:
        
        return {"Team URL":url,
                "Rounds": [],
                "Round Reports": [],
                "Cites": [],
                "Errors": "Not configured properly"}
    
    # collect all rounds
    rounds = []
    
    for row in rnds.find_all("tr")[1:]:
        
        # get pieces
        cols = row.find_all("td")
        trn = cols[0].text
        rnd = cols[1].text
        opp = cols[2].text
        jdg = cols[3].text
        osrc = cols[6].find("a")
        if osrc:
            docURL = osrc.get("href")
        else:
            docURL = ""
            
        rounds.append([trn, rnd, opp, jdg, docURL])
    
    # collect all round reports
    roundReports = []
    
    for row in rndrprts.find_all("tr")[1:]:
        try:
            pars = roundReports.append(row.find_all("td")[2].find_all("p")[1].text)
        except:
            continue

    # collect all cites
    cites = [row.find_all("td")[0].find("span").text for row in cts.find_all('tr')[1:]]
        
    return {"Team URL":url,
            "Rounds": rounds,
            "Round Reports": roundReports,
            "Cites": cites,
            "Errors": ""}

# %%
getDisclosure("https://hsld17.debatecoaches.org/Acton-Boxborough/Liu%20Aff")
# Out:
# {'Team URL': 'https://hsld17.debatecoaches.org/Acton-Boxborough/Liu%20Aff',
#  'Rounds': [['-', 'Finals', '-', '-', ''],
#   ['Harvard', '2', 'Dan Shahab', 'David Moon', ''],
#   ['Lexington Winter Invitational', '2', 'Scarsdale AW', 'David Moon', ''],
#   ['Newark Invitational', '4', 'Stuyvesant JL', 'Amit Kukreja', ''],
#   ['Practice Round', '1', 'Michelle I drop T Li', 'the coolest judge', ''],
#   ['Practice Round', 'Semis', '-', '-', '']],
#  'Round Reports': [],
#  'Cites': ['Contact',
#   'JF - Brown Bear AC',
#   'JF - Brown Bear AC v2',
#   'JF - Brown Bear AC v3',
#   'JF - Deleuzian Narrativity 1AC'],
#  'Errors': ''}

# %% [markdown]
# #### Execution
#
# Loop through wikis, find all schools, visit all entry pages, scrape all positions.

# %%
for wiki in WIKIS:
    
    # unpack wiki
    wikiName = wiki[0]
    wikiURL = wiki[1]
    
    # if it exists, don't overwrite
    if (not OVERWRITE) and path.exists(OUTPATH + wikiName + "_schools_wiki.csv"):
        continue
        
    # open output file
    with open(OUTPATH + wikiName + "schools_wiki.csv", 'w', encoding="utf-8") as SCHOOLFILE, open(OUTPATH + wikiName + "teams_wiki.csv", 'w', encoding="utf-8") as TEAMFILE:
        
        # instantaite writer
        schoolWriter = csv.DictWriter(SCHOOLFILE,
                                     fieldnames = ["School Name",
                                                   "School URL",
                                                   "School Teams",
                                                   "Errors"],
                                      quotechar='"', 
                                      quoting=csv.QUOTE_NONNUMERIC,
                                     lineterminator = "\n")
        
        # write header
        schoolWriter.writeheader()
        
        # instantaite writer
        teamWriter = csv.DictWriter(TEAMFILE,
                                    fieldnames = ["Team Name",
                                                  "Side",
                                                  "Team URL",
                                                  "Rounds",
                                                  "Round Reports",
                                                  "Cites",
                                                  "Errors"],
                                    lineterminator = "\n")
        
        # write header
        teamWriter.writeheader()
            
        print("Scraping " + wikiName)
        
        # get school URLs
        schools = getSchools(wikiURL)
        
        print("There are " + str(len(schools)) + " schools")
        
        for school in schools:
            
            # get school name and URL
            schoolName, schoolURL = school[0], wikiURL + school[1]
            
            print("Checking " + schoolName)
            
            # get teams from the school
            numTeams, teamNames, teamURLs, errors = getTeams(schoolURL)
            
            print("Found " + str(numTeams) + " teams")
            
            # write school information
            schoolWriter.writerow({"School Name" : schoolName,
                                  "School URL": schoolURL,
                                  "School Teams": teamNames,
                                  "Errors": errors})
            
            for team in teamNames:
                
                try:
                
                    print("Scraping " + team)

                    # get team URL
                    teamURL = teamURLs[team]
                    affURL = wikiURL + teamURL[0]
                    negURL = wikiURL + teamURL[1]

                    # aff scraping
                    affInfo = getDisclosure(affURL)
                    affInfo["Team Name"] = team
                    affInfo["Side"] = "Aff"

                    # write aff info
                    teamWriter.writerow(affInfo)

                    # neg scraping
                    negInfo = getDisclosure(negURL)
                    negInfo["Team Name"] = team
                    negInfo["Side"] = "Neg"

                    # write neg info
                    teamWriter.writerow(negInfo)
                    
                except:
                    
                    print(team + " failed.")
# Out:
# Scraping LD17
# There are 495 schools
# Checking Aberdeen Central (SD)
# Found 0 teams
# Checking Academy of Higher Learning (CA)
# Found 0 teams
# Checking Acton-Boxborough (MA)
# Found 3 teams
# Scraping Acton-Boxborough - Matthew Liu
# Scraping Acton-Boxborough - Jeffrey Huang
# Scraping Acton-Boxborough - Jerry Wu
# Checking Advanced Technologies Academy (NV)
# Found 0 teams
# Checking Albany (CA)
# Found 0 teams
# Checking Albuquerque Academy (NM)
# Found 1 teams
# Scraping Albuquerque Academy - Harrison Bay
# Checking Alief Taylor (TX)
# Found 2 teams
# Scraping Alief Taylor - Steven Ha
# Scraping Alief Taylor - Jayden Kannedy
# Scraping Bronx Science - Rod Rofougaran
# Scraping Bronx Science - Annie Wang
# Scraping Bronx Science -  Caroline Wang
# Checking Brophy College Prep (AZ)
# Found 5 teams
# Scraping Brophy - Nikolas Kirk
# Scraping Brophy - Rohan Sidhu
# Scraping Brophy - Kevin Yin
# Scraping Brophy - Amber Ashton
# Scraping Brophy - Calvin Tyler
# Checking Brown (KY)
# Found 0 teams
# Checking Byram Hills (NY)
# Found 4 teams
# Scraping Byram Hills - Lindsey Perlman
# Scraping Byram Hills - Arjun Goyal
# Scraping Byram Hills - Luke Gastelu
# Scraping Byram Hills - Mark Fakler
# Checking Byron Nelson (TX)
# Found 1 teams
# Scraping Byron Nelson - Victoria Ivey
# Checking Cabot (AR)
# Found 4 teams
# Scraping Cabot - Briana Griffin
# Scraping Cabot - Jonathan Riles
# Scraping Cabot - Alex Mills
# Scraping Cabot - Dustin Lauderdale
# Checking Calhoun Homeschool (TX)
# Found 0 teams
# Checking Cambridge Rindge (MA)
# Found 2 teams
# Scraping Cambridge Rindge - Andrew Garber
# Scraping Cambridge Rindge - Martino Boni Beadle
# Checking Canyon Crest (CA)
# Found 13 teams
# Scraping Canyon Crest - Kevin Li
# Scraping Canyon Crest - Reva Agashe
# Scraping Canyon Crest - Natalie Feldman
# Scraping Canyon Crest - Ruchi Agasher
# Scraping Canyon Crest - Rithvik Rao
# Scraping Canyon Crest - Edward Li E
# Scraping Canyon Crest - Natalia Zorrilla
# Scraping Canyon Crest - Jason Yang
# Scraping Canyon Crest - Samuel Xiong
# Scraping Canyon Crest - Justin Wang
# Scraping Canyon Crest - Catherine Wangc
# Scraping Canyon Crest - Sophia Teglia
# Scraping Canyon Crest - Jacob Spiegelman
# Checking Canyon Springs (NV)
# Found 0 teams
# Checking Cape Fear Academy (NC)
# Found 1 teams
# Scraping Cape Fear Academy - Maya Arora
# Checking Carmel Valley Independent (CA)
# Found 13 teams
# Scraping Canyon Crest - Kevin Li
# Scraping Canyon Crest - Reva Agashe
# Scraping Canyon Crest - Natalie Feldman
# Scraping Canyon Crest - Ruchi Agasher
# Scraping Canyon Crest - Rithvik Rao
# Scraping Canyon Crest - Edward Li E
# Scraping Canyon Crest - Natalia Zorrilla
# Scraping Canyon Crest - Jason Yang
# Scraping Canyon Crest - Samuel Xiong
# Scraping Canyon Crest - Justin Wang
# Scraping Canyon Crest - Catherine Wangc
# Scraping Canyon Crest - Sophia Teglia
# Scraping Canyon Crest - Jacob Spiegelman
# Checking Carnegie Vanguard (TX)
# Found 1 teams
# Scraping Carnegie Vanguard - Arnav Burudgunte
# Checking Carpe Diem (NJ)
# Found 1 teams
# Scraping Carpe Diem - Rithvik Seela
# Checking Cary Academy (NC)
# Found 1 teams
# Scraping Cary Academy - Will Aarons
# Checking Catalina Foothills (AZ)
# Found 2 teams
# Scraping Catalina Foothills - Joshua Cohen
# Scraping Catalina Foothills - Sylvia Zarnescu
# Checking Cedar Park (TX)
# Found 0 teams
# Checking Cedar Ridge (TX)
# Found 0 teams
# Checking Centennial (ID)
# Found 2 teams
# Scraping Centennial - Avalyn Hine
# Scraping Centennial - Harrison Hall
# Checking Centennial (TX)
# Found 1 teams
# Scraping Centennial TX - Arlinda Chen
# Checking Center For Talented Youth (MD)
# Found 0 teams
# Checking Cerritos (CA)
# Found 0 teams
# Checking Chaminade (CA)
# Found 6 teams
# Scraping Chaminade - Ronak Ahuja
# Scraping Chaminade - Joey Thornhill
# Scraping Chaminade -  Azi Hormozdiari
# Scraping Chaminade - Austin Li
# Scraping Chaminade -  Josh Kirshner
# Scraping Chaminade - Jatin Batta
# Checking Chandler (AZ)
# Found 0 teams
# Checking Chandler Prep (AZ)
# Found 0 teams
# Checking Chantilly (VA)
# Found 2 teams
# Scraping Chantilly - Thomas Maher
# Scraping Chantilly - Aaron Lin
# Checking Chaparral (AZ)
# Found 0 teams
# Checking Charles E Smith (MD)
# Found 0 teams
# Checking Charlotte Catholic (NC)
# Found 1 teams
# Scraping Charlotte Catholic - David Edwards
# Checking Charlotte Latin (NC)
# Found 2 teams
# Scraping Charlotte Latin - Anna Catherine Henley
# Scraping Charlotte Latin - Justin Smith
# Checking Cherokee (GA)
# Found 3 teams
# Scraping Cherokee GA - John Peterson
# Scraping Cherokee GA - Anne Greer
# Scraping Cherokee GA - Sean Howell
# Checking Cherokee (OK)
# Found 0 teams
# Checking Cherry Creek (CO)
# Found 1 teams
# Scraping Cherry Creek - Maya Robbins
# Checking Christ Episcopal (LA)
# Found 0 teams
# Checking Christopher Columbus (FL)
# Found 2 teams
# Scraping Christopher Columbus - Angel Toro
# Scraping Christopher Columbus - Daniel De Izaguirre
# Checking Citrus Valley (CA)
# Found 0 teams
# Checking Claremont (CA)
# Found 0 teams
# Checking Clark (NV)
# Found 0 teams
# Checking Clark (TX)
# Found 1 teams
# Scraping Clark TX - Aryan Jasani
# Checking Clear Brook (TX)
# Found 0 teams
# Checking Clements (TX)
# Found 5 teams
# Scraping Clements - Ronak Shah
# Scraping Clements - Arnav Sethi
# Scraping Clements - Parth Dargan
# Scraping Clements - Cameron Diao
# Scraping Clements - Thomas Rivera
# Checking Clovis North (CA)
# Found 0 teams
# Checking College Prep (CA)
# Found 0 teams
# Checking Collegiate (NY)
# Found 1 teams
# Scraping Collegiate - Christopher Wong
# Checking Colleyville Heritage (TX)
# Found 7 teams
# Scraping Colleyville - Celine Wei
# Scraping Colleyville - Arsh Ladhani
# Scraping Colleyville - Sarah Manjee
# Scraping Colleyville - Eesha Charanyia
# Scraping Colleyville - Itbaan Nafi
# Scraping Colleyville - Sarthak Sirotiya
# Scraping Colleyville - Ali Bharwani
# Checking Concord Carlisle (MA)
# Found 0 teams
# Checking Concordia Lutheran (TX)
# Found 0 teams
# Checking Connally (TX)
# Found 2 teams
# Scraping Connally - Anthony Kern
# Scraping Connally - Sarah Raymond
# Checking Coral Glades (FL)
# Found 0 teams
# Checking Coral Science (NV)
# Found 0 teams
# Checking Coral Springs (FL)
# Found 0 teams
# Checking Coppell (TX)
# Found 0 teams
# Checking Copper Hills (UT)
# Found 0 teams
# Checking Corona Del Sol (AZ)
# Found 1 teams
# Scraping Corona Del Sol - Zane Encinas
# Checking Crandall (TX)
# Found 0 teams
# Checking Crosby (TX)
# Found 1 teams
# Scraping Crosby - Matthew Schneider
# Checking Crossroads (CA)
# Found 0 teams
# Checking CTCS (TX)
# Found 1 teams
# Scraping CTCS - Nathan Smith
# Checking Cupertino (CA)
# Found 1 teams
# Scraping Cupertino - Haritha Kumar
# Checking Cy-Fair (TX)
# Found 5 teams
# Scraping Cy-Fair - Tess Welch
# Scraping Cy-Fair - Corey Hughes
# Scraping Cy-Fair - Katy Aing
# Scraping Cy-Fair - Kevin Luu
# Scraping Cy-Fair - Kavya Sethi
# Checking Cypress Bay (FL)
# Found 5 teams
# Scraping Cypress Bay - Charlie Seldin
# Scraping Cypress Bay - Kavya Sarin
# Scraping Cypress Bay - Garrett Bishop
# Scraping Cypress Bay - Isabella Ollie Mason
# Scraping Cypress Bay - Nicole Buckley
# Checking Cypress Falls (TX)
# Found 2 teams
# Scraping Cypress Falls - Rajveer Kindra
# Scraping Cypress Falls - Creg Moulton
# Checking Cypress Lakes (TX)
# Found 0 teams
# Checking Cypress-Ranch (TX)
# Found 2 teams
# Scraping Cypress-Ranch - Michael Zhou
# Scraping Cypress-Ranch - Mingrui Qian
# Checking Cypress Ridge (TX)
# Found 0 teams
# Checking Cypress Springs (TX)
# Found 0 teams
# Checking Cypress Woods (TX)
# Found 6 teams
# Scraping Cypress Woods - Yohan Wang
# Scraping Cypress Woods - Chakra Jonnalagadda
# Scraping Cypress Woods - Angela Zhong
# Scraping Cypress Woods - Kiran Khan
# Scraping Cypress Woods - Archit Junnarkar
# Scraping Cypress Woods - Maya Trivedi
# Checking Cyprus (UT)
# Found 1 teams
# Scraping Cyprus - Andrew Mortensen
# Checking Dallastown (PA)
# Found 2 teams
# Scraping Dallastown - Emily White
# Scraping Dallastown - Nevin Kara
# Checking Davis (CA)
# Found 4 teams
# Scraping Davis - Elise Turkovich
# Scraping Davis - Kenneth Wang
# Scraping Davis - Vasanth Kumar
# Scraping Davis - Albert Hu
# Checking Decatur Heritage (AL)
# Found 1 teams
# Scraping Decatur Heritage - Justin McCleskey
# Checking Delbarton (NJ)
# Found 0 teams
# Checking Denver East (CO)
# Found 7 teams
# Scraping Denver East - Owen DehmlerBuckley
# Scraping Denver East - Max Boubin
# Scraping Denver East - Acacia Downs
# Scraping Denver East - Talia Hart
# Scraping Denver East - Fiona Cannon
# Scraping Denver East - Austin BarishSR
# Scraping Denver East - Serena BarishSOPH
# Checking Derby (KS)
# Found 0 teams
# Checking Des Moines Roosevelt (IA)
# Found 1 teams
# Scraping Des Moines Roosevelt - Quinn Mattison
# Checking Desert Vista (AZ)
# Found 4 teams
# Scraping Desert Vista - Armando Montero
# Scraping Desert Vista - Lauren Welsh
# Scraping Desert Vista - Shawn Yousefelahi
# Scraping Desert Vista - Jason Mittelman
# Checking Diamond Bar (CA)
# Found 0 teams
# Checking Dobson (AZ)
# Found 0 teams
# Scraping Edina - Stella OlkenHunt
# Scraping Edina - Matthew Ruppert
# Scraping Edina - Ananth Veluvali
# Checking Edmond North (OK)
# Found 0 teams
# Checking Edmond Santa Fe (OK)
# Found 1 teams
# Scraping Edmond Santa Fe - Christine Nguyen
# Checking Eisenhower (KS)
# Found 0 teams
# Checking El Cerrito (CA)
# Found 0 teams
# Checking Elite of Irvine (CA)
# Found 2 teams
# Scraping Elite of Irvine - Allen Pau
# Scraping Elite of Irvine - Caitlin Lee
# Checking Elkins (TX)
# Found 1 teams
# Scraping Elkins - Kedar Pandya
# Checking Enloe (NC)
# Found 1 teams
# Scraping Enloe - Tej Gedela
# Checking ESD (TX)
# Found 2 teams
# Scraping ESD - Zan Haq
# Scraping ESD - Jiaying Fu
# Checking Evanston (IL)
# Found 11 teams
# Scraping Evanston - Henry Eberhart
# Scraping Evanston - Elliot Davis
# Scraping Evanston - Zachary Schwartz
# Scraping Evanston - Joshua Ahn
# Scraping Evanston - Owen Janssen
# Scraping Evanston - Lane Deamant
# Scraping Evanston - Elizabeth Sperti
# Scraping Evanston - Chirasree Mandal
# Scraping Evanston - Luis Toro
# Scraping Evanston - Quinn Hughes
# Scraping Evanston - Gabriel Stern
# Checking Evergreen Valley (CA)
# Found 0 teams
# Checking Ferris (TX)
# Found 0 teams
# Checking Flintridge Prep (CA)
# Found 0 teams
# Checking Flintridge Sacred Heart (CA)
# Found 1 teams
# Scraping Flintridge - Catherine Bauer
# Checking Flower Mound (TX)
# Found 4 teams
# Scraping Flower Mound - Nikhil Guddati
# Scraping Flower Mound - Grace Li
# Scraping Flower Mound - Likhit Agrawal
# Scraping Flower Mound - Colton Moraine
# Checking Fordham Prep (NY)
# Found 0 teams
# Checking Fort Lauderdale (FL)
# Found 0 teams
# Checking Fort Walton Beach (FL)
# Found 1 teams
# Scraping Fort Walton Beach - Roxanne Daniel
# Checking Freehold Township (NJ)
# Found 1 teams
# Scraping Freehold Township - Nelson Lin
# Checking Fremont (NE)
# Found 0 teams
# Checking Frontier (MO)
# Found 0 teams
# Checking Gabrielino (CA)
# Found 2 teams
# Scraping Gabrielino - Ethan Tan
# Scraping Gabrielino - Monie Choi
# Checking Garland (TX)
# Found 5 teams
# Scraping Garland - Khoa Pham
# Scraping Garland - Brandon Molina
# Scraping Garland - Ishan Rereddy
# Scraping Garland - Saketh Venattu
# Scraping Garland - Brian Lam
# Checking George Ranch (TX)
# Found 2 teams
# Scraping George Ranch - Mohammad Sheikh
# Scraping George Ranch - Arshaan Ali
# Checking George Washington (CO)
# Found 2 teams
# Scraping George Washington - Caitlin Soch
# Scraping George Washington - Sofia Chavez
# Checking Georgetown Day (DC)
# Found 0 teams
# Checking Gig Harbor (WA)
# Found 1 teams
# Scraping Gig Harbor - Kayla Garcia
# Checking Gilmour (OH)
# Found 1 teams
# Scraping Gilmour - Sebastian Williams
# Checking Glacier Peak (WA)
# Found 1 teams
# Scraping Glacier Peak - Richard Ahn
# Checking Glenbrook South (IL)
# Found 0 teams
# Checking Glencoe (OR)
# Scraping King - Arpan Bagui
# Checking Kingwood (TX)
# Found 0 teams
# Checking Kinkaid (TX)
# Found 4 teams
# Scraping Kinkaid - Shreya Mehta
# Scraping Kinkaid - Jack Scofield
# Scraping Kinkaid - Jiya Ghei
# Scraping Kinkaid - Sam Segal
# Checking Klein (TX)
# Found 1 teams
# Scraping Klein - Nate Galang
# Checking Klein Oak (TX)
# Found 2 teams
# Scraping Klein Oak - Alan George
# Scraping Klein Oak - Ryan Rashid
# Checking Kudos College (CA)
# Found 4 teams
# Scraping Kudos College - Ethan Chang
# Scraping Kudos College - Aaron Lee
# Scraping Kudos College - Aaron Zhang
# Scraping Kudos College - Christina Feng
# Checking Kugnus Acts (NJ)
# Found 1 teams
# Scraping Kugnus Acts - Elizabeth Lee
# Checking La Canada (CA)
# Found 0 teams
# Checking La Costa Canyon (CA)
# Found 0 teams
# Checking La Jolla (CA)
# Found 0 teams
# Checking La Reina (CA)
# Found 5 teams
# Scraping La Reina -  Emma Martin
# Scraping La Reina -  Alex Martin
# Scraping La Reina -  Olivia Arthur
# Scraping La Reina -  Andrea Chow
# Scraping La Reina -  Alanna Cronk
# Checking La Salle (CA)
# Found 1 teams
# Scraping La Salle - Asher Towner
# Checking Lafayette (LA)
# Found 1 teams
# Scraping Lafayette LA - Mason Mitchell
# Checking Lafayette (MO)
# Found 0 teams
# Checking Lake Highland (FL)
# Found 15 teams
# Scraping Lake Highland - Ari Azbel
# Scraping Lake Highland - Muhammad Khattak
# Scraping Lake Highland - Steve Goldware
# Scraping Lake Highland - Julia Wu
# Scraping Lake Highland - Sachin Shah
# Scraping Lake Highland - Jerome Nashed
# Scraping Lake Highland - Abby Morris
# Scraping Lake Highland - Hannah Koegler
# Scraping Lake Highland - Meghana Srinivasa
# Scraping Lake Highland - Serena Lyou
# Scraping Lake Highland - Parnika Agrawal
# Scraping Lake Highland - Sana Sheik
# Scraping Lake Highland - Rithvik Seela
# Scraping Lake Highland - Mimi Sawhney
# Scraping Lake Highland - Jaya Dayal
# Checking Lake Travis (TX)
# Found 10 teams
# Scraping Lake Travis - Evan Margiotta
# Scraping Lake Travis - Blake Ochoa
# Scraping Lake Travis - Mackenzie Matheson
# Scraping Lake Travis - Emma Young
# Scraping Lake Travis - Joel Alexander
# Scraping Lake Travis - Lee Scheffe
# Scraping Lake Travis - Vivian McDonald
# Scraping Lake Travis - Maya Obregon
# Scraping Lake Travis - Beckett Larcher
# Scraping Lake Travis - Isabella Sommer
# Checking Lakeville North (MN)
# Found 2 teams
# Scraping Lakeville North - Noah Gallagher
# Scraping Lakeville North - Shashwot Tripathy
# Checking Lakeville South (MN)
# Found 3 teams
# Scraping Lakeville South - Elliot Harvanko
# Scraping Lakeville South - Nina Baker
# Scraping Lakeville South - Logan Stenzel
# Checking Lamar (TX)
# Found 1 teams
# Scraping Lamar - Maximilian Tran
# Checking LAMP (AL)
# Found 0 teams
# Checking Law Magnet (TX)
# Found 3 teams
# Scraping Law Magnet - Michael Gao
# Scraping Law Magnet - Adan Nevarez
# Scraping Law Magnet - Benjamin Jones
# Checking Langham Creek (TX)
# Found 0 teams
# Checking Lansing (KS)
# Found 1 teams
# Scraping Lansing - Salem Clemens
# Checking LaSalle College (PA)
# Found 2 teams
# Scraping LaSalle College - Martin Csongradi
# Scraping LaSalle College - Zachary Quinn
# Checking Lawrence Free State (KS)
# Found 0 teams
# Checking Lawrenceville (NJ)
# Found 1 teams
# Scraping Lawrenceville - Elaine Wang
# Checking Layton (UT)
# Found 0 teams
# Checking Leland (CA)
# Found 1 teams
# Scraping Leland - Dheerj Jasuja
# Checking Leucadia Independent (CA)
# Found 0 teams
# Checking Lexington (MA)
# Found 19 teams
# Scraping Lexington - Avani Kabra
# Scraping Lexington - Klil Loeb
# Scraping Lexington - Cynthia Chen
# Scraping Lexington - Ollie Rourke
# Scraping Lexington - Jeffrey Gu
# Scraping Lexington - Reed Weiler
# Scraping Lexington - Avery Fortier
# Scraping Lexington - Simran Gandhi
# Scraping Lexington - Janet Mariadoss
# Scraping Lexington - Yianni Zavaliagkos
# Scraping Lexington - Vedant Roy
# Scraping Lexington - Luke Eriksson
# Scraping Lexington - Evan Li
# Scraping Lexington - Pranathi Srirangam
# Scraping Lexington - Kevin Yang
# Scraping Lexington - Stephen Alessandro
# Scraping Lexington - Nicholas NewtonCheh
# Scraping Lexington - Christine Wang
# Scraping Lexington - Megha Prasad
# Checking Liberty Christian (TX)
# Found 0 teams
# Checking Lincoln (OR)
# Found 0 teams
# Checking Lincoln (NE)
# Found 2 teams
# Scraping Lincoln NE - Jesse Nguyen
# Scraping Lincoln NE - Sara Al Rishawi
# Checking Lincoln East (NE)
# Found 2 teams
# Scraping Lincoln East - Sasha Belashchenko
# Scraping Lincoln East - Jennifer Wang
# Checking Lindale (TX)
# Found 1 teams
# Scraping Lindale - Robert McWhorter
# Checking Little Rock Central (AR)
# Found 2 teams
# Scraping Little Rock Central - Sahar Tariq
# Scraping Little Rock Central - Anna Rumpz
# Checking Livingston (NJ)
# Found 1 teams
# Scraping Livingston - Kenneth Ding
# Checking Logan (UT)
# Found 3 teams
# Scraping Logan - Wesley Carter
# Scraping Logan - Kai Torrens
# Scraping Logan - Andre Nguyen
# Checking Lone Peak (UT)
# Found 0 teams
# Checking Los Alamos (NM)
# Found 2 teams
# Scraping Los Alamos - Antonio Dowdy
# Scraping Los Alamos - Sam Menefee
# Checking Los Altos (CA)
# Found 4 teams
# Scraping Los Altos - Nathan Huang
# Scraping Los Altos - Josh Hejna
# Scraping Los Altos - Parth Dhanotra
# Scraping Los Altos - Natalie Huan g
# Checking Los Osos (CA)
# Found 1 teams
# Scraping Los Osos - Ron Nath
# Checking Louisville (OH)
# Found 0 teams
# Checking Lovejoy (TX)
# Found 4 teams
# Scraping Lovejoy - Collins Morgan
# Scraping Lovejoy - Ashley Rihani
# Scraping Lovejoy - Ana Kusbit
# Scraping Lovejoy - Kaya Czyz
# Checking Lovett (GA)
# Found 2 teams
# Scraping Lovett - Peter Kessler
# Scraping Lovett - Sloane Saxon
# Checking Loyola (CA)
# Found 18 teams
# Scraping Loyola - Nathaniel Tran
# Scraping Loyola - Sam Troyer
# Scraping Loyola - Austin Tra n
# Scraping Loyola - Luis Arbelaez
# Scraping Loyola - Joseph Namkung
# Scraping Loyola - Dante Bajarias
# Scraping Loyola - Ryan Beckman
# Scraping Loyola - Holden Fraser
# Scraping Loyola - Connor Lindquist
# Scraping Loyola - John Choi
# Scraping Loyola - Andrew Overing
# Scraping Loyola - Michael Castro
# Scraping Loyola - James Duchesneau
# Scraping Loyola - Jack Koenig
# Scraping Loyola - Lucas Hunter
# Scraping Loyola - John Soza
# Scraping Loyola - Patrick Oh
# Scraping Loyola - Alessandro Behney
# Checking Loyola Blakefield (MA)
# Found 0 teams
# Checking Lynbrook (CA)
# Found 13 teams
# Scraping Lynbrook - Chris Wang
# Scraping Lynbrook - Nikhil Ajjarapu
# Scraping Lynbrook - Yichen Zhu
# Scraping Lynbrook - Anya Poplavska
# Scraping Lynbrook - Susan Zhou
# Scraping Lynbrook - Selina Li
# Scraping Lynbrook - Hsinyen Huang
# Scraping Lynbrook - Divya Nelakonda
# Scraping Lynbrook - Meera Balaji
# Scraping Lynbrook - Cindy Xu
# Scraping Lynbrook - Lakshay Maharana
# Scraping Lynbrook - Nisha Fernandes
# Scraping Lynbrook - Sloka Suresh
# Checking Maeser Prep (UT)
# Found 0 teams
# Checking Maize (KS)
# Found 1 teams
# Scraping Maize - Connor Mitchell
# Checking Mannford (OK)
# Found 0 teams
# Checking Marcus (TX)
# Found 6 teams
# Scraping Marcus - Kyle Lleras
# Scraping Marcus - Sahithi Talasila
# Marcus - Sahithi Talasila failed.
# Scraping Marcus - Alex LIeras
# Scraping Marcus - Uma Obalapuram
# Scraping Marcus - Brooklyn Green
# Scraping Marcus - Sarah Saleem
# Checking Marist (GA)
# Found 5 teams
# Scraping Marist - Anna Price
# Scraping Marist - William Ross
# Scraping Marist - Drew Sherman
# Scraping Marist - Mackenzie Childs
# Scraping Marist - Rachel Lee
# Checking Marlborough (CA)
# Found 14 teams
# Scraping Marlborough - Mia Coates
# Scraping Marlborough - Zoe Wasserman
# Scraping Marlborough - Sophia Danielpour
# Scraping Marlborough - Amy Jarkow
# Scraping Marlborough - Grace Nelson
# Scraping Marlborough - Cameron Lange
# Scraping Marlborough - Julia Steinberg
# Scraping Marlborough - Lydia Dimsu
# Scraping Marlborough - SarahMae Tuohy
# Scraping Marlborough - Emma Yanai
# Scraping Marlborough - Heather Thomasian
# Scraping Marlborough - Olivia Feldman
# Scraping Marlborough - Bella Whitney
# Scraping Marlborough - Emilynne Newsom
# Marlborough - Emilynne Newsom failed.
# Checking Marquette (WI)
# Found 1 teams
# Scraping Marquette - Sam Larson
# Checking Marvin Baker (TX)
# Found 0 teams
# Checking McClintock (AZ)
# Found 1 teams
# Scraping McClintock - Carter Miller
# Checking McDowell (PA)
# Found 0 teams
# Checking McKinney (TX)
# Found 1 teams
# Scraping McKinney - David Gutierrez
# Checking McMillen (TX)
# Scraping Mountain Brook - Griffin Darden
# Scraping Mountain Brook - Pavel Shirley
# Scraping Mountain Brook - Jack Sansbury
# Scraping Mountain Brook - Spencer Keel
# Scraping Mountain Brook - Christian Glenos
# Scraping Mountain Brook - Russell Weas
# Checking Mountain Pointe (AZ)
# Found 0 teams
# Checking Mountain View (ID)
# Found 1 teams
# Scraping Mountain View ID - David Luke
# Checking Mountain View (CA)
# Found 2 teams
# Scraping Mountain View - Maya Sanghavi
# Scraping Mountain View - Varun Paranjpe
# Checking Mountain View (AZ)
# Found 1 teams
# Scraping Mountain View AZ - Anderson Zhang
# Checking Murphy Middle (TX)
# Found 0 teams
# Checking NCSSM (NC)
# Found 0 teams
# Checking Needham (MA)
# Found 2 teams
# Scraping Needham - Zachary Lu
# Scraping Needham - Sam Cogen
# Checking Neenah (WI)
# Found 2 teams
# Scraping Neenah - Maddie Alft
# Scraping Neenah - Megan OKeefe
# Checking New Orleans Jesuit (LA)
# Found 0 teams
# Checking New Trier (IL)
# Found 4 teams
# Scraping New Trier - Patrick Tolan
# Scraping New Trier - William Thornton
# Scraping New Trier - Caity Kacena
# Scraping New Trier - Keara McLaughlin
# Checking Newark Science (NJ)
# Found 6 teams
# Scraping Newark Science - Brianna Aaron
# Scraping Newark Science - Teslimah Ojifinni
# Scraping Newark Science - Temitope Ogundare
# Scraping Newark Science - Osmane Sanogo
# Scraping Newark Science - Shah Bano
# Scraping Newark Science - Simone Braithwaite
# Checking Newburgh Free Academy (NY)
# Found 0 teams
# Checking Newport (WA)
# Found 5 teams
# Scraping Newport - Anne Lim
# Scraping Newport - Vanessa Chen
# Scraping Newport - Sarah Xu
# Scraping Newport - Akhil Mandala
# Scraping Newport - Aaron Xie
# Checking Newsome (FL)
# Found 2 teams
# Scraping Newsome - Dylan Burke
# Scraping Newsome - Adam Gorman
# Checking Niskayuna (NY)
# Found 1 teams
# Scraping Niskayuna - Shreyas Ramanujam
# Checking North Allegheny (PA)
# Found 1 teams
# Scraping North Allegheny - Joy Fu
# Checking North Crowley (TX)
# Found 0 teams
# Checking North Hollywood (CA)
# Found 1 teams
# Scraping North Hollywood - Jack Stern
# Checking Northland Christian (TX)
# Found 9 teams
# Scraping Northland Christian - Kaitlyn England
# Scraping Northland Christian - Marly Grace Rogers
# Scraping Northland Christian - Jordan Wang
# Scraping Northland Christian - Andy Van
# Scraping Northland Christian - Austin Broussard
# Scraping Northland Christian - Jack Quisenberry
# Scraping Northland Christian - Sydney OConnell
# Scraping Northland Christian - Eathan Newman
# Scraping Northland Christian - Aaron Barcio
# Checking Northwest Career and Technical (NV)
# Found 1 teams
# Scraping Northwest Career and Technical - Cosette Fronczek
# Checking Northwood (CA)
# Found 10 teams
# Scraping Northwood - Garrett Arnold
# Scraping Northwood - Viren Abhyankar
# Scraping Northwood - Karthik Krishnan
# Scraping Northwood - Allison Huang
# Scraping Northwood - Andrew Do
# Scraping Northwood - David Choi
# Scraping Northwood - Sasha Anand
# Scraping Northwood - Ekas Chawla
# Scraping Northwood - Daniel Luo
# Scraping Northwood - Lara Elhassan
# Checking Notre Dame (CA)
# Found 2 teams
# Scraping Notre Dame - Arushi Bansal
# Scraping Notre Dame - Dipashreya Sur
# Checking Nueva (CA)
# Found 1 teams
# Scraping Nueva - Adam Keller
# Checking Oak Hall (FL)
# Found 1 teams
# Scraping Oak Hall - Kumail Zaidi
# Checking Oakwood (CA)
# Found 7 teams
# Scraping Oakwood - Maximillian Wolf Valdes
# Scraping Oakwood - Arlo Weiner
# Scraping Oakwood - Logan Bauman
# Scraping Oakwood - Wyatt Alpert
# Scraping Oakwood - Sarah Mostow
# Scraping Oakwood - Nikki Bayat
# Scraping Oakwood - August Orser
# Checking Oakwood (OH)
# Found 1 teams
# Scraping Oakwood OH - Madelynn Einhorn
# Checking Okoboji (IA)
# Found 0 teams
# Checking Olathe West (KS)
# Found 0 teams
# Checking Oxbridge (FL)
# Found 0 teams
# Checking Oxford (CA)
# Found 0 teams
# Checking Oxford (MS)
# Found 1 teams
# Scraping Oxford MS - Bennett Brown
# Checking Pacific Hills (CA)
# Found 1 teams
# Scraping Pacific Hills - Alexander Shaikh
# Checking Pacific Ridge (CA)
# Found 0 teams
# Checking Palm Beach Gardens (FL)
# Found 0 teams
# Checking Palo Alto Independent (CA)
# Found 2 teams
# Scraping Palo Alto Independent - Frances Zhuang
# Scraping Palo Alto Independent - Barry He
# Checking Palo Verde (NV)
# Found 1 teams
# Scraping Palo Verde - Madison Gardecki
# Checking Palos Verdes Peninsula (CA)
# Found 0 teams
# Checking Paradise Valley (AZ)
# Found 0 teams
# Checking Park Crossing (AL)
# Found 0 teams
# Checking Parkview (MO)
# Found 1 teams
# Scraping Parkview MO - Andre Swai
# Checking Peak to Peak (CO)
# Found 0 teams
# Checking Pembroke Pines (FL)
# Found 0 teams
# Checking Pennsbury (PA)
# Found 1 teams
# Scraping Pennsbury - Carolyn Zou
# Checking Perry (AZ)
# Found 2 teams
# Scraping Perry - Clayton Marfori
# Scraping Perry - Mariah Hays
# Checking Pflugerville (TX)
# Found 1 teams
# Scraping Pflugerville - Hoden AbdiYusuf
# Checking Phillips Academy Andover (MA)
# Found 1 teams
# Scraping Phillips Academy Andover - Tiffany Chang
# Checking Phoenix Country Day (AZ)
# Found 0 teams
# Checking Pine Crest (FL)
# Found 1 teams
# Scraping Pine Crest - Zachary Vlessing
# Checking Pingry (NJ)
# Found 0 teams
# Checking Pinnacle (AZ)
# Found 1 teams
# Scraping Pinnacle - Kristen Arnold
# Checking Pittsburgh Central Catholic (PA)
# Found 0 teams
# Checking Plano East (TX)
# Found 6 teams
# Scraping Plano East - Cedric Zhou
# Scraping Plano East - Jonathan Lee
# Scraping Plano East - Ameera Khan
# Scraping Plano East - Catherine Vo
# Scraping Plano East - Vandan Patel
# Scraping Plano East - William Zhang
# Checking Plano Senior (TX)
# Found 1 teams
# Scraping Plano Senior - Allen Wu
# Checking Plano West (TX)
# Found 4 teams
# Scraping Plano West - Bora Oztekin
# Scraping Plano West - Anirudh Garg
