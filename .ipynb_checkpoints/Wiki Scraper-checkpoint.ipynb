# %% [markdown]
# Wiki Scraper
# ---
#
# Author: Peter Zhang
#
# Scraping tool for the Wiki.

# %% [markdown]
# ### Setup
#
# #### Imports

# %%
# imports
import urllib.request, urllib.parse, urllib.error
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import csv
import os.path
from os import path
import re

# %% [markdown]
# #### Settings
#
# - OVERWRITE determines whether or not to update existing files.
# - PAGES_URL is a list of Wiki pages
# - OUTPATH is where files are stored

# %%
# settings
OVERWRITE = True
TARGET_WIKIS = ["LD20"]

# %%
# get page URLs
WIKIS_URL = "tools/wiki_pages.csv"
WIKIS = [row for row in csv.reader(open(WIKIS_URL, 'r'))]

# %%
# outpath
OUTPATH = "wiki_data/"

# %% [markdown]
# ### Scrapers
#
# #### Wiki Page
#
# Take the URL to a wiki page and returns a list of all the school names and their respective URLs.

# %%
# for a given archive year, return all schools
def getSchools(url):
    
    # try opening URL
    try:
        html = urlopen(url).read()
    except Exeption:
        print("Wiki URL broke")
        return []
    
    
    # soupify
    soup = BeautifulSoup(html, "html.parser")
    
    # find all links
    links = soup.find_all('a')
    
    # find only school links
    links = [link for link in links if "(" in link.text and ")" in link.text]
    
    # get link text and URL
    schools = [[link.text, link.get('href')] for link in links]

    return schools

# %%
getSchools("https://hspolicy19.debatecoaches.org/")
# Out:
# [['Advanced Technologies Academy (NV)', '/Advanced%20Technologies%20Academy/'],
#  ['Airline (AL)', '/Airline/'],
#  ['Aledo (TX)', '/Aledo/'],
#  ['Alief Taylor (TX)', '/Alief%20Taylor/'],
#  ['Alpharetta (GA)', '/Alpharetta/'],
#  ['Altamont (AL)', '/Altamont/'],
#  ['American Heritage (FL)', '/American%20Heritage/'],
#  ['Anderson (TX)', '/Anderson/'],
#  ['Andover (KS)', '/Andover/'],
#  ['Andover Central (KS)', '/Andover%20Central/'],
#  ['Andrews (TX)', '/Andrews/'],
#  ['Archbishop Mitty (CA)', '/Archbishop%20Mitty/'],
#  ['Ashland (OR)', '/Ashland/'],
#  ['Asian Debate League (AK)', '/Asian%20Debate%20League/'],
#  ['Athens (TX)', '/Athens/'],
#  ['Aubrey (TX)', '/Aubrey/'],
#  ['BASIS Chandler (AZ)', '/BASIS%20Chandler/'],
#  ['BASIS Peoria (AZ)', '/BASIS%20Peoria/'],
#  ['BASIS Shavano (TX)', '/BASIS%20Shavano/'],
#  ['Bakersfield (CA)', '/Bakersfield/'],
#  ['Baltimore City College (MD)', '/Baltimore%20City%20College/'],
#  ['Barstow (MO)', '/Barstow/'],
#  ['Baton Rouge Magnet (LA)', '/Baton%20Rouge%20Magnet/'],
#  ['Bellarmine (CA)', '/Bellarmine/'],
#  ['Benjamin Tasker (MD)', '/Benjamin%20Tasker/'],
#  ['Bentonville (AR)', '/Bentonville/'],
#  ['Bentonville West (AR)', '/Bentonville%20West/'],
#  ['Berkeley Prep (FL)', '/Berkeley%20Prep/'],
#  ['Bingham (UT)', '/Bingham/'],
#  ['Blue Springs South (MO)', '/Blue%20Springs%20South/'],
#  ['Blue Valley (KS)', '/Blue%20Valley/'],
#  ['Blue Valley North (KS)', '/Blue%20Valley%20North/'],
#  ['Blue Valley Northwest (KS)', '/Blue%20Valley%20Northwest/'],
#  ['Blue Valley Southwest (KS)', '/Blue%20Valley%20Southwest/'],
#  ['Blue Valley West (KS)', '/Blue%20Valley%20West/'],
#  ['Bolivar (MO)', '/Bolivar/'],
#  ['Boston Latin Academy (MA)', '/Boston%20Latin%20Academy/'],
#  ['Bowie (MD)', '/Bowie/'],
#  ['Branham (CA)', '/Branham/'],
#  ['Bravo (CA)', '/Bravo/'],
#  ['Bronx Science (NY)', '/Bronx%20Science/'],
#  ['Brooke (MA)', '/Brooke/'],
#  ['Brooklyn Technical (NY)', '/Brooklyn%20Technical/'],
#  ['Buhler (KS)', '/Buhler/'],
#  ['CHAMPS (CA)', '/CHAMPS/'],
#  ['CK McClatchy (CA)', '/CK%20McClatchy/'],
#  ['Cabot (AR)', '/Cabot/'],
#  ['Caddo Magnet (LA)', '/Caddo%20Magnet/'],
#  ['Calhoun (GA)', '/Calhoun/'],
#  ['Calvert Hall (MD)', '/Calvert%20Hall/'],
#  ['Cambridge (GA)', '/Cambridge/'],
#  ['Canyon Crest (CA)', '/Canyon%20Crest/'],
#  ['Capital City (DC)', '/Capital%20City/'],
#  ['Carlsbad (CA)', '/Carlsbad/'],
#  ['Carmel Valley Independent (CA)', '/Carmel%20Valley%20Independent/'],
#  ['Carrollton Sacred Heart (FL)', '/Carrollton%20Sacred%20Heart/'],
#  ['Carthage (MO)', '/Carthage/'],
#  ['Casady (OK)', '/Casady/'],
#  ['Cathedral Prep (PA)', '/Cathedral%20Prep/'],
#  ['Cedar Rapids Washington (IA)', '/Cedar%20Rapids%20Washington/'],
#  ['Century (ID)', '/Century/'],
#  ['Chaminade (CA)', '/Chaminade/'],
#  ['Champion (TX)', '/Champion/'],
#  ['Charlestown (MA)', '/Charlestown/'],
#  ['Charlotte Catholic (NC)', '/Charlotte%20Catholic/'],
#  ['Charter School Of Wilmington (DE)', '/Charter%20School%20Of%20Wilmington/'],
#  ['Chattahoochee (GA)', '/Chattahoochee/'],
#  ['Chesterton (IN)', '/Chesterton/'],
#  ['Children Of Per Bear (FL)', '/Children%20Of%20Per%20Bear/'],
#  ['China Spring (TX)', '/China%20Spring/'],
#  ['Clackamas (OR)', '/Clackamas/'],
#  ['Classical Academy (CA)', '/Classical%20Academy/'],
#  ['Cleveland (OR)', '/Cleveland/'],
#  ['College Prep (CA)', '/College%20Prep/'],
#  ['Colleyville Heritage (TX)', '/Colleyville%20Heritage/'],
#  ['Connally (TX)', '/Connally/'],
#  ['Coppell (TX)', '/Coppell/'],
#  ['Coppell Ninth (TX)', '/Coppell%20Ninth/'],
#  ['Copper Hills (UT)', '/Copper%20Hills/'],
#  ['Coronado (NV)', '/Coronado/'],
#  ['Crenshaw (CA)', '/Crenshaw/'],
#  ['Crossings Christian School (AL)', '/Crossings%20Christian%20School/'],
#  ['Cueva (NM)', '/Cueva/'],
#  ['Cypress Bay (FL)', '/Cypress%20Bay/'],
#  ['Cypress Woods (TX)', '/Cypress%20Woods/'],
#  ['DC International (DC)', '/DC%20International/'],
#  ['DMV INDEPENDENT (DC)', '/DMV%20INDEPENDENT/'],
#  ['Dallas TAG Magnet (TX)', '/Dallas%20TAG%20Magnet/'],
#  ['Damien (CA)', '/Damien/'],
#  ['Davidson (NV)', '/Davidson/'],
#  ['Davis (UT)', '/Davis/'],
#  ['Davis Senior (CA)', '/Davis%20Senior/'],
#  ['Dawson (TX)', '/Dawson/'],
#  ['DeBakey (TX)', '/DeBakey/'],
#  ['Decatur (GA)', '/Decatur/'],
#  ['Delbarton School (NJ)', '/Delbarton%20School/'],
#  ['Denver Center For International Studies (CO)',
#   '/Denver%20Center%20For%20International%20Studies/'],
#  ['Denver East (CO)', '/Denver%20East/'],
#  ['Derby (KS)', '/Derby/'],
#  ['Desert Vista (AZ)', '/Desert%20Vista/'],
#  ['Detroit Country Day (MI)', '/Detroit%20Country%20Day/'],
#  ['Dougherty Valley (CA)', '/Dougherty%20Valley/'],
#  ['Douglas (SD)', '/Douglas/'],
#  ['Dowling (IA)', '/Dowling/'],
#  ['Downtown College Prep (CA)', '/Downtown%20College%20Prep/'],
#  ['Downtown Magnets (CA)', '/Downtown%20Magnets/'],
#  ['Drew Charter (GA)', '/Drew%20Charter/'],
#  ['Dripping Springs (TX)', '/Dripping%20Springs/'],
#  ['Druid Hills (GA)', '/Druid%20Hills/'],
#  ['DuVal (MD)', '/DuVal/'],
#  ['Dulles (TX)', '/Dulles/'],
#  ['Durham (NC)', '/Durham/'],
#  ['Duval (MD)', '/Duval/'],
#  ['Eagan (MN)', '/Eagan/'],
#  ['Eagle (ID)', '/Eagle/'],
#  ['Eaglecrest (CO)', '/Eaglecrest/'],
#  ['Eastlake (WA)', '/Eastlake/'],
#  ['Eastside (WA)', '/Eastside/'],
#  ['Edgemont (NY)', '/Edgemont/'],
#  ['Edina (MN)', '/Edina/'],
#  ['Eisenhower (KS)', '/Eisenhower/'],
#  ['Elizabeth LC (CA)', '/Elizabeth%20LC/'],
#  ['Emporia (KS)', '/Emporia/'],
#  ['Evanston (IL)', '/Evanston/'],
#  ['Fairview (CO)', '/Fairview/'],
#  ['Farmington (MN)', '/Farmington/'],
#  ['Ferris (WA)', '/Ferris/'],
#  ['Fort Collins (CO)', '/Fort%20Collins/'],
#  ['Fox Chapel (PA)', '/Fox%20Chapel/'],
#  ['Fremont (CA)', '/Fremont/'],
#  ['Galloway (GA)', '/Galloway/'],
#  ['Galloway School (GA)', '/Galloway%20School/'],
#  ['Garfield (WA)', '/Garfield/'],
#  ['George Washington (CO)', '/George%20Washington/'],
#  ['Georgetown Day (DC)', '/Georgetown%20Day/'],
#  ['Gilman (MD)', '/Gilman/'],
#  ['Glenbrook North (IL)', '/Glenbrook%20North/'],
#  ['Glenbrook South (IL)', '/Glenbrook%20South/'],
#  ['Glendale (MO)', '/Glendale/'],
#  ['Grace (TX)', '/Grace/'],
#  ['Grand Rapids City (MI)', '/Grand%20Rapids%20City/'],
#  ['Grapevine (TX)', '/Grapevine/'],
#  ['Green Valley (NV)', '/Green%20Valley/'],
#  ['Greenhill (TX)', '/Greenhill/'],
#  ['Greenwood Lab School (MO)', '/Greenwood%20Lab%20School/'],
#  ['Groves (MI)', '/Groves/'],
#  ['Gulliver (FL)', '/Gulliver/'],
#  ['Gunn (CA)', '/Gunn/'],
#  ['Guyer (TX)', '/Guyer/'],
#  ['H H Dow (MI)', '/H%20H%20Dow/'],
#  ['Hamilton (AZ)', '/Hamilton/'],
#  ['Harbor Teacher Prep (CA)', '/Harbor%20Teacher%20Prep/'],
#  ['Harding Charter Prep (OK)', '/Harding%20Charter%20Prep/'],
#  ['Harker (CA)', '/Harker/'],
#  ['Harvard Westlake (CA)', '/Harvard%20Westlake/'],
#  ['Hawken (OH)', '/Hawken/'],
#  ['Hawknatius (OH)', '/Hawknatius/'],
#  ['Head Royce (CA)', '/Head%20Royce/'],
#  ['Hebron (TX)', '/Hebron/'],
#  ['Heights (TX)', '/Heights/'],
#  ['Hendrickson (TX)', '/Hendrickson/'],
#  ['Henry M Gunn (CA)', '/Henry%20M%20Gunn/'],
#  ['Henry W Grady (GA)', '/Henry%20W%20Grady/'],
#  ['Heritage Hall (OK)', '/Heritage%20Hall/'],
#  ['Highland (ID)', '/Highland/'],
#  ['Highland Park (MN)', '/Highland%20Park/'],
#  ['Highland Park Dallas (TX)', '/Highland%20Park%20Dallas/'],
#  ['Homestead (WI)', '/Homestead/'],
#  ['Hoover (OH)', '/Hoover/'],
#  ['Houston (TX)', '/Houston/'],
#  ['Houston Memorial (TX)', '/Houston%20Memorial/'],
#  ['Humanities And Arts (CA)', '/Humanities%20And%20Arts/'],
#  ['Hume Fogg (TN)', '/Hume%20Fogg/'],
#  ['Hunter College (NY)', '/Hunter%20College/'],
#  ['Hyattsville Independent (MD)', '/Hyattsville%20Independent/'],
#  ['Immaculate Heart (CA)', '/Immaculate%20Heart/'],
#  ['Independence Independent (TX)', '/Independence%20Independent/'],
#  ['Ingraham (WA)', '/Ingraham/'],
#  ['Inspired Teaching (DC)', '/Inspired%20Teaching/'],
#  ['Interlake (WA)', '/Interlake/'],
#  ['Iowa City City (IA)', '/Iowa%20City%20City/'],
#  ['Iowa City West (AL)', '/Iowa%20City%20West/'],
#  ['Irma Rangel YWLS (TX)', '/Irma%20Rangel%20YWLS/'],
#  ['Isidore Newman (LA)', '/Isidore%20Newman/'],
#  ['Jack C Hays (TX)', '/Jack%20C%20Hays/'],
#  ['Jackson (OH)', '/Jackson/'],
#  ['James Logan (CA)', '/James%20Logan/'],
#  ['James Madison (NY)', '/James%20Madison/'],
#  ['Jefferson City (MO)', '/Jefferson%20City/'],
#  ['Jenks (OK)', '/Jenks/'],
#  ['Jesuit Dallas (TX)', '/Jesuit%20Dallas/'],
#  ['John C Fremont (CA)', '/John%20C%20Fremont/'],
#  ['Johns Creek (GA)', '/Johns%20Creek/'],
#  ['Jones College Prep (IL)', '/Jones%20College%20Prep/'],
#  ['Josiah Quincy (MA)', '/Josiah%20Quincy/'],
#  ['Juan Diego (UT)', '/Juan%20Diego/'],
#  ['Juicewrld Intermediate (ID)', '/Juicewrld%20Intermediate/'],
#  ['KIPP San Francisco College Preparatory (CA)',
#   '/KIPP%20San%20Francisco%20College%20Preparatory/'],
#  ['KIS (MD)', '/KIS/'],
#  ['Kamiak (WA)', '/Kamiak/'],
#  ['Kapaun Mount Carmel (KS)', '/Kapaun%20Mount%20Carmel/'],
#  ['Kennedy (IL)', '/Kennedy/'],
#  ['Kent Denver (CO)', '/Kent%20Denver/'],
#  ['Kenwood (IL)', '/Kenwood/'],
#  ['Kerr (TX)', '/Kerr/'],
#  ['Kickapoo (MO)', '/Kickapoo/'],
#  ['Kinkaid (TX)', '/Kinkaid/'],
#  ['La Crosse Central (WI)', '/La%20Crosse%20Central/'],
#  ['La Cueva (NM)', '/La%20Cueva/'],
#  ['La Reina (CA)', '/La%20Reina/'],
#  ['La Salle College (PA)', '/La%20Salle%20College/'],
#  ['Lake City (ID)', '/Lake%20City/'],
#  ['Lake Travis (TX)', '/Lake%20Travis/'],
#  ['Lane Tech (IL)', '/Lane%20Tech/'],
#  ['Langham Creek (TX)', '/Langham%20Creek/'],
#  ['Lansing (KS)', '/Lansing/'],
#  ['Law Magnet (TX)', '/Law%20Magnet/'],
#  ['Lawrence (KS)', '/Lawrence/'],
#  ['Lawrence Free State (KS)', '/Lawrence%20Free%20State/'],
#  ['Lees Summit West (MO)', '/Lees%20Summit%20West/'],
#  ['Leland (CA)', '/Leland/'],
#  ['Leon M Goldstein (NY)', '/Leon%20M%20Goldstein/'],
#  ['Lewis And Clark (WA)', '/Lewis%20And%20Clark/'],
#  ['Lexington (MA)', '/Lexington/'],
#  ['Liberal Arts And Science Academy (TX)',
#   '/Liberal%20Arts%20And%20Science%20Academy/'],
#  ['Liberty (MO)', '/Liberty/'],
#  ['Lilburn (GA)', '/Lilburn/'],
#  ['Lincoln (OR)', '/Lincoln/'],
#  ['Lincoln CA (CA)', '/Lincoln%20CA/'],
#  ['Lincoln East (NE)', '/Lincoln%20East/'],
#  ['Lincoln North Star (NE)', '/Lincoln%20North%20Star/'],
#  ['Lincoln Park (IL)', '/Lincoln%20Park/'],
#  ['Lincoln Southeast (NE)', '/Lincoln%20Southeast/'],
#  ['Lindale (TX)', '/Lindale/'],
#  ['Lindblom (IL)', '/Lindblom/'],
#  ['Little Rock Central (AR)', '/Little%20Rock%20Central/'],
#  ['Lone Peak (UT)', '/Lone%20Peak/'],
#  ['Long Branch (NJ)', '/Long%20Branch/'],
#  ['Lovejoy (TX)', '/Lovejoy/'],
#  ['Lowell (CA)', '/Lowell/'],
#  ['Madison Central (MS)', '/Madison%20Central/'],
#  ['Madison East (WI)', '/Madison%20East/'],
#  ['Maine East (IL)', '/Maine%20East/'],
#  ['Maize (KS)', '/Maize/'],
#  ['Mamaroneck (NY)', '/Mamaroneck/'],
#  ['Manhattan (KS)', '/Manhattan/'],
#  ['Maplewood (MO)', '/Maplewood/'],
#  ['Marian (MI)', '/Marian/'],
#  ['Marquette (WI)', '/Marquette/'],
#  ['Maywood (CA)', '/Maywood/'],
#  ['McCormack (MA)', '/McCormack/'],
#  ['McDonogh (MD)', '/McDonogh/'],
#  ['McDonough (MD)', '/McDonough/'],
#  ['McDowell (PA)', '/McDowell/'],
#  ['McLain (OK)', '/McLain/'],
#  ['McQueen (NV)', '/McQueen/'],
#  ['Mckinney Boyd (TX)', '/Mckinney%20Boyd/'],
#  ['Melissa (TX)', '/Melissa/'],
#  ['Midland (MI)', '/Midland/'],
#  ['Midway Academy Of Fine Arts (TX)', '/Midway%20Academy%20Of%20Fine%20Arts/'],
#  ['Mill Valley (KS)', '/Mill%20Valley/'],
#  ['Millard North (NE)', '/Millard%20North/'],
#  ['Millard South (NE)', '/Millard%20South/'],
#  ['Millard West (NE)', '/Millard%20West/'],
#  ['Minneapolis South (MN)', '/Minneapolis%20South/'],
#  ['Minneapolis Washburn (MN)', '/Minneapolis%20Washburn/'],
#  ['Miramonte (CA)', '/Miramonte/'],
#  ['ModernBrain (CA)', '/ModernBrain/'],
#  ['Montgomery Bell (TN)', '/Montgomery%20Bell/'],
#  ['Montgomery Blair (MD)', '/Montgomery%20Blair/'],
#  ['Moore (OK)', '/Moore/'],
#  ['Mount Pleasant (TX)', '/Mount%20Pleasant/'],
#  ['Mount Vernon (AL)', '/Mount%20Vernon/'],
#  ['Mountain Brook (AL)', '/Mountain%20Brook/'],
#  ['Mountain House (CA)', '/Mountain%20House/'],
#  ['Nashua South (NH)', '/Nashua%20South/'],
#  ['Neenah (WI)', '/Neenah/'],
#  ['Nevada Union (CA)', '/Nevada%20Union/'],
#  ['Neville (LA)', '/Neville/'],
#  ['New Designs UP (CA)', '/New%20Designs%20UP/'],
#  ['New Mission (MA)', '/New%20Mission/'],
#  ['New Technology (CA)', '/New%20Technology/'],
#  ['New Trier (IL)', '/New%20Trier/'],
#  ['Newark Science (NJ)', '/Newark%20Science/'],
#  ['NewarkTech (NJ)', '/NewarkTech/'],
#  ['Newton (KS)', '/Newton/'],
#  ['Niles North (IL)', '/Niles%20North/'],
#  ['Niles West (IL)', '/Niles%20West/'],
#  ['Norman North (OK)', '/Norman%20North/'],
#  ['North Allegheny (PA)', '/North%20Allegheny/'],
#  ['North Broward Prep (FL)', '/North%20Broward%20Prep/'],
#  ['North Central (WA)', '/North%20Central/'],
#  ['North Liberty (IA)', '/North%20Liberty/'],
#  ['NorthStar (NJ)', '/NorthStar/'],
#  ['Northridge (UT)', '/Northridge/'],
#  ['Northside (IL)', '/Northside/'],
#  ['Northview (AL)', '/Northview/'],
#  ['Northwest (NV)', '/Northwest/'],
#  ['Northwest TX (TX)', '/Northwest%20TX/'],
#  ['Northwestern (MD)', '/Northwestern/'],
#  ['Northwood (CA)', '/Northwood/'],
#  ['Notre Dame (CA)', '/Notre%20Dame/'],
#  ['OBryant (MA)', '/OBryant/'],
#  ['Oak Grove (CA)', '/Oak%20Grove/'],
#  ['Oak Hall (FL)', '/Oak%20Hall/'],
#  ['Oak Hill (OR)', '/Oak%20Hill/'],
#  ['Oak Park River Forest (IL)', '/Oak%20Park%20River%20Forest/'],
#  ['Oakland Tech (CA)', '/Oakland%20Tech/'],
#  ['Oakton (VA)', '/Oakton/'],
#  ['Oakton Independent (VA)', '/Oakton%20Independent/'],
#  ['Okemos (MI)', '/Okemos/'],
#  ['Olathe East (KS)', '/Olathe%20East/'],
#  ['Olympia (FL)', '/Olympia/'],
#  ['Omaha Marian (NE)', '/Omaha%20Marian/'],
#  ['Oregon Episcopal School (OR)', '/Oregon%20Episcopal%20School/'],
#  ['Padre Pio Academy (OH)', '/Padre%20Pio%20Academy/'],
#  ['Palo Verde (NV)', '/Palo%20Verde/'],
#  ['Park Hill (MO)', '/Park%20Hill/'],
#  ['Park Hill South (MO)', '/Park%20Hill%20South/'],
#  ['Parkview (MO)', '/Parkview/'],
#  ['Parkview Magnet (AR)', '/Parkview%20Magnet/'],
#  ['Parkway (LA)', '/Parkway/'],
#  ['Peninsula (CA)', '/Peninsula/'],
#  ['Penn (IN)', '/Penn/'],
#  ['Perry (OH)', '/Perry/'],
#  ['Phoenix Country Day School (AZ)', '/Phoenix%20Country%20Day%20School/'],
#  ['Phoenix Military Academy (IL)', '/Phoenix%20Military%20Academy/'],
#  ['Pine Crest (FL)', '/Pine%20Crest/'],
#  ['Pine Crest School (FL)', '/Pine%20Crest%20School/'],
#  ['Piper (KS)', '/Piper/'],
#  ['Pittsburg (KS)', '/Pittsburg/'],
#  ['Pittsburgh Central Catholic (PA)', '/Pittsburgh%20Central%20Catholic/'],
#  ['Plano East (TX)', '/Plano%20East/'],
#  ['Plano West (TX)', '/Plano%20West/'],
#  ['Pocatello (ID)', '/Pocatello/'],
#  ['Poly Prep (NY)', '/Poly%20Prep/'],
#  ['Polytechnic (CA)', '/Polytechnic/'],
#  ['Port Of Los Angeles (CA)', '/Port%20Of%20Los%20Angeles/'],
#  ['Presentation (CA)', '/Presentation/'],
#  ['Princeton (TX)', '/Princeton/'],
#  ['Princeton NJ (NJ)', '/Princeton%20NJ/'],
#  ['Prosper (TX)', '/Prosper/'],
#  ['Providence (NC)', '/Providence/'],
#  ['Rancho (CA)', '/Rancho/'],
#  ['Rancho San Joaquin (CA)', '/Rancho%20San%20Joaquin/'],
#  ['RaymorePeculiar (MO)', '/RaymorePeculiar/'],
#  ['Reagan (TX)', '/Reagan/'],
#  ['Riverfield (OK)', '/Riverfield/'],
#  ['Riverwood (GA)', '/Riverwood/'],
#  ['Rock Springs (WY)', '/Rock%20Springs/'],
#  ['Rockdale County (GA)', '/Rockdale%20County/'],
#  ['Rocky Mountain (CO)', '/Rocky%20Mountain/'],
#  ['Roosevelt (MN)', '/Roosevelt/'],
#  ['Rosemont (CA)', '/Rosemont/'],
#  ['Rosemount (MN)', '/Rosemount/'],
#  ['Roseville (MN)', '/Roseville/'],
#  ['Roswell (GA)', '/Roswell/'],
#  ['Round Rock (TX)', '/Round%20Rock/'],
#  ['Rowland Hall (UT)', '/Rowland%20Hall/'],
#  ['Rufus King (WI)', '/Rufus%20King/'],
#  ['Rural Independent (KS)', '/Rural%20Independent/'],
#  ['SA Harlem North Central (NJ)', '/SA%20Harlem%20North%20Central/'],
#  ['SA Queens (NY)', '/SA%20Queens/'],
#  ['SLC West (UT)', '/SLC%20West/'],
#  ['SPASH (WI)', '/SPASH/'],
#  ['STEAM Legacy (CA)', '/STEAM%20Legacy/'],
#  ['SWW (DC)', '/SWW/'],
#  ['Saint Georges (WA)', '/Saint%20Georges/'],
#  ['Salem Hills (UT)', '/Salem%20Hills/'],
#  ['Shawnee Mission East (KS)', '/Shawnee%20Mission%20East/'],
#  ['Shawnee Mission North (KS)', '/Shawnee%20Mission%20North/'],
#  ['Shawnee Mission Northwest (KS)', '/Shawnee%20Mission%20Northwest/'],
#  ['Shawnee Mission South (KS)', '/Shawnee%20Mission%20South/'],
#  ['Shawnee Mission West (KS)', '/Shawnee%20Mission%20West/'],
#  ['Sidwell Friends (DC)', '/Sidwell%20Friends/'],
#  ['Silver Creek (CA)', '/Silver%20Creek/'],
#  ['Sioux Falls (SD)', '/Sioux%20Falls/'],
#  ['Sioux Falls Roosevelt (SD)', '/Sioux%20Falls%20Roosevelt/'],
#  ['Sky View (UT)', '/Sky%20View/'],
#  ['Skyline UT (UT)', '/Skyline%20UT/'],
#  ['Slocum (TX)', '/Slocum/'],
#  ['Solon (OH)', '/Solon/'],
#  ['Solorio (IL)', '/Solorio/'],
#  ['Sonoma Academy (CA)', '/Sonoma%20Academy/'],
#  ['South Eugene (OR)', '/South%20Eugene/'],
#  ['South Gate (CA)', '/South%20Gate/'],
#  ['Springfield Catholic (MO)', '/Springfield%20Catholic/'],
#  ['St Andrews Episcopal School (MS)', '/St%20Andrews%20Episcopal%20School/'],
#  ['St Francis (CA)', '/St%20Francis/'],
#  ['St Ignatius (OH)', '/St%20Ignatius/'],
#  ['St Marks (TX)', '/St%20Marks/'],
#  ['St Paul Central (MN)', '/St%20Paul%20Central/'],
#  ['Stanford Online (CA)', '/Stanford%20Online/'],
#  ['Stern MASS (CA)', '/Stern%20MASS/'],
#  ['Stockdale (CA)', '/Stockdale/'],
#  ['Strath Haven (PA)', '/Strath%20Haven/'],
#  ['Stuyvesant (NY)', '/Stuyvesant/'],
#  ['Success Academy Bronx (NY)', '/Success%20Academy%20Bronx/'],
#  ['Success Academy DP (NY)', '/Success%20Academy%20DP/'],
#  ['Success Academy Midtown West (NY)', '/Success%20Academy%20Midtown%20West/'],
#  ['Summit Christian Academy (MO)', '/Summit%20Christian%20Academy/'],
#  ['The Meadows School (NV)', '/The%20Meadows%20School/'],
#  ['Thomas Jefferson (VA)', '/Thomas%20Jefferson/'],
#  ['Thomas Kelly (IL)', '/Thomas%20Kelly/'],
#  ['Topeka (KS)', '/Topeka/'],
#  ['Trinity (TX)', '/Trinity/'],
#  ['Trinity Academy (KS)', '/Trinity%20Academy/'],
#  ['Truman (MO)', '/Truman/'],
#  ['Tuloso Midway (TX)', '/Tuloso%20Midway/'],
#  ['Tulsa Union (OK)', '/Tulsa%20Union/'],
#  ['U Chicago Lab (IL)', '/U%20Chicago%20Lab/'],
#  ['USN (TN)', '/USN/'],
#  ['Unionville (PA)', '/Unionville/'],
#  ['University (CA)', '/University/'],
#  ['University Hi (WA)', '/University%20Hi/'],
#  ['VHTPA (CA)', '/VHTPA/'],
#  ['VIP (CA)', '/VIP/'],
#  ['Valdosta (GA)', '/Valdosta/'],
#  ['Valle De Mill (KS)', '/Valle%20De%20Mill/'],
#  ['Valor (CA)', '/Valor/'],
#  ['Vespa College Prep (CA)', '/Vespa%20College%20Prep/'],
#  ['Village (TX)', '/Village/'],
#  ['Vista Ridge (TX)', '/Vista%20Ridge/'],
#  ['WB Ray (TX)', '/WB%20Ray/'],
#  ['Waco Midway (TX)', '/Waco%20Midway/'],
#  ['Wakeland (TX)', '/Wakeland/'],
#  ['Wallenberg (CA)', '/Wallenberg/'],
#  ['Walter Payton (IL)', '/Walter%20Payton/'],
#  ['Washburn Rural (KS)', '/Washburn%20Rural/'],
#  ['Washington (SD)', '/Washington/'],
#  ['Washington Latin (DC)', '/Washington%20Latin/'],
#  ['Wayzata (MN)', '/Wayzata/'],
#  ['West Campus (CA)', '/West%20Campus/'],
#  ['West Des Moines Valley (IA)', '/West%20Des%20Moines%20Valley/'],
#  ['Westminster (GA)', '/Westminster/'],
#  ['Westside (TX)', '/Westside/'],
#  ['Westview (OR)', '/Westview/'],
#  ['Westwood (TX)', '/Westwood/'],
#  ['Wheeler (GA)', '/Wheeler/'],
#  ['Whitney Young (IL)', '/Whitney%20Young/'],
#  ['Wichita East (KS)', '/Wichita%20East/'],
#  ['Will Rogers (OK)', '/Will%20Rogers/'],
#  ['Willard (MO)', '/Willard/'],
#  ['William Chrisman (MO)', '/William%20Chrisman/'],
#  ['Winston Churchill (TX)', '/Winston%20Churchill/'],
#  ['Woodward (GA)', '/Woodward/'],
#  ['Wooster (OH)', '/Wooster/'],
#  ['Wylie (TX)', '/Wylie/'],
#  ['Yerba Buena (CA)', '/Yerba%20Buena/']]

# %% [markdown]
# #### School Page
#
# Take the URL to a school and return a list of debaters and the URLs that point to their Aff and Neg pages

# %%
# return aff and neg URLs for all the debaters of a given school

def getTeams(url):
    
    # try opening URL
    try:
        html = urlopen(url).read()
    except Exception:
        return (0, [], {}, "School URL broke")
        
    # soupify
    soup = BeautifulSoup(html, "html.parser")
    
    # look for a table
    if len(soup.find_all("table")):
        table = soup.find_all("table")[0]
    else:
        return (0, [], {}, "School page not set up")
        
    # exclude header
    numDebaters = len(table.find_all('tr'))-1
    
    if numDebaters == 0:
        return (0, [], {}, "No debaters listed")
    
    # track team names and map to URLs
    teamNames = []
    pageURLs = {}
    
    
    # for each table row
    for row in table.find_all('tr')[1:]:
        
        # the first column's string is the team name
        team = row.find('td').string
        teamNames.append(team)
        
        # collect the URLs to the aff and neg page
        links = row.find_all('a')
        URLs = [link.get("href") for link in links]
        pageURLs[team] = URLs
    
    return (numDebaters, teamNames, pageURLs, "")

# %%
getTeams("https://hspolicy19.debatecoaches.org/Advanced%20Technologies%20Academy")
# Out:
# (3,
#  ['Advanced Technologies Academy Jacqueline Balanovsky - Raymond Behnke',
#   'Advanced Technologies Academy Sam Self - Jonah Gentleman',
#   'Advanced Technologies Academy Ryan Fritchel - Hannah Lewis'],
#  {'Advanced Technologies Academy Jacqueline Balanovsky - Raymond Behnke': ['/Advanced%20Technologies%20Academy/Balanovsky-Behnke%20Aff',
#    '/Advanced%20Technologies%20Academy/Balanovsky-Behnke%20Neg'],
#   'Advanced Technologies Academy Sam Self - Jonah Gentleman': ['/Advanced%20Technologies%20Academy/Self-Gentleman%20Aff',
#    '/Advanced%20Technologies%20Academy/Self-Gentleman%20Neg'],
#   'Advanced Technologies Academy Ryan Fritchel - Hannah Lewis': ['/Advanced%20Technologies%20Academy/Fritchel-Lewis%20Aff',
#    '/Advanced%20Technologies%20Academy/Fritchel-Lewis%20Neg']},
#  '')

# %% [markdown]
# #### Team Page

# %%
def getDisclosure(url):

    # try opening URL
    try:
        html = urlopen(url).read().decode('utf-8-sig')
        
    except Exception:
        return {"Team URL":url,
                "Rounds": [],
                "Round Reports": [],
                "Cites": [],
                "Errors": "Did not open"}
    
    
    # soupify
    soup = BeautifulSoup(html, "html.parser")
    
    tables = soup.find_all("table")

    if len(tables) > 2:
        
        rnds = tables[0]
        rndrprts = tables[1]
        cts = tables[2]
    
    else:
        
        return {"Team URL":url,
                "Rounds": [],
                "Round Reports": [],
                "Cites": [],
                "Errors": "Not configured properly"}
    
    # collect all rounds
    rounds = []
    
    for row in rnds.find_all("tr")[1:]:
        
        # get pieces
        cols = row.find_all("td")
        trn = cols[0].text
        rnd = cols[1].text
        opp = cols[2].text
        jdg = cols[3].text
        osrc = cols[6].find("a")
        if osrc:
            docURL = osrc.get("href")
        else:
            docURL = ""
            
        rounds.append([trn, rnd, opp, jdg, docURL])
    
    # collect all round reports
    roundReports = []
    
    for row in rndrprts.find_all("tr")[1:]:
        try:
            pars = roundReports.append(row.find_all("td")[2].find_all("p")[1].text)
        except:
            continue

    # collect all cites
    cites = [row.find_all("td")[0].find("span").text for row in cts.find_all('tr')[1:]]
        
    return {"Team URL":url,
            "Rounds": rounds,
            "Round Reports": roundReports,
            "Cites": cites,
            "Errors": ""}

# %%
getDisclosure("https://hsld17.debatecoaches.org/Acton-Boxborough/Liu%20Aff")
# Out:
# {'Team URL': 'https://hsld17.debatecoaches.org/Acton-Boxborough/Liu%20Aff',
#  'Rounds': [['-', 'Finals', '-', '-', ''],
#   ['Harvard', '2', 'Dan Shahab', 'David Moon', ''],
#   ['Lexington Winter Invitational', '2', 'Scarsdale AW', 'David Moon', ''],
#   ['Newark Invitational', '4', 'Stuyvesant JL', 'Amit Kukreja', ''],
#   ['Practice Round', '1', 'Michelle I drop T Li', 'the coolest judge', ''],
#   ['Practice Round', 'Semis', '-', '-', '']],
#  'Round Reports': [],
#  'Cites': ['Contact',
#   'JF - Brown Bear AC',
#   'JF - Brown Bear AC v2',
#   'JF - Brown Bear AC v3',
#   'JF - Deleuzian Narrativity 1AC'],
#  'Errors': ''}

# %% [markdown]
# #### Execution
#
# Loop through wikis, find all schools, visit all entry pages, scrape all positions.

# %%
for wiki in WIKIS:
    
    # unpack wiki
    wikiName = wiki[0]
    wikiURL = wiki[1]
    
    # if not in target wikis, don't write
    if wikiName not in TARGET_WIKIS:
        continue
    
    # if it exists, don't overwrite
    if (not OVERWRITE) and path.exists(OUTPATH + wikiName + "_schools_wiki.csv"):
        continue
        
    # open output file
    with open(OUTPATH + wikiName + "schools_wiki.csv", 'w', encoding="utf-8") as SCHOOLFILE, open(OUTPATH + wikiName + "teams_wiki.csv", 'w', encoding="utf-8") as TEAMFILE:
        
        # instantaite writer
        schoolWriter = csv.DictWriter(SCHOOLFILE,
                                     fieldnames = ["School Name",
                                                   "School URL",
                                                   "School Teams",
                                                   "Errors"],
                                      quotechar='"', 
                                      quoting=csv.QUOTE_NONNUMERIC,
                                     lineterminator = "\n")
        
        # write header
        schoolWriter.writeheader()
        
        # instantaite writer
        teamWriter = csv.DictWriter(TEAMFILE,
                                    fieldnames = ["Team Name",
                                                  "Side",
                                                  "Team URL",
                                                  "Rounds",
                                                  "Round Reports",
                                                  "Cites",
                                                  "Errors"],
                                    lineterminator = "\n")
        
        # write header
        teamWriter.writeheader()
            
        print("Scraping " + wikiName)
        
        # get school URLs
        schools = getSchools(wikiURL)
        
        print("There are " + str(len(schools)) + " schools")
        
        for school in schools:
            
            # get school name and URL
            schoolName, schoolURL = school[0], wikiURL + school[1]
            
            print("Checking " + schoolName)
            
            # get teams from the school
            numTeams, teamNames, teamURLs, errors = getTeams(schoolURL)
            
            print("Found " + str(numTeams) + " teams")
            
            # write school information
            schoolWriter.writerow({"School Name" : schoolName,
                                  "School URL": schoolURL,
                                  "School Teams": teamNames,
                                  "Errors": errors})
            
            for team in teamNames:
                
                try:
                
                    print("Scraping " + team)

                    # get team URL
                    teamURL = teamURLs[team]
                    affURL = wikiURL + teamURL[0]
                    negURL = wikiURL + teamURL[1]

                    # aff scraping
                    affInfo = getDisclosure(affURL)
                    affInfo["Team Name"] = team
                    affInfo["Side"] = "Aff"

                    # write aff info
                    teamWriter.writerow(affInfo)

                    # neg scraping
                    negInfo = getDisclosure(negURL)
                    negInfo["Team Name"] = team
                    negInfo["Side"] = "Neg"

                    # write neg info
                    teamWriter.writerow(negInfo)
                    
                except:
                    
                    print(team + " failed.")
# Out:
# Scraping LD14
# There are 250 schools
# Checking Aberdeen Central (SD)
# Found 1 teams
# Scraping Aberdeen Central - Sam Mehlhaff
# Checking Anderson (TX)
# Found 5 teams
# Scraping Anderson - Brian Lee
# Scraping Anderson - Bailey Dettmer
# Scraping Anderson - Isaac Swedlow
# Scraping Anderson - James Thomason
# Scraping Anderson - Adam Beach
# Checking Annie Wright (WA)
# Found 1 teams
# Scraping Annie Wright - Anisha Vora
# Checking Apple Valley (MN)
# Found 4 teams
# Scraping Apple Valley - Prince Hyeamang
# Scraping Apple Valley - Grace Haffa
# Scraping Apple Valley - John Boals
# Scraping Apple Valley - Henry Dikeman
# Checking Appleton East (WI)
# Found 2 teams
# Scraping Appleton East - Brad Arnoldussen
# Scraping Appleton East - Jack Vogel
# Checking Arbor View (NV)
# Found 1 teams
# Scraping Arbor View - Arjun Arora
# Checking Arcadia (CA)
# Found 3 teams
# Scraping Arcadia - Victor Li
# Scraping Arcadia - Morven Sharp
# Scraping Arcadia - Victor Luo
# Checking Ashland (OR)
# Found 0 teams
# Checking Bainbridge (WA)
# Found 1 teams
# Scraping Cambridge Rindge - Paloma OConnor
# Scraping Cambridge Rindge - Oliver Sussman
# Checking Canyon Springs (NV)
# Found 2 teams
# Scraping Canyon Springs - Ayleen Perry
# Scraping Canyon Springs - Gavin Garcia
# Checking Carpe Diem (NJ)
# Found 0 teams
# Checking Cedar Park (TX)
# Found 2 teams
# Scraping Cedar Park - Morgan Grosch
# Scraping Cedar Park - Macalah Thomas
# Checking Cedar Ridge (TX)
# Found 1 teams
# Scraping Cedar Ridge - Raunak Pillai
# Checking Centennial (ID)
# Found 1 teams
# Scraping Centennial - Zane Miller
# Checking Center For Talented Youth (MD)
# Found 0 teams
# Checking Cerritos (CA)
# Found 1 teams
# Scraping Cerritos - John Cho
# Checking Chaminade (CA)
# Found 7 teams
# Scraping Chaminade - Axel Sarkissian
# Scraping Chaminade - Emilio Rivera
# Scraping Chaminade - Bhaskar Suri
# Scraping Chaminade - Leo Kim
# Scraping Chaminade - Jeremiah Cha
# Scraping Chaminade - Shreya Yepuri
# Scraping Chaminade - Brian Gilmartin
# Checking Chandler (AZ)
# Found 1 teams
# Scraping Chandler - Nikpreet Singh
# Checking Chandler Prep (AZ)
# Found 0 teams
# Checking Charles E Smith (MD)
# Found 0 teams
# Checking Christ Episcopal (LA)
# Found 0 teams
# Checking Christopher Columbus (FL)
# Found 0 teams
# Checking Citrus Valley (CA)
# Found 0 teams
# Checking Claremont (CA)
# Found 0 teams
# Checking Clear Brook (TX)
# Found 0 teams
# Checking Clements (TX)
# Found 3 teams
# Scraping Clements - Rebecca Gelfer
# Scraping Clements - Felix Tan
# Scraping Clements - Edward Metelitsa
# Checking College Prep (CA)
# Found 1 teams
# Scraping College Prep - Meher George
# Checking Collegiate (NY)
# Found 3 teams
# Scraping Collegiate - Dean Kieserman
# Scraping Collegiate - Eric Wallach
# Scraping Collegiate - David Moon
# Checking Colleyville Heritage (TX)
# Found 3 teams
# Scraping Colleyville - Alizah Charaniya
# Scraping Colleyville - Rachana Kolli
# Scraping Colleyville - Inaara Shiraz
# Checking Concord Carlisle (MA)
# Found 1 teams
# Scraping Concord Carlisle - Daniel Lu
# Checking Concordia Lutheran (TX)
# Found 0 teams
# Checking Coral Science (NV)
# Found 2 teams
# Scraping Coral Science - Shadden Abdalla
# Scraping Coral Science - Arbab Khalid
# Checking Coral Springs (FL)
# Found 1 teams
# Scraping Coral Springs - Every Debater
# Checking Coppell (TX)
# Found 1 teams
# Scraping Coppell - Varshni Muralidharan
# Checking Copper Hills (UT)
# Found 0 teams
# Checking Crandall (TX)
# Found 1 teams
# Scraping Crandall - Graham Phlieger
# Checking Crossroads (CA)
# Found 1 teams
# Scraping Crossroads - Noah Simon
# Checking Cy-Fair (TX)
# Found 2 teams
# Scraping Cy-Fair - Cameron McConway
# Scraping Cy-Fair - Tess Welch
# Checking Cypress Bay (FL)
# Found 2 teams
# Scraping Cypress Bay - Jake Steirn
# Scraping Cypress Bay - Shawn Hatchwell
# Checking Cypress Falls (TX)
# Found 2 teams
# Scraping Cypress Falls - Syeda Hubbul Rizvi
# Scraping Cypress Falls - Karman NewSingh
# Checking Cypress Ridge (TX)
# Found 0 teams
# Checking Cypress Woods (TX)
# Found 2 teams
# Scraping Cypress Woods - Natasha Stewart
# Scraping Cypress Woods - Conner Fiedler
# Checking Delbarton (NJ)
# Found 2 teams
# Scraping Delbarton - Vinayak Kumar
# Scraping Delbarton - Ethan Czerniecki
# Checking Derby (KS)
# Found 0 teams
# Checking Des Moines Roosevelt (IA)
# Found 1 teams
# Scraping Des Moines Roosevelt - Emma Weddle
# Checking Desert Vista (AZ)
# Found 1 teams
# Scraping Desert Vista - Lauren Barney
# Checking Dobson (AZ)
# Found 0 teams
# Checking Dougherty Valley (CA)
# Found 4 teams
# Scraping Dougherty Valley - Sameer Ziaee
# Scraping Dougherty Valley - Rohan Bhargava
# Scraping Dougherty Valley - Connor Riano
# Scraping Dougherty Valley - Chait Sayani
# Checking Dowling Catholic (IA)
# Found 3 teams
# Scraping Dowling Catholic - Cati Kalinoski
# Scraping Dowling Catholic - Dillon Kladivo
# Scraping Dowling Catholic - Joie Otting
# Checking Dulles (TX)
# Found 7 teams
# Scraping Dulles - Kevin Si
# Scraping Dulles - Nolan Burdett
# Scraping Dulles - Kathie Lin
# Scraping Dulles - Suchin Kundra
# Scraping Dulles - Ashish Wadhwani
# Scraping Dulles - Shruthi Avantsa
# Scraping Dulles - Nima Nayeri
# Checking Eastside Catholic (WA)
# Found 1 teams
# Scraping Eastside Catholic - Tinuola Dada
# Checking Edmond Santa Fe (OK)
# Found 2 teams
# Scraping Edmond Santa Fe - Ian Mooers
# Scraping Edmond Santa Fe - Madison Witman
# Checking Elkins (TX)
# Found 0 teams
# Checking Enloe (NC)
# Found 1 teams
# Scraping Enloe - Cory You
# Checking Episcopal (TX)
# Found 1 teams
# Scraping Episcopal - Adam Brown
# Checking Evanston (IL)
# Found 3 teams
# Scraping Evanston - Eric Weine
# Scraping Evanston - Joey Schnide
# Scraping Evanston - Carlos Taylor
# Checking Evergreen Valley (CA)
# Found 4 teams
# Scraping Evergreen Valley - Kaustubh Vinchure
# Scraping Evergreen Valley - Violet Sinnarkar
# Scraping Evergreen Valley - Amit Tallapragada
# Scraping Evergreen Valley - Ramneek Singh
# Checking Flintridge Sacred Heart (CA)
# Found 1 teams
# Scraping Flintridge - Madeline Collins
# Checking Flower Mound (TX)
# Found 5 teams
# Scraping Flower Mound - Jalaj Sood
# Scraping Flower Mound - Audrey Zhang
# Scraping Flower Mound - Harshita Davuluri
# Scraping Flower Mound - Amany AbuHijleh
# Scraping Flower Mound - Jeremy Ling Tsai
# Checking Fordham Prep (NY)
# Found 0 teams
# Checking Fort Lauderdale (FL)
# Found 0 teams
# Checking Frontier (MO)
# Found 0 teams
# Checking George Ranch (TX)
# Found 0 teams
# Checking Gig Harbor (WA)
# Found 3 teams
# Scraping Gig Harbor - Cameron Allen
# Scraping Gig Harbor - Alec Bellis
# Scraping Gig Harbor - Max Stephens
# Checking Glenbrook South (IL)
# Found 1 teams
# Scraping Glenbrook South - Jane Joann Brennan Lin
# Checking Grand Junction (CO)
# Found 0 teams
# Checking Mountain View (CA)
# Found 1 teams
# Scraping Mountain View - Derek Zhang
# Checking NCSSM (NC)
# Found 1 teams
# Scraping NCSSM - Tejal Patwardhan
# Checking New Orleans Jesuit (LA)
# Found 2 teams
# Scraping New Orleans Jesuit - Robert Cerise
# Scraping New Orleans Jesuit - Benjamin Gillen
# Checking New Trier (IL)
# Found 2 teams
# Scraping New Trier - Louie Kollar
# Scraping New Trier - Nicky Kacena
# Checking Newark Science (NJ)
# Found 5 teams
# Scraping Newark Science - SunHee Simon
# Scraping Newark Science - Adegoke Fakorede
# Scraping Newark Science - Amit Kukreja
# Scraping Newark Science - Nick Santiago
# Scraping Newark Science - Christian Quiroz
# Checking Newburgh Free Academy (NY)
# Found 0 teams
# Checking North Crowley (TX)
# Found 1 teams
# Scraping North Crowley - Andres Rosero
# Checking Northland Christian (TX)
# Found 3 teams
# Scraping Northland Christian - Davis LaBarre
# Scraping Northland Christian - Margaret Purcell
# Scraping Northland Christian - Madison Lewis
# Checking Oakwood (CA)
# Found 6 teams
# Scraping Oakwood - Jack Wareham
# Scraping Oakwood - James Sanger
# Scraping Oakwood - Alex Bauman
# Scraping Oakwood - Ari Mostow
# Scraping Oakwood - Nathan Mostoww
# Scraping Oakwood - Jack Gill
# Checking Okoboji (IA)
# Found 0 teams
# Checking Oxbridge (FL)
# Found 1 teams
# Scraping Oxbridge - Nalin Vattigunta
# Checking Pacific Ridge (CA)
# Found 1 teams
# Scraping Pacific Ridge - Roshan Srinivasan
# Checking Palo Alto (CA)
# Found 4 teams
# Scraping Palo Alto - Anna Lu
# Scraping Palo Alto - Anant Marur
# Scraping Palo Alto - Griffin Carlson
# Scraping Palo Alto - Ethan Teo
# Checking Palos Verdes Peninsula (CA)
# Found 9 teams
# Scraping Palos Verdes - Akhil Jalan
# Scraping Palos Verdes - James Zhang
# Scraping Palos Verdes - Kris Kaya
# Scraping Palos Verdes - Arjun Tambe
# Scraping Palos Verdes - Catherine Kim
# Scraping Palos Verdes - Ishan Gaur
# Scraping Palos Verdes - Jonas Le Barillec
# Scraping Palos Verdes - Muhannad Hassan
# Scraping Palos Verdes - Moon Sung Gwak
# Checking Park Crossing (AL)
# Found 0 teams
# Checking Peak to Peak (CO)
# Found 0 teams
# Checking Pembroke Pines (FL)
# Found 2 teams
# Scraping Pembroke Pines - Jordan Farenhem
# Scraping Pembroke Pines - Yasmeen Metellus
# Checking Phoenix Country Day (AZ)
# Found 2 teams
# Scraping Phoenix Country Day - Parker Whitfill
# Scraping Phoenix Country Day - Ari Bradshaw
# Checking Plano East (TX)
# Found 3 teams
# Scraping Plano East - Shomik Ati
# Scraping Plano East - Aisha Bawany
# Scraping Plano East - Aimun Khan
# Checking Presentation (CA)
# Found 5 teams
# Scraping Presentation - Mariah Stewart
# Scraping Presentation - Kaitlynn Sierra
# Scraping Presentation - Renuka Garg
# Scraping Presentation - Nancy Hung
# Scraping Presentation - Nithya Kiron
# Checking Princeton (NJ)
# Found 3 teams
# Scraping Princeton - Justin Kim
# Scraping Princeton - Evan ODonnell
# Scraping Princeton - Connor Protter
# Checking Rancho Bernardo (CA)
# Found 4 teams
# Scraping Rancho Bernardo - Ishan Timalsina
# Scraping Rancho Bernardo - Amir Rezvani
# Scraping Rancho Bernardo - Nicholas Rui
# Scraping Rancho Bernardo - Joshua Wee
# Checking Randolph (NJ)
# Found 3 teams
# Scraping Randolph - Harrison Kern
# Scraping Randolph - Sangho Lee
# Scraping Randolph - Rahul Naik
# Checking Reagan (TX)
# Found 2 teams
# Scraping Reagan - Michael Richardson
# Scraping Reagan - Nikunj Patel
# Checking Ridge (NJ)
# Found 5 teams
# Scraping Ridge - Timothy Tang
# Scraping Ridge - Shankar Krishnan
# Scraping Ridge - Neha Pai
# Scraping Ridge - Vikram Kalghatgi
# Scraping Ridge - Aditya Sheth
# Checking Riverside (SC)
# Found 0 teams
# Checking Roseville (MN)
# Found 2 teams
# Scraping Roseville - Dean Doneen
# Scraping Roseville - Nathan Meyer
# Checking Round Rock (TX)
# Found 0 teams
# Checking Rowland Hall (UT)
# Found 2 teams
# Scraping Rowland Hall - David Bernstein
# Scraping Rowland Hall - Kenzo Okazaki
# Checking Sacred Heart (MA)
# Found 1 teams
# Scraping Sacred Heart - Adam Tomasi
# Checking Salado (TX)
# Found 0 teams
# Checking Sammamish (WA)
# Found 0 teams
# Checking San Dieguito (CA)
# Found 0 teams
# Checking San Marino (CA)
# Found 2 teams
# Scraping San Marino - Kirk Wu
# Scraping San Marino - Eric Lau
# Checking SandHoke (NC)
# Found 1 teams
# Scraping SandHoke - Brandon Sweeney
# Checking Saratoga (CA)
# Found 2 teams
# Scraping Saratoga - Rohith Krishna
# Scraping Saratoga - Shrey Desai
# Checking Scarsdale (NY)
# Found 13 teams
# Scraping Scarsdale - Samara Jacobson
# Scraping Scarsdale - David Wang
# Scraping Scarsdale - Michael Bogaty
# Scraping Scarsdale - Rahul Gosain
# Scraping Scarsdale - Lauren Singer
# Scraping Scarsdale - Gustaf Ahdritz
# Scraping Scarsdale - Marie Ceske
# Scraping Scarsdale - Matt Mandel
# Scraping Scarsdale - Zoe Ewing
# Scraping Scarsdale - Emily Chase
# Scraping Scarsdale - Jonathan Natarajan
# Scraping Scarsdale - brian sussman
# Scraping Scarsdale - Spencer Keats
# Checking Servite (CA)
# Found 1 teams
# Scraping Servite - Patrick Aimone
# Checking Seven Lakes (TX)
# Found 0 teams
# Checking Shawnee Mission East (KS)
# Found 3 teams
# Scraping Shawnee Mission East - Parker Mitchell
# Scraping Shawnee Mission East - Casey Owen
# Scraping Shawnee Mission East - Nick Massa
# Checking Shawnee Mission South (KS)
# Found 0 teams
# Checking Southlake Carroll (TX)
# Found 0 teams
# Checking Sprague (OR)
# Found 2 teams
# Scraping Sprague - Brandon Roth
# Scraping Sprague - Colin Gesik
# Checking St Francis (CA)
# Found 0 teams
# Checking St James (AL)
# Found 3 teams
# Scraping St James - Phillip Davis
# Scraping St James - Carter Payne
# Scraping St James - Justin Lee
# Checking St Louis Park (MN)
# Found 0 teams
# Checking St Margarets (CA)
# Found 0 teams
# Checking St Marys Hall (TX)
# Found 0 teams
# Checking St Thomas (MN)
# Found 0 teams
# Checking St Thomas (TX)
# Found 1 teams
# Scraping St Thomas - Jonathan Beavers
# Checking Stephen F Austin (TX)
# Found 1 teams
# Scraping Stephen F Austin - Hamza Khatri
# Checking Stoneman Douglas (FL)
# Found 0 teams
# Checking Stony Point (TX)
# Found 1 teams
# Scraping Stony Point - Rachana Jadala
# Checking Strake Jesuit (TX)
# Found 6 teams
# Scraping Strake Jesuit - Joe Zaghrini
# Scraping Strake Jesuit - Richard Cook
# Scraping Strake Jesuit - Sean McCormick
# Scraping Strake Jesuit - Anthony Tohme
# Scraping Strake Jesuit - Kyle Fennessy
# Scraping Strake Jesuit - Alberto Tohm
# Checking Stratford (TX)
# Found 0 teams
# Checking Stuyvesant (NY)
# Found 7 teams
# Scraping Stuyvesant - Shannon Lee
# Scraping Stuyvesant - Muni Rahman
# Scraping Stuyvesant - Aleksandar Shipetich
# Scraping Stuyvesant - Katherine Fennell
# Scraping Stuyvesant - Ahmad Alnasser
# Scraping Stuyvesant - Talia Coyne
# Scraping Stuyvesant - Kathy Wang
# Checking Sunnyslope (AZ)
# Found 0 teams
# Checking Syosset (NY)
# Found 2 teams
# Scraping Syosset - Aram Moghaddassi
# Scraping Syosset - Jonah Wu
# Checking Talley (AZ)
# Found 1 teams
# Scraping Talley - Parker Whitfill
# Checking Timber Creek (FL)
# Found 1 teams
# Scraping Timber Creek - Brandon Manbahal
# Checking Timothy Christian (NJ)
# Found 0 teams
# Checking Torrey Pines (CA)
# Found 8 teams
# Scraping Torrey Pines - Varun Bhave
# Scraping Torrey Pines - Sujay Singh
# Scraping Torrey Pines - Katya Brooun
# Scraping Torrey Pines - Kevin Krotz
# Scraping Torrey Pines - Kathleen Chang
# Scraping Torrey Pines - Arun Sundar
# Scraping Torrey Pines - Tanvi Shinkre
# Scraping Torrey Pines - Ash Israni
# Checking Travis (TX)
# Found 0 teams
# Checking Trinity Prep (FL)
# Found 0 teams
# Checking Trinity Valley (TX)
# Found 0 teams
# Checking Turlock (CA)
# Found 0 teams
# Checking Union (OK)
# Found 2 teams
# Scraping Union - Colton Smith
# Scraping Union - Brock Spencer
# Checking Unionville (PA)
# Found 0 teams
# Checking University School (OH)
# Found 0 teams
# Checking University (FL)
# Found 5 teams
# Scraping University FL - David Branse
# Scraping University FL - Alejandro Frydman
# Scraping University FL - Karan Choudhary
# Scraping University FL - Jacob Ronkin
# Scraping University FL - Samantha Koreman
# Checking Upper Arlington (OH)
# Found 1 teams
# Scraping Upper Arlington - Henry Wu
# Checking Valley (IA)
# Found 3 teams
# Scraping Valley - Trent Gilbert
# Scraping Valley - Gina Scorpiniti
# Scraping Valley - TJ Foley
# Checking Valor Christian (CO)
# Found 0 teams
# Checking Vashon (WA)
# Found 0 teams
# Checking Veritas Prep (AZ)
# Found 0 teams
# Checking Vincentian (PA)
# Found 1 teams
# Scraping Vincentian - Thomas IkHyun Kim
# Checking Walla Walla (WA)
# Found 1 teams
# Scraping Walla Walla - Malcolm Gabbard
# Checking Walt Whitman (MD)
# Found 9 teams
# Scraping Bronx Science - Agniva Sinha
# Scraping Bronx Science - Shadman Jahangir
# Scraping Bronx Science - Uma Balachandran
# Scraping Bronx Science - Zoe Posner
# Scraping Bronx Science - Rainy Rosch
# Scraping Bronx Science - Winfred Darko
# Scraping Bronx Science - Gabriel Manak
# Bronx Science - Gabriel Manak failed.
# Scraping Bronx Science - Oliver Korten
# Scraping Bronx Science - Ash Siddiqui
# Checking Brophy College Prep (AZ)
# Found 1 teams
# Scraping Brophy - Brendan Morey
# Checking Brown (KY)
# Found 1 teams
# Scraping Brown - Blake Dawson
# Checking Byram Hills (NY)
# Found 4 teams
# Scraping Byram Hills - Paul Erlanger
# Scraping Byram Hills - Alex Wurm
# Scraping Byram Hills - Jack Briody
# Scraping Byram Hills - Lindsey Perlman
# Checking Cabot (AR)
# Found 3 teams
# Scraping Cabot - Zane Ashcraft
# Scraping Cabot - Briana Griffin
# Scraping Cabot - Collin Smith
# Checking Calhoun Homeschool (TX)
# Found 0 teams
# Checking Cambridge Rindge (MA)
# Found 3 teams
# Scraping Cambridge Rindge - Paloma OConnor
# Scraping Cambridge Rindge - Oliver Sussman
# Scraping Cambridge Rindge - Shuvom Sadhuka
# Checking Canyon Crest (CA)
# Found 4 teams
# Scraping Canyon Crest - Reva Agashe
# Scraping Canyon Crest - Rithvik Rao
# Scraping Canyon Crest - Catherine Cang
# Scraping Canyon Crest - Kevin Li
# Checking Canyon Springs (NV)
# Found 1 teams
# Scraping Canyon Springs - Gavin Garcia
# Checking Carmel Valley Independent (CA)
# Found 4 teams
# Scraping Canyon Crest - Reva Agashe
# Scraping Canyon Crest - Rithvik Rao
# Scraping Canyon Crest - Catherine Cang
# Scraping Canyon Crest - Kevin Li
# Checking Carpe Diem (NJ)
# Found 0 teams
# Checking Cedar Park (TX)
# Found 2 teams
# Scraping Cedar Park - Morgan Grosch
# Scraping Cedar Park - Macalah Thomas
# Checking Cedar Ridge (TX)
# Found 0 teams
# Checking Centennial (ID)
# Found 0 teams
# Checking Center For Talented Youth (MD)
# Found 0 teams
# Checking Cerritos (CA)
# Found 0 teams
# Checking Chaminade (CA)
# Found 2 teams
# Scraping Chaminade - Emilio Rivera
# Scraping Chaminade - Bhaskar Suri
# Checking Chandler (AZ)
# Found 0 teams
# Checking Chandler Prep (AZ)
# Found 0 teams
# Checking Chaparral (AZ)
# Found 1 teams
# Scraping Chaparral - Alekhya Reddy
# Checking Charles E Smith (MD)
# Found 0 teams
# Checking Christ Episcopal (LA)
# Found 0 teams
# Checking Christopher Columbus (FL)
# Found 2 teams
# Scraping Christopher Columbus - Javier Navarrete
# Scraping Christopher Columbus - Angel Toro
# Checking Cinco Ranch (TX)
# Found 0 teams
# Checking Citrus Valley (CA)
# Found 0 teams
# Checking Claremont (CA)
# Found 0 teams
# Checking Clark (NV)
# Found 3 teams
# Scraping Clark - Angelo Robledo
# Scraping Clark - Sahan Paliskara
# Scraping Clark - Ishan Saran
# Checking Clear Brook (TX)
# Found 1 teams
# Scraping Clear Brook - Anish Antony
# Checking Clements (TX)
# Found 1 teams
# Scraping Clements - Felix Tan
# Checking Clovis North (CA)
# Found 2 teams
# Scraping Clovis North - Sahil Dang
# Scraping Clovis North - Ranpreet Gill
# Checking College Prep (CA)
# Found 2 teams
# Scraping College Prep - Deirdre Baker
# Scraping College Prep - Zoe Dove
# Checking Collegiate (NY)
# Found 5 teams
# Scraping Collegiate - David Moon
# Scraping Collegiate - Kyle Yuan
# Scraping Collegiate - Eric Wallach
# Scraping Collegiate - Dean Kieserman
# Scraping Collegiate - Henry Liu
# Checking Colleyville Heritage (TX)
# Found 1 teams
# Scraping Colleyville - Alisha Samnani
# Checking Concord Carlisle (MA)
# Found 1 teams
# Scraping Concord Carlisle - Daniel Lu
# Checking Concordia Lutheran (TX)
# Found 1 teams
# Scraping Concordia Lutheran - Matthew Kantenberger
# Checking Coral Glades (FL)
# Found 1 teams
# Scraping Coral Glades - Liam Jennings
# Checking Coral Science (NV)
# Found 0 teams
# Checking Coral Springs (FL)
# Found 1 teams
# Scraping Coral Springs - Every Debater
# Checking Coppell (TX)
# Found 1 teams
# Scraping Coppell - Varshni Muralidharan
# Checking Copper Hills (UT)
# Found 0 teams
# Checking Crandall (TX)
# Found 0 teams
# Checking Crossroads (CA)
# Found 1 teams
# Scraping Crossroads - Noah Simon
# Checking Cy-Fair (TX)
# Found 3 teams
# Scraping Cy-Fair - Cameron McConway
# Scraping Cy-Fair - Tess Welch
# Scraping Cy-Fair - Amanda Liu
# Checking Cypress Bay (FL)
# Found 2 teams
# Scraping Cypress Bay - Jake Steirn
# Scraping Cypress Bay - Shawn Hatchwell
# Checking Cypress Falls (TX)
# Found 2 teams
# Scraping Cypress Falls - Karman Singh
# Scraping Cypress Falls - Syeda Rizvi
# Checking Cypress Lakes (TX)
# Found 0 teams
# Checking Cypress Ridge (TX)
# Found 0 teams
# Checking Cypress Springs (TX)
# Found 0 teams
# Checking Cypress Woods (TX)
# Found 3 teams
# Scraping Cypress Woods - Lucas Clarke
# Scraping Cypress Woods - Chakra Jonnalagadda
# Scraping Cypress Woods - Joseph Dieciedue
# Checking Dallastown (PA)
# Found 4 teams
# Scraping Dallastown - Ohanna Mohammad
# Scraping Dallastown - Amy Zhong
# Scraping Dallastown - Nevin Kara
# Scraping Dallastown - Nicholas Dolinger
# Checking Delbarton (NJ)
# Found 2 teams
# Scraping Delbarton - Ethan Czerniecki
# Scraping Delbarton - Vinayak Kumar
# Checking Derby (KS)
# Found 0 teams
# Checking Des Moines Roosevelt (IA)
# Found 0 teams
# Checking Desert Vista (AZ)
# Found 0 teams
# Checking Dobson (AZ)
# Found 0 teams
# Checking Dougherty Valley (CA)
# Found 3 teams
# Scraping Dougherty Valley - Sameer Ziaee
# Scraping Dougherty Valley - Ayush Maganahalli
# Scraping Dougherty Valley - chait sayani
# Checking Dowling Catholic (IA)
# Found 1 teams
# Scraping Dowling Catholic - Joie Otting
# Checking Dulles (TX)
# Found 5 teams
# Scraping Dulles - Nolan Burdett
# Scraping Dulles - Kathie Lin
# Scraping Dulles - Kevin Si
# Scraping Dulles - Sanika Phanse
# Scraping Dulles - Ashish Wadhwani
# Checking duPont Manual (KY)
# Found 3 teams
# Scraping duPont Manual - Xinlan Emily Hu
# Scraping duPont Manual - David Yi
# Scraping duPont Manual - Kayla Soren
# Checking Dwyer (FL)
# Found 1 teams
# Scraping Dwyer - Lindsey McNamara
# Checking Eastside Catholic (WA)
# Found 0 teams
# Checking Edgemont (NY)
# Found 1 teams
# Scraping Edgemont - Faizan Hussain
# Checking Edmond Santa Fe (OK)
# Found 1 teams
# Scraping Edmond Santa Fe - Ian Mooers
# Checking El Cerrito (CA)
# Found 0 teams
# Checking Elkins (TX)
# Found 0 teams
# Checking Enloe (NC)
# Found 0 teams
# Checking Episcopal (TX)
# Found 1 teams
# Scraping Episcopal - Adam Brown
# Checking Evanston (IL)
# Found 3 teams
# Scraping Evanston - Gabe Hull
# Scraping Evanston - Danny FrankSiegel
# Scraping Evanston - Henry Smith
# Checking Evergreen Valley (CA)
# Found 0 teams
# Checking Ferris (TX)
# Found 1 teams
# Scraping Ferris - Chris Coles
# Checking Flintridge Sacred Heart (CA)
# Found 0 teams
# Checking Flower Mound (TX)
# Found 0 teams
# Checking Fordham Prep (NY)
# Found 0 teams
# Checking Fort Lauderdale (FL)
# Found 1 teams
# Scraping Fort Lauderdale - Ariel Olson
# Checking Fort Walton Beach (FL)
# Found 1 teams
# Scraping Fort Walton Beach - Roxanne Daniel
# Checking Fremont (NE)
# Found 1 teams
# Scraping Fremont - Chase Cate
# Checking Frontier (MO)
# Found 0 teams
# Checking George Ranch (TX)
# Found 1 teams
# Scraping George Ranch - Aisha Sheikh
# Checking Gig Harbor (WA)
# Found 4 teams
# Scraping Gig Harbor - Cameron Allen
# Scraping Gig Harbor - Alec Bellis
# Scraping Gig Harbor - Colin McKay
# Scraping Gig Harbor - Max Stephens
# Checking Gilmour (OH)
# Found 1 teams
# Scraping Gilmour - Sebastian Williams
# Checking Glenbrook South (IL)
# Found 1 teams
# Scraping Glenbrook South - Aaashiv Qualemala
# Checking Grand Junction (CO)
# Found 0 teams
# Checking Grapevine (TX)
# Found 2 teams
# Scraping Grapevine - Nathan Sims
# Scraping Grapevine - Pierce Teeuwen
# Checking Green Valley (NV)
# Found 0 teams
# Checking Greenhill (TX)
# Found 5 teams
# Scraping Greenhill - Bennett Eckert
# Scraping Greenhill - Graham Baker
# Scraping Greenhill - Varad Agarwala
# Scraping Greenhill - Shreya Agarwal
# Scraping Greenhill - Shruthi Krishnan
# Checking Hamilton (AZ)
# Found 0 teams
# Checking Hamilton (MT)
# Found 0 teams
# Checking Harker (CA)
# Found 17 teams
# Scraping Harker - Zarek Drozda
# Scraping Harker - Karen Qi
# Scraping Harker - Srivatsav Pyda
# Scraping Harker - Raymond Xu
# Scraping Harker - Satvik Narasimhan
# Scraping Harker - Manan Shah
# Scraping Harker - Serena Lu
# Scraping Harker - Catherine Zhao
# Scraping Harker - Annie Ma
# Scraping Harker - Kelly Shen
# Scraping Harker - Matthew Lee
# Scraping Harker - Suraj Pakala
# Scraping Harker - Akhilesh Chegu
# Scraping Harker - Sachin Shah Harker
# Scraping Harker - Emmiee Malyugina
# Scraping Harker - Akshay Manglik
# Scraping Harker - Neha Tallapragada
# Checking Harmony (TX)
# Found 0 teams
# Checking Harrison (NY)
# Found 7 teams
# Scraping Harrison - Raffi Piliero
# Scraping Harrison - Elyssa Alfieri
# Scraping Harrison - Kathryn Kenny
# Scraping Harrison - Sarah Ryan
# Scraping Harrison - Matt Zinman
# Scraping Harrison - Adam Eljamal
# Scraping Harrison - Sammi OReilly
# Checking Harvard Westlake (CA)
# Found 39 teams
# Scraping Harvard Westlake - Nick Steele
# Scraping Harvard Westlake - Cameron Cohen
# Scraping Harvard Westlake - Eun Seo Elly Choi
# Scraping Harvard Westlake - Chasia Jeffries
# Scraping Harvard Westlake - Jake Davidson
# Scraping Harvard Westlake - Vishan Chaudhary
# Scraping Harvard Westlake - Indu Pandey
# Scraping Harvard Westlake - Ethan Rosen
# Scraping Harvard Westlake - Emmanuel Zilber
# Scraping Harvard Westlake - Nick Platt
# Scraping Harvard Westlake - Kimberley Kimura
# Scraping Harvard Westlake - Spencer Paul
# Scraping Harvard Westlake - William Park
# Scraping Harvard Westlake - Evan Engel
# Scraping Harvard Westlake - Connor Engell
# Scraping Harvard Westlake - Matthew Gross
# Scraping Harvard Westlake - Dario Madyoon
# Scraping Harvard Westlake - Jesse Nadel
# Scraping Harvard Westlake - Will Berlin
# Scraping Harvard Westlake - Caroline Phillips
# Scraping Harvard Westlake - Lauren Morganbesser
# Scraping Harvard Westlake - Liz Yount
# Scraping Harvard Westlake - Kevin Wesel
# Scraping Harvard Westlake - Julia Cosgrove
# Scraping Harvard Westlake - Charles Connon
# Scraping Harvard Westlake - Samuel BuckleyBonanno
# Scraping Harvard Westlake - Spencer Klink
# Scraping Harvard Westlake - Alexandra Mork
# Scraping Harvard Westlake - Jaya Nayar
# Scraping Harvard Westlake - Hannah Mittleman
# Scraping Harvard Westlake - Natalie Winters
# Scraping Harvard Westlake - Jessa Glassman
# Scraping Harvard Westlake - Will CookHealy
# Scraping Harvard Westlake - Evan Keare
# Scraping Harvard Westlake - Sarah Reiff
# Scraping Harvard Westlake - Anjee Feng
# Scraping Harvard Westlake - Eunice Kiang
# Scraping Harvard Westlake - George Grube
# Scraping Harvard Westlake - Aiden Luscinski
# Checking Hawken (OH)
# Found 1 teams
# Scraping Hawken - Nicole Kastelic
# Checking Head Royce (CA)
# Found 0 teams
# Checking Hebron (TX)
# Found 2 teams
# Scraping Hebron - Asad Sayani
# Scraping Hebron - Altamish Nayani
# Checking Heights (MD)
# Found 0 teams
# Checking Hendrick Hudson (NY)
# Found 1 teams
# Scraping Hendrick Hudson - Matthew Gofman
# Checking Henry Grady (GA)
# Found 2 teams
# Scraping Henry Grady - Conor Downey
# Scraping Henry Grady - Will Taft
# Checking Highland (UT)
# Found 0 teams
# Checking Highland (ID)
# Found 0 teams
# Checking Hockaday (TX)
# Found 4 teams
# Scraping Hockaday - Maggie Stein
# Scraping Hockaday - Sahar Massoudian
# Scraping Hockaday - Sarah Kate Feferman
# Scraping Hockaday - Kate Keough
# Checking Holy Cross (LA)
# Scraping La Jolla - Evan Prasad
# Checking La Reina (CA)
# Found 2 teams
# Scraping La Reina - Elizabeth Pavlath
# Scraping La Reina - Andrea Chow
# Checking Lafayette (MO)
# Found 0 teams
# Checking Lake Highland (FL)
# Found 14 teams
# Scraping Lake Highland - Neal Kapoor
# Scraping Lake Highland - Michael Corder
# Scraping Lake Highland - Jerome Nashed
# Scraping Lake Highland - Muhammad Khattak
# Scraping Lake Highland - Ari Azbel
# Scraping Lake Highland - Krupali Patel
# Scraping Lake Highland - Steve Goldware
# Scraping Lake Highland - Rithvik Seela
# Scraping Lake Highland - Suzie Sharpe
# Scraping Lake Highland - Sreya Pinnamaneni
# ...
# Scraping Oakwood - Sarah Mostoww
# Scraping Oakwood - August Orser
# Scraping Oakwood - Eli Pallrand
# Scraping Oakwood - Wyatt Alpertt
# Checking Okoboji (IA)
# Found 0 teams
# Checking Oxbridge (FL)
# Found 1 teams
# Scraping Oxbridge - Ari Wells
# Checking Oxford (CA)
# Found 0 teams
# Checking Pacific Ridge (CA)
# Found 0 teams
# Checking Palm Beach Gardens (FL)
# Found 0 teams
# Checking Palo Alto Independent (CA)
# Found 3 teams
# Scraping Palo Alto Independent - Colin Fee
# Scraping Palo Alto Independent - Frances Zhuang
# Scraping Palo Alto Independent - Barry he
# Checking Palos Verdes Peninsula (CA)
# Found 8 teams
# Scraping Palos Verdes - Jonas Le Barillec
# Scraping Palos Verdes - Ishan Gaur
# Scraping Palos Verdes - Yeji Cho
# Scraping Palos Verdes - Kristen Lu
# Scraping Palos Verdes - Sean Lipps
# Scraping Palos Verdes - Daniel Jung
# Scraping Palos Verdes - Kaylen Ng
# Scraping Palos Verdes - Moon Gwak
# Checking Park Crossing (AL)
# Found 0 teams
# Checking Peak to Peak (CO)
# Found 0 teams
# Checking Pembroke Pines (FL)
# Found 3 teams
# Scraping Pembroke Pines - Jordan Farenhem
# Scraping Pembroke Pines - Stephen Scopa
# Scraping Pembroke Pines - Wynton White
# Checking Pennsbury (PA)
# Found 1 teams
# Scraping Pennsbury - Carolyn Zou
# Checking Phillips Academy Andover (MA)
# Found 1 teams
# Scraping Phillips Academy Andover - Tiffany Chang
# Checking Phoenix Country Day (AZ)
# Found 1 teams
# Scraping Phoenix Country Day - Parker Whitfil
# Checking Pine Crest (FL)
# Found 1 teams
# Scraping Pine Crest - Zachary Vlessing
# Checking Pingry (NJ)
# Found 1 teams
# Scraping Pingry - Akshina Gupta
# Checking Pittsburgh Central Catholic (PA)
# Found 4 teams
# Scraping Pittsburgh Central Catholic - Warren Sipe
# Scraping Pittsburgh Central Catholic - Andrew Klabnik
# Scraping Pittsburgh Central Catholic - Joe Fantini
# Scraping Pittsburgh Central Catholic - Lewis Richardson
# Checking Plano East (TX)
# Found 3 teams
# Scraping Plano East - Vandan Patel
# Scraping Plano East - Cedric Zhou
# Scraping Plano East - Ameera Khan
# Checking Polytechnic (CA)
# Found 3 teams
# Scraping Polytechnic - Jonathan Liu
# Scraping Polytechnic - Esteban Mendoza
# Scraping Polytechnic - Matthew Burke
# Checking Presentation (CA)
# Found 3 teams
# Scraping Presentation - Amy Santos
# Scraping Presentation - afra ahmed
# Scraping Presentation - Natasha Ajii
# Checking Princeton (NJ)
# Found 8 teams
# Scraping Princeton - Daniel Shahab Diaz
# Scraping Princeton - Nick Eikelberner
# Scraping Princeton - Michael Meyer
# Scraping Princeton - Devansh Chauhan
# Scraping Princeton - Katie Stewart
# Scraping Princeton - Daniel Lin
# Scraping Princeton - Elizabeth Zhang
# Scraping Princeton - Chris Pan
# Checking Prosper (TX)
# Found 4 teams
# Scraping Prosper - zach elmer
# Scraping Prosper - Morgan Kee
# Scraping Prosper - Emma Herring
# Scraping Prosper - Alec Antonakakis
# Checking Quarry Lane (CA)
# Found 3 teams
# Scraping Quarry Lane - Lori Luo
# Scraping Quarry Lane - Priya Narain
# Scraping Quarry Lane - Saianurag Karavadi
# Checking Raisbeck-Aviation (WA)
# Found 1 teams
# Scraping Raisbeck-Aviation - Emily Readey
# Checking Rancho Bernardo (CA)
# Found 4 teams
# Scraping Rancho Bernardo - Alexandre Walsh
# Scraping Rancho Bernardo - Angela Liu
# Scraping Rancho Bernardo - Tejas Srinivasan
# Scraping Rancho Bernardo - Eric Timmerman
# Checking Randolph (NJ)
# Found 1 teams
# Scraping Randolph - Amy Pu
# Checking Reagan (TX)
# Found 5 teams
# Scraping Reagan - Deena Mainali
# Scraping Reagan - Michael Corser
# Scraping Reagan - Julian Galaz
# Scraping Reagan - Reeda Virani
# Scraping Reagan - Zory Montemayor
# Checking Richardson (TX)
# Found 0 teams
# Checking Ridge (NJ)
# Found 4 teams
# Scraping Ridge - Shankar Krishnan
# Scraping Ridge - Vikram Kalghatgi
# Scraping Ridge - Vamsi Talasila
# Scraping Ridge - Alan Liu
# Checking Ridge Point (TX)
# Found 0 teams
# Checking Riverside (SC)
# Found 0 teams
# Checking Robert Vela (TX)
# Found 0 teams
# Checking Rosemount (MN)
# Found 0 teams
# Checking Roseville (MN)
# Found 0 teams
# Checking Round Rock (TX)
# Found 0 teams
# Checking Rowland Hall (UT)
# Found 4 teams
# Scraping Rowland Hall - Lena Chan
# Scraping Rowland Hall - Abed Alsolaiman
# Scraping Rowland Hall - Kenzo Okazaki
# Scraping Rowland Hall - Leonie Anderson
# Checking Royse City (TX)
# Found 1 teams
# Scraping Royse City - Jake RICHTER
# Checking Ruston (LA)
# Found 1 teams
# Scraping Ruston - Trevor Blackstock
# Checking Sacred Heart (MA)
# Found 0 teams
# Checking Sacred Heart (MS)
# Found 0 teams
# Checking Sage Hill (CA)
# Found 2 teams
# Scraping Sage Hill - Luca WhiteMatthews
# Scraping Sage Hill - Maya Jaffe
# Checking Sage Ridge (NV)
# Found 0 teams
# Checking Salado (TX)
# Found 0 teams
# Checking Salpointe Catholic (AZ)
# Found 1 teams
# Scraping Salpointe Catholic - Emma Hagyard
# Checking Sammamish (WA)
# Found 0 teams
# Checking San Dieguito (CA)
# Found 0 teams
# Checking San Marino (CA)
# Found 6 teams
# Scraping San Marino - Ian Chen
# Scraping San Marino - Kirk Wu
# Scraping San Marino - Eric Deng
# Scraping San Marino - Kelly Wong
# Scraping San Marino - Vincent Liu
# Scraping San Marino - Kyle Weng
# Checking SandHoke (NC)
# Found 0 teams
# Checking Santa Monica (CA)
# Found 1 teams
# Scraping Santa Monica - Rex Evans
# Checking Sarasota (FL)
# Found 1 teams
# Scraping Sarasota - Charles Karcher
# Checking Saratoga (CA)
# Found 3 teams
# Scraping Saratoga - Ujjwal Krishnamurthi
# Scraping Saratoga - David Koh
# Scraping Saratoga - Victor Liu
# Checking Scarsdale (NY)
# Found 8 teams
# Scraping Scarsdale - Gillian Zipursky
# Scraping Scarsdale - Zoe Ewing
# Scraping Scarsdale - Zack Gelles
# Scraping Scarsdale - Natalie Isak
# Scraping Scarsdale - Lauren Singer
# Scraping Scarsdale - Michael Landau
# Scraping Scarsdale - Ananta Wadhwa
# Scraping Scarsdale - Ezra Levine
# Checking Servite (CA)
# Found 1 teams
# Scraping Servite - Aimone Patrick
# Checking Seven Lakes (TX)
# Found 2 teams
# Scraping Seven Lakes - JaeKyung Sim
# Scraping Seven Lakes - Rohan Rao
# Checking Shawnee Mission East (KS)
# Found 1 teams
# Scraping Shawnee Mission East - Chris Munar
# Checking Shawnee Mission Northwest (KS)
# Found 2 teams
# Scraping Shawnee Mission Northwest - Julian Kuffour
# Scraping Shawnee Mission Northwest - Emmanuel Osei
# Checking Shawnee Mission South (KS)
# Found 0 teams
# Checking Shawnee Mission West (KS)
# Found 0 teams
# Checking Sky View (UT)
# Found 1 teams
# Scraping Sky View - Jake Kunzler
# Checking Skyline (UT)
# Found 0 teams
# Checking Smithson Valley (TX)
# Found 0 teams
# Checking Southlake Carroll (TX)
# Found 5 teams
# Scraping Southlake Carroll - Samir Mohsin
# Scraping Southlake Carroll - Gautam Iyer
# Scraping Southlake Carroll - Rishik Puppala
# Scraping Southlake Carroll - Jonathan Chiang
# Scraping Southlake Carroll - Aman Patel
# Checking Sprague (OR)
# Found 1 teams
# Scraping Sprague - Santiago Monleon
# Checking St Agnes (TX)
# Found 1 teams
# Scraping St Agnes - Cara Day
# Checking St Andrews (MS)
# Found 2 teams
# Scraping St Andrews - Ishan Bhatt
# Scraping St Andrews - Bailey McHale
# Checking St Francis (CA)
# Found 1 teams
# Scraping St Francis - Deep Joshi
# Checking St James (AL)
# Found 0 teams
# Checking St Johns (TX)
# Found 1 teams
# Scraping St Johns - Andrew Wan
# Checking St Louis Park (MN)
# Found 1 teams
# Scraping St Louis Park - Dotan Appelbaum
# Checking St Margarets (CA)
# Found 0 teams
# Checking St Marys Hall (TX)
# Found 0 teams
# Checking St Thomas (MN)
# Found 2 teams
# Scraping St Thomas MN - Nick Weir
# Scraping St Thomas MN - Sophia Kuriscak
# Checking St Thomas (TX)
# Found 0 teams
# Checking Stephen F Austin (TX)
# Found 0 teams
# Checking Stoneman Douglas (FL)
# Found 0 teams
# Checking Stony Point (TX)
# Found 0 teams
# Checking Strake Jesuit (TX)
# Found 10 teams
# Scraping Strake Jesuit - Matthew Chen
# Scraping Strake Jesuit - Charles Li
# Scraping Strake Jesuit - Richard Cook
# Scraping Strake Jesuit - Joshua Herrera
# Scraping Strake Jesuit - Jack Marsh
# Scraping Strake Jesuit - Andrew Thorburn
# Scraping Strake Jesuit - The Real Wyatt Hat Field
# Scraping Strake Jesuit - Neville Tom
# Scraping Strake Jesuit - Andrew Nguyen
# Scraping Strake Jesuit - Vincent Liu
# Checking Stratford (TX)
# Found 0 teams
# Checking Stratford Independent (CA)
# Found 0 teams
# Checking Stuyvesant (NY)
# Found 6 teams
# Scraping Stuyvesant - Katherine Fennell
# Scraping Stuyvesant - Kevin Li
# Scraping Stuyvesant - Pacy Yan
# Scraping Stuyvesant - Aleksandar Shipetic
# Scraping Stuyvesant - Olivia Gallager
# Scraping Stuyvesant - Claire Liu
# Checking Success Academy (NY)
# Found 3 teams
# Scraping Success Academy - Sekou Black
# Scraping Success Academy - Aida Bathily
# Scraping Success Academy - Lawrence Leiva
# Checking Sunnyslope (AZ)
# Found 0 teams
# Checking Sunset (OR)
# Found 3 teams
# Scraping Sunset - ashwin bhat
# Scraping Sunset - rohan bharadwaj
# Scraping Sunset - Jason Shi
# Checking Syosset (NY)
# Found 3 teams
# Scraping Syosset - Aram Moghaddassi
# Scraping Syosset - Jonah Wu
# Scraping Syosset - Christopher Moon
# Checking Tahoma (WA)
# Found 2 teams
# Scraping Tahoma - Hansel Guzman Soto
# Scraping Tahoma - Joey Ribera
# Checking Talley (AZ)
# Found 0 teams
# Checking Texas Academy of Math and Science (TX)
# Found 1 teams
# Scraping Texas Academy of Math and Science - Maya Xia
# Checking Thomas Jefferson (VA)
# Found 7 teams
# Scraping Thomas Jefferson - Amitesh Kotwal
# Scraping Thomas Jefferson - Naman Barayas
# Scraping Thomas Jefferson - Aakash Shukla
# Scraping Thomas Jefferson - Rishabh Krishnan
# Scraping Thomas Jefferson - Vishal Tandale
# Scraping Thomas Jefferson - Shivam Kollur
# Scraping Thomas Jefferson - Yukta Chidanandan
# Checking Thompkins (TX)
# Found 0 teams
# Checking Timber Creek (FL)
# Found 0 teams
# Checking Timothy Christian (NJ)
# Found 0 teams
# Checking Tom C Clark (TX)
# Found 2 teams
# Scraping Tom C Clark - Sophia Carranco
# Scraping Tom C Clark - Micheal Myers
# Checking Tompkins (TX)
# Found 0 teams
# Checking Torrey Pines (CA)
# Found 2 teams
# Scraping Torrey Pines - Farzaan Kaiyom
# Scraping Torrey Pines - Joshua Chung
# Checking Travis (TX)
# Found 0 teams
# Checking Trinity (KY)
# Found 1 teams
# Scraping Trinity KY - Mark Hughes
# Checking Trinity Prep (FL)
# Found 3 teams
# Scraping Trinity - Alexandre Spallone
# Scraping Trinity - Danielle Field
# Scraping Trinity - Arlen Plotts
# Checking Trinity Valley (TX)
# Found 0 teams
# Checking Truman (PA)
# Found 0 teams
# Checking Turlock (CA)
# Found 0 teams
# Checking Union (OK)
# Found 0 teams
# Checking Unionville (PA)
# Found 0 teams
# Checking University High (CA)
# Found 1 teams
# Scraping University CA - Jasun Chen
# Checking University School (OH)
# Found 0 teams
# Checking University (FL)
# Found 1 teams
# Scraping University FL - Gabriel Frydman
# Checking Upper Arlington (OH)
# Found 0 teams
# Checking Upper Dublin (PA)
# Found 0 teams
# Checking Valley (IA)
# Found 12 teams
# Scraping Valley - TJ Foley
# Scraping Valley - Manasi Singh
# Scraping Valley - Evan McKinney
# Scraping Valley - Kyle Kopf
# Scraping Valley - Conal Thomas McGinnis
# Scraping Valley - cABBAGE sIENA
# Scraping Valley - Trent Gilbert
# Scraping Valley - Brian Gu
# Scraping Valley - Henry Schwob
# Scraping Valley - Lauren Gilbert L
# Scraping Valley - Animesh Joshi
# Scraping Valley - Carly Rieger
# Checking Valor Christian (CO)
# Found 0 teams
# Checking Vashon (WA)
# Found 0 teams
# Checking Ventura (CA)
# Found 0 teams
# Checking Veritas Prep (AZ)
# Found 0 teams
# Checking Vestavia Hills (AL)
# Found 5 teams
# Scraping Vestavia Hills - Rahul Parikh
# Scraping Vestavia Hills - Joey Compton
# Scraping Vestavia Hills - Rachel Ding
# Scraping Vestavia Hills - Mei Mei Sun
# Scraping Vestavia Hills - Sarah Zhao
# Checking Vincentian (PA)
# Found 0 teams
# Checking Walla Walla (WA)
# Found 0 teams
# Checking Walt Whitman (MD)
# Found 6 teams
# Scraping Walt Whitman - Xavier RobertsGaal
# Scraping Walt Whitman - Camille Caldera
# Scraping Walt Whitman - Ivy Xun
# Scraping Walt Whitman - Daniel Harris
# Scraping Walt Whitman - Michael Hepburn
# Scraping Walt Whitman - Jacqueline Lydon
# Checking Warren (TX)
# Found 1 teams
# Scraping Warren - Nelson Okunlola
# Checking Wenatchee (WA)
# Found 0 teams
# Checking West (UT)
# Found 6 teams
# Scraping West - Gideon Gomm
# Scraping West - Kenneth Nelson
# Scraping West - Kenji Aoki
# Scraping West - Emil Welker
# Scraping West - Michael Tao
# Scraping West - Nithin ChaIapathi
# Checking West Ranch (CA)
# Found 2 teams
# Scraping West Ranch - Jong Hak Won
# Scraping West Ranch - Minjoon Kang
# Checking Westford (MA)
# Found 1 teams
# Scraping Westford - Andee Song
# Checking Westlake (TX)
# Found 3 teams
# Scraping Westlake - Amanda Chen
# Scraping Westlake - Andrew Lee
# Scraping Westlake - Jackie Ballard
# Checking Westview (OR)
# Found 1 teams
# Scraping Westview - Rohith Sudhakar
# Checking Westwood (TX)
# Found 13 teams
# Scraping Westwood - Rishabh Shhah
# Scraping Westwood - Dhruva Mambapoor
# Scraping Westwood - Jugal Amodwala
# Scraping Westwood - Saavan Nanavati
# Scraping Westwood - Abby Grifno
# Scraping Westwood - Rohith Mandavilli
# Scraping Westwood - Saket Myneni
# Scraping Westwood - Richard Lai
# Scraping Westwood - Amogh Dambal
# Scraping Westwood - Truman Le
# Scraping Westwood - Harsha Jandhyala
# Scraping Westwood - Joel Abraham
# Scraping Westwood - Nisha Rajasekar
# Checking Whitefish Bay (WI)
# Found 0 teams
# Checking Whitney (CA)
# Found 0 teams
# Checking Wilson (DC)
# Found 0 teams
# Checking Winston Churchill (TX)
# Found 5 teams
# Scraping Winston Churchill - William Coltzer
# Scraping Winston Churchill - Bianca Rathwick
# Scraping Winston Churchill - Jacob Lugo
