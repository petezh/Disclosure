# %% [markdown]
# Wiki Scraper
# ---
#
# Author: Peter Zhang
#
# Scraping tool for the Wiki.

# %% [markdown]
# ### Setup
#
# #### Imports

# %%
# imports
import urllib.request, urllib.parse, urllib.error
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import csv
import os.path
from os import path
import re

# %% [markdown]
# #### Settings
#
# - OVERWRITE determines whether or not to update existing files.
# - PAGES_URL is a list of Wiki pages
# - OUTPATH is where files are stored

# %%
# settings
OVERWRITE = False

# %%
# get page URLs
WIKIS_URL = "tools/wiki_pages.csv"
WIKIS = [row for row in csv.reader(open(WIKIS_URL, 'r'))]

# %%
# outpath
OUTPATH = "wiki_data/"

# %% [markdown]
# ### Scrapers
#
# #### Wiki Page
#
# Take the URL to a wiki page and returns a list of all the school names and their respective URLs.

# %%
# for a given archive year, return all schools
def getSchools(url):
    
    # try opening URL
    try:
        html = urlopen(url).read()
    except Exeption:
        print("Wiki URL broke")
        return []
    
    
    # soupify
    soup = BeautifulSoup(html, "html.parser")
    
    # find all links
    links = soup.find_all('a')
    
    # find only school links
    links = [link for link in links if "(" in link.text and ")" in link.text]
    
    # get link text and URL
    schools = [[link.text, link.get('href')] for link in links]

    return schools

# %%
getSchools("https://hspolicy19.debatecoaches.org/")
# Out:
# [['Advanced Technologies Academy (NV)', '/Advanced%20Technologies%20Academy/'],
#  ['Airline (AL)', '/Airline/'],
#  ['Aledo (TX)', '/Aledo/'],
#  ['Alief Taylor (TX)', '/Alief%20Taylor/'],
#  ['Alpharetta (GA)', '/Alpharetta/'],
#  ['Altamont (AL)', '/Altamont/'],
#  ['American Heritage (FL)', '/American%20Heritage/'],
#  ['Anderson (TX)', '/Anderson/'],
#  ['Andover (KS)', '/Andover/'],
#  ['Andover Central (KS)', '/Andover%20Central/'],
#  ['Andrews (TX)', '/Andrews/'],
#  ['Archbishop Mitty (CA)', '/Archbishop%20Mitty/'],
#  ['Ashland (OR)', '/Ashland/'],
#  ['Asian Debate League (AK)', '/Asian%20Debate%20League/'],
#  ['Athens (TX)', '/Athens/'],
#  ['Aubrey (TX)', '/Aubrey/'],
#  ['BASIS Chandler (AZ)', '/BASIS%20Chandler/'],
#  ['BASIS Peoria (AZ)', '/BASIS%20Peoria/'],
#  ['BASIS Shavano (TX)', '/BASIS%20Shavano/'],
#  ['Bakersfield (CA)', '/Bakersfield/'],
#  ['Baltimore City College (MD)', '/Baltimore%20City%20College/'],
#  ['Barstow (MO)', '/Barstow/'],
#  ['Baton Rouge Magnet (LA)', '/Baton%20Rouge%20Magnet/'],
#  ['Bellarmine (CA)', '/Bellarmine/'],
#  ['Benjamin Tasker (MD)', '/Benjamin%20Tasker/'],
#  ['Bentonville (AR)', '/Bentonville/'],
#  ['Bentonville West (AR)', '/Bentonville%20West/'],
#  ['Berkeley Prep (FL)', '/Berkeley%20Prep/'],
#  ['Bingham (UT)', '/Bingham/'],
#  ['Blue Springs South (MO)', '/Blue%20Springs%20South/'],
#  ['Blue Valley (KS)', '/Blue%20Valley/'],
#  ['Blue Valley North (KS)', '/Blue%20Valley%20North/'],
#  ['Blue Valley Northwest (KS)', '/Blue%20Valley%20Northwest/'],
#  ['Blue Valley Southwest (KS)', '/Blue%20Valley%20Southwest/'],
#  ['Blue Valley West (KS)', '/Blue%20Valley%20West/'],
#  ['Bolivar (MO)', '/Bolivar/'],
#  ['Boston Latin Academy (MA)', '/Boston%20Latin%20Academy/'],
#  ['Bowie (MD)', '/Bowie/'],
#  ['Branham (CA)', '/Branham/'],
#  ['Bravo (CA)', '/Bravo/'],
#  ['Bronx Science (NY)', '/Bronx%20Science/'],
#  ['Brooke (MA)', '/Brooke/'],
#  ['Brooklyn Technical (NY)', '/Brooklyn%20Technical/'],
#  ['Buhler (KS)', '/Buhler/'],
#  ['CHAMPS (CA)', '/CHAMPS/'],
#  ['CK McClatchy (CA)', '/CK%20McClatchy/'],
#  ['Cabot (AR)', '/Cabot/'],
#  ['Caddo Magnet (LA)', '/Caddo%20Magnet/'],
#  ['Calhoun (GA)', '/Calhoun/'],
#  ['Calvert Hall (MD)', '/Calvert%20Hall/'],
#  ['Cambridge (GA)', '/Cambridge/'],
#  ['Canyon Crest (CA)', '/Canyon%20Crest/'],
#  ['Capital City (DC)', '/Capital%20City/'],
#  ['Carlsbad (CA)', '/Carlsbad/'],
#  ['Carmel Valley Independent (CA)', '/Carmel%20Valley%20Independent/'],
#  ['Carrollton Sacred Heart (FL)', '/Carrollton%20Sacred%20Heart/'],
#  ['Carthage (MO)', '/Carthage/'],
#  ['Casady (OK)', '/Casady/'],
#  ['Cathedral Prep (PA)', '/Cathedral%20Prep/'],
#  ['Cedar Rapids Washington (IA)', '/Cedar%20Rapids%20Washington/'],
#  ['Century (ID)', '/Century/'],
#  ['Chaminade (CA)', '/Chaminade/'],
#  ['Champion (TX)', '/Champion/'],
#  ['Charlestown (MA)', '/Charlestown/'],
#  ['Charlotte Catholic (NC)', '/Charlotte%20Catholic/'],
#  ['Charter School Of Wilmington (DE)', '/Charter%20School%20Of%20Wilmington/'],
#  ['Chattahoochee (GA)', '/Chattahoochee/'],
#  ['Chesterton (IN)', '/Chesterton/'],
#  ['Children Of Per Bear (FL)', '/Children%20Of%20Per%20Bear/'],
#  ['China Spring (TX)', '/China%20Spring/'],
#  ['Clackamas (OR)', '/Clackamas/'],
#  ['Classical Academy (CA)', '/Classical%20Academy/'],
#  ['Cleveland (OR)', '/Cleveland/'],
#  ['College Prep (CA)', '/College%20Prep/'],
#  ['Colleyville Heritage (TX)', '/Colleyville%20Heritage/'],
#  ['Connally (TX)', '/Connally/'],
#  ['Coppell (TX)', '/Coppell/'],
#  ['Coppell Ninth (TX)', '/Coppell%20Ninth/'],
#  ['Copper Hills (UT)', '/Copper%20Hills/'],
#  ['Coronado (NV)', '/Coronado/'],
#  ['Crenshaw (CA)', '/Crenshaw/'],
#  ['Crossings Christian School (AL)', '/Crossings%20Christian%20School/'],
#  ['Cueva (NM)', '/Cueva/'],
#  ['Cypress Bay (FL)', '/Cypress%20Bay/'],
#  ['Cypress Woods (TX)', '/Cypress%20Woods/'],
#  ['DC International (DC)', '/DC%20International/'],
#  ['DMV INDEPENDENT (DC)', '/DMV%20INDEPENDENT/'],
#  ['Dallas TAG Magnet (TX)', '/Dallas%20TAG%20Magnet/'],
#  ['Damien (CA)', '/Damien/'],
#  ['Davidson (NV)', '/Davidson/'],
#  ['Davis (UT)', '/Davis/'],
#  ['Davis Senior (CA)', '/Davis%20Senior/'],
#  ['Dawson (TX)', '/Dawson/'],
#  ['DeBakey (TX)', '/DeBakey/'],
#  ['Decatur (GA)', '/Decatur/'],
#  ['Delbarton School (NJ)', '/Delbarton%20School/'],
#  ['Denver Center For International Studies (CO)',
#   '/Denver%20Center%20For%20International%20Studies/'],
#  ['Denver East (CO)', '/Denver%20East/'],
#  ['Derby (KS)', '/Derby/'],
#  ['Desert Vista (AZ)', '/Desert%20Vista/'],
#  ['Detroit Country Day (MI)', '/Detroit%20Country%20Day/'],
#  ['Dougherty Valley (CA)', '/Dougherty%20Valley/'],
#  ['Douglas (SD)', '/Douglas/'],
#  ['Dowling (IA)', '/Dowling/'],
#  ['Downtown College Prep (CA)', '/Downtown%20College%20Prep/'],
#  ['Downtown Magnets (CA)', '/Downtown%20Magnets/'],
#  ['Drew Charter (GA)', '/Drew%20Charter/'],
#  ['Dripping Springs (TX)', '/Dripping%20Springs/'],
#  ['Druid Hills (GA)', '/Druid%20Hills/'],
#  ['DuVal (MD)', '/DuVal/'],
#  ['Dulles (TX)', '/Dulles/'],
#  ['Durham (NC)', '/Durham/'],
#  ['Duval (MD)', '/Duval/'],
#  ['Eagan (MN)', '/Eagan/'],
#  ['Eagle (ID)', '/Eagle/'],
#  ['Eaglecrest (CO)', '/Eaglecrest/'],
#  ['Eastlake (WA)', '/Eastlake/'],
#  ['Eastside (WA)', '/Eastside/'],
#  ['Edgemont (NY)', '/Edgemont/'],
#  ['Edina (MN)', '/Edina/'],
#  ['Eisenhower (KS)', '/Eisenhower/'],
#  ['Elizabeth LC (CA)', '/Elizabeth%20LC/'],
#  ['Emporia (KS)', '/Emporia/'],
#  ['Evanston (IL)', '/Evanston/'],
#  ['Fairview (CO)', '/Fairview/'],
#  ['Farmington (MN)', '/Farmington/'],
#  ['Ferris (WA)', '/Ferris/'],
#  ['Fort Collins (CO)', '/Fort%20Collins/'],
#  ['Fox Chapel (PA)', '/Fox%20Chapel/'],
#  ['Fremont (CA)', '/Fremont/'],
#  ['Galloway (GA)', '/Galloway/'],
#  ['Galloway School (GA)', '/Galloway%20School/'],
#  ['Garfield (WA)', '/Garfield/'],
#  ['George Washington (CO)', '/George%20Washington/'],
#  ['Georgetown Day (DC)', '/Georgetown%20Day/'],
#  ['Gilman (MD)', '/Gilman/'],
#  ['Glenbrook North (IL)', '/Glenbrook%20North/'],
#  ['Glenbrook South (IL)', '/Glenbrook%20South/'],
#  ['Glendale (MO)', '/Glendale/'],
#  ['Grace (TX)', '/Grace/'],
#  ['Grand Rapids City (MI)', '/Grand%20Rapids%20City/'],
#  ['Grapevine (TX)', '/Grapevine/'],
#  ['Green Valley (NV)', '/Green%20Valley/'],
#  ['Greenhill (TX)', '/Greenhill/'],
#  ['Greenwood Lab School (MO)', '/Greenwood%20Lab%20School/'],
#  ['Groves (MI)', '/Groves/'],
#  ['Gulliver (FL)', '/Gulliver/'],
#  ['Gunn (CA)', '/Gunn/'],
#  ['Guyer (TX)', '/Guyer/'],
#  ['H H Dow (MI)', '/H%20H%20Dow/'],
#  ['Hamilton (AZ)', '/Hamilton/'],
#  ['Harbor Teacher Prep (CA)', '/Harbor%20Teacher%20Prep/'],
#  ['Harding Charter Prep (OK)', '/Harding%20Charter%20Prep/'],
#  ['Harker (CA)', '/Harker/'],
#  ['Harvard Westlake (CA)', '/Harvard%20Westlake/'],
#  ['Hawken (OH)', '/Hawken/'],
#  ['Hawknatius (OH)', '/Hawknatius/'],
#  ['Head Royce (CA)', '/Head%20Royce/'],
#  ['Hebron (TX)', '/Hebron/'],
#  ['Heights (TX)', '/Heights/'],
#  ['Hendrickson (TX)', '/Hendrickson/'],
#  ['Henry M Gunn (CA)', '/Henry%20M%20Gunn/'],
#  ['Henry W Grady (GA)', '/Henry%20W%20Grady/'],
#  ['Heritage Hall (OK)', '/Heritage%20Hall/'],
#  ['Highland (ID)', '/Highland/'],
#  ['Highland Park (MN)', '/Highland%20Park/'],
#  ['Highland Park Dallas (TX)', '/Highland%20Park%20Dallas/'],
#  ['Homestead (WI)', '/Homestead/'],
#  ['Hoover (OH)', '/Hoover/'],
#  ['Houston (TX)', '/Houston/'],
#  ['Houston Memorial (TX)', '/Houston%20Memorial/'],
#  ['Humanities And Arts (CA)', '/Humanities%20And%20Arts/'],
#  ['Hume Fogg (TN)', '/Hume%20Fogg/'],
#  ['Hunter College (NY)', '/Hunter%20College/'],
#  ['Hyattsville Independent (MD)', '/Hyattsville%20Independent/'],
#  ['Immaculate Heart (CA)', '/Immaculate%20Heart/'],
#  ['Independence Independent (TX)', '/Independence%20Independent/'],
#  ['Ingraham (WA)', '/Ingraham/'],
#  ['Inspired Teaching (DC)', '/Inspired%20Teaching/'],
#  ['Interlake (WA)', '/Interlake/'],
#  ['Iowa City City (IA)', '/Iowa%20City%20City/'],
#  ['Iowa City West (AL)', '/Iowa%20City%20West/'],
#  ['Irma Rangel YWLS (TX)', '/Irma%20Rangel%20YWLS/'],
#  ['Isidore Newman (LA)', '/Isidore%20Newman/'],
#  ['Jack C Hays (TX)', '/Jack%20C%20Hays/'],
#  ['Jackson (OH)', '/Jackson/'],
#  ['James Logan (CA)', '/James%20Logan/'],
#  ['James Madison (NY)', '/James%20Madison/'],
#  ['Jefferson City (MO)', '/Jefferson%20City/'],
#  ['Jenks (OK)', '/Jenks/'],
#  ['Jesuit Dallas (TX)', '/Jesuit%20Dallas/'],
#  ['John C Fremont (CA)', '/John%20C%20Fremont/'],
#  ['Johns Creek (GA)', '/Johns%20Creek/'],
#  ['Jones College Prep (IL)', '/Jones%20College%20Prep/'],
#  ['Josiah Quincy (MA)', '/Josiah%20Quincy/'],
#  ['Juan Diego (UT)', '/Juan%20Diego/'],
#  ['Juicewrld Intermediate (ID)', '/Juicewrld%20Intermediate/'],
#  ['KIPP San Francisco College Preparatory (CA)',
#   '/KIPP%20San%20Francisco%20College%20Preparatory/'],
#  ['KIS (MD)', '/KIS/'],
#  ['Kamiak (WA)', '/Kamiak/'],
#  ['Kapaun Mount Carmel (KS)', '/Kapaun%20Mount%20Carmel/'],
#  ['Kennedy (IL)', '/Kennedy/'],
#  ['Kent Denver (CO)', '/Kent%20Denver/'],
#  ['Kenwood (IL)', '/Kenwood/'],
#  ['Kerr (TX)', '/Kerr/'],
#  ['Kickapoo (MO)', '/Kickapoo/'],
#  ['Kinkaid (TX)', '/Kinkaid/'],
#  ['La Crosse Central (WI)', '/La%20Crosse%20Central/'],
#  ['La Cueva (NM)', '/La%20Cueva/'],
#  ['La Reina (CA)', '/La%20Reina/'],
#  ['La Salle College (PA)', '/La%20Salle%20College/'],
#  ['Lake City (ID)', '/Lake%20City/'],
#  ['Lake Travis (TX)', '/Lake%20Travis/'],
#  ['Lane Tech (IL)', '/Lane%20Tech/'],
#  ['Langham Creek (TX)', '/Langham%20Creek/'],
#  ['Lansing (KS)', '/Lansing/'],
#  ['Law Magnet (TX)', '/Law%20Magnet/'],
#  ['Lawrence (KS)', '/Lawrence/'],
#  ['Lawrence Free State (KS)', '/Lawrence%20Free%20State/'],
#  ['Lees Summit West (MO)', '/Lees%20Summit%20West/'],
#  ['Leland (CA)', '/Leland/'],
#  ['Leon M Goldstein (NY)', '/Leon%20M%20Goldstein/'],
#  ['Lewis And Clark (WA)', '/Lewis%20And%20Clark/'],
#  ['Lexington (MA)', '/Lexington/'],
#  ['Liberal Arts And Science Academy (TX)',
#   '/Liberal%20Arts%20And%20Science%20Academy/'],
#  ['Liberty (MO)', '/Liberty/'],
#  ['Lilburn (GA)', '/Lilburn/'],
#  ['Lincoln (OR)', '/Lincoln/'],
#  ['Lincoln CA (CA)', '/Lincoln%20CA/'],
#  ['Lincoln East (NE)', '/Lincoln%20East/'],
#  ['Lincoln North Star (NE)', '/Lincoln%20North%20Star/'],
#  ['Lincoln Park (IL)', '/Lincoln%20Park/'],
#  ['Lincoln Southeast (NE)', '/Lincoln%20Southeast/'],
#  ['Lindale (TX)', '/Lindale/'],
#  ['Lindblom (IL)', '/Lindblom/'],
#  ['Little Rock Central (AR)', '/Little%20Rock%20Central/'],
#  ['Lone Peak (UT)', '/Lone%20Peak/'],
#  ['Long Branch (NJ)', '/Long%20Branch/'],
#  ['Lovejoy (TX)', '/Lovejoy/'],
#  ['Lowell (CA)', '/Lowell/'],
#  ['Madison Central (MS)', '/Madison%20Central/'],
#  ['Madison East (WI)', '/Madison%20East/'],
#  ['Maine East (IL)', '/Maine%20East/'],
#  ['Maize (KS)', '/Maize/'],
#  ['Mamaroneck (NY)', '/Mamaroneck/'],
#  ['Manhattan (KS)', '/Manhattan/'],
#  ['Maplewood (MO)', '/Maplewood/'],
#  ['Marian (MI)', '/Marian/'],
#  ['Marquette (WI)', '/Marquette/'],
#  ['Maywood (CA)', '/Maywood/'],
#  ['McCormack (MA)', '/McCormack/'],
#  ['McDonogh (MD)', '/McDonogh/'],
#  ['McDonough (MD)', '/McDonough/'],
#  ['McDowell (PA)', '/McDowell/'],
#  ['McLain (OK)', '/McLain/'],
#  ['McQueen (NV)', '/McQueen/'],
#  ['Mckinney Boyd (TX)', '/Mckinney%20Boyd/'],
#  ['Melissa (TX)', '/Melissa/'],
#  ['Midland (MI)', '/Midland/'],
#  ['Midway Academy Of Fine Arts (TX)', '/Midway%20Academy%20Of%20Fine%20Arts/'],
#  ['Mill Valley (KS)', '/Mill%20Valley/'],
#  ['Millard North (NE)', '/Millard%20North/'],
#  ['Millard South (NE)', '/Millard%20South/'],
#  ['Millard West (NE)', '/Millard%20West/'],
#  ['Minneapolis South (MN)', '/Minneapolis%20South/'],
#  ['Minneapolis Washburn (MN)', '/Minneapolis%20Washburn/'],
#  ['Miramonte (CA)', '/Miramonte/'],
#  ['ModernBrain (CA)', '/ModernBrain/'],
#  ['Montgomery Bell (TN)', '/Montgomery%20Bell/'],
#  ['Montgomery Blair (MD)', '/Montgomery%20Blair/'],
#  ['Moore (OK)', '/Moore/'],
#  ['Mount Pleasant (TX)', '/Mount%20Pleasant/'],
#  ['Mount Vernon (AL)', '/Mount%20Vernon/'],
#  ['Mountain Brook (AL)', '/Mountain%20Brook/'],
#  ['Mountain House (CA)', '/Mountain%20House/'],
#  ['Nashua South (NH)', '/Nashua%20South/'],
#  ['Neenah (WI)', '/Neenah/'],
#  ['Nevada Union (CA)', '/Nevada%20Union/'],
#  ['Neville (LA)', '/Neville/'],
#  ['New Designs UP (CA)', '/New%20Designs%20UP/'],
#  ['New Mission (MA)', '/New%20Mission/'],
#  ['New Technology (CA)', '/New%20Technology/'],
#  ['New Trier (IL)', '/New%20Trier/'],
#  ['Newark Science (NJ)', '/Newark%20Science/'],
#  ['NewarkTech (NJ)', '/NewarkTech/'],
#  ['Newton (KS)', '/Newton/'],
#  ['Niles North (IL)', '/Niles%20North/'],
#  ['Niles West (IL)', '/Niles%20West/'],
#  ['Norman North (OK)', '/Norman%20North/'],
#  ['North Allegheny (PA)', '/North%20Allegheny/'],
#  ['North Broward Prep (FL)', '/North%20Broward%20Prep/'],
#  ['North Central (WA)', '/North%20Central/'],
#  ['North Liberty (IA)', '/North%20Liberty/'],
#  ['NorthStar (NJ)', '/NorthStar/'],
#  ['Northridge (UT)', '/Northridge/'],
#  ['Northside (IL)', '/Northside/'],
#  ['Northview (AL)', '/Northview/'],
#  ['Northwest (NV)', '/Northwest/'],
#  ['Northwest TX (TX)', '/Northwest%20TX/'],
#  ['Northwestern (MD)', '/Northwestern/'],
#  ['Northwood (CA)', '/Northwood/'],
#  ['Notre Dame (CA)', '/Notre%20Dame/'],
#  ['OBryant (MA)', '/OBryant/'],
#  ['Oak Grove (CA)', '/Oak%20Grove/'],
#  ['Oak Hall (FL)', '/Oak%20Hall/'],
#  ['Oak Hill (OR)', '/Oak%20Hill/'],
#  ['Oak Park River Forest (IL)', '/Oak%20Park%20River%20Forest/'],
#  ['Oakland Tech (CA)', '/Oakland%20Tech/'],
#  ['Oakton (VA)', '/Oakton/'],
#  ['Oakton Independent (VA)', '/Oakton%20Independent/'],
#  ['Okemos (MI)', '/Okemos/'],
#  ['Olathe East (KS)', '/Olathe%20East/'],
#  ['Olympia (FL)', '/Olympia/'],
#  ['Omaha Marian (NE)', '/Omaha%20Marian/'],
#  ['Oregon Episcopal School (OR)', '/Oregon%20Episcopal%20School/'],
#  ['Padre Pio Academy (OH)', '/Padre%20Pio%20Academy/'],
#  ['Palo Verde (NV)', '/Palo%20Verde/'],
#  ['Park Hill (MO)', '/Park%20Hill/'],
#  ['Park Hill South (MO)', '/Park%20Hill%20South/'],
#  ['Parkview (MO)', '/Parkview/'],
#  ['Parkview Magnet (AR)', '/Parkview%20Magnet/'],
#  ['Parkway (LA)', '/Parkway/'],
#  ['Peninsula (CA)', '/Peninsula/'],
#  ['Penn (IN)', '/Penn/'],
#  ['Perry (OH)', '/Perry/'],
#  ['Phoenix Country Day School (AZ)', '/Phoenix%20Country%20Day%20School/'],
#  ['Phoenix Military Academy (IL)', '/Phoenix%20Military%20Academy/'],
#  ['Pine Crest (FL)', '/Pine%20Crest/'],
#  ['Pine Crest School (FL)', '/Pine%20Crest%20School/'],
#  ['Piper (KS)', '/Piper/'],
#  ['Pittsburg (KS)', '/Pittsburg/'],
#  ['Pittsburgh Central Catholic (PA)', '/Pittsburgh%20Central%20Catholic/'],
#  ['Plano East (TX)', '/Plano%20East/'],
#  ['Plano West (TX)', '/Plano%20West/'],
#  ['Pocatello (ID)', '/Pocatello/'],
#  ['Poly Prep (NY)', '/Poly%20Prep/'],
#  ['Polytechnic (CA)', '/Polytechnic/'],
#  ['Port Of Los Angeles (CA)', '/Port%20Of%20Los%20Angeles/'],
#  ['Presentation (CA)', '/Presentation/'],
#  ['Princeton (TX)', '/Princeton/'],
#  ['Princeton NJ (NJ)', '/Princeton%20NJ/'],
#  ['Prosper (TX)', '/Prosper/'],
#  ['Providence (NC)', '/Providence/'],
#  ['Rancho (CA)', '/Rancho/'],
#  ['Rancho San Joaquin (CA)', '/Rancho%20San%20Joaquin/'],
#  ['RaymorePeculiar (MO)', '/RaymorePeculiar/'],
#  ['Reagan (TX)', '/Reagan/'],
#  ['Riverfield (OK)', '/Riverfield/'],
#  ['Riverwood (GA)', '/Riverwood/'],
#  ['Rock Springs (WY)', '/Rock%20Springs/'],
#  ['Rockdale County (GA)', '/Rockdale%20County/'],
#  ['Rocky Mountain (CO)', '/Rocky%20Mountain/'],
#  ['Roosevelt (MN)', '/Roosevelt/'],
#  ['Rosemont (CA)', '/Rosemont/'],
#  ['Rosemount (MN)', '/Rosemount/'],
#  ['Roseville (MN)', '/Roseville/'],
#  ['Roswell (GA)', '/Roswell/'],
#  ['Round Rock (TX)', '/Round%20Rock/'],
#  ['Rowland Hall (UT)', '/Rowland%20Hall/'],
#  ['Rufus King (WI)', '/Rufus%20King/'],
#  ['Rural Independent (KS)', '/Rural%20Independent/'],
#  ['SA Harlem North Central (NJ)', '/SA%20Harlem%20North%20Central/'],
#  ['SA Queens (NY)', '/SA%20Queens/'],
#  ['SLC West (UT)', '/SLC%20West/'],
#  ['SPASH (WI)', '/SPASH/'],
#  ['STEAM Legacy (CA)', '/STEAM%20Legacy/'],
#  ['SWW (DC)', '/SWW/'],
#  ['Saint Georges (WA)', '/Saint%20Georges/'],
#  ['Salem Hills (UT)', '/Salem%20Hills/'],
#  ['Shawnee Mission East (KS)', '/Shawnee%20Mission%20East/'],
#  ['Shawnee Mission North (KS)', '/Shawnee%20Mission%20North/'],
#  ['Shawnee Mission Northwest (KS)', '/Shawnee%20Mission%20Northwest/'],
#  ['Shawnee Mission South (KS)', '/Shawnee%20Mission%20South/'],
#  ['Shawnee Mission West (KS)', '/Shawnee%20Mission%20West/'],
#  ['Sidwell Friends (DC)', '/Sidwell%20Friends/'],
#  ['Silver Creek (CA)', '/Silver%20Creek/'],
#  ['Sioux Falls (SD)', '/Sioux%20Falls/'],
#  ['Sioux Falls Roosevelt (SD)', '/Sioux%20Falls%20Roosevelt/'],
#  ['Sky View (UT)', '/Sky%20View/'],
#  ['Skyline UT (UT)', '/Skyline%20UT/'],
#  ['Slocum (TX)', '/Slocum/'],
#  ['Solon (OH)', '/Solon/'],
#  ['Solorio (IL)', '/Solorio/'],
#  ['Sonoma Academy (CA)', '/Sonoma%20Academy/'],
#  ['South Eugene (OR)', '/South%20Eugene/'],
#  ['South Gate (CA)', '/South%20Gate/'],
#  ['Springfield Catholic (MO)', '/Springfield%20Catholic/'],
#  ['St Andrews Episcopal School (MS)', '/St%20Andrews%20Episcopal%20School/'],
#  ['St Francis (CA)', '/St%20Francis/'],
#  ['St Ignatius (OH)', '/St%20Ignatius/'],
#  ['St Marks (TX)', '/St%20Marks/'],
#  ['St Paul Central (MN)', '/St%20Paul%20Central/'],
#  ['Stanford Online (CA)', '/Stanford%20Online/'],
#  ['Stern MASS (CA)', '/Stern%20MASS/'],
#  ['Stockdale (CA)', '/Stockdale/'],
#  ['Strath Haven (PA)', '/Strath%20Haven/'],
#  ['Stuyvesant (NY)', '/Stuyvesant/'],
#  ['Success Academy Bronx (NY)', '/Success%20Academy%20Bronx/'],
#  ['Success Academy DP (NY)', '/Success%20Academy%20DP/'],
#  ['Success Academy Midtown West (NY)', '/Success%20Academy%20Midtown%20West/'],
#  ['Summit Christian Academy (MO)', '/Summit%20Christian%20Academy/'],
#  ['The Meadows School (NV)', '/The%20Meadows%20School/'],
#  ['Thomas Jefferson (VA)', '/Thomas%20Jefferson/'],
#  ['Thomas Kelly (IL)', '/Thomas%20Kelly/'],
#  ['Topeka (KS)', '/Topeka/'],
#  ['Trinity (TX)', '/Trinity/'],
#  ['Trinity Academy (KS)', '/Trinity%20Academy/'],
#  ['Truman (MO)', '/Truman/'],
#  ['Tuloso Midway (TX)', '/Tuloso%20Midway/'],
#  ['Tulsa Union (OK)', '/Tulsa%20Union/'],
#  ['U Chicago Lab (IL)', '/U%20Chicago%20Lab/'],
#  ['USN (TN)', '/USN/'],
#  ['Unionville (PA)', '/Unionville/'],
#  ['University (CA)', '/University/'],
#  ['University Hi (WA)', '/University%20Hi/'],
#  ['VHTPA (CA)', '/VHTPA/'],
#  ['VIP (CA)', '/VIP/'],
#  ['Valdosta (GA)', '/Valdosta/'],
#  ['Valle De Mill (KS)', '/Valle%20De%20Mill/'],
#  ['Valor (CA)', '/Valor/'],
#  ['Vespa College Prep (CA)', '/Vespa%20College%20Prep/'],
#  ['Village (TX)', '/Village/'],
#  ['Vista Ridge (TX)', '/Vista%20Ridge/'],
#  ['WB Ray (TX)', '/WB%20Ray/'],
#  ['Waco Midway (TX)', '/Waco%20Midway/'],
#  ['Wakeland (TX)', '/Wakeland/'],
#  ['Wallenberg (CA)', '/Wallenberg/'],
#  ['Walter Payton (IL)', '/Walter%20Payton/'],
#  ['Washburn Rural (KS)', '/Washburn%20Rural/'],
#  ['Washington (SD)', '/Washington/'],
#  ['Washington Latin (DC)', '/Washington%20Latin/'],
#  ['Wayzata (MN)', '/Wayzata/'],
#  ['West Campus (CA)', '/West%20Campus/'],
#  ['West Des Moines Valley (IA)', '/West%20Des%20Moines%20Valley/'],
#  ['Westminster (GA)', '/Westminster/'],
#  ['Westside (TX)', '/Westside/'],
#  ['Westview (OR)', '/Westview/'],
#  ['Westwood (TX)', '/Westwood/'],
#  ['Wheeler (GA)', '/Wheeler/'],
#  ['Whitney Young (IL)', '/Whitney%20Young/'],
#  ['Wichita East (KS)', '/Wichita%20East/'],
#  ['Will Rogers (OK)', '/Will%20Rogers/'],
#  ['Willard (MO)', '/Willard/'],
#  ['William Chrisman (MO)', '/William%20Chrisman/'],
#  ['Winston Churchill (TX)', '/Winston%20Churchill/'],
#  ['Woodward (GA)', '/Woodward/'],
#  ['Wooster (OH)', '/Wooster/'],
#  ['Wylie (TX)', '/Wylie/'],
#  ['Yerba Buena (CA)', '/Yerba%20Buena/']]

# %% [markdown]
# #### School Page
#
# Take the URL to a school and return a list of debaters and the URLs that point to their Aff and Neg pages

# %%
# return aff and neg URLs for all the debaters of a given school

def getTeams(url):
    
    # try opening URL
    try:
        html = urlopen(url).read()
    except Exception:
        return (0, [], {}, "School URL broke")
        
    # soupify
    soup = BeautifulSoup(html, "html.parser")
    
    # look for a table
    if len(soup.find_all("table")):
        table = soup.find_all("table")[0]
    else:
        return (0, [], {}, "School page not set up")
        
    # exclude header
    numDebaters = len(table.find_all('tr'))-1
    
    if numDebaters == 0:
        return (0, [], {}, "No debaters listed")
    
    # track team names and map to URLs
    teamNames = []
    pageURLs = {}
    
    
    # for each table row
    for row in table.find_all('tr')[1:]:
        
        # the first column's string is the team name
        team = row.find('td').string
        teamNames.append(team)
        
        # collect the URLs to the aff and neg page
        links = row.find_all('a')
        URLs = [link.get("href") for link in links]
        pageURLs[team] = URLs
    
    return (numDebaters, teamNames, pageURLs, "")

# %%
getTeams("https://hspolicy19.debatecoaches.org/Advanced%20Technologies%20Academy")
# Out:
# (3,
#  ['Advanced Technologies Academy Jacqueline Balanovsky - Raymond Behnke',
#   'Advanced Technologies Academy Sam Self - Jonah Gentleman',
#   'Advanced Technologies Academy Ryan Fritchel - Hannah Lewis'],
#  {'Advanced Technologies Academy Jacqueline Balanovsky - Raymond Behnke': ['/Advanced%20Technologies%20Academy/Balanovsky-Behnke%20Aff',
#    '/Advanced%20Technologies%20Academy/Balanovsky-Behnke%20Neg'],
#   'Advanced Technologies Academy Sam Self - Jonah Gentleman': ['/Advanced%20Technologies%20Academy/Self-Gentleman%20Aff',
#    '/Advanced%20Technologies%20Academy/Self-Gentleman%20Neg'],
#   'Advanced Technologies Academy Ryan Fritchel - Hannah Lewis': ['/Advanced%20Technologies%20Academy/Fritchel-Lewis%20Aff',
#    '/Advanced%20Technologies%20Academy/Fritchel-Lewis%20Neg']},
#  '')

# %% [markdown]
# #### Team Page

# %%
def getDisclosure(url):

    # try opening URL
    try:
        html = urlopen(url).read().decode('utf-8-sig')
        
    except Exception:
        return {"Team URL":url,
                "Rounds": [],
                "Round Reports": [],
                "Cites": [],
                "Errors": "Did not open"}
    
    
    # soupify
    soup = BeautifulSoup(html, "html.parser")
    
    tables = soup.find_all("table")

    if len(tables) > 2:
        
        rnds = tables[0]
        rndrprts = tables[1]
        cts = tables[2]
    
    else:
        
        return {"Team URL":url,
                "Rounds": [],
                "Round Reports": [],
                "Cites": [],
                "Errors": "Not configured properly"}
    
    # collect all rounds
    rounds = []
    
    for row in rnds.find_all("tr")[1:]:
        
        # get pieces
        cols = row.find_all("td")
        trn = cols[0].text
        rnd = cols[1].text
        opp = cols[2].text
        jdg = cols[3].text
        osrc = cols[6].find("a")
        if osrc:
            docURL = osrc.get("href")
        else:
            docURL = ""
            
        rounds.append([trn, rnd, opp, jdg, docURL])
    
    # collect all round reports
    roundReports = []
    
    for row in rndrprts.find_all("tr")[1:]:
        try:
            pars = roundReports.append(row.find_all("td")[2].find_all("p")[1].text)
        except:
            continue

    # collect all cites
    cites = [row.find_all("td")[0].find("span").text for row in cts.find_all('tr')[1:]]
        
    return {"Team URL":url,
            "Rounds": rounds,
            "Round Reports": roundReports,
            "Cites": cites,
            "Errors": ""}

# %%
getDisclosure("https://hsld17.debatecoaches.org/Acton-Boxborough/Liu%20Aff")
# Out:
# {'Team URL': 'https://hsld17.debatecoaches.org/Acton-Boxborough/Liu%20Aff',
#  'Rounds': [['-', 'Finals', '-', '-', ''],
#   ['Harvard', '2', 'Dan Shahab', 'David Moon', ''],
#   ['Lexington Winter Invitational', '2', 'Scarsdale AW', 'David Moon', ''],
#   ['Newark Invitational', '4', 'Stuyvesant JL', 'Amit Kukreja', ''],
#   ['Practice Round', '1', 'Michelle I drop T Li', 'the coolest judge', ''],
#   ['Practice Round', 'Semis', '-', '-', '']],
#  'Round Reports': [],
#  'Cites': ['Contact',
#   'JF - Brown Bear AC',
#   'JF - Brown Bear AC v2',
#   'JF - Brown Bear AC v3',
#   'JF - Deleuzian Narrativity 1AC'],
#  'Errors': ''}

# %% [markdown]
# #### Execution
#
# Loop through wikis, find all schools, visit all entry pages, scrape all positions.

# %%
for wiki in WIKIS[2:]:
    
    # unpack wiki
    wikiName = wiki[0]
    wikiURL = wiki[1]
    
    # if it exists, don't overwrite
    if (not OVERWRITE) and path.exists(OUTPATH + wikiName + "_schools_wiki.csv"):
        continue
        
    # open output file
    with open(OUTPATH + wikiName + "schools_wiki.csv", 'w', encoding="utf-8") as SCHOOLFILE, open(OUTPATH + wikiName + "teams_wiki.csv", 'w', encoding="utf-8") as TEAMFILE:
        
        # instantaite writer
        schoolWriter = csv.DictWriter(SCHOOLFILE,
                                     fieldnames = ["School Name",
                                                   "School URL",
                                                   "School Teams",
                                                   "Errors"],
                                      quotechar='"', 
                                      quoting=csv.QUOTE_NONNUMERIC,
                                     lineterminator = "\n")
        
        # write header
        schoolWriter.writeheader()
        
        # instantaite writer
        teamWriter = csv.DictWriter(TEAMFILE,
                                    fieldnames = ["Team Name",
                                                  "Side",
                                                  "Team URL",
                                                  "Rounds",
                                                  "Round Reports",
                                                  "Cites",
                                                  "Errors"],
                                    lineterminator = "\n")
        
        # write header
        teamWriter.writeheader()
            
        print("Scraping " + wikiName)
        
        # get school URLs
        schools = getSchools(wikiURL)
        
        print("There are " + str(len(schools)) + " schools")
        
        for school in schools:
            
            # get school name and URL
            schoolName, schoolURL = school[0], wikiURL + school[1]
            
            print("Checking " + schoolName)
            
            # get teams from the school
            numTeams, teamNames, teamURLs, errors = getTeams(schoolURL)
            
            print("Found " + str(numTeams) + " teams")
            
            # write school information
            schoolWriter.writerow({"School Name" : schoolName,
                                  "School URL": schoolURL,
                                  "School Teams": teamNames,
                                  "Errors": errors})
            
            for team in teamNames:
                
                try:
                
                    print("Scraping " + team)

                    # get team URL
                    teamURL = teamURLs[team]
                    affURL = wikiURL + teamURL[0]
                    negURL = wikiURL + teamURL[1]

                    # aff scraping
                    affInfo = getDisclosure(affURL)
                    affInfo["Team Name"] = team
                    affInfo["Side"] = "Aff"

                    # write aff info
                    teamWriter.writerow(affInfo)

                    # neg scraping
                    negInfo = getDisclosure(negURL)
                    negInfo["Team Name"] = team
                    negInfo["Side"] = "Neg"

                    # write neg info
                    teamWriter.writerow(negInfo)
                    
                except:
                    
                    print(team + " failed.")
# Out:
# Scraping LD19
# There are 463 schools
# Checking Acton Boxborough (MA)
# Found 8 teams
# Scraping Acton Boxborough - Matthew Liu
# Scraping Acton Boxborough - Olivia Hu
# Scraping Acton Boxborough - Sophie Zhang
# Scraping Acton Boxborough - Chris Xu
# Scraping Acton Boxborough - Iris Shu
# Scraping Acton Boxborough - Samuel Cogen
# Scraping Acton Boxborough - Amanda Wu
# Scraping Acton Boxborough - bellerina hu
# Checking Advanced Technologies Academy (NV)
# Found 4 teams
# Scraping Advanced Technologies Academy - Jonah Gentleman
# Scraping Advanced Technologies Academy - Aleem Ahmed
# Scraping Advanced Technologies Academy - Samuel Self
# Scraping Advanced Technologies Academy - Jack Marshall
# Checking Airline (LA)
# Found 4 teams
# Scraping Airline - Aidan Price
# Scraping Airline - Nicholas Cooksey
# Scraping Airline - Kai Macias
# Scraping Airline - Jadyn Nourse
# Checking Alameda Independent (CA)
# Found 2 teams
# Scraping Alameda Independent - Grant Aung
# Scraping Alameda Independent - Grant Aung
