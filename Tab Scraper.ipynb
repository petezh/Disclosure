# %% [markdown]
# Tab Scraper
# ---
#
# Author: Peter Zhang
#
# Scraping tool for Tabroom.

# %% [markdown]
# ### Setup
#
# #### Imports

# %%
# imports
import urllib.request, urllib.parse, urllib.error
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import csv
import os.path
from os import path
import sys
from string import ascii_lowercase

# %% [markdown]
# #### Settings
#
# - OVERWRITE determines whether or not to update existing files.
# - PAGES_URL is a list of Wiki pages
# - OUTPATH is where files are stored

# %%
# settings
OVERWRITE = True

# %%
# get tournament URLS
TOURNAMENT_CSV = 'tools/ld_tourns.csv'

# %%
# outpath
OUTPATH = "tab_data/"
ENTRIES_FILE = "disclosure_entries.csv"
INFO_FILE = "disclosure_info.csv"

# %%
# equivalent names
VLD_NAMES = [name.strip() for name in open('tools/VLD_names.txt', 'r')]
JVLD_NAMES = [name.strip() for name in open('tools/JVLD_names.txt', 'r')]
NLD_NAMES = [name.strip() for name in open('tools/NLD_names.txt', 'r')]
VPF_NAMES = [name.strip() for name in open('tools/VPF_names.txt', 'r')]
JVPF_NAMES = [name.strip() for name in open('tools/JVPF_names.txt', 'r')]
NPF_NAMES = [name.strip() for name in open('tools/NPF_names.txt', 'r')]
VCX_NAMES = [name.strip() for name in open('tools/VCX_names.txt', 'r')]
JVCX_NAMES = [name.strip() for name in open('tools/JVCX_names.txt', 'r')]
NCX_NAMES = [name.strip() for name in open('tools/NCX_names.txt', 'r')]

# %%
# set events to scrape
TARGET_EVENTS = ["VLD", "JVLD", "NLD", "VPF", "JVPF", "NPF", "VCX", "JVCX", "NCX"]
def getType(raw_name):
    if raw_name in VLD_NAMES:
        return "VLD"
    if raw_name in JVLD_NAMES:
        return "JVLD"
    if raw_name in NLD_NAMES:
        return "NLD"
    if raw_name in VPF_NAMES:
        return "VPF"
    if raw_name in JVPF_NAMES:
        return "JVPF"
    if raw_name in NPF_NAMES:
        return "NPF"
    if raw_name in VCX_NAMES:
        return "VCX"
    if raw_name in JVCX_NAMES:
        return "JVCX"
    if raw_name in NCX_NAMES:
        return "NCX"
    return "None"

# %% [markdown]
# ### Entry Scrapers
#
# #### Events
#
# Take a tournament ID and get links to events.

# %%
def getEvents(tourn_id):
    url = "https://www.tabroom.com/index/tourn/fields.mhtml?tourn_id=" + tourn_id
    html = urlopen(url).read()
    soup = BeautifulSoup(html, "html.parser")
    links = [link for link in soup.find_all('a') if "event_id" in link.get('href')]
    return [(link.contents[0].strip(), link.get('href')) for link in links]

# %%
getEvents("16856")
# Out:
# [('Congressional Debate',
#   '/index/tourn/fields.mhtml?tourn_id=16856&event_id=141000'),
#  ('JV LD', '/index/tourn/fields.mhtml?tourn_id=16856&event_id=141001'),
#  ('Novice LD', '/index/tourn/fields.mhtml?tourn_id=16856&event_id=141003'),
#  ('Novice Public Forum',
#   '/index/tourn/fields.mhtml?tourn_id=16856&event_id=141004'),
#  ('Varsity LD', '/index/tourn/fields.mhtml?tourn_id=16856&event_id=141005'),
#  ('Varsity Public Forum',
#   '/index/tourn/fields.mhtml?tourn_id=16856&event_id=141006')]

# %% [markdown]
# #### Entries
#
# Take the URL to an event's page and return event entry info.

# %%
# extract table from a page
def getEntries(url, eventType, tournName):
    
    html = urlopen(url).read()
    soup = BeautifulSoup(html, "html.parser")

    table = soup.find("table").find("tbody")
    
    entries = []
    for row in table.find_all("tr"):
        
        entries.append([tournName, eventType] + [field.text.strip() for field in row.find_all("td")])
    
    return entries

# %%
getEntries("https://www.tabroom.com/index/tourn/fields.mhtml?tourn_id=16856&event_id=141005", "JVLD", "AppleValley")
# Out:
# [['AppleValley',
#   'JVLD',
#   'Acton-Boxborough Regional High Scho',
#   'MA/US',
#   'Bellerina Hu',
#   'Acton-Boxborough BH'],
#  ['AppleValley',
#   'JVLD',
#   'Apple Valley High School',
#   'MN/US',
#   'John Schwartz',
#   'Apple Valley JS'],
#  ['AppleValley',
#   'JVLD',
#   'Apple Valley High School',
#   'MN/US',
#   'Nora Bolsoni',
#   'Apple Valley NB'],
#  ['AppleValley',
#   'JVLD',
#   'Appleton North',
#   'WI/US',
#   'Mihir Uberoi',
#   'Appleton North MU'],
#  ['AppleValley',
#   'JVLD',
#   'BASIS Independent Silicon Valley In',
#   'CA/US',
#   'Shreyas Kapavarapu',
#   'BASIS Independent Silicon Valley Independent SK'],
#  ['AppleValley',
#   'JVLD',
#   'Bergen County Academies',
#   'NJ/US',
#   'Andrew Kim',
#   'Bergen County Academies AK'],
#  ['AppleValley',
#   'JVLD',
#   'Bettendorf High School',
#   'IA/US',
#   'Noah Rantilla',
#   'Bettendorf NR'],
#  ['AppleValley',
#   'JVLD',
#   'Brentwood School',
#   'CA/US',
#   'Sophie Rubin',
#   'Brentwood SR'],
#  ['AppleValley',
#   'JVLD',
#   'Byram Hills High School',
#   'NY/US',
#   'Eleanor Wangensteen',
#   'Byram Hills EW'],
#  ['AppleValley',
#   'JVLD',
#   'Byram Hills High School',
#   'NY/US',
#   'Magdalena Whelley',
#   'Byram Hills MW'],
#  ['AppleValley',
#   'JVLD',
#   'Byram Hills High School',
#   'NY/US',
#   'Sam Hadiono',
#   'Byram Hills SH'],
#  ['AppleValley',
#   'JVLD',
#   'Carmel Valley Independent',
#   'CA/US',
#   'Andrew Kang',
#   'Carmel Valley Independent AK'],
#  ['AppleValley',
#   'JVLD',
#   'Carmel Valley Independent',
#   'CA/US',
#   'Elaine Dong',
#   'Carmel Valley Independent ED'],
#  ['AppleValley',
#   'JVLD',
#   'Carmel Valley Independent',
#   'CA/US',
#   'Katie Wang',
#   'Carmel Valley Independent KW'],
#  ['AppleValley',
#   'JVLD',
#   'Carmel Valley Independent',
#   'CA/US',
#   'Max Norman',
#   'Carmel Valley Independent MN'],
#  ['AppleValley',
#   'JVLD',
#   'Carmel Valley Independent',
#   'CA/US',
#   'Sarah Zhou',
#   'Carmel Valley Independent SZ'],
#  ['AppleValley',
#   'JVLD',
#   'Carnegie Vanguard High School',
#   'TX/US',
#   'Cindy Cui',
#   'Carnegie Vanguard CC'],
#  ['AppleValley',
#   'JVLD',
#   'Carnegie Vanguard High School',
#   'TX/US',
#   'Leon Sakata',
#   'Carnegie Vanguard LS'],
#  ['AppleValley',
#   'JVLD',
#   'Carnegie Vanguard High School',
#   'TX/US',
#   'Siddhartha Rana',
#   'Carnegie Vanguard SR'],
#  ['AppleValley',
#   'JVLD',
#   'Carnegie Vanguard High School',
#   'TX/US',
#   'Tanish Madan',
#   'Carnegie Vanguard TM'],
#  ['AppleValley',
#   'JVLD',
#   'Chanhassen High School',
#   'MN/US',
#   'Abby Newman',
#   'Chanhassen AN'],
#  ['AppleValley',
#   'JVLD',
#   'Coppell High School',
#   'TX/US',
#   'Vansh Nanda',
#   'Coppell VN'],
#  ['AppleValley',
#   'JVLD',
#   'Coppell High School',
#   'TX/US',
#   'Vishal Sivamani',
#   'Coppell VS'],
#  ['AppleValley',
#   'JVLD',
#   'Dougherty Valley High School',
#   'CA/US',
#   'Arjun Garg',
#   'Dougherty Valley AG'],
#  ['AppleValley',
#   'JVLD',
#   'Dougherty Valley High School',
#   'CA/US',
#   'Aditya Madaraju',
#   'Dougherty Valley AM'],
#  ['AppleValley',
#   'JVLD',
#   'Dougherty Valley High School',
#   'CA/US',
#   'Tarpan Mishra',
#   'Dougherty Valley TM'],
#  ['AppleValley',
#   'JVLD',
#   'Dowling Catholic High School',
#   'IA/US',
#   'James Piazza',
#   'Dowling Catholic JP'],
#  ['AppleValley',
#   'JVLD',
#   'Dulles High School',
#   'TX/US',
#   'Abhinav Sinha',
#   'Dulles AS'],
#  ['AppleValley',
#   'JVLD',
#   'Dulles High School',
#   'TX/US',
#   'Connor Self',
#   'Dulles CS'],
#  ['AppleValley',
#   'JVLD',
#   'Dulles High School',
#   'TX/US',
#   'Rhea Biswas',
#   'Dulles RB'],
#  ['AppleValley',
#   'JVLD',
#   'Dulles High School',
#   'TX/US',
#   'Sarah Zheng',
#   'Dulles SZ'],
#  ['AppleValley',
#   'JVLD',
#   'Dulles High School',
#   'TX/US',
#   'Tommy Yu',
#   'Dulles TY'],
#  ['AppleValley',
#   'JVLD',
#   'Durham Academy',
#   'NC/US',
#   'Aadesh Anchailya',
#   'Durham AA'],
#  ['AppleValley', 'JVLD', 'Durham Academy', 'NC/US', 'Vika Wei', 'Durham VW'],
#  ['AppleValley',
#   'JVLD',
#   'Dutchtown High School',
#   'LA/US',
#   'Harun Vemulapalli',
#   'Dutchtown HV'],
#  ['AppleValley',
#   'JVLD',
#   'Eagan High School',
#   'MN/',
#   'Ashley Chen',
#   'Eagan AC'],
#  ['AppleValley', 'JVLD', 'Eagan High School', 'MN/', 'Arush Iyer', 'Eagan AI'],
#  ['AppleValley',
#   'JVLD',
#   'Eagan High School',
#   'MN/',
#   'Bianca Turman',
#   'Eagan BT'],
#  ['AppleValley',
#   'JVLD',
#   'Eagan High School',
#   'MN/',
#   'Julia Schowalter',
#   'Eagan JS'],
#  ['AppleValley',
#   'JVLD',
#   'Eagan High School',
#   'MN/',
#   'Vrusha Patel',
#   'Eagan VPa'],
#  ['AppleValley',
#   'JVLD',
#   'Eastside Independent',
#   'WA/US',
#   'Margaret Li',
#   'Eastside Independent ML'],
#  ['AppleValley',
#   'JVLD',
#   'Eden Prairie High School',
#   'MN/US',
#   'Avik Garg',
#   'Eden Prairie AGa'],
#  ['AppleValley',
#   'JVLD',
#   'Edina High School',
#   'MN/US',
#   'Ananth Veluvali',
#   'Edina AV'],
#  ['AppleValley',
#   'JVLD',
#   'Edina High School',
#   'MN/US',
#   'Leo Hickey',
#   'Edina LH'],
#  ['AppleValley',
#   'JVLD',
#   'Edina High School',
#   'MN/US',
#   'Matt Kumar-Montei',
#   'Edina MK'],
#  ['AppleValley',
#   'JVLD',
#   'Elkins High School',
#   'TX/US',
#   'Ayush Manoj',
#   'Elkins AM'],
#  ['AppleValley',
#   'JVLD',
#   'Evergreen Valley Independent',
#   'CA/US',
#   'Saurish Srivastava',
#   'Evergreen Valley SS'],
#  ['AppleValley',
#   'JVLD',
#   'Flintridge Preparatory',
#   'CA/US',
#   'Thomas Vandenburg',
#   'Flintridge Prep TV'],
#  ['AppleValley',
#   'JVLD',
#   'Greenhill School',
#   'TX/US',
#   'Arush Adabala',
#   'Greenhill AA'],
#  ['AppleValley',
#   'JVLD',
#   'Greenhill School',
#   'TX/US',
#   'Krutin Devesh',
#   'Greenhill KD'],
#  ['AppleValley',
#   'JVLD',
#   'Greenhill School',
#   'TX/US',
#   'Kelly Meng',
#   'Greenhill KM'],
#  ['AppleValley',
#   'JVLD',
#   'Greenhill School',
#   'TX/US',
#   'Nikitha Thoduguli',
#   'Greenhill NT'],
#  ['AppleValley',
#   'JVLD',
#   'Greenhill School',
#   'TX/US',
#   'Ramateja Mettu',
#   'Greenhill RM'],
#  ['AppleValley',
#   'JVLD',
#   'Greenhill School',
#   'TX/US',
#   'Varsha Gande',
#   'Greenhill VG'],
#  ['AppleValley',
#   'JVLD',
#   'Hamilton High Independent',
#   'AZ/US',
#   'Nolan Burke',
#   'Hamilton High Independent NB'],
#  ['AppleValley', 'JVLD', 'Harrison', 'NY/US', 'Ali Ahmad', 'Harrison AA'],
#  ['AppleValley',
#   'JVLD',
#   'Harrison',
#   'NY/US',
#   'Elizabeth Murno',
#   'Harrison EM'],
#  ['AppleValley', 'JVLD', 'Harrison', 'NY/US', 'Giovanni Cutri', 'Harrison GC'],
#  ['AppleValley', 'JVLD', 'Harrison', 'NY/US', 'Mai Blaustein', 'Harrison MB'],
#  ['AppleValley', 'JVLD', 'Harrison', 'NY/US', 'Sonali Nicola', 'Harrison SN'],
#  ['AppleValley',
#   'JVLD',
#   'Hopkins High School',
#   'MN/US',
#   'Ezana Tedla',
#   'Hopkins ET'],
#  ['AppleValley',
#   'JVLD',
#   'Houston Memorial High School',
#   'TX/US',
#   'Daniel Xu',
#   'Houston Memorial DX'],
#  ['AppleValley',
#   'JVLD',
#   'Immaculate Heart High School',
#   'CA/US',
#   'Beatrice Culligan',
#   'Immaculate Heart BC'],
#  ['AppleValley',
#   'JVLD',
#   'Immaculate Heart High School',
#   'CA/US',
#   'Felicity Park',
#   'Immaculate Heart FP'],
#  ['AppleValley',
#   'JVLD',
#   'Immaculate Heart High School',
#   'CA/US',
#   'Jane Lichtman',
#   'Immaculate Heart JL'],
#  ['AppleValley',
#   'JVLD',
#   'Immaculate Heart High School',
#   'CA/US',
#   'Lucia Botham',
#   'Immaculate Heart LB'],
#  ['AppleValley',
#   'JVLD',
#   'Immaculate Heart High School',
#   'CA/US',
#   'Riley Rees',
#   'Immaculate Heart RR'],
#  ['AppleValley',
#   'JVLD',
#   'Immaculate Heart High School',
#   'CA/US',
#   'Zofia Barr',
#   'Immaculate Heart ZB'],
#  ['AppleValley',
#   'JVLD',
#   'Iowa City West',
#   'IA/US',
#   'Jayden Shin',
#   'Iowa City West JS'],
#  ['AppleValley',
#   'JVLD',
#   'Iowa City West',
#   'IA/US',
#   'Nathan Weimar',
#   'Iowa City West NW'],
#  ['AppleValley',
#   'JVLD',
#   'L C Anderson High School',
#   'TX/US',
#   'Aseel Rawashdeh',
#   'L C Anderson AR'],
#  ['AppleValley',
#   'JVLD',
#   'L C Anderson High School',
#   'TX/US',
#   'Brett Cryan',
#   'L C Anderson BC'],
#  ['AppleValley',
#   'JVLD',
#   'Lake Highland Preparatory School',
#   'FL/US',
#   'Anay Shah',
#   'Lake Highland Prep AS'],
#  ['AppleValley',
#   'JVLD',
#   'Lake Highland Preparatory School',
#   'FL/US',
#   'Arjun Verma',
#   'Lake Highland Prep AV'],
#  ['AppleValley',
#   'JVLD',
#   'Lake Highland Preparatory School',
#   'FL/US',
#   'Dylan Pandya',
#   'Lake Highland Prep DP'],
#  ['AppleValley',
#   'JVLD',
#   'Lake Highland Preparatory School',
#   'FL/US',
#   'Krithik Seela',
#   'Lake Highland Prep KS'],
#  ['AppleValley',
#   'JVLD',
#   'Lake Highland Preparatory School',
#   'FL/US',
#   'Yash Agrawal',
#   'Lake Highland Prep YA'],
#  ['AppleValley',
#   'JVLD',
#   'Legacy Christian Academy',
#   'TX/US',
#   'Breigh Plat',
#   'Legacy Christian BP'],
#  ['AppleValley',
#   'JVLD',
#   'Lexington HS',
#   'MA/US',
#   'Archit Kumar',
#   'Lexington AKu'],
#  ['AppleValley',
#   'JVLD',
#   'Lexington HS',
#   'MA/US',
#   'Anuka Manghwani',
#   'Lexington AMa'],
#  ['AppleValley',
#   'JVLD',
#   'Lexington HS',
#   'MA/US',
#   'Aavedon Roy',
#   'Lexington AR'],
#  ['AppleValley',
#   'JVLD',
#   'Lexington HS',
#   'MA/US',
#   'Brett Fortier',
#   'Lexington BF'],
#  ['AppleValley',
#   'JVLD',
#   'Lexington HS',
#   'MA/US',
#   'Christian Han',
#   'Lexington CH'],
#  ['AppleValley',
#   'JVLD',
#   'Lexington HS',
#   'MA/US',
#   'Jeong-Wan Choi',
#   'Lexington JC'],
#  ['AppleValley',
#   'JVLD',
#   'Lexington HS',
#   'MA/US',
#   'Mahad Sohail',
#   'Lexington MS'],
#  ['AppleValley',
#   'JVLD',
#   'Lexington HS',
#   'MA/US',
#   'Vikrant Maan',
#   'Lexington VM'],
#  ['AppleValley',
#   'JVLD',
#   'Lincoln East High School',
#   'NE/US',
#   'Elena Belashchenko',
#   'Lincoln East EB'],
#  ['AppleValley',
#   'JVLD',
#   'Lincoln East High School',
#   'NE/US',
#   'Pratham Soni',
#   'Lincoln East PS'],
#  ['AppleValley',
#   'JVLD',
#   'Loyola High School',
#   'CA/US',
#   'Benjamin Cortez',
#   'Loyola BC'],
#  ['AppleValley',
#   'JVLD',
#   'Loyola High School',
#   'CA/US',
#   'Braden Masih',
#   'Loyola BM'],
#  ['AppleValley',
#   'JVLD',
#   'Loyola High School',
#   'CA/US',
#   'Daniel Beck',
#   'Loyola DB'],
#  ['AppleValley',
#   'JVLD',
#   'Loyola High School',
#   'CA/US',
#   'Lucas Hunter',
#   'Loyola LH'],
#  ['AppleValley',
#   'JVLD',
#   'Loyola High School',
#   'CA/US',
#   'Sameer Nayyar',
#   'Loyola SN'],
#  ['AppleValley', 'JVLD', 'Lynbrook HS', 'CA/US', 'Allison Hsu', 'Lynbrook AH'],
#  ['AppleValley',
#   'JVLD',
#   'Lynbrook HS',
#   'CA/US',
#   'Keshav Dandu',
#   'Lynbrook KD'],
#  ['AppleValley',
#   'JVLD',
#   'Marlborough School',
#   'CA/US',
#   'Eva Rodriguez',
#   'Marlborough ER'],
#  ['AppleValley',
#   'JVLD',
#   'Marlborough School',
#   'CA/US',
#   'Wyeth Renwick',
#   'Marlborough WR'],
#  ['AppleValley',
#   'JVLD',
#   'McNeil High School',
#   'TX/',
#   'Anshul Gulati',
#   'McNeil AG'],
#  ['AppleValley',
#   'JVLD',
#   'McNeil High School',
#   'TX/',
#   'Adrita RayChaudhuri',
#   'McNeil AR'],
#  ['AppleValley',
#   'JVLD',
#   'Millard North High School',
#   'NE/US',
#   'Nathan Liu',
#   'Millard North NL'],
#  ['AppleValley',
#   'JVLD',
#   'Millard North High School',
#   'NE/US',
#   'Ryan Lampman',
#   'Millard North RL'],
#  ['AppleValley',
#   'JVLD',
#   'Millard North High School',
#   'NE/US',
#   'Shiv Lele',
#   'Millard North SL'],
#  ['AppleValley',
#   'JVLD',
#   'Milton Academy',
#   'MA/US',
#   'Andrew Tsang',
#   'Milton Acad AT'],
#  ['AppleValley',
#   'JVLD',
#   'Mission San Jose High School',
#   'CA/US',
#   'Advika Bhike',
#   'Mission San Jose AB'],
#  ['AppleValley',
#   'JVLD',
#   'Mission San Jose High School',
#   'CA/US',
#   'Allison Wang',
#   'Mission San Jose AW'],
#  ['AppleValley',
#   'JVLD',
#   'Mission San Jose High School',
#   'CA/US',
#   'Sanah Bhardwaj',
#   'Mission San Jose SB'],
#  ['AppleValley',
#   'JVLD',
#   'Mission San Jose High School',
#   'CA/US',
#   'Shrey Raju',
#   'Mission San Jose SR'],
#  ['AppleValley',
#   'JVLD',
#   'Mission San Jose High School',
#   'CA/US',
#   'Saranya Singh',
#   'Mission San Jose SS'],
#  ['AppleValley',
#   'JVLD',
#   'Murphy Independent',
#   'TX/US',
#   'Aadit Walia',
#   'Murphy Independent AW'],
#  ['AppleValley',
#   'JVLD',
#   'Needham High School',
#   'MA/US',
#   'Vijay Fisch',
#   'Needham VF'],
#  ['AppleValley',
#   'JVLD',
#   'New Trier High School',
#   'IL/US',
#   'Izaak Van Til',
#   'New Trier IV'],
#  ['AppleValley',
#   'JVLD',
#   'North Mecklenburg High School',
#   'NC/US',
#   'Patrick Mays',
#   'North Mecklenburg PM'],
#  ['AppleValley',
#   'JVLD',
#   'Northern Valley HS Independent',
#   'NJ/US',
#   'James Song',
#   'Northern Valley HS Independent JS'],
#  ['AppleValley',
#   'JVLD',
#   'Northland Christian School',
#   'TX/US',
#   'Lilly Broussard',
#   'Northland Christian LB'],
#  ['AppleValley',
#   'JVLD',
#   'Northview High School',
#   'GA/US',
#   'Sreyaash Das',
#   'Northview SD'],
#  ['AppleValley',
#   'JVLD',
#   'Northview High School',
#   'GA/US',
#   'Yasmin Shalim',
#   'Northview YS'],
#  ['AppleValley',
#   'JVLD',
#   'Olympia HS',
#   'FL/US',
#   'Omar Elsakhawy',
#   'Olympia OE'],
#  ['AppleValley',
#   'JVLD',
#   'Peninsula High School',
#   'CA/US',
#   'Anish Ramireddy',
#   'Peninsula AR'],
#  ['AppleValley',
#   'JVLD',
#   'Peninsula High School',
#   'CA/US',
#   'Henry Chung',
#   'Peninsula HC'],
#  ['AppleValley',
#   'JVLD',
#   'Peninsula High School',
#   'CA/US',
#   'Rhys Moon',
#   'Peninsula RM'],
#  ['AppleValley',
#   'JVLD',
#   'Peninsula High School',
#   'CA/US',
#   'Saul Munn',
#   'Peninsula SM'],
#  ['AppleValley',
#   'JVLD',
#   'Plano Independent',
#   'TX/US',
#   'Nathan Gong',
#   'Plano Independent NG'],
#  ['AppleValley',
#   'JVLD',
#   'Portola High School',
#   'CA/US',
#   'Amitoj Singh',
#   'Portola AS'],
#  ['AppleValley',
#   'JVLD',
#   'Riverside HS',
#   'SC/US',
#   'Kritika Sethi',
#   'Riverside KS'],
#  ['AppleValley',
#   'JVLD',
#   'Rosemount Sr High School',
#   'MN/US',
#   'Alex Owens',
#   'Rosemount AO'],
#  ['AppleValley',
#   'JVLD',
#   'Rosemount Sr High School',
#   'MN/US',
#   'Cierra Phillips',
#   'Rosemount CP'],
#  ['AppleValley',
#   'JVLD',
#   'Rosemount Sr High School',
#   'MN/US',
#   'Tanvi Adige',
#   'Rosemount TA'],
#  ['AppleValley', 'JVLD', 'STA/Vis', 'MN/US', 'Isabel Brandt', 'STA/Vis IB'],
#  ['AppleValley', 'JVLD', 'Saratoga HS', 'CA/US', 'Arnav Garg', 'Saratoga AG'],
#  ['AppleValley',
#   'JVLD',
#   'Scarsdale High School',
#   'NY/US',
#   'Bryan Shi',
#   'Scarsdale BS'],
#  ['AppleValley',
#   'JVLD',
#   'Scarsdale High School',
#   'NY/US',
#   'Caroline Shi',
#   'Scarsdale CS'],
#  ['AppleValley',
#   'JVLD',
#   'Scarsdale High School',
#   'NY/US',
#   'Jaden Tepper',
#   'Scarsdale JT'],
#  ['AppleValley',
#   'JVLD',
#   'Scarsdale High School',
#   'NY/US',
#   'Katherine Shi',
#   'Scarsdale KS'],
#  ['AppleValley',
#   'JVLD',
#   'Southlake Carroll',
#   'TX/US',
#   'Cristina Capriglione',
#   'Southlake Carroll CC'],
#  ['AppleValley',
#   'JVLD',
#   'Southlake Carroll',
#   'TX/US',
#   'Enya Pinjani',
#   'Southlake Carroll EP'],
#  ['AppleValley',
#   'JVLD',
#   'Southlake Carroll',
#   'TX/US',
#   'Pranav Kaginele',
#   'Southlake Carroll PK'],
#  ['AppleValley',
#   'JVLD',
#   'Southlake Carroll',
#   'TX/US',
#   'Samhith Dharani',
#   'Southlake Carroll SD'],
#  ['AppleValley',
#   'JVLD',
#   'St Michael Albertville High School',
#   'MN/US',
#   'Alexander Boltz',
#   'St Michael Albertville AB'],
#  ['AppleValley',
#   'JVLD',
#   'St. Croix Prep',
#   'MN/US',
#   'Alexandriana Davis',
#   'St Croix Prep AD'],
#  ['AppleValley',
#   'JVLD',
#   'St. Croix Prep',
#   'MN/US',
#   'Avery DeWitt',
#   'St Croix Prep ADe'],
#  ['AppleValley',
#   'JVLD',
#   'Stanford Online High School',
#   'CA/US',
#   'Mahir Bansal',
#   'Stanford Online MB'],
#  ['AppleValley',
#   'JVLD',
#   'Strake Jesuit College Preparatory',
#   'TX/US',
#   'Ben Erdmann',
#   'Strake Jesuit  BE'],
#  ['AppleValley',
#   'JVLD',
#   'Strake Jesuit College Preparatory',
#   'TX/US',
#   'Diego Arcos',
#   'Strake Jesuit  DA'],
#  ['AppleValley',
#   'JVLD',
#   'Strake Jesuit College Preparatory',
#   'TX/US',
#   'Joseph Georges',
#   'Strake Jesuit  JG'],
#  ['AppleValley',
#   'JVLD',
#   'Strake Jesuit College Preparatory',
#   'TX/US',
#   'JD Kollar',
#   'Strake Jesuit  JK'],
#  ['AppleValley',
#   'JVLD',
#   'Strake Jesuit College Preparatory',
#   'TX/US',
#   'Jet Sun',
#   'Strake Jesuit  JS'],
#  ['AppleValley',
#   'JVLD',
#   'Strake Jesuit College Preparatory',
#   'TX/US',
#   'Karan Shah',
#   'Strake Jesuit  KS'],
#  ['AppleValley',
#   'JVLD',
#   'Strake Jesuit College Preparatory',
#   'TX/US',
#   'Lucas Walker',
#   'Strake Jesuit  LWa'],
#  ['AppleValley',
#   'JVLD',
#   'Strake Jesuit College Preparatory',
#   'TX/US',
#   'Michael Stuckert',
#   'Strake Jesuit  MS'],
#  ['AppleValley',
#   'JVLD',
#   'Strake Jesuit College Preparatory',
#   'TX/US',
#   'Vail Chen',
#   'Strake Jesuit  VC'],
#  ['AppleValley',
#   'JVLD',
#   'Strake Jesuit College Preparatory',
#   'TX/US',
#   'Vratin Mankidy',
#   'Strake Jesuit  VM'],
#  ['AppleValley',
#   'JVLD',
#   'Strath Haven',
#   'PA/US',
#   'Ava Manaker',
#   'Strath Haven AM'],
#  ['AppleValley',
#   'JVLD',
#   'Success Academy HS - Liberal Arts',
#   'NY/US',
#   'Silma Bathily',
#   'Success Academy HS - Liberal Arts SB'],
#  ['AppleValley',
#   'JVLD',
#   'The Bronx High School Of Science',
#   'NY/US',
#   'Dahlia Bekong',
#   'Bronx Science DB'],
#  ['AppleValley',
#   'JVLD',
#   'The Bronx High School Of Science',
#   'NY/US',
#   'Leo Matthes',
#   'Bronx Science LM'],
#  ['AppleValley',
#   'JVLD',
#   'The Bronx High School Of Science',
#   'NY/US',
#   'Nicolas Kim',
#   'Bronx Science NK'],
#  ['AppleValley',
#   'JVLD',
#   'The Bronx High School Of Science',
#   'NY/US',
#   'Yona Litwin',
#   'Bronx Science YL'],
#  ['AppleValley',
#   'JVLD',
#   'The Harker School',
#   'CA/US',
#   'Anshul Reddy',
#   'Harker AR'],
#  ['AppleValley',
#   'JVLD',
#   'The Harker School',
#   'CA/US',
#   'Deven Shah',
#   'Harker DS'],
#  ['AppleValley',
#   'JVLD',
#   'The Harker School',
#   'CA/US',
#   'Rohan Thakur',
#   'Harker RT'],
#  ['AppleValley',
#   'JVLD',
#   'The Oxford Academy',
#   'CA/US',
#   'Viren Mehta',
#   'Oxford VM'],
#  ['AppleValley',
#   'JVLD',
#   'The Quarry Lane School',
#   'CA/US',
#   'Mackenzie Davis',
#   'Quarry Lane MD'],
#  ['AppleValley',
#   'JVLD',
#   'Thomas Horace Rogers',
#   'TX/US',
#   'Justin Wen',
#   'Thomas Horace Rogers JW'],
#  ['AppleValley',
#   'JVLD',
#   'Troy Independent',
#   'CA/US',
#   'Andrew Park',
#   'Troy Independent AP'],
#  ['AppleValley',
#   'JVLD',
#   'West Des Moines Valley High School',
#   'IA/US',
#   'Connor Fogarty',
#   'West Des Moines Valley CF'],
#  ['AppleValley',
#   'JVLD',
#   'West Des Moines Valley High School',
#   'IA/US',
#   'Jalyn Wu',
#   'West Des Moines Valley JW'],
#  ['AppleValley',
#   'JVLD',
#   'West Des Moines Valley High School',
#   'IA/US',
#   'Kauai Cua',
#   'West Des Moines Valley KC'],
#  ['AppleValley',
#   'JVLD',
#   'West Des Moines Valley High School',
#   'IA/US',
#   'Michael Meng',
#   'West Des Moines Valley MM'],
#  ['AppleValley',
#   'JVLD',
#   'West Des Moines Valley High School',
#   'IA/US',
#   'Shreya Joshi',
#   'West Des Moines Valley SJ'],
#  ['AppleValley',
#   'JVLD',
#   'West Des Moines Valley High School',
#   'IA/US',
#   'Tony Holm',
#   'West Des Moines Valley TH'],
#  ['AppleValley',
#   'JVLD',
#   'West High School SLC',
#   'UT/US',
#   'Amrita Krishna',
#   'West HS SLC AK'],
#  ['AppleValley',
#   'JVLD',
#   'West High School SLC',
#   'UT/US',
#   'Henry Zheng',
#   'West HS SLC HZ'],
#  ['AppleValley',
#   'JVLD',
#   'Westlake',
#   'TX/US',
#   'Anastasia Keeler',
#   'Westlake AK']]

# %% [markdown]
# #### Info
#
# Get a tournament ID and get the tournament info.

# %%
def getInfo(tourn_id):

    url = "https://www.tabroom.com/index/tourn/index.mhtml?tourn_id=" + tourn_id

    # load page
    html = urlopen(url).read()
    soup = BeautifulSoup(html, "html.parser")

    # find header
    header = soup.select('h5')[0].text.strip()
    
    # get sub-header
    year = header.split('—')[0].strip()
    location = header.split('—')[1].strip()
    if ',' in location:
        city = location.split(',')[0].strip()
        state = location.split(',')[1].strip()
    
    else:
        city = "None"
        state = location

    # get info box
    info = soup.find_all('span', {'class' : 'smaller half'})[0].text
    date = ' '.join(info.split())

    return [date, year, city, state]

# %%
getInfo("16856")
# Out:
# ['11/6 to 11/8', '2020', 'NSDA Campus', 'MN/US']

# %% [markdown]
# #### Execution
#
# Loop through tournaments.

# %%
# read tourn list
with open(TOURNAMENT_CSV, 'r') as tourn_file,  open(OUTPATH + ENTRIES_FILE, 'w') as out_file:
    
    tourn_reader = csv.DictReader(tourn_file)
    tournWriter = csv.writer(out_file,
                                    lineterminator = "\n")
    
    tournWriter.writerow(["Tournament", "Event", "School", "State", "Name", "Code", "Status"])

    for tourn in tourn_reader:
        tourn_name = tourn["Name"]
        tourn_id = tourn["URL"]
        
        print("Checking " + tourn_name)
            
        events = getEvents(tourn_id)

        for event in events:

            eventType = getType(event[0])
            print(event[0], "-->", eventType)
                
            if eventType in TARGET_EVENTS:
                    
                eventURL = "https://www.tabroom.com/" + event[1]

                tournWriter.writerows(getEntries(eventURL, eventType, tourn_name))
                
                print("Scraped", eventType, "for", tourn_name)
# Out:
# Checking alta15
# LD --> VLD
# Scraped VLD for alta15
# PF --> VPF
# Scraped VPF for alta15
# Policy --> VCX
# Scraped VCX for alta15
# Checking alta16
# LD --> VLD
# Scraped VLD for alta16
# PF --> VPF
# Scraped VPF for alta16
# Policy --> VCX
# Scraped VCX for alta16
# Checking alta17
# LD --> VLD
# Scraped VLD for alta17
# PF --> VPF
# Scraped VPF for alta17
# Policy --> VCX
# Scraped VCX for alta17
# Checking alta18
# LD --> VLD
# Scraped VLD for alta18
# PF --> VPF
# Scraped VPF for alta18
# Policy --> VCX
# Scraped VCX for alta18
# Checking alta19
# LD --> VLD
# Scraped VLD for alta19
# PF --> VPF
# Scraped VPF for alta19
# Policy --> VCX
# Scraped VCX for alta19
# Checking alta20
# LD --> VLD
# Scraped VLD for alta20
# PF --> VPF
# Scraped VPF for alta20
# Policy --> VCX
# Scraped VCX for alta20
# Checking applevalley15
# Round Robin --> None
# Varsity LD --> VLD
# Scraped VLD for applevalley15
# Varsity Public Forum --> VPF
# Scraped VPF for applevalley15
# Checking applevalley16
# Varsity LD --> VLD
# Scraped VLD for applevalley16
# Varsity Public Forum --> VPF
# Scraped VPF for applevalley16
# Checking applevalley17
# Congressional Debate --> None
# JV LD --> JVLD
# Scraped JVLD for applevalley17
# Novice LD --> NLD
# Scraped NLD for applevalley17
# Novice Public Forum --> NPF
# Scraped NPF for applevalley17
# Varsity LD --> VLD
# Scraped VLD for applevalley17
# Varsity Public Forum --> VPF
# Scraped VPF for applevalley17
# Checking applevalley18
# Congressional Debate --> None
# JV LD --> JVLD
# Scraped JVLD for applevalley18
# Novice LD --> NLD
# Scraped NLD for applevalley18
# Novice Public Forum --> NPF
# Scraped NPF for applevalley18
# Varsity LD --> VLD
# Scraped VLD for applevalley18
# Varsity Public Forum --> VPF
# Scraped VPF for applevalley18
# Checking applevalley19
# Congressional Debate --> None
# JV LD --> JVLD
# Scraped JVLD for applevalley19
# Novice LD --> NLD
# Scraped NLD for applevalley19
# Novice Public Forum --> NPF
# Scraped NPF for applevalley19
# Varsity LD --> VLD
# Scraped VLD for applevalley19
# Varsity Public Forum --> VPF
# Scraped VPF for applevalley19
# Checking applevalley20
# Congressional Debate --> None
# JV LD --> JVLD
# Scraped JVLD for applevalley20
# Novice LD --> NLD
# Scraped NLD for applevalley20
# Novice Public Forum --> NPF
# Scraped NPF for applevalley20
# Varsity LD --> VLD
# Scraped VLD for applevalley20
# Varsity Public Forum --> VPF
# Scraped VPF for applevalley20
# Checking arthurschool20
# Declamation --> None
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Informative --> None
# Legislative Debate --> None
# Novice Lincoln Douglas Debate --> NLD
# Scraped NLD for arthurschool20
# Novice Policy Debate --> NCX
# Scraped NCX for arthurschool20
# Program Oral Interpretation --> None
# Prose Reading --> None
# Public Forum --> VPF
# Scraped VPF for arthurschool20
# Varsity Lincoln Douglas Debate --> VLD
# Scraped VLD for arthurschool20
# Varsity Policy Debate --> VCX
# Scraped VCX for arthurschool20
# World Schools --> None
# Checking asu16
# Congress --> None
# Dramatic Interp --> None
# Duo Interp --> None
# Expository --> None
# Extemp --> None
# Humorous Interp --> None
# Impromptu --> None
# Novice LD --> NLD
# Scraped NLD for asu16
# Novice Policy --> NCX
# Scraped NCX for asu16
# Oratory --> None
# Poetry Interp --> None
# Programmed Oral Interp --> None
# Prose Interp --> None
# Public Forum --> VPF
# Scraped VPF for asu16
# Varsity LD --> VLD
# Scraped VLD for asu16
# Varsity Policy --> VCX
# Scraped VCX for asu16
# Checking asu17
# Congress --> None
# Dramatic Interp --> None
# Duo Interp --> None
# Expository --> None
# Extemp --> None
# Humorous Interp --> None
# Impromptu --> None
# Novice LD --> NLD
# Scraped NLD for asu17
# Novice Policy --> NCX
# Scraped NCX for asu17
# Novice Public Forum --> NPF
# Scraped NPF for asu17
# Oratory --> None
# Poetry Interp --> None
# Programmed Oral Interp --> None
# Prose Interp --> None
# Varsity LD --> VLD
# Scraped VLD for asu17
# Varsity Policy --> VCX
# Scraped VCX for asu17
# Varsity Public Forum --> VPF
# Scraped VPF for asu17
# Checking asu18
# Congress --> None
# Dramatic Interp --> None
# Duo Interp --> None
# Extemp --> None
# Humorous Interp --> None
# Impromptu --> None
# Informative --> None
# Novice Drama --> None
# Novice Extemp --> None
# Novice Humor --> None
# Novice Impromptu --> None
# Novice LD --> NLD
# Scraped NLD for asu18
# Novice Oral Interp --> None
# Novice Oratory --> None
# Novice Policy --> NCX
# Scraped NCX for asu18
# Novice Public Forum --> NPF
# Scraped NPF for asu18
# Oratory --> None
# Poetry Interp --> None
# Programmed Oral Interp --> None
# Prose Interp --> None
# Varsity LD --> VLD
# Scraped VLD for asu18
# Varsity Policy --> VCX
# Scraped VCX for asu18
# Varsity Public Forum --> VPF
# Scraped VPF for asu18
# Checking asu19
# Congress --> None
# Dramatic Interp --> None
# Duo Interp --> None
# Extemp --> None
# Humorous Interp --> None
# Impromptu --> None
# Informative --> None
# Novice LD --> NLD
# Scraped NLD for asu19
# Novice Policy --> NCX
# Scraped NCX for asu19
# Novice Public Forum --> NPF
# Scraped NPF for asu19
# Oratory --> None
# Poetry Interp --> None
# Programmed Oral Interp --> None
# Prose Interp --> None
# Varsity LD --> VLD
# Scraped VLD for asu19
# Varsity Policy --> VCX
# Scraped VCX for asu19
# Varsity Public Forum --> VPF
# Scraped VPF for asu19
# Checking asu20
# Congress --> None
# Dramatic Interp --> None
# Duo Interp --> None
# Extemp --> None
# Humorous Interp --> None
# Impromptu --> None
# Informative --> None
# Novice LD --> NLD
# Scraped NLD for asu20
# Novice Policy --> NCX
# Scraped NCX for asu20
# Novice Public Forum --> NPF
# Scraped NPF for asu20
# Oratory --> None
# Poetry Interp --> None
# Programmed Oral Interp --> None
# Prose Interp --> None
# Varsity LD --> VLD
# Scraped VLD for asu20
# Varsity Policy --> VCX
# Scraped VCX for asu20
# Varsity Public Forum --> VPF
# Scraped VPF for asu20
# Checking asu21
# Congress --> None
# Dramatic Interp --> None
# Duo Interp --> None
# Extemp --> None
# Humorous Interp --> None
# Impromptu --> None
# Informative --> None
# Junior Policy --> JVCX
# Scraped JVCX for asu21
# Novice LD --> NLD
# Scraped NLD for asu21
# Novice Policy --> NCX
# Scraped NCX for asu21
# Novice Public Forum --> NPF
# Scraped NPF for asu21
# Oratory --> None
# Poetry/Prose Interp --> None
# Programmed Oral Interp --> None
# Varsity LD --> VLD
# Scraped VLD for asu21
# Varsity Policy --> VCX
# Scraped VCX for asu21
# Varsity Public Forum --> VPF
# Scraped VPF for asu21
# Checking bethelpark17
# Checking bethelpark18
# Checking bethelpark19
# Checking bethelpark20
# Checking beltway17
# LD --> VLD
# Scraped VLD for beltway17
# Public Forum --> VPF
# Scraped VPF for beltway17
# Checking beltway16
# LD --> VLD
# Scraped VLD for beltway16
# Policy --> VCX
# Scraped VCX for beltway16
# Public Forum --> VPF
# Scraped VPF for beltway16
# Checking beltway15
# LD --> VLD
# Scraped VLD for beltway15
# Policy --> VCX
# Scraped VCX for beltway15
# Public Forum --> VPF
# Scraped VPF for beltway15
# Checking beltway14
# LD --> VLD
# Scraped VLD for beltway14
# Policy --> VCX
# Scraped VCX for beltway14
# Public Forum --> VPF
# Scraped VPF for beltway14
# Checking blake15
# Congressional Debate --> None
# Congressional Round Robin --> None
# Extemp Speaking --> None
# Extemp Speaking RR --> None
# Lincoln Douglas --> VLD
# Scraped VLD for blake15
# Policy Debate --> VCX
# Scraped VCX for blake15
# Public Forum --> VPF
# Scraped VPF for blake15
# Public Forum Round Robin --> None
# Checking blake16
# Big Questions --> None
# Congressional Debate --> None
# Congressional Round Robin --> None
# Extemp Speaking Friday --> None
# Extemp Speaking Saturday --> None
# Extemp Speaking Sunday --> None
# Lincoln Douglas --> VLD
# Scraped VLD for blake16
# Policy Debate --> VCX
# Scraped VCX for blake16
# Public Forum --> VPF
# Scraped VPF for blake16
# Public Forum Round Robin --> None
# World Schools --> None
# Checking blake17
# Big Questions --> None
# Congressional Debate --> None
# Congressional Round Robin --> None
# Extemp Speaking Clinic --> None
# Extemp Speaking Round Robin --> None
# Lincoln Douglas --> VLD
# Scraped VLD for blake17
# Policy Debate --> VCX
# Scraped VCX for blake17
# Public Forum --> VPF
# Scraped VPF for blake17
# Public Forum Round Robin --> None
# World Schools --> None
# Checking blake18
# Big Questions --> None
# Congressional Debate --> None
# Congressional Round Robin --> None
# Extemp Speaking Clinic --> None
# Extemp Speaking Round Robin --> None
# Lincoln Douglas --> VLD
# Scraped VLD for blake18
# Policy Debate --> VCX
# Scraped VCX for blake18
# Public Forum --> VPF
# Scraped VPF for blake18
# Public Forum Round Robin --> None
# World Schools --> None
# Checking blake19
# Big Questions --> None
# Congressional Debate --> None
# Congressional Round Robin --> None
# Lincoln Douglas --> VLD
# Scraped VLD for blake19
# Policy Debate --> VCX
# Scraped VCX for blake19
# Public Forum --> VPF
# Scraped VPF for blake19
# Public Forum Round Robin --> None
# World Schools --> None
# Checking blake20
# Congressional Debate --> None
# Lincoln Douglas --> VLD
# Scraped VLD for blake20
# Middle School/Novice Policy --> NCX
# Scraped NCX for blake20
# Policy Debate --> VCX
# Scraped VCX for blake20
# Public Forum --> VPF
# Scraped VPF for blake20
# Public Forum Round Robin --> None
# World Schools --> None
# Checking bluekey19
# Varsity Lincoln Douglas --> VLD
# Scraped VLD for bluekey19
# Varsity Public Forum --> VPF
# Scraped VPF for bluekey19
# Checking bluekey20
# Dramatic Interpretation --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Informative Speaking --> None
# Novice Lincoln Douglas --> NLD
# Scraped NLD for bluekey20
# Novice Public Forum --> NPF
# Scraped NPF for bluekey20
# Original Oratory --> None
# Program Oral Interpretation --> None
# Student Congress --> None
# Varsity Lincoln Douglas --> VLD
# Scraped VLD for bluekey20
# Varsity Public Forum --> VPF
# Scraped VPF for bluekey20
# Checking bronx15
# Congressional Debate --> None
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Lincoln-Douglas Debate --> VLD
# Scraped VLD for bronx15
# Original Oratory --> None
# Policy Debate --> VCX
# Scraped VCX for bronx15
# Prose and Poetry --> None
# Public Forum Debate --> VPF
# Scraped VPF for bronx15
# Checking bronx16
# Congressional Debate --> None
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Lincoln-Douglas Debate --> VLD
# Scraped VLD for bronx16
# Original Oratory --> None
# Policy Debate --> VCX
# Scraped VCX for bronx16
# Prose and Poetry --> None
# Public Forum Debate --> VPF
# Scraped VPF for bronx16
# Checking bronx17
# Congressional Debate --> None
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Lincoln-Douglas Debate --> VLD
# Scraped VLD for bronx17
# Original Oratory --> None
# Policy Debate --> VCX
# Scraped VCX for bronx17
# Program Oral Interpretation --> None
# Prose and Poetry --> None
# Public Forum --> VPF
# Scraped VPF for bronx17
# Checking bronx18
# Congressional Debate --> None
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Lincoln-Douglas Debate --> VLD
# Scraped VLD for bronx18
# Original Oratory --> None
# Policy Debate --> VCX
# Scraped VCX for bronx18
# Program Oral Interpretation --> None
# Prose and Poetry --> None
# Public Forum --> VPF
# Scraped VPF for bronx18
# Checking bronx19
# Congressional Debate --> None
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Informative Speaking --> None
# Lincoln-Douglas Debate --> VLD
# Scraped VLD for bronx19
# Original Oratory --> None
# Policy Debate --> VCX
# Scraped VCX for bronx19
# Program Oral Interpretation --> None
# Prose and Poetry --> None
# Public Forum --> VPF
# Scraped VPF for bronx19
# Checking bronx20
# Congressional Debate --> None
# Extemporaneous Speaking --> None
# Lincoln-Douglas Debate --> VLD
# Scraped VLD for bronx20
# Lincoln-Douglas Debate JV --> JVLD
# Scraped JVLD for bronx20
# Original Oratory --> None
# Policy Debate --> VCX
# Scraped VCX for bronx20
# Policy Debate JV --> JVCX
# Scraped JVCX for bronx20
# Public Forum --> VPF
# Scraped VPF for bronx20
# Public Forum Debate JV --> JVPF
# Scraped JVPF for bronx20
# Checking cal15
# Congressional Debate --> None
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Expository Speaking --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Impromptu Speaking --> None
# JV LD --> JVLD
# Scraped JVLD for cal15
# JV Policy --> JVCX
# Scraped JVCX for cal15
# JV Public Forum --> JVPF
# Scraped JVPF for cal15
# Original Oratory --> None
# Varsity LD --> VLD
# Scraped VLD for cal15
# Varsity Policy --> VCX
# Scraped VCX for cal15
# Varsity Public Forum --> VPF
# Scraped VPF for cal15
# Checking cal16
# Congressional Debate --> None
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Expository Speaking --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Impromptu Speaking --> None
# JV LD --> JVLD
# Scraped JVLD for cal16
# JV Policy --> JVCX
# Scraped JVCX for cal16
# JV Public Forum --> JVPF
# Scraped JVPF for cal16
# Original Oratory --> None
# Thematic Interpretation --> None
# Varsity LD --> VLD
# Scraped VLD for cal16
# Varsity Policy --> VCX
# Scraped VCX for cal16
# Varsity Public Forum --> VPF
# Scraped VPF for cal16
# Checking cal17
# Congressional Debate --> None
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Expository Speaking --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Impromptu Speaking --> None
# JV LD --> JVLD
# Scraped JVLD for cal17
# JV Policy --> JVCX
# Scraped JVCX for cal17
# JV Public Forum --> JVPF
# Scraped JVPF for cal17
# Original Oratory --> None
# Thematic Interpretation --> None
# Varsity LD --> VLD
# Scraped VLD for cal17
# Varsity Policy --> VCX
# Scraped VCX for cal17
# Varsity Public Forum --> VPF
# Scraped VPF for cal17
# Checking cal18
# Congressional Debate --> None
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Expository Speaking --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Impromptu Speaking --> None
# JV LD --> JVLD
# Scraped JVLD for cal18
# JV Policy --> JVCX
# Scraped JVCX for cal18
# JV Public Forum --> JVPF
# Scraped JVPF for cal18
# Original Oratory --> None
# Thematic Interpretation --> None
# Varsity LD --> VLD
# Scraped VLD for cal18
# Varsity Policy --> VCX
# Scraped VCX for cal18
# Varsity Public Forum --> VPF
# Scraped VPF for cal18
# Checking cal19
# Congressional Debate --> None
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Expository/Informative Speaking --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Impromptu Speaking --> None
# JV LD --> JVLD
# Scraped JVLD for cal19
# JV Policy --> JVCX
# Scraped JVCX for cal19
# JV Public Forum --> JVPF
# Scraped JVPF for cal19
# Original Oratory --> None
# Thematic Interpretation/POI --> None
# Varsity LD --> VLD
# Scraped VLD for cal19
# Varsity Policy --> VCX
# Scraped VCX for cal19
# Varsity Public Forum --> VPF
# Scraped VPF for cal19
# Checking cal20
# Congressional Debate --> None
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Impromptu Speaking --> None
# Informative Speaking --> None
# JV LD --> JVLD
# Scraped JVLD for cal20
# JV Policy --> JVCX
# Scraped JVCX for cal20
# JV Public Forum --> JVPF
# Scraped JVPF for cal20
# Original Oratory --> None
# Programmed Oral Interp --> None
# Varsity LD --> VLD
# Scraped VLD for cal20
# Varsity Policy --> VCX
# Scraped VCX for cal20
# Varsity Public Forum --> VPF
# Scraped VPF for cal20
# Checking centralvalley15
# Open Congress --> None
# Open LD --> VLD
# Scraped VLD for centralvalley15
# Open Public Forum --> VPF
# Scraped VPF for centralvalley15
# Checking centralvalley16
# Open Congress --> None
# Open LD --> VLD
# Scraped VLD for centralvalley16
# Open Policy --> VCX
# Scraped VCX for centralvalley16
# Open Public Forum --> VPF
# Scraped VPF for centralvalley16
# Checking centralvalley17
# Open Congress --> None
# Open LD --> VLD
# Scraped VLD for centralvalley17
# Open Policy --> VCX
# Scraped VCX for centralvalley17
# Open Public Forum --> VPF
# Scraped VPF for centralvalley17
# Checking saintjames17
# Congressional Debate --> None
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Impromptu --> None
# Informative --> None
# Novice Lincoln Douglas --> NLD
# Scraped NLD for saintjames17
# Oral Interpretation --> None
# Original Oratory --> None
# Policy Debate --> VCX
# Scraped VCX for saintjames17
# Program Oral Interpretation --> None
# Public Forum --> VPF
# Scraped VPF for saintjames17
# Varsity Lincoln Douglas --> VLD
# Scraped VLD for saintjames17
# Checking wakeforest16
# Congress --> None
# Lincoln-Douglas --> VLD
# Scraped VLD for wakeforest16
# Public Forum --> VPF
# Scraped VPF for wakeforest16
# Checking churchill17
# Championship C-X --> VCX
# Scraped VCX for churchill17
# Championship L-D --> VLD
# Scraped VLD for churchill17
# Championship Public Forum Debate --> VPF
# Scraped VPF for churchill17
# Novice L-D --> None
# Novice Public Forum Debate --> NPF
# Scraped NPF for churchill17
# Checking churchill18
# Championship CX --> VCX
# Scraped VCX for churchill18
# Championship LD --> VLD
# Scraped VLD for churchill18
# Novice CX --> NCX
# Scraped NCX for churchill18
# Novice LD --> NLD
# Scraped NLD for churchill18
# Novice PF --> NPF
# Scraped NPF for churchill18
# Public Forum --> VPF
# Scraped VPF for churchill18
# Checking churchill19
# Championship C-X --> VCX
# Scraped VCX for churchill19
# Championship L-D --> VLD
# Scraped VLD for churchill19
# Championship Public Forum Debate --> VPF
# Scraped VPF for churchill19
# Novice C-X --> NCX
# Scraped NCX for churchill19
# Novice L-D --> None
# Novice Public Forum Debate --> NPF
# Scraped NPF for churchill19
# Checking churchill20
# Championship C-X --> VCX
# Scraped VCX for churchill20
# Championship L-D --> VLD
# Scraped VLD for churchill20
# Championship Public Forum Debate --> VPF
# Scraped VPF for churchill20
# Novice C-X --> NCX
# Scraped NCX for churchill20
# Novice L-D --> None
# Novice Public Forum Debate --> NPF
# Scraped NPF for churchill20
# Checking churchill21
# Congressional Debate --> None
# Domestic Extemp --> None
# Dramatic Interp --> None
# Duet Acting --> None
# Duo Interpretation --> None
# Humorous Interp --> None
# Informative Speaking --> None
# International Extemp --> None
# Novice Lincoln Douglas --> NLD
# Scraped NLD for churchill21
# Novice Policy --> NCX
# Scraped NCX for churchill21
# Original Oratory --> None
# Poetry --> None
# Program Oral Interpretation --> None
# Prose --> None
# Varsity Lincoln Douglas --> VLD
# Scraped VLD for churchill21
# Varsity Policy --> VCX
# Scraped VCX for churchill21
# Varsity Public Forum --> VPF
# Scraped VPF for churchill21
# World Schools Debate --> None
# Checking colleyville17
# Checking colleyville18
# Checking colleyville19
# Congressional Debate --> None
# Domestic Extemp --> None
# Dramatic Interp --> None
# Duet Acting --> None
# Duo Interp --> None
# Foreign Extemp --> None
# Humorous Interp --> None
# Informative Speaking --> None
# MS Extemp --> None
# MS Original Oratory --> None
# MS Prose Poetry --> None
# MS World Schools --> None
# NCX --> NCX
# Scraped NCX for colleyville19
# NLD --> NLD
# Scraped NLD for colleyville19
# NPF --> NPF
# Scraped NPF for colleyville19
# Original Oratory --> None
# Poetry Interp --> None
# Program Oral Interp --> None
# Prose Interp --> None
# VCX --> VCX
# Scraped VCX for colleyville19
# VLD --> VLD
# Scraped VLD for colleyville19
# VPF --> VPF
# Scraped VPF for colleyville19
# World Schools --> None
# Checking colleyville20
# Congressional Debate --> None
# Domestic Extemp --> None
# Dramatic Interp --> None
# Duet Acting --> None
# Duo Interp --> None
# Foreign Extemp --> None
# Humorous Interp --> None
# Informative Speaking --> None
# NCX --> NCX
# Scraped NCX for colleyville20
# NLD --> NLD
# Scraped NLD for colleyville20
# NPF --> NPF
# Scraped NPF for colleyville20
# Original Oratory --> None
# Poetry Interp --> None
# Program Oral Interp --> None
# Prose Interp --> None
# VCX --> VCX
# Scraped VCX for colleyville20
# VLD --> VLD
# Scraped VLD for colleyville20
# VPF --> VPF
# Scraped VPF for colleyville20
# World Schools --> None
# Checking columbia15
# Public Forum --> VPF
# Scraped VPF for columbia15
# Varsity LD --> VLD
# Scraped VLD for columbia15
# Checking columbia16
# Public Forum --> VPF
# Scraped VPF for columbia16
# Varsity LD --> VLD
# Scraped VLD for columbia16
# Checking columbia17
# Public Forum --> VPF
# Scraped VPF for columbia17
# Varsity LD --> VLD
# Scraped VLD for columbia17
# Checking columbia18
# Public Forum --> VPF
# Scraped VPF for columbia18
# Varsity LD --> VLD
# Scraped VLD for columbia18
# Checking columbia19
# Public Forum --> VPF
# Scraped VPF for columbia19
# Student Congress --> None
# Varsity LD --> VLD
# Scraped VLD for columbia19
# Checking columbia20
# Novice LD --> NLD
# Scraped NLD for columbia20
# Public Forum --> VPF
# Scraped VPF for columbia20
# Student Congress --> None
# Varsity LD --> VLD
# Scraped VLD for columbia20
# Checking cps15
# NLD --> NLD
# Scraped NLD for cps15
# OLD --> VLD
# Scraped VLD for cps15
# Checking cps16
# NLD --> NLD
# Scraped NLD for cps16
# OLD --> VLD
# Scraped VLD for cps16
# Checking cps17
# NLD --> NLD
# Scraped NLD for cps17
# OLD --> VLD
# Scraped VLD for cps17
# Checking cps18
# NLD --> NLD
# Scraped NLD for cps18
# OLD --> VLD
# Scraped VLD for cps18
# Checking cps19
# NLD --> NLD
# Scraped NLD for cps19
# OLD --> VLD
# Scraped VLD for cps19
# Checking cps20
# Novice LD --> NLD
# Scraped NLD for cps20
# Open LD --> VLD
# Scraped VLD for cps20
# TOC LD --> VLD
# Scraped VLD for cps20
# Checking cypress16
# Lincoln Douglas --> VLD
# Scraped VLD for cypress16
# Novice Policy --> NCX
# Scraped NCX for cypress16
# Policy --> VCX
# Scraped VCX for cypress16
# Public Forum --> VPF
# Scraped VPF for cypress16
# Checking cypress17
# Lincoln Douglas --> VLD
# Scraped VLD for cypress17
# Novice Policy --> NCX
# Scraped NCX for cypress17
# Policy --> VCX
# Scraped VCX for cypress17
# Public Forum --> VPF
# Scraped VPF for cypress17
# Checking cypress18
# Lincoln Douglas --> VLD
# Scraped VLD for cypress18
# Novice Policy --> NCX
# Scraped NCX for cypress18
# Public Forum --> VPF
# Scraped VPF for cypress18
# Varsity Policy --> VCX
# Scraped VCX for cypress18
# Checking cypress19
# Lincoln Douglas --> VLD
# Scraped VLD for cypress19
# Novice Policy --> NCX
# Scraped NCX for cypress19
# Public Forum --> VPF
# Scraped VPF for cypress19
# Varsity Policy --> VCX
# Scraped VCX for cypress19
# Checking cypress20
# Junior Varsity Public Forum --> JVPF
# Scraped JVPF for cypress20
# Lincoln Douglas --> VLD
# Scraped VLD for cypress20
# Novice Policy --> NCX
# Scraped NCX for cypress20
# Public Forum --> VPF
# Scraped VPF for cypress20
# Varsity Policy --> VCX
# Scraped VCX for cypress20
# Checking dowling17
# JV Policy Debate --> JVCX
# Scraped JVCX for dowling17
# Novice Policy --> NCX
# Scraped NCX for dowling17
# Policy Debate --> VCX
# Scraped VCX for dowling17
# Checking dowling18
# JV Policy Debate --> JVCX
# Scraped JVCX for dowling18
# Novice Policy --> NCX
# Scraped NCX for dowling18
# Policy Debate --> VCX
# Scraped VCX for dowling18
# Checking dowling19
# Congress --> None
# JV Policy Debate --> JVCX
# Scraped JVCX for dowling19
# Lincoln Douglas --> VLD
# Scraped VLD for dowling19
# Novice Policy --> NCX
# Scraped NCX for dowling19
# Policy Debate --> VCX
# Scraped VCX for dowling19
# Public Forum --> VPF
# Scraped VPF for dowling19
# Checking dowling20
# Congress --> None
# JV Policy Debate --> JVCX
# Scraped JVCX for dowling20
# Lincoln Douglas --> VLD
# Scraped VLD for dowling20
# Novice LD --> NLD
# Scraped NLD for dowling20
# Novice Policy --> NCX
# Scraped NCX for dowling20
# Policy Debate --> VCX
# Scraped VCX for dowling20
# Public Forum --> VPF
# Scraped VPF for dowling20
# Checking duke19
# Declamation --> None
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Impromptu Speaking --> None
# Informative Speaking --> None
# Novice Congressional Debate --> None
# Novice Lincoln-Douglas --> NLD
# Scraped NLD for duke19
# Novice Public Forum --> NPF
# Scraped NPF for duke19
# Oral Interpretation --> None
# Original Oratory --> None
# Program Oral Interpretation --> None
# Varsity Congressional Debate --> None
# Varsity Lincoln-Douglas --> VLD
# Scraped VLD for duke19
# Varsity Public Forum --> VPF
# Scraped VPF for duke19
# Checking duke20
# Congressional Debate --> None
# Declamation --> None
# Dramatic Interpretation --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Impromptu Speaking --> None
# Informative Speaking --> None
# Junior Varsity Lincoln-Douglas --> JVLD
# Scraped JVLD for duke20
# Junior Varsity Public Forum --> JVPF
# Scraped JVPF for duke20
# Oral Interpretation --> None
# Original Oratory --> None
# Program Oral Interpretation --> None
# Varsity Lincoln-Douglas --> VLD
# Scraped VLD for duke20
# Varsity Public Forum --> VPF
# Scraped VPF for duke20
# Checking durham19
# Congressional Debate --> None
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Impromptu Speaking --> None
# Informative Speaking --> None
# LD Debate --> VLD
# Scraped VLD for durham19
# Oral Interpretation --> None
# Original Oratory --> None
# Program of Oral Interpretation --> None
# Public Forum Challenge --> JVPF
# Scraped JVPF for durham19
# Public Forum Debate --> VPF
# Scraped VPF for durham19
# Checking durham20
# Congressional Debate --> None
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Impromptu Speaking --> None
# Informative Speaking --> None
# LD Challenge --> JVLD
# Scraped JVLD for durham20
# LD Debate --> VLD
# Scraped VLD for durham20
# Oral Interpretation --> None
# Original Oratory --> None
# Program of Oral Interpretation --> None
# Public Forum Challenge --> JVPF
# Scraped JVPF for durham20
# Public Forum Debate --> VPF
# Scraped VPF for durham20
# Checking emory16
# Lincoln-Douglas --> VLD
# Scraped VLD for emory16
# Pelham Debate --> None
# Public Forum --> VPF
# Scraped VPF for emory16
# Checking emory17
# Lincoln-Douglas --> VLD
# Scraped VLD for emory17
# Pelham Debate --> None
# Public Forum --> VPF
# Scraped VPF for emory17
# Checking emory18
# Lincoln-Douglas --> VLD
# Scraped VLD for emory18
# Pelham Debate --> None
# Public Forum --> VPF
# Scraped VPF for emory18
# Checking emory19
# Congressional Debate --> None
# Lincoln-Douglas --> VLD
# Scraped VLD for emory19
# Pelham Debate --> None
# Public Forum --> VPF
# Scraped VPF for emory19
# Checking emory20
# Congressional Debate --> None
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Informative Speaking --> None
# Lincoln-Douglas --> VLD
# Scraped VLD for emory20
# Original Oratory --> None
# Pelham Debate --> None
# Program Oral Interpretation --> None
# Public Forum --> VPF
# Scraped VPF for emory20
# Checking glenbrooks15
# Public Forum --> VPF
# Scraped VPF for glenbrooks15
# Varsity Policy --> VCX
# Scraped VCX for glenbrooks15
# Checking glenbrooks16
# Congressional Debate --> None
# Junior Varsity Lincoln Douglas --> JVLD
# Scraped JVLD for glenbrooks16
# Junior Varsity Policy RR --> None
# Novice Policy RR --> None
# Novice Public Forum --> NPF
# Scraped NPF for glenbrooks16
# Varsity Lincoln Douglas --> VLD
# Scraped VLD for glenbrooks16
# Varsity Policy --> VCX
# Scraped VCX for glenbrooks16
# Varsity Policy Round Robin --> None
# Varsity Public Forum --> VPF
# Scraped VPF for glenbrooks16
# Checking glenbrooks17
# Congressional Debate --> None
# Junior Varsity Lincoln Douglas --> JVLD
# Scraped JVLD for glenbrooks17
# Junior Varsity Policy RR --> None
# Novice Policy RR --> None
# Novice Public Forum --> NPF
# Scraped NPF for glenbrooks17
# Varsity Lincoln Douglas --> VLD
# Scraped VLD for glenbrooks17
# Varsity Policy --> VCX
# Scraped VCX for glenbrooks17
# Varsity Public Forum --> VPF
# Scraped VPF for glenbrooks17
# Checking glenbrooks18
# Congressional Debate --> None
# Junior Varsity Lincoln Douglas --> JVLD
# Scraped JVLD for glenbrooks18
# Junior Varsity Policy RR --> None
# Novice Policy RR --> None
# Novice Public Forum --> NPF
# Scraped NPF for glenbrooks18
# Varsity Lincoln Douglas --> VLD
# Scraped VLD for glenbrooks18
# Varsity Policy --> VCX
# Scraped VCX for glenbrooks18
# Varsity Public Forum --> VPF
# Scraped VPF for glenbrooks18
# Checking glenbrooks19
# Congressional Debate --> None
# Junior Varsity Lincoln Douglas --> JVLD
# Scraped JVLD for glenbrooks19
# Junior Varsity Policy RR --> None
# Novice Policy RR --> None
# Novice Public Forum --> NPF
# Scraped NPF for glenbrooks19
# Varsity Lincoln Douglas --> VLD
# Scraped VLD for glenbrooks19
# Varsity Policy --> VCX
# Scraped VCX for glenbrooks19
# Varsity Public Forum --> VPF
# Scraped VPF for glenbrooks19
# Checking glenbrooks20
# Congressional Debate --> None
# Junior Varsity Lincoln Douglas --> JVLD
# Scraped JVLD for glenbrooks20
# Junior Varsity Policy --> JVCX
# Scraped JVCX for glenbrooks20
# Novice Policy --> NCX
# Scraped NCX for glenbrooks20
# Novice Public Forum --> NPF
# Scraped NPF for glenbrooks20
# Varsity Lincoln Douglas --> VLD
# Scraped VLD for glenbrooks20
# Varsity Policy --> VCX
# Scraped VCX for glenbrooks20
# Varsity Public Forum --> VPF
# Scraped VPF for glenbrooks20
# Checking goldendesert15
# NCX --> NCX
# Scraped NCX for goldendesert15
# NLD --> NLD
# Scraped NLD for goldendesert15
# PF --> VPF
# Scraped VPF for goldendesert15
# VCX --> VCX
# Scraped VCX for goldendesert15
# VLD --> VLD
# Scraped VLD for goldendesert15
# Checking goldendesert16
# NCX --> NCX
# Scraped NCX for goldendesert16
# NLD --> NLD
# Scraped NLD for goldendesert16
# PF --> VPF
# Scraped VPF for goldendesert16
# VCX --> VCX
# Scraped VCX for goldendesert16
# VLD --> VLD
# Scraped VLD for goldendesert16
# Checking goldendesert17
# NCX --> NCX
# Scraped NCX for goldendesert17
# NLD --> NLD
# Scraped NLD for goldendesert17
# PF --> VPF
# Scraped VPF for goldendesert17
# VCX --> VCX
# Scraped VCX for goldendesert17
# VLD --> VLD
# Scraped VLD for goldendesert17
# Checking goldendesert18
# NCX --> NCX
# Scraped NCX for goldendesert18
# NLD --> NLD
# Scraped NLD for goldendesert18
# PF --> VPF
# Scraped VPF for goldendesert18
# VCX --> VCX
# Scraped VCX for goldendesert18
# VLD --> VLD
# Scraped VLD for goldendesert18
# Checking goldendesert19
# NCX --> NCX
# Scraped NCX for goldendesert19
# NLD --> NLD
# Scraped NLD for goldendesert19
# PF --> VPF
# Scraped VPF for goldendesert19
# VCX --> VCX
# Scraped VCX for goldendesert19
# VLD --> VLD
# Scraped VLD for goldendesert19
# Checking goldendesert20
# NCX --> NCX
# Scraped NCX for goldendesert20
# NLD --> NLD
# Scraped NLD for goldendesert20
# PF --> VPF
# Scraped VPF for goldendesert20
# VCX --> VCX
# Scraped VCX for goldendesert20
# VLD --> VLD
# Scraped VLD for goldendesert20
# Checking grapevine15
# Checking grapevine16
# Checking grapevine17
# Checking grapevine18
# LD --> VLD
# Scraped VLD for grapevine18
# World Schools --> None
# Checking grapevine19
# CX --> VCX
# Scraped VCX for grapevine19
# Congressional Debate --> None
# LD --> VLD
# Scraped VLD for grapevine19
# PFD --> VPF
# Scraped VPF for grapevine19
# World Schools --> None
# Checking grapevine20
# Congressional Debate --> None
# Domestic Extemp --> None
# Dramatic Interp --> None
# Humorous Interp --> None
# Informative --> None
# International Extemp --> None
# JV Lincoln Douglas --> JVLD
# Scraped JVLD for grapevine20
# JV Policy --> JVCX
# Scraped JVCX for grapevine20
# JV Public Forum Debate --> JVPF
# Scraped JVPF for grapevine20
# Original Oratory --> None
# Poetry --> None
# Program Oral Interp --> None
# Prose --> None
# Varsity Lincoln Douglas --> VLD
# Scraped VLD for grapevine20
# Varsity Policy --> VCX
# Scraped VCX for grapevine20
# Varsity Public Forum Debate --> VPF
# Scraped VPF for grapevine20
# World Schools --> None
# Checking greenhill14
# Checking greenhill15
# Lincoln Douglas --> VLD
# Scraped VLD for greenhill15
# Lincoln Douglas RR --> None
# Policy Debate --> VCX
# Scraped VCX for greenhill15
# Policy RR --> None
# World Schools --> None
# Checking greenhill16
# Lincoln Douglas --> VLD
# Scraped VLD for greenhill16
# Policy Debate --> VCX
# Scraped VCX for greenhill16
# Checking greenhill17
# Lincoln Douglas --> VLD
# Scraped VLD for greenhill17
# Lincoln Douglas RR --> None
# Policy Debate --> VCX
# Scraped VCX for greenhill17
# Policy RR --> None
# Checking greenhill18
# Lincoln Douglas --> VLD
# Scraped VLD for greenhill18
# Lincoln Douglas RR --> None
# Policy Debate --> VCX
# Scraped VCX for greenhill18
# Policy RR --> None
# World Schools --> None
# Checking greenhill19
# Lincoln Douglas --> VLD
# Scraped VLD for greenhill19
# Lincoln Douglas RR --> None
# Policy Debate --> VCX
# Scraped VCX for greenhill19
# World Schools --> None
# Checking greenhill20
# Lincoln Douglas --> VLD
# Scraped VLD for greenhill20
# Lincoln Douglas RR --> None
# Policy Debate --> VCX
# Scraped VCX for greenhill20
# Policy RR --> None
# World Schools (Gold) --> None
# World Schools (Green) --> None
# Checking harvard14
# LD Round Robin --> None
# Policy Round Robin --> None
# JV Lincoln Douglas --> JVLD
# Scraped JVLD for harvard14
# JV Policy --> JVCX
# Scraped JVCX for harvard14
# JV Public Forum --> JVPF
# Scraped JVPF for harvard14
# Varsity Lincoln Douglas --> VLD
# Scraped VLD for harvard14
# Varsity Policy --> VCX
# Scraped VCX for harvard14
# Varsity Public Forum --> VPF
# Scraped VPF for harvard14
# Checking harvard16
# International Public Forum Debate --> None
# JV Policy Debate --> JVCX
# Scraped JVCX for harvard16
# JVLD --> JVLD
# Scraped JVLD for harvard16
# JVPF --> JVPF
# Scraped JVPF for harvard16
# Lincoln Douglas Round Robin --> None
# Policy Round Robin --> None
# Public Forum Round Robin --> None
# VLD --> VLD
# Scraped VLD for harvard16
# VPF --> VPF
# Scraped VPF for harvard16
# Varsity Policy Debate --> VCX
# Scraped VCX for harvard16
# Checking harvard17
# JV Lincoln Douglas --> JVLD
# Scraped JVLD for harvard17
# JV Policy --> JVCX
# Scraped JVCX for harvard17
# JV Public Forum --> JVPF
# Scraped JVPF for harvard17
# Novice Public Forum --> NPF
# Scraped NPF for harvard17
# Varsity Lincoln Douglas --> VLD
# Scraped VLD for harvard17
# Varsity Policy --> VCX
# Scraped VCX for harvard17
# Varsity Public Forum --> VPF
# Scraped VPF for harvard17
# Checking harvard18
# JVLD --> JVLD
# Scraped JVLD for harvard18
# JVP --> None
# JVPF --> JVPF
# Scraped JVPF for harvard18
# NPF --> NPF
# Scraped NPF for harvard18
# VLD --> VLD
# Scraped VLD for harvard18
# VPD --> None
# VPF --> VPF
# Scraped VPF for harvard18
# Checking harvard19
# Dramatic Interp --> None
# Duo Interpretation --> None
# Extemp --> None
# Humorous Interp --> None
# Informative Speaking --> None
# JVCX --> JVCX
# Scraped JVCX for harvard19
# JVLD --> JVLD
# Scraped JVLD for harvard19
# JVPF --> JVPF
# Scraped JVPF for harvard19
# MSPF --> None
# NPF --> NPF
# Scraped NPF for harvard19
# Original Oratory --> None
# Program of Oral Interpretation --> None
# VCX --> VCX
# Scraped VCX for harvard19
# VLD --> VLD
# Scraped VLD for harvard19
# VPF --> VPF
# Scraped VPF for harvard19
# Checking harvard20
# Dramatic Interp --> None
# Duo Interpretation --> None
# Extemp --> None
# Humorous Interp --> None
# Informative Speaking --> None
# JVCX --> JVCX
# Scraped JVCX for harvard20
# JVLD --> JVLD
# Scraped JVLD for harvard20
# JVPF --> JVPF
# Scraped JVPF for harvard20
# MSPF --> None
# NPF --> NPF
# Scraped NPF for harvard20
# Original Oratory --> None
# Program of Oral Interpretation --> None
# VCX --> VCX
# Scraped VCX for harvard20
# VLD --> VLD
# Scraped VLD for harvard20
# VPF --> VPF
# Scraped VPF for harvard20
# Checking heritagehall16
# Gregg Hartney Varsity Policy --> VCX
# Scraped VCX for heritagehall16
# Novice Policy --> NCX
# Scraped NCX for heritagehall16
# Varsity Lincoln Douglas --> VLD
# Scraped VLD for heritagehall16
# Checking heritagehall17
# Gregg Hartney Novice Policy --> NCX
# Scraped NCX for heritagehall17
# Rosie Valdez Varsity policy --> VCX
# Scraped VCX for heritagehall17
# Varsity Lincoln Douglas --> VLD
# Scraped VLD for heritagehall17
# Varsity Public Forum --> VPF
# Scraped VPF for heritagehall17
# Checking heritagehall18
# Greg Malis Varsity policy --> VCX
# Scraped VCX for heritagehall18
# Gregg Hartney Novice Policy --> NCX
# Scraped NCX for heritagehall18
# Varsity Lincoln Douglas --> VLD
# Scraped VLD for heritagehall18
# Varsity Public Forum --> VPF
# Scraped VPF for heritagehall18
# Checking heritagehall19
# Congressional Debate --> None
# Domestic Extemp --> None
# Dramatic Interp --> None
# Duet Acting --> None
# Duo Interp --> None
# Foreign Extemp --> None
# Humorous Interp --> None
# Informative Speaking --> None
# MS Extemp --> None
# MS Original Oratory --> None
# MS Prose Poetry --> None
# MS World Schools --> None
# NCX --> NCX
# Scraped NCX for heritagehall19
# NLD --> NLD
# Scraped NLD for heritagehall19
# NPF --> NPF
# Scraped NPF for heritagehall19
# Original Oratory --> None
# Poetry Interp --> None
# Program Oral Interp --> None
# Prose Interp --> None
# VCX --> VCX
# Scraped VCX for heritagehall19
# VLD --> VLD
# Scraped VLD for heritagehall19
# VPF --> VPF
# Scraped VPF for heritagehall19
# World Schools --> None
# Checking heritagehall20
# Congressional Debate --> None
# Domestic Extemp --> None
# Dramatic Interp --> None
# Duet Acting --> None
# Duo Interp --> None
# Foreign Extemp --> None
# Humorous Interp --> None
# Informative Speaking --> None
# NCX --> NCX
# Scraped NCX for heritagehall20
# NLD --> NLD
# Scraped NLD for heritagehall20
# NPF --> NPF
# Scraped NPF for heritagehall20
# Original Oratory --> None
# Poetry Interp --> None
# Program Oral Interp --> None
# Prose Interp --> None
# VCX --> VCX
# Scraped VCX for heritagehall20
# VLD --> VLD
# Scraped VLD for heritagehall20
# VPF --> VPF
# Scraped VPF for heritagehall20
# World Schools --> None
# Checking heritagehall21
# Congressional Debate --> None
# Domestic Extemp --> None
# Dramatic Interp --> None
# Duo Interp --> None
# Foreign Extemp --> None
# Humorous Interp --> None
# Informative Speaking --> None
# Novice Lincoln Douglas --> NLD
# Scraped NLD for heritagehall21
# Novice Policy --> NCX
# Scraped NCX for heritagehall21
# Novice Public Forum --> NPF
# Scraped NPF for heritagehall21
# Original Oratory --> None
# Poetry Interp --> None
# Program Oral Interp --> None
# Prose Interp --> None
# Varsity Lincoln Douglas --> VLD
# Scraped VLD for heritagehall21
# Varsity Policy --> VCX
# Scraped VCX for heritagehall21
# Varsity Public Forum --> VPF
# Scraped VPF for heritagehall21
# World Schools --> None
# Checking holycross15
# Lincoln Douglas Debate --> VLD
# Scraped VLD for holycross15
# Public Forum --> VPF
# Scraped VPF for holycross15
# Checking holycross16
# Lincoln Douglas Debate --> VLD
# Scraped VLD for holycross16
# Novice Policy Debate --> NCX
# Scraped NCX for holycross16
# Public Forum --> VPF
# Scraped VPF for holycross16
# Varsity Policy Debate --> VCX
# Scraped VCX for holycross16
# Checking holycross17
# Checking holycross18
# Lincoln Douglas Debate --> VLD
# Scraped VLD for holycross18
# Novice Policy Debate --> NCX
# Scraped NCX for holycross18
# Public Forum --> VPF
# Scraped VPF for holycross18
# Varsity Policy Debate --> VCX
# Scraped VCX for holycross18
# Checking holycross19
# Lincoln Douglas Debate --> VLD
# Scraped VLD for holycross19
# Novice Policy Debate --> NCX
# Scraped NCX for holycross19
# Public Forum --> VPF
# Scraped VPF for holycross19
# Varsity Policy Debate --> VCX
# Scraped VCX for holycross19
# Checking holycross20
# Lincoln Douglas Debate --> VLD
# Scraped VLD for holycross20
# Public Forum --> VPF
# Scraped VPF for holycross20
# Varsity Policy Debate --> VCX
# Scraped VCX for holycross20
# Checking houston15
# A. UH Congress --> None
# A. UH PF --> None
# A. UH Policy --> None
# Checking houston16
# Domestic Extemp --> None
# Foreign Extemp --> None
# Impromptu --> None
# Lincoln Douglas --> VLD
# Scraped VLD for houston16
# Original Oratory --> None
# Policy --> VCX
# Scraped VCX for houston16
# Public Forum --> VPF
# Scraped VPF for houston16
# Checking houston17
# Domestic Extemp --> None
# Foreign Extemp --> None
# Impromptu --> None
# Lincoln Douglas --> VLD
# Scraped VLD for houston17
# Original Oratory --> None
# Policy --> VCX
# Scraped VCX for houston17
# Public Forum --> VPF
# Scraped VPF for houston17
# Checking houston18
# Congress --> None
# Domestic Extemp --> None
# Dramatic Interp --> None
# Duo Interp --> None
# Foreign Extemp --> None
# Impromptu --> None
# Informative --> None
# Lincoln Douglas --> VLD
# Scraped VLD for houston18
# Original Oratory --> None
# Policy --> VCX
# Scraped VCX for houston18
# Program Oral Interpretation --> None
# Prose --> None
# Public Forum --> VPF
# Scraped VPF for houston18
# Checking houston19
# Lincoln Douglas --> VLD
# Scraped VLD for houston19
# Policy --> VCX
# Scraped VCX for houston19
# Public Forum --> VPF
# Scraped VPF for houston19
# Checking houston20
# Lincoln-Douglas Debate --> VLD
# Scraped VLD for houston20
# Policy Debate --> VCX
# Scraped VCX for houston20
# Public Forum --> VPF
# Scraped VPF for houston20
# Checking houston21
# Congress --> None
# Domestic Extemp --> None
# Dramatic Interpetation --> None
# Duo Interp --> None
# Foreign Extemp --> None
# Humorous Interpretation --> None
# Informative --> None
# Lincoln-Douglas Debate --> VLD
# Scraped VLD for houston21
# Novice Lincoln-Douglas --> NLD
# Scraped NLD for houston21
# Novice Policy Debate --> NCX
# Scraped NCX for houston21
# Novice Public Forum --> NPF
# Scraped NPF for houston21
# Oratory --> None
# Poetry --> None
# Policy Debate --> VCX
# Scraped VCX for houston21
# Program Oral Interp --> None
# Prose --> None
# Public Forum --> VPF
# Scraped VPF for houston21
# Checking hwestlake15
# Debate.LA Challenge --> None
# Novice LD --> NLD
# Scraped NLD for hwestlake15
# Varsity LD --> VLD
# Scraped VLD for hwestlake15
# World Schools --> None
# Checking hwestlake16
# Debate.LA Challenge --> None
# Novice LD --> NLD
# Scraped NLD for hwestlake16
# Policy Debate --> VCX
# Scraped VCX for hwestlake16
# Varsity LD --> VLD
# Scraped VLD for hwestlake16
# World Schools --> None
# Checking hwestlake17
# MSPDP --> None
# Novice LD --> NLD
# Scraped NLD for hwestlake17
# Policy --> VCX
# Scraped VCX for hwestlake17
# Varsity LD --> VLD
# Scraped VLD for hwestlake17
# debateLA RR --> None
# Checking hwestlake18
# Novice LD --> NLD
# Scraped NLD for hwestlake18
# Varsity LD --> VLD
# Scraped VLD for hwestlake18
# World Schools --> None
# debateLA Round Robin --> None
# Checking hwestlake19
# Middle School Debate --> None
# Novice LD --> NLD
# Scraped NLD for hwestlake19
# Varsity LD --> VLD
# Scraped VLD for hwestlake19
# World Schools --> None
# debateLA RR --> None
# Checking hwestlake20
# Novice LD --> NLD
# Scraped NLD for hwestlake20
# Varsity LD --> VLD
# Scraped VLD for hwestlake20
# World Schools --> None
# debateLA Challenge --> None
# Checking isidore16
# Congressional Debate --> None
# Declamation Speaking --> None
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Impromptu Speaking --> None
# Informative Speaking --> None
# Novice LD Debate --> NLD
# Scraped NLD for isidore16
# Novice Policy Debate --> NCX
# Scraped NCX for isidore16
# Oral Interpretation --> None
# Original Oratory --> None
# Program of Oral Interpretation --> None
# Public Forum Debate --> VPF
# Scraped VPF for isidore16
# Varsity LD Debate --> VLD
# Scraped VLD for isidore16
# Varsity Policy Debate --> VCX
# Scraped VCX for isidore16
# Checking isidore17
# Congressional Debate --> None
# Declamation Speaking --> None
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Impromptu Speaking --> None
# Informative Speaking --> None
# Novice LD Debate --> NLD
# Scraped NLD for isidore17
# Novice Policy Debate --> NCX
# Scraped NCX for isidore17
# Oral Interpretation --> None
# Original Oratory --> None
# Program of Oral Interpretation --> None
# Public Forum Debate --> VPF
# Scraped VPF for isidore17
# Varsity LD Debate --> VLD
# Scraped VLD for isidore17
# Varsity Policy Debate --> VCX
# Scraped VCX for isidore17
# Checking isidore18
# Congressional Debate --> None
# Declamation Speaking --> None
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Impromptu Speaking --> None
# Informative Speaking --> None
# Novice LD Debate --> NLD
# Scraped NLD for isidore18
# Novice PF Debate --> NPF
# Scraped NPF for isidore18
# Novice Policy Debate --> NCX
# Scraped NCX for isidore18
# Oral Interpretation --> None
# Original Oratory --> None
# Program of Oral Interpretation --> None
# Varsity LD Debate --> VLD
# Scraped VLD for isidore18
# Varsity PF Debate --> VPF
# Scraped VPF for isidore18
# Varsity Policy Debate --> VCX
# Scraped VCX for isidore18
# World Schools Debate --> None
# Checking isidore19
# Congressional Debate --> None
# Declamation Speaking --> None
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Impromptu Speaking --> None
# Informative Speaking --> None
# Novice Lincoln Douglas Debate --> NLD
# Scraped NLD for isidore19
# Novice Policy Debate --> NCX
# Scraped NCX for isidore19
# Novice Public Forum Debate --> NPF
# Scraped NPF for isidore19
# Oral Interpretation --> None
# Original Oratory --> None
# Program of Oral Interpretation --> None
# Varsity Lincoln Douglas Debate --> VLD
# Scraped VLD for isidore19
# Varsity Policy Debate --> VCX
# Scraped VCX for isidore19
# Varsity Public Forum Debate --> VPF
# Scraped VPF for isidore19
# World Schools Debate --> None
# Checking isidore20
# Congressional Debate --> None
# Declamation Speaking --> None
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Impromptu Speaking --> None
# Informative Speaking --> None
# Lincoln Douglas Debate Novice --> NLD
# Scraped NLD for isidore20
# Lincoln Douglas Debate Varsity --> VLD
# Scraped VLD for isidore20
# Oral Interpretation --> None
# Original Oratory --> None
# Policy Debate Novice --> NCX
# Scraped NCX for isidore20
# Policy Debate Varsity --> VCX
# Scraped VCX for isidore20
# Program of Oral Interpretation --> None
# Public Forum Debate Novice --> NPF
# Scraped NPF for isidore20
# Public Forum Debate Varsity --> VPF
# Scraped VPF for isidore20
# World Schools Debate --> None
# Checking lewisandclark17
# 1st Year LD --> NLD
# Scraped NLD for lewisandclark17
# 1st Year Policy --> NCX
# Scraped NCX for lewisandclark17
# 2nd Year LD --> JVLD
# Scraped JVLD for lewisandclark17
# 2nd Year Policy --> JVCX
# Scraped JVCX for lewisandclark17
# Checking lewisandclark18
# Novice Expository --> None
# Novice Extemporaneous --> None
# Novice Impromptu --> None
# Novice Lincoln-Douglas --> NLD
# Scraped NLD for lewisandclark18
# Novice Parliamentary --> None
# Novice Poetry --> None
# Novice Prose --> None
# Novice Public Forum --> NPF
# Scraped NPF for lewisandclark18
# Novice Radio --> None
# Open After Dinner Speaking --> None
# Open Congress --> None
# Open Dramatic Interpretation --> None
# Open Duo Interpretation --> None
# Open Expository --> None
# Open Extemporaneous --> None
# Open Humorous Interpretation --> None
# Open Impromptu --> None
# Open Lincoln-Douglas --> VLD
# Scraped VLD for lewisandclark18
# Open Original Oratory --> None
# Open POI --> None
# Open Parliamentary --> None
# Open Poetry --> None
# Open Policy Debate --> VCX
# Scraped VCX for lewisandclark18
# Open Prose --> None
# Open Public Forum --> VPF
# Scraped VPF for lewisandclark18
# Open Radio --> None
# Checking lewisandclark19
# Novice Extemporaneous --> None
# Novice Impromptu --> None
# Novice Informative --> None
# Novice Lincoln-Douglas --> NLD
# Scraped NLD for lewisandclark19
# Novice Parliamentary --> None
# Novice Poetry --> None
# Novice Prose --> None
# Novice Public Forum --> NPF
# Scraped NPF for lewisandclark19
# Novice Radio --> None
# Open After Dinner Speaking --> None
# Open Congress --> None
# Open Dramatic Interpretation --> None
# Open Duo Interpretation --> None
# Open Extemporaneous --> None
# Open Humorous Interpretation --> None
# Open Impromptu --> None
# Open Informative --> None
# Open Lincoln-Douglas --> VLD
# Scraped VLD for lewisandclark19
# Open Original Oratory --> None
# Open POI --> None
# Open Parliamentary --> None
# Open Poetry --> None
# Open Policy Debate --> VCX
# Scraped VCX for lewisandclark19
# Open Prose --> None
# Open Public Forum --> VPF
# Scraped VPF for lewisandclark19
# Open Radio --> None
# Checking lewisandclark20
# Novice Extemporaneous --> None
# Novice Impromptu --> None
# Novice Informative --> None
# Novice Lincoln-Douglas --> NLD
# Scraped NLD for lewisandclark20
# Novice Parliamentary --> None
# Novice Poetry --> None
# Novice Prose --> None
# Novice Public Forum --> NPF
# Scraped NPF for lewisandclark20
# Novice Radio --> None
# Open After Dinner Speaking --> None
# Open Congress --> None
# Open Dramatic Interpretation --> None
# Open Duo Interpretation --> None
# Open Extemporaneous --> None
# Open Humorous Interpretation --> None
# Open Impromptu --> None
# Open Informative --> None
# Open Lincoln-Douglas --> VLD
# Scraped VLD for lewisandclark20
# Open Original Oratory --> None
# Open POI --> None
# Open Parliamentary --> None
# Open Poetry --> None
# Open Policy Debate --> VCX
# Scraped VCX for lewisandclark20
# Open Prose --> None
# Open Public Forum --> VPF
# Scraped VPF for lewisandclark20
# Open Radio --> None
# Checking lex15
# Novice LD --> NLD
# Scraped NLD for lex15
# Novice Policy --> NCX
# Scraped NCX for lex15
# Public Forum --> VPF
# Scraped VPF for lex15
# Varsity LD --> VLD
# Scraped VLD for lex15
# Varsity Policy --> VCX
# Scraped VCX for lex15
# Checking lex16
# Novice LD --> NLD
# Scraped NLD for lex16
# Novice Policy --> NCX
# Scraped NCX for lex16
# Public Forum --> VPF
# Scraped VPF for lex16
# Varsity LD --> VLD
# Scraped VLD for lex16
# Varsity Policy --> VCX
# Scraped VCX for lex16
# Checking lex17
# Novice LD --> NLD
# Scraped NLD for lex17
# ...
# Public Forum Debate --> VPF
# Scraped VPF for princeton18
# Varsity LD --> VLD
# Scraped VLD for princeton18
# Checking princeton19
# Congressional Debate --> None
# Dramatic --> None
# Duo Interp --> None
# Extemp --> None
# Humorous --> None
# Novice LD --> NLD
# Scraped NLD for princeton19
# Oral Interp --> None
# Oratory --> None
# Public Forum Debate --> VPF
# Scraped VPF for princeton19
# Varsity LD --> VLD
# Scraped VLD for princeton19
# Checking princeton20
# Ballot Test --> None
# Congressional Debate --> None
# Dramatic --> None
# Duo Interp --> None
# Extemp --> None
# Humorous --> None
# Informative Speaking --> None
# JV LD --> JVLD
# Scraped JVLD for princeton20
# JV Public Forum --> JVPF
# Scraped JVPF for princeton20
# Novice LD --> NLD
# Scraped NLD for princeton20
# Novice Public Forum --> NPF
# Scraped NPF for princeton20
# Oral Interp --> None
# Oratory --> None
# Program Oral Interpretation --> None
# Varsity LD --> VLD
# Scraped VLD for princeton20
# Varsity Public Forum --> VPF
# Scraped VPF for princeton20
# Checking pugetsound16
# CX JV --> JVCX
# Scraped JVCX for pugetsound16
# CX Open --> VCX
# Scraped VCX for pugetsound16
# Congress JV --> None
# Congress Open --> None
# DUO Novice --> None
# Dramatic Interp Novice --> None
# Dramatic Interp Open --> None
# Duo Open --> None
# Expository Novice --> None
# Expository Open --> None
# Extemp Novice --> None
# Extemp Open --> None
# Humorous Interp. Novice --> None
# Humorous Interp. Open --> None
# Impromptu Novice --> None
# Impromptu Open --> None
# Interp. Reading Novice --> None
# Interp. Reading Open --> None
# Junior Public Forum --> JVPF
# Scraped JVPF for pugetsound16
# LD JV --> JVLD
# Scraped JVLD for pugetsound16
# LD Novice --> NLD
# Scraped NLD for pugetsound16
# LD Open --> VLD
# Scraped VLD for pugetsound16
# Novice Public Forum --> NPF
# Scraped NPF for pugetsound16
# Open Public Forum --> VPF
# Scraped VPF for pugetsound16
# Oratory Novice --> None
# Oratory Open --> None
# Checking pugetsound17
# Checking pugetsound18
# CX Novice --> None
# CX Open --> VCX
# Scraped VCX for pugetsound18
# Congress Novice --> None
# Congress Open --> None
# DUO Novice --> None
# Dramatic Interp Novice --> None
# Dramatic Interp Open --> None
# Duo Open --> None
# Expository Novice --> None
# Expository Open --> None
# Extemp Novice --> None
# Extemp Open --> None
# Humorous Interp. Open --> None
# Impromptu Novice --> None
# Impromptu Open --> None
# Interp. Reading Novice --> None
# Interp. Reading Open --> None
# Junior Public Forum --> JVPF
# Scraped JVPF for pugetsound18
# LD JV --> JVLD
# Scraped JVLD for pugetsound18
# LD Novice --> NLD
# Scraped NLD for pugetsound18
# LD Open --> VLD
# Scraped VLD for pugetsound18
# Novice Public Forum --> NPF
# Scraped NPF for pugetsound18
# Open Public Forum --> VPF
# Scraped VPF for pugetsound18
# Oratory Novice --> None
# Oratory Open --> None
# Checking pugetsound19
# CX Open --> VCX
# Scraped VCX for pugetsound19
# Congress Novice --> None
# Congress Open --> None
# DUO Novice --> None
# DUO Open --> None
# Dramatic Interp Novice --> None
# Dramatic Interp Open --> None
# Expository Novice --> None
# Expository Open --> None
# Extemp Novice --> None
# Extemp Open --> None
# Humorous Interp. Open --> None
# Impromptu Novice --> None
# Impromptu Open --> None
# LD JV --> JVLD
# Scraped JVLD for pugetsound19
# LD Novice --> NLD
# Scraped NLD for pugetsound19
# LD Open --> VLD
# Scraped VLD for pugetsound19
# Novice Public Forum --> NPF
# Scraped NPF for pugetsound19
# Open Public Forum --> VPF
# Scraped VPF for pugetsound19
# Oratory Novice --> None
# Oratory Open --> None
# POI Open --> None
# Checking pugetsound20
# CX Open --> VCX
# Scraped VCX for pugetsound20
# Congress Open --> None
# DUO Open --> None
# Dramatic Interp Open --> None
# Extemp Novice --> None
# Extemp Open --> None
# Humorous Interp. Open --> None
# Impromptu Novice --> None
# Impromptu Open --> None
# Informative Novice --> None
# Informative Open --> None
# LD JV --> JVLD
# Scraped JVLD for pugetsound20
# LD Novice --> NLD
# Scraped NLD for pugetsound20
# LD Open --> VLD
# Scraped VLD for pugetsound20
# Novice Public Forum --> NPF
# Scraped NPF for pugetsound20
# Open Public Forum --> VPF
# Scraped VPF for pugetsound20
# Oratory Novice --> None
# Oratory Open --> None
# POI Open --> None
# Checking rideg15
# Checking ridge16
# Checking ridge17
# Checking ridge18
# Congressional Debate --> None
# Open - Lincoln-Douglas --> VLD
# Scraped VLD for ridge18
# Open - Policy Debate --> VCX
# Scraped VCX for ridge18
# Open - Public Forum Debate --> VPF
# Scraped VPF for ridge18
# Checking ridge19
# Novice - Lincoln-Douglas --> NLD
# Scraped NLD for ridge19
# Novice - Public Forum --> NPF
# Scraped NPF for ridge19
# Open - Lincoln-Douglas --> VLD
# Scraped VLD for ridge19
# Open - Policy Debate --> VCX
# Scraped VCX for ridge19
# Open - Public Forum Debate --> VPF
# Scraped VPF for ridge19
# Parliamentary Debate --> None
# Checking ridge20
# Novice - Lincoln-Douglas --> NLD
# Scraped NLD for ridge20
# Novice - Policy Debate --> NCX
# Scraped NCX for ridge20
# Novice - Public Forum --> NPF
# Scraped NPF for ridge20
# Open - Lincoln-Douglas --> VLD
# Scraped VLD for ridge20
# Open - Policy Debate --> VCX
# Scraped VCX for ridge20
# Open - Public Forum Debate --> VPF
# Scraped VPF for ridge20
# Parliamentary Debate --> None
# Checking scarsdale15
# Checking scarsdale16
# Checking scarsdale17
# Checking scarsdale18
# Novice LD --> NLD
# Scraped NLD for scarsdale18
# Novice PF --> NPF
# Scraped NPF for scarsdale18
# Varsity LD --> VLD
# Scraped VLD for scarsdale18
# Varsity PF --> VPF
# Scraped VPF for scarsdale18
# Checking scarsdale19
# Checking scarsdale20
# Novice LD --> NLD
# Scraped NLD for scarsdale20
# Novice PF --> NPF
# Scraped NPF for scarsdale20
# Varsity LD --> VLD
# Scraped VLD for scarsdale20
# Varsity PF --> VPF
# Scraped VPF for scarsdale20
# Checking seattle19
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Editorial Commentary --> None
# Junior Lincoln Douglas --> JVLD
# Scraped JVLD for seattle19
# Novice Congress --> None
# Novice Extemp --> None
# Novice Humorous Interp --> None
# Novice Impromptu --> None
# Novice Informative --> None
# Novice Lincoln Douglas --> NLD
# Scraped NLD for seattle19
# Novice Original Oratory --> None
# Novice Policy --> NCX
# Scraped NCX for seattle19
# Novice Public Forum --> NPF
# Scraped NPF for seattle19
# Open Congress --> None
# Open Extemp --> None
# Open Humorous --> None
# Open Impromptu --> None
# Open Informative --> None
# Open Lincoln Douglas --> VLD
# Scraped VLD for seattle19
# Open Original Oratory --> None
# Open Policy --> VCX
# Scraped VCX for seattle19
# Open Public Forum --> VPF
# Scraped VPF for seattle19
# Original Performance --> None
# Program Oral Interpretation --> None
# Checking seattle20
# Duo Interp --> None
# Editorial Commentary --> None
# Junior Lincoln Douglas --> JVLD
# Scraped JVLD for seattle20
# Junior Public Forum --> JVPF
# Scraped JVPF for seattle20
# Novice Congress --> None
# Novice Dramatic --> None
# Novice Extemp --> None
# Novice Humorous Interp --> None
# Novice Impromptu --> None
# Novice Informative --> None
# Novice Lincoln Douglas --> NLD
# Scraped NLD for seattle20
# Novice Original Oratory --> None
# Novice Public Forum --> NPF
# Scraped NPF for seattle20
# Open Congress --> None
# Open Dramatic Interp --> None
# Open Extemp --> None
# Open Humorous --> None
# Open Impromptu --> None
# Open Informative --> None
# Open Lincoln Douglas --> VLD
# Scraped VLD for seattle20
# Open Original Oratory --> None
# Open Policy --> VCX
# Scraped VCX for seattle20
# Open Program Oral Interp --> None
# Open Public Forum --> VPF
# Scraped VPF for seattle20
# Oral Interp (Not POI) --> None
# Original Performance --> None
# Checking stanford15
# JCX --> JVCX
# Scraped JVCX for stanford15
# JLD --> JVLD
# Scraped JVLD for stanford15
# JPD --> None
# VPD --> None
# Checking stanford16
# JV Lincoln Douglas --> JVLD
# Scraped JVLD for stanford16
# JV Parli --> None
# Varsity Lincoln Douglas --> VLD
# Scraped VLD for stanford16
# Varsity Parli --> None
# Varsity Public Forum --> VPF
# Scraped VPF for stanford16
# Checking stanford17
# JV Lincoln Douglas --> JVLD
# Scraped JVLD for stanford17
# Checking stanford18
# JV Lincoln Douglas --> JVLD
# Scraped JVLD for stanford18
# JV Parli --> None
# JV Policy Debate --> JVCX
# Scraped JVCX for stanford18
# JV Public Forum --> JVPF
# Scraped JVPF for stanford18
# Middle School Congress --> None
# Varsity Congress --> None
# Varsity Lincoln Douglas --> VLD
# Scraped VLD for stanford18
# Varsity Parli --> None
# Varsity Policy --> VCX
# Scraped VCX for stanford18
# Varsity Public Forum --> VPF
# Scraped VPF for stanford18
# Checking stanford19
# Checking stanford20
# Checking strake15
# Varsity LD --> VLD
# Scraped VLD for strake15
# Checking strake16
# LD Round Robin --> None
# Varsity LD --> VLD
# Scraped VLD for strake16
# Checking strake17
# LD Round Robin --> None
# Varsity LD --> VLD
# Scraped VLD for strake17
# Checking strake18
# LD Round Robin --> None
# PF Round Robin --> None
# Varsity LD --> VLD
# Scraped VLD for strake18
# Checking strake19
# LD Round Robin --> None
# PF Round Robin --> None
# Varsity LD --> VLD
# Scraped VLD for strake19
# Checking strake20
# Varsity LD --> VLD
# Scraped VLD for strake20
# Checking sunvite20
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Impromptu Speaking --> None
# Informative Speaking --> None
# Lincoln Douglas --> VLD
# Scraped VLD for sunvite20
# Novice Policy Debate --> NCX
# Scraped NCX for sunvite20
# Original Oratory --> None
# Program Oral Interpretation --> None
# Public Forum --> VPF
# Scraped VPF for sunvite20
# Student Congress --> None
# Checking sunvite21
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Impromptu Speaking --> None
# Informative Speaking --> None
# JV Public Forum --> JVPF
# Scraped JVPF for sunvite21
# Novice Lincoln Douglas --> NLD
# Scraped NLD for sunvite21
# Novice Policy Debate --> NCX
# Scraped NCX for sunvite21
# Novice Public Forum --> NPF
# Scraped NPF for sunvite21
# Original Oratory --> None
# Program Oral Interpretation --> None
# Student Congress --> None
# Varsity Lincoln Douglas --> VLD
# Scraped VLD for sunvite21
# Varsity Public Forum --> VPF
# Scraped VPF for sunvite21
# Checking uk17
# Congressional Debate --> None
# Dramatic Interpratation --> None
# Duo Interpretation --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Informative Speaking --> None
# JV PF --> JVPF
# Scraped JVPF for uk17
# Middle School PF --> None
# Novice LD --> NLD
# Scraped NLD for uk17
# Novice Policy Debate --> NCX
# Scraped NCX for uk17
# Oral Interpretation --> None
# Original Oratory --> None
# PF Round Robin --> None
# Program Oral Intrepretation --> None
# Varsity LD --> VLD
# Scraped VLD for uk17
# Varsity PF --> VPF
# Scraped VPF for uk17
# Varsity Policy Debate --> VCX
# Scraped VCX for uk17
# Checking uk18
# Congressional Debate --> None
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Informative Speaking --> None
# JV PF --> JVPF
# Scraped JVPF for uk18
# Middle School PF --> None
# Novice Policy Debate --> NCX
# Scraped NCX for uk18
# Oral Interpretation --> None
# Original Oratory --> None
# PF Round Robin --> None
# Program Oral Intrepretation --> None
# Varsity LD --> VLD
# Scraped VLD for uk18
# Varsity PF --> VPF
# Scraped VPF for uk18
# Varsity Policy Debate --> VCX
# Scraped VCX for uk18
# Checking uk19
# Congressional Debate --> None
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Informative Speaking --> None
# LD Varsity --> VLD
# Scraped VLD for uk19
# Oral Interpretation --> None
# Original Oratory --> None
# Policy - Novice --> NCX
# Scraped NCX for uk19
# Policy - Varsity --> VCX
# Scraped VCX for uk19
# Program Oral Intrepretation --> None
# Public Forum - JV --> JVPF
# Scraped JVPF for uk19
# Public Forum - Middle School --> NPF
# Scraped NPF for uk19
# Public Forum - Varsity --> VPF
# Scraped VPF for uk19
# Checking uk20
# Congressional Debate --> None
# Dramatic Interpretation --> None
# Duo Interpretation --> None
# Extemporaneous Speaking --> None
# Humorous Interpretation --> None
# Informative Speaking --> None
# LD - Rising Stars --> JVLD
# Scraped JVLD for uk20
# LD - Varsity --> VLD
# Scraped VLD for uk20
# Oral Interpretation --> None
# Original Oratory --> None
# Poetry --> None
# Policy - Novice --> NCX
# Scraped NCX for uk20
# Policy - Rising Stars --> JVCX
# Scraped JVCX for uk20
# Policy - Varsity --> VCX
# Scraped VCX for uk20
# Program Oral Intrepretation --> None
# Prose --> None
# Public Forum - Middle School --> NPF
# Scraped NPF for uk20
# Public Forum - Rising Stars --> JVPF
# Scraped JVPF for uk20
# Public Forum - Varsity --> VPF
# Scraped VPF for uk20
# Checking UT15
# Checking UT16
# 2016 Texas Round Robin --> None
# Championship CX --> VCX
# Scraped VCX for UT16
# Championship LD --> VLD
# Scraped VLD for UT16
# Novice CX --> NCX
# Scraped NCX for UT16
# Public Forum --> VPF
# Scraped VPF for UT16
# Checking UT17
# 2017 Texas Round Robin --> None
# Championship CX --> VCX
# Scraped VCX for UT17
# Championship LD --> VLD
# Scraped VLD for UT17
# Novice CX --> NCX
# Scraped NCX for UT17
# Public Forum --> VPF
# Scraped VPF for UT17
# Checking UT18
# Lincoln-Douglas --> VLD
# Scraped VLD for UT18
# Public Forum --> VPF
# Scraped VPF for UT18
# Varsity Policy --> VCX
# Scraped VCX for UT18
# Checking UT19
# Lincoln-Douglas --> VLD
# Scraped VLD for UT19
# Public Forum --> VPF
# Scraped VPF for UT19
# Varsity Policy --> VCX
# Scraped VCX for UT19
# Checking UT20
# Novice Lincoln-Douglas --> NLD
# Scraped NLD for UT20
# Novice Policy --> NCX
# Scraped NCX for UT20
# Novice Public Forum --> NPF
# Scraped NPF for UT20
# Open Lincoln-Douglas --> VLD
# Scraped VLD for UT20
# Open Policy --> VCX
# Scraped VCX for UT20
# Open Public Forum --> VPF
# Scraped VPF for UT20
# Open World Schools --> None
# Checking valley16
# LD --> VLD
# Scraped VLD for valley16
# Checking valley17
# LD --> VLD
# Scraped VLD for valley17
# Policy --> VCX
# Scraped VCX for valley17
# Public Forum --> VPF
# Scraped VPF for valley17
# Checking valley18
# LD --> VLD
# Scraped VLD for valley18
# Policy --> VCX
# Scraped VCX for valley18
# Public Forum --> VPF
# Scraped VPF for valley18
# Checking valley19
# Congressional Debate --> None
# JV LD --> JVLD
# Scraped JVLD for valley19
# Novice LD --> NLD
# Scraped NLD for valley19
# Novice Public Forum --> NPF
# Scraped NPF for valley19
# Varsity LD --> VLD
# Scraped VLD for valley19
# Varsity Public Forum --> VPF
# Scraped VPF for valley19
# Checking valley20
# LD --> VLD
# Scraped VLD for valley20
# Policy --> VCX
# Scraped VCX for valley20
# Public Forum --> VPF
# Scraped VPF for valley20
# Sophomore Throw Down --> None
# Checking yale14
# Congress --> None
# JV LD --> JVLD
# Scraped JVLD for yale14
# Policy Debate --> VCX
# Scraped VCX for yale14
# Public Forum --> VPF
# Scraped VPF for yale14
# Varsity LD --> VLD
# Scraped VLD for yale14
# Checking yale15
# Congress --> None
# JV LD --> JVLD
# Scraped JVLD for yale15
# Policy Debate --> VCX
# Scraped VCX for yale15
# Public Forum --> VPF
# Scraped VPF for yale15
# Varsity LD --> VLD
# Scraped VLD for yale15
# Checking yale16
# Congress --> None
# Dramatic --> None
# Duo --> None
# Extemp --> None
# Humorous --> None
# Junior Varsity LD --> JVLD
# Scraped JVLD for yale16
# Oral Interp --> None
# Oratory --> None
# Parliamentary Debate --> None
# Policy Debate --> VCX
# Scraped VCX for yale16
# Program Oral Interpretation --> None
# Public Forum --> VPF
# Scraped VPF for yale16
# Varsity LD --> VLD
# Scraped VLD for yale16
# Checking yale17
# Checking yale18
# JV Lincoln Douglas --> JVLD
# Scraped JVLD for yale18
# JV Public Forum --> JVPF
# Scraped JVPF for yale18
# Policy Debate --> VCX
# Scraped VCX for yale18
# Varsity Lincoln Douglas --> VLD
# Scraped VLD for yale18
# Varsity Public Forum --> VPF
# Scraped VPF for yale18
# Checking yale19
# JV Lincoln Douglas --> JVLD
# Scraped JVLD for yale19
# JV Public Forum --> JVPF
# Scraped JVPF for yale19
# Policy Debate --> VCX
# Scraped VCX for yale19
# Varsity Lincoln Douglas --> VLD
# Scraped VLD for yale19
# Varsity Public Forum --> VPF
# Scraped VPF for yale19
# Checking yale20
# Congress --> None
# Declamation --> None
# Dramatic --> None
# Extemp --> None
# Humorous --> None
# Informative --> None
# JV Lincoln Douglas --> JVLD
# Scraped JVLD for yale20
# JV Policy Debate --> JVCX
# Scraped JVCX for yale20
# JV Public Forum --> JVPF
# Scraped JVPF for yale20
# Oral Interp --> None
# Oratory --> None
# Parliamentary Debate --> None
# Program Oral Interpretation --> None
# Varsity Lincoln Douglas --> VLD
# Scraped VLD for yale20
# Varsity Policy Debate --> VCX
# Scraped VCX for yale20
# Varsity Public Forum --> VPF
# Scraped VPF for yale20

# %%
# read tourn list
with open(TOURNAMENT_CSV, 'r') as tourn_file,   open(OUTPATH + INFO_FILE, 'w') as out_file:
    
    tourn_reader = csv.DictReader(tourn_file)
    tournWriter = csv.writer(out_file,
                                    lineterminator = "\n")
    
    tournWriter.writerow(["Tourn Name", "Dates", "Year", "Location", "State"])

    for tourn in tourn_reader:
        tourn_name = tourn["Name"]
        tourn_id = tourn["URL"]
        
        print("Checking " + tourn_name)
        
        tournWriter.writerow([tourn_name] + getInfo(tourn_id))
# Out:
# Checking alta15
# Checking alta16
# Checking alta17
# Checking alta18
# Checking alta19
# Checking alta20
# Checking applevalley15
# Checking applevalley16
# Checking applevalley17
# Checking applevalley18
# Checking applevalley19
# Checking applevalley20
# Checking arthurschool20
# Checking asu16
# Checking asu17
# Checking asu18
# Checking asu19
# Checking asu20
# Checking asu21
# Checking bethelpark17
# Checking bethelpark18
# Checking bethelpark19
# Checking bethelpark20
# Checking beltway17
# Checking beltway16
# Checking beltway15
# Checking beltway14
# Checking blake15
# Checking blake16
# Checking blake17
# Checking blake18
# Checking blake19
# Checking blake20
# Checking bluekey19
# Checking bluekey20
# Checking bronx15
# Checking bronx16
# Checking bronx17
# Checking bronx18
# Checking bronx19
# Checking bronx20
# Checking cal15
# Checking cal16
# Checking cal17
# Checking cal18
# Checking cal19
# Checking cal20
# Checking centralvalley15
# Checking centralvalley16
# Checking centralvalley17
# Checking saintjames17
# Checking wakeforest16
# Checking churchill17
# Checking churchill18
# Checking churchill19
# Checking churchill20
# Checking churchill21
# Checking colleyville17
# Checking colleyville18
# Checking colleyville19
# Checking colleyville20
# Checking columbia15
# Checking columbia16
# Checking columbia17
# Checking columbia18
# Checking columbia19
# Checking columbia20
# Checking cps15
# Checking cps16
# Checking cps17
# Checking cps18
# Checking cps19
# Checking cps20
# Checking cypress16
# Checking cypress17
# Checking cypress18
# Checking cypress19
# Checking cypress20
# Checking dowling17
# Checking dowling18
# Checking dowling19
# Checking dowling20
# Checking duke19
# Checking duke20
# Checking durham19
# Checking durham20
# Checking emory16
# Checking emory17
# Checking emory18
# Checking emory19
# Checking emory20
# Checking glenbrooks15
# Checking glenbrooks16
# Checking glenbrooks17
# Checking glenbrooks18
# Checking glenbrooks19
# Checking glenbrooks20
# Checking goldendesert15
# Checking goldendesert16
# Checking goldendesert17
# Checking goldendesert18
# Checking goldendesert19
# Checking goldendesert20
# Checking grapevine15
# Checking grapevine16
# Checking grapevine17
# Checking grapevine18
# Checking grapevine19
# Checking grapevine20
# Checking greenhill14
# Checking greenhill15
# Checking greenhill16
# Checking greenhill17
# Checking greenhill18
# Checking greenhill19
# Checking greenhill20
# Checking harvard14
# Checking harvard16
# Checking harvard17
# Checking harvard18
# Checking harvard19
# Checking harvard20
# Checking heritagehall16
# Checking heritagehall17
# Checking heritagehall18
# Checking heritagehall19
# Checking heritagehall20
# Checking heritagehall21
# Checking holycross15
# Checking holycross16
# Checking holycross17
# Checking holycross18
# Checking holycross19
# Checking holycross20
# Checking houston15
# Checking houston16
# Checking houston17
# Checking houston18
# Checking houston19
# Checking houston20
# Checking houston21
# Checking hwestlake15
# Checking hwestlake16
# Checking hwestlake17
# Checking hwestlake18
# Checking hwestlake19
# Checking hwestlake20
# Checking isidore16
# Checking isidore17
# Checking isidore18
# Checking isidore19
# Checking isidore20
# Checking lewisandclark17
# Checking lewisandclark18
# Checking lewisandclark19
# Checking lewisandclark20
# Checking lex15
# Checking lex16
# Checking lex17
# Checking lex18
# Checking lex19
# Checking lex20
# Checking longbeach15
# Checking longbeach16
# Checking longbeach17
# Checking longbeach18
# Checking longbeach19
# Checking longbeach20
# Checking loyola15
# Checking loyola16
# Checking loyola17
# Checking loyola18
# Checking loyola19
# Checking loyola20
# Checking marks15
# Checking marks16
# Checking marks17
# Checking marks18
# Checking marks19
# Checking marlborough18
# Checking marlborough19
# Checking marlborough20
# Checking meadows15
# Checking meadows16
# Checking meadows17
# Checking meadows18
# Checking meadows19
# Checking meadows20
# Checking middleton15
# Checking middleton16
# Checking middleton17
# Checking middleton18
# Checking middleton19
# Checking middleton20
# Checking millardnorth16
# Checking millardnorth17
# Checking millardnorth18
# Checking millardnorth19
# Checking millardnorth20
# Checking myerspark20
# Checking myerspark21
# Checking newark15
# Checking newark16
# Checking newark17
# Checking newark18
# Checking newark19
# Checking newark20
# Checking newark21
# Checking northalleghany20
# Checking northalleghany21
# Checking notredame15
# Checking notredame16
# Checking notredame17
# Checking notredame18
# Checking notredame19
# Checking notredame20
# Checking peninsula17
# Checking peninsula18
# Checking peninsula19
# Checking peninsula20
# Checking penn15
# Checking penn16
# Checking penn17
# Checking penn18
# Checking penn19
# Checking penn20
# Checking penn21
# Checking presentation15
# Checking presentation16
# Checking presentation17
# Checking presentation18
# Checking presentation19
# Checking presentation20
# Checking princeton15
# Checking princeton16
# Checking princeton17
# Checking princeton18
# Checking princeton19
# Checking princeton20
# Checking pugetsound16
# Checking pugetsound17
# Checking pugetsound18
# Checking pugetsound19
# Checking pugetsound20
# Checking rideg15
# Checking ridge16
# Checking ridge17
# Checking ridge18
# Checking ridge19
# Checking ridge20
# Checking scarsdale15
# Checking scarsdale16
# Checking scarsdale17
# Checking scarsdale18
# Checking scarsdale19
# Checking scarsdale20
# Checking seattle19
# Checking seattle20
# Checking stanford15
# Checking stanford16
# Checking stanford17
# Checking stanford18
# Checking stanford19
# Checking stanford20
# Checking strake15
# Checking strake16
# Checking strake17
# Checking strake18
# Checking strake19
# Checking strake20
# Checking sunvite20
# Checking sunvite21
# Checking uk17
# Checking uk18
# Checking uk19
# Checking uk20
# Checking UT15
# Checking UT16
# Checking UT17
# Checking UT18
# Checking UT19
# Checking UT20
# Checking valley16
# Checking valley17
# Checking valley18
# Checking valley19
# Checking valley20
# Checking yale14
# Checking yale15
# Checking yale16
# Checking yale17
# Checking yale18
# Checking yale19
# Checking yale20

# %% [markdown]
# ### Judge Scraper
#
# #### Collect Links

# %%
paradigm_links = []

# iterate through all judges by first name
for c in ascii_lowercase:
    
    print(c)
    
    url = "https://www.tabroom.com/index/paradigm.mhtml?search_first={char}&search_last=".format(char = c)
    
    # load page
    html = urlopen(url).read()
    soup = BeautifulSoup(html, "html.parser")
    
    # get all links
    links = [link.get("href") for link in soup.find_all("a")]
    print(len(links))
    
    # append all paradigm links
    paradigm_links += [link for link in links if "judge_person" in link]
# Out:
# a
# 3229
# b
# 1217
# c
# 1624
# d
# 1386
# e
# 1088
# f
# 266
# g
# 670
# h
# 647
# i
# 307
# j
# 3011
# k
# 1471
# l
# 953
# m
# 2278
# n
# 993
# o
# 188
# p
# 747
# q
# 83
# r
# 1526
# s
# 2507
# t
# 1045
# u
# 66
# v
# 468
# w
# 362
# x
# 76
# y
# 219
# z
# 274

# %%
# save judgelinks
with open(OUTPATH + "judgeLinks.txt", 'w') as outFile:
    for link in set(paradigm_links):
        outFile.write(link + "\n")

# %% [markdown]
# #### Collect Records

# %%
paradigm_links = list(set([name.strip() for name in open(OUTPATH + "judgeLinks.txt", 'r')]))

# %%
def getRecords(url):
    
    judgeID = url.split("=")[1]
    
    # load page
    html = urlopen(url).read()
    soup = BeautifulSoup(html, "html.parser")
    name = " ".join(soup.find("span", {"class": "twothirds"}).text.strip().split()[:-1])
    table = soup.find("table")
    
    records = []
    for row in table.find_all("tr")[1:]:
        cols = row.find_all("td")
        tourn = cols[0].text.strip()
        date = cols[1].text.split()[1]
        event = cols[2].text.strip()
        roundNum= cols[3].span.text
        roundName = cols[3].a.text
        aff = cols[4].text.strip()
        neg = cols[5].text.strip()
        decision = cols[6].text.strip()
        panel = cols[7].text.strip()
        records.append({"Judge" : name,
                        "Judge ID" : judgeID,
                       "Tournament": tourn,
                       "Date" : date,
                       "Event" : event,
                       "Round Number" : roundNum,
                       "Round Name" : roundName,
                       "Aff" : aff,
                       "Neg" : neg,
                       "Decision" : decision,
                       "Panel" : panel})
        
    return records

# %%
with open(OUTPATH + "records2.csv", 'w') as outFile:
    
    outWriter  = csv.DictWriter(outFile,
                                fieldnames = ["Judge",
                                              "Judge ID",
                                            "Tournament",
                                            "Date",
                                            "Event",
                                            "Round Number",
                                            "Round Name",
                                            "Aff",
                                            "Neg", 
                                            "Decision",
                                            "Panel"],
                                quotechar='"', 
                                quoting=csv.QUOTE_NONNUMERIC,
                                lineterminator = "\n")
    
    outWriter.writeheader()
    
    count = 0
    for link in paradigm_links:
        count += 1
        url = "https://www.tabroom.com/index/" + link
        
        try:
        
            records = getRecords(url)
            if (count % 100 == 0):
                print(count)
            outWriter.writerows(records)
        except KeyboardInterrupt:
            sys.exit(0)
        except:
            print("Broke for " + url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-60b5be327432> in <module>
#      20
#      21     count = 0
# ---> 22     for link in paradigm_links:
#      23         count += 1
#      24         url = "https://www.tabroom.com/index/" + link
#
# NameError: name 'paradigm_links' is not defined

# %%
len(paradigm_links[23000:])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-745234ef682f> in <module>
# ----> 1 len(paradigm_links[23000:])
#
# TypeError: 'set' object is not subscriptable
